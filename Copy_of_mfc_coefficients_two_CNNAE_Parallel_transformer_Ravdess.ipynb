# %% [markdown]
# <a href="https://colab.research.google.com/github/zahra-sharifzadeh/Master_thesis/blob/main/Copy_of_mfc_coefficients_two_CNNAE_Parallel_transformer_Ravdess.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Setup

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os, glob
import librosa
import librosa.display
import IPython
from IPython.display import Audio
from IPython.display import Image
import warnings; warnings.filterwarnings('ignore') #matplot lib complains about librosa

# %%
# needed to import dataset from google drive into colab
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# copy RAVDESS dataset from gdrive and unzip
# !cp '/content/gdrive/MyDrive/RAVDESS.zip' .
# !unzip -q RAVDESS.zip

# %% [markdown]
# ## Define features
#
# Define features as in the previous notebook on this task from my ['sklearn-audio-classification' repo](https://github.com/IliaZenkov/sklearn-audio-classification). That notebook explains the motivation behind the Mel Spectrogram and its derivative MFCC, which we use as a feature. In short, we're looking for transitions in audible pitch frequencies.
#
# **MFCCs alone provide the best accuracy in this model with training considerations in mind - and provide as good an accuracy as using chromagrams + mel spectrograms + MFCCs. We don't want extra complexity in a highly parameterized deep neural net such as this one** (unless we absolutely need it).

# %%
# RAVDESS native sample rate is 16000
sample_rate = 48000

# Mel Spectrograms are not directly used as a feature in this model
# Mel Spectrograms are used in calculating MFCCs, which are a higher-level representation of pitch transition
# MFCCs work better - left the mel spectrogram function here in case anyone wants to experiment
def feature_melspectrogram(
    waveform,
    sample_rate,
    fft = 1024,
    winlen = 512,
    window='hamming',
    hop=256,
    mels=128,
    ):

    # Produce the mel spectrogram for all STFT frames and get the mean of each column of the resulting matrix to create a feature array
    # Using 8khz as upper frequency bound should be enough for most speech classification tasks
    melspectrogram = librosa.feature.melspectrogram(
        y=waveform,
        sr=sample_rate,
        n_fft=fft,
        win_length=winlen,
        window=window,
        hop_length=hop,
        n_mels=mels,
        fmax=sample_rate/2)

    # convert from power (amplitude**2) to decibels
    # necessary for network to learn - doesn't converge with raw power spectrograms
    melspectrogram = librosa.power_to_db(melspectrogram, ref=np.max)

    return melspectrogram

def feature_mfcc(
    waveform,
    sample_rate,
    n_mfcc = 40,
    fft = 1024,
    winlen = 512,
    window='hamming',
    #hop=256, # increases # of time steps; was not helpful
    mels=128
    ):

    # Compute the MFCCs for all STFT frames
    # 40 mel filterbanks (n_mfcc) = 40 coefficients
    mfc_coefficients=librosa.feature.mfcc(
        y=waveform,
        sr=sample_rate,
        n_mfcc=n_mfcc,
        n_fft=fft,
        win_length=winlen,
        window=window,
        #hop_length=hop,
        n_mels=mels,
        fmax=sample_rate/2
        )

    return mfc_coefficients

def get_features(waveforms, features, samplerate):

    # initialize counter to track progress
    file_count = 0

    # process each waveform individually to get its MFCCs
    for waveform in waveforms:
        mfccs = feature_mfcc(waveform, sample_rate)
        features.append(mfccs)
        file_count += 1
        # print progress
        print('\r'+f' Processed {file_count}/{len(waveforms)} waveforms',end='')

    # return all features from list of waveforms
    return features

def get_waveforms(file):

    # load an individual sample audio file
    # read the full 3 seconds of the file, cut off the first 0.5s of silence; native sample rate = 48k
    # don't need to store the sample rate that librosa.load returns
    waveform, _ = librosa.load(file, duration=3, offset=0.5, sr=sample_rate)

    # make sure waveform vectors are homogenous by defining explicitly
    waveform_homo = np.zeros((int(sample_rate*3,)))
    waveform_homo[:len(waveform)] = waveform

    # return a single file's waveform
    return waveform_homo

# RAVDESS dataset emotions
# shift emotions left to be 0 indexed for PyTorch
emotions_dict ={
    '0':'surprised',
    '1':'neutral',
    '2':'calm',
    '3':'happy',
    '4':'sad',
    '5':'angry',
    '6':'fearful',
    '7':'disgust'
}

# Additional attributes from RAVDESS to play with
emotion_attributes = {
    '01': 'normal',
    '02': 'strong'
}

# %% [markdown]
# ## Load Data and Extract Features
#
#
# We process each file in the dataset and extract its features.
#
# We return the waveforms and the labels (from the file names of the RAVDESS audio samples). We return the raw waveforms because we're going to do some extra processing.

# %%
# path to data for glob
data_path = '/content/Actor_*/*.wav'

def load_data():
    # features and labels
    emotions = []
    # raw waveforms to augment later
    waveforms = []
    # extra labels
    intensities, genders = [],[]
    # progress counter
    file_count = 0
    for file in glob.glob(data_path):
        # get file name with labels
        file_name = os.path.basename(file)

        # get emotion label from the sample's file
        emotion = int(file_name.split("-")[2])

        #  move surprise to 0 for cleaner behaviour with PyTorch/0-indexing
        if emotion == 8: emotion = 0 # surprise is now at 0 index; other emotion indeces unchanged

        # can convert emotion label to emotion string if desired, but
        # training on number is better; better convert to emotion string after predictions are ready
        # emotion = emotions_dict[str(emotion)]

        # get other labels we might want
        intensity = emotion_attributes[file_name.split("-")[3]]
        # even actors are female, odd are male
        if (int((file_name.split("-")[6]).split(".")[0]))%2==0:
            gender = 'female'
        else:
            gender = 'male'

        # get waveform from the sample
        waveform = get_waveforms(file)

        # store waveforms and labels
        waveforms.append(waveform)
        emotions.append(emotion)
        intensities.append(intensity) # store intensity in case we wish to predict
        genders.append(gender) # store gender in case we wish to predict

        file_count += 1
        # keep track of data loader's progress
        print('\r'+f' Processed {file_count}/{1440} audio samples',end='')

    return waveforms, emotions, intensities, genders

# %%
# load data
# init explicitly to prevent data leakage from past sessions, since load_data() appends
waveforms, emotions, intensities, genders = [],[],[],[]
waveforms, emotions, intensities, genders = load_data()
# Out:
#  Processed 1440/1440 audio samples

# %% [markdown]
# ## Check extracted audio waveforms and labels:

# %%
print(f'Waveforms set: {len(waveforms)} samples')
# we have 1440 waveforms but we need to know their length too; should be 3 sec * 48k = 144k
print(f'Waveform signal length: {len(waveforms[0])}')
print(f'Emotions set: {len(emotions)} sample labels')
# Out:
# Waveforms set: 1440 samples
# Waveform signal length: 144000
# Emotions set: 1440 sample labels

# %% [markdown]
# Looks good. 1440 samples and 1440 labels in total.
#
# **Waveforms are 144k long because 3 seconds * 48k sample rate = 144k length array representing the 3 second audio snippet.**

# %% [markdown]
# ## Split into Train/Validation/Test Sets
# We'll use an 80/10/10 train/validation/test split to maximize training data and keep a reasonable validation/test set.
#
# **We're splitting waveforms so we can process train/validation/test waveforms separately and avoid data leakage.**
#
# **Have to take care to split the sets proportionally w.r.t. emotion.**
#
# **Yes, we can use sklearn - but to convince myself I've eradicated data leakage issues I did this manually.**

# %%
# create storage for train, validation, test sets and their indices
train_set,valid_set,test_set = [],[],[]
X_train,X_valid,X_test = [],[],[]
y_train,y_valid,y_test = [],[],[]

# convert waveforms to array for processing
waveforms = np.array(waveforms)

# process each emotion separately to make sure we builf balanced train/valid/test sets
for emotion_num in range(len(emotions_dict)):

    # find all indices of a single unique emotion
    emotion_indices = [index for index, emotion in enumerate(emotions) if emotion==emotion_num]

    # seed for reproducibility
    np.random.seed(69)
    # shuffle indicies
    emotion_indices = np.random.permutation(emotion_indices)

    # store dim (length) of the emotion list to make indices
    dim = len(emotion_indices)

    # store indices of training, validation and test sets in 80/10/10 proportion
    # train set is first 80%
    train_indices = emotion_indices[:int(0.8*dim)]
    # validation set is next 10% (between 80% and 90%)
    valid_indices = emotion_indices[int(0.8*dim):int(0.9*dim)]
    # test set is last 10% (between 90% - end/100%)
    test_indices = emotion_indices[int(0.9*dim):]

    # create train waveforms/labels sets
    X_train.append(waveforms[train_indices,:])
    y_train.append(np.array([emotion_num]*len(train_indices),dtype=np.int32))
    # create validation waveforms/labels sets
    X_valid.append(waveforms[valid_indices,:])
    y_valid.append(np.array([emotion_num]*len(valid_indices),dtype=np.int32))
    # create test waveforms/labels sets
    X_test.append(waveforms[test_indices,:])
    y_test.append(np.array([emotion_num]*len(test_indices),dtype=np.int32))

    # store indices for each emotion set to verify uniqueness between sets
    train_set.append(train_indices)
    valid_set.append(valid_indices)
    test_set.append(test_indices)

# concatenate, in order, all waveforms back into one array
X_train = np.concatenate(X_train,axis=0)
X_valid = np.concatenate(X_valid,axis=0)
X_test = np.concatenate(X_test,axis=0)

# concatenate, in order, all emotions back into one array
y_train = np.concatenate(y_train,axis=0)
y_valid = np.concatenate(y_valid,axis=0)
y_test = np.concatenate(y_test,axis=0)

# combine and store indices for all emotions' train, validation, test sets to verify uniqueness of sets
train_set = np.concatenate(train_set,axis=0)
valid_set = np.concatenate(valid_set,axis=0)
test_set = np.concatenate(test_set,axis=0)

# check shape of each set
print(f'Training waveforms:{X_train.shape}, y_train:{y_train.shape}')
print(f'Validation waveforms:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'Test waveforms:{X_test.shape}, y_test:{y_test.shape}')

# make sure train, validation, test sets have no overlap/are unique
# get all unique indices across all sets and how many times each index appears (count)
uniques, count = np.unique(np.concatenate([train_set,test_set,valid_set],axis=0), return_counts=True)

# if each index appears just once, and we have 1440 such unique indices, then all sets are unique
if sum(count==1) == len(emotions):
    print(f'\nSets are unique: {sum(count==1)} samples out of {len(emotions)} are unique')
else:
    print(f'\nSets are NOT unique: {sum(count==1)} samples out of {len(emotions)} are unique')
# Out:
# Training waveforms:(1147, 144000), y_train:(1147,)
# Validation waveforms:(143, 144000), y_valid:(143,)
# Test waveforms:(150, 144000), y_test:(150,)
#
# Sets are unique: 1440 samples out of 1440 are unique

# %% [markdown]
# ## Extract Features

# %% [markdown]
# Extract the features from unaugmented waveforms first. In the next step, we'll append features from augmented waveforms to these 'native' features.

# %%
# initialize feature arrays
# We extract MFCC features from waveforms and store in respective 'features' array
features_train, features_valid, features_test = [],[],[]

print('Train waveforms:') # get training set features
features_train = get_features(X_train, features_train, sample_rate)

print('\n\nValidation waveforms:') # get validation set features
features_valid = get_features(X_valid, features_valid, sample_rate)

print('\n\nTest waveforms:') # get test set features
features_test = get_features(X_test, features_test, sample_rate)

print(f'\n\nFeatures set: {len(features_train)+len(features_test)+len(features_valid)} total, {len(features_train)} train, {len(features_valid)} validation, {len(features_test)} test samples')
print(f'Features (MFC coefficient matrix) shape: {len(features_train[0])} mel frequency coefficients x {len(features_train[0][1])} time steps')
# Out:
# Train waveforms:
#  Processed 1147/1147 waveforms
#
# Validation waveforms:
#  Processed 143/143 waveforms
#
# Test waveforms:
#  Processed 150/150 waveforms
#
# Features set: 1440 total, 1147 train, 143 validation, 150 test samples
# Features (MFC coefficient matrix) shape: 40 mel frequency coefficients x 282 time steps

# %% [markdown]
# ## Augmenting the Data with AWGN - Additive White Gaussian Noise
#
# ### Motivation
#
# Since our dataset is small, it is prone to overfitting - especially with highly parameterized deep neural net models
# such as the one we aim to build in this notebook. As such, we're going to want to augment our data. Generating more real samples will be immensely difficult. Instead, we can add white noise to the audio signals - not only to mask the effect of random noise present in the training set - but also **to create pseudo-new training samples and offset the impact of noise intrinsic to the dataset.**
#
# In addition, the RAVDESS dataset is extremely clean - we will likely want to make predictions on noisy, real-world data - yet another reason to augment the training data.
#
# We're going to use Additive White Gaussian Noise (AWGN). It's Additive because we're adding it to the source audio signal,
# **it's Gaussian because the noise vector will be sampled from a normal distribution and have a time average of zero (zero-mean), and it's white because after a whitening transformation the noise will add power to the audio signal uniformly across the frequency distribution.**
#
# We need a good balance of noise - too little will be useless, and too much will make it too difficult for the network to learn from the training data. **Note that this is just for training - we would _not_ need to add AWGN to real-world data on which we make predictions** (although we could).
#
# ### Math
# The key parameters in AWGN are the signal to noise ratio (SNR), defining the magnitude of the noise added w.r.t. the audio signal. We parameterize AWGN with the minimum and maximize SNR so we can pick a random SNR to use in augmenting each sample's waveform.
#
# We need to constrain covariance to make it true AWGN. **We make a zero-mean vector of Gaussian noises (np.random.normal) that are statistically dependent. We need to apply a [whitening transformation](https://en.wikipedia.org/wiki/Whitening_transformation)**, a linear transformation taking a vector of random normal (Gaussian) variables with a known covariance matrix and mapping it to a new vector whose covariance is the identity matrix, i.e. the vector is now perfectly uncorrelated with a diaganol covariance matrix, each point of noise having variance == stdev == 1. **The whitening transformation by definition transforms a vector into a white noise vector.**
#
# We're going to add the AWGN augmented waveforms as new samples to our dataset. **Since we generate AWGN which is random for each and every sample - random random noise - we can add multiples of our noise-augmented dataset. I'll add 2 extra identical, randomly noisy datasets with 1440 samples each to get a dataset with 1440 native + 1440x2 == 4320 noisy samples.**

# %%
def awgn_augmentation(waveform, multiples=2, bits=16, snr_min=15, snr_max=30):

    # get length of waveform (should be 3*48k = 144k)
    wave_len = len(waveform)

    # Generate normally distributed (Gaussian) noises
    # one for each waveform and multiple (i.e. wave_len*multiples noises)
    noise = np.random.normal(size=(multiples, wave_len))

    # Normalize waveform and noise
    norm_constant = 2.0**(bits-1)
    norm_wave = waveform / norm_constant
    norm_noise = noise / norm_constant

    # Compute power of waveform and power of noise
    signal_power = np.sum(norm_wave ** 2) / wave_len
    noise_power = np.sum(norm_noise ** 2, axis=1) / wave_len

    # Choose random SNR in decibels in range [15,30]
    snr = np.random.randint(snr_min, snr_max)

    # Apply whitening transformation: make the Gaussian noise into Gaussian white noise
    # Compute the covariance matrix used to whiten each noise
    # actual SNR = signal/noise (power)
    # actual noise power = 10**(-snr/10)
    covariance = np.sqrt((signal_power / noise_power) * 10 ** (- snr / 10))
    # Get covariance matrix with dim: (144000, 2) so we can transform 2 noises: dim (2, 144000)
    covariance = np.ones((wave_len, multiples)) * covariance

    # Since covariance and noise are arrays, * is the haddamard product
    # Take Haddamard product of covariance and noise to generate white noise
    multiple_augmented_waveforms = waveform + covariance.T * noise

    return multiple_augmented_waveforms

# %%
def augment_waveforms(waveforms, features, emotions, multiples):
    # keep track of how many waveforms we've processed so we can add correct emotion label in the same order
    emotion_count = 0
    # keep track of how many augmented samples we've added
    added_count = 0
    # convert emotion array to list for more efficient appending
    emotions = emotions.tolist()

    for waveform in waveforms:

        # Generate 2 augmented multiples of the dataset, i.e. 1440 native + 1440*2 noisy = 4320 samples total
        augmented_waveforms = awgn_augmentation(waveform, multiples=multiples)

        # compute spectrogram for each of 2 augmented waveforms
        for augmented_waveform in augmented_waveforms:

            # Compute MFCCs over augmented waveforms
            augmented_mfcc = feature_mfcc(augmented_waveform, sample_rate=sample_rate)

            # append the augmented spectrogram to the rest of the native data
            features.append(augmented_mfcc)
            emotions.append(emotions[emotion_count])

            # keep track of new augmented samples
            added_count += 1

            # check progress
            print('\r'+f'Processed {emotion_count + 1}/{len(waveforms)} waveforms for {added_count}/{len(waveforms)*multiples} new augmented samples',end='')

        # keep track of the emotion labels to append in order
        emotion_count += 1

        # store augmented waveforms to check their shape
        augmented_waveforms_temp.append(augmented_waveforms)

    return features, emotions

# %% [markdown]
# ### Compute AWGN-augmented features and add to the rest of the dataset

# %%
# store augmented waveforms to verify their shape and random-ness
augmented_waveforms_temp = []

# specify multiples of our dataset to add as augmented data
multiples = 2

print('Train waveforms:') # augment waveforms of training set
features_train , y_train = augment_waveforms(X_train, features_train, y_train, multiples)

print('\n\nValidation waveforms:') # augment waveforms of validation set
features_valid, y_valid = augment_waveforms(X_valid, features_valid, y_valid, multiples)

print('\n\nTest waveforms:') # augment waveforms of test set
features_test, y_test = augment_waveforms(X_test, features_test, y_test, multiples)

# Check new shape of extracted features and data:
print(f'\n\nNative + Augmented Features set: {len(features_train)+len(features_test)+len(features_valid)} total, {len(features_train)} train, {len(features_valid)} validation, {len(features_test)} test samples')
print(f'{len(y_train)} training sample labels, {len(y_valid)} validation sample labels, {len(y_test)} test sample labels')
print(f'Features (MFCC matrix) shape: {len(features_train[0])} mel frequency coefficients x {len(features_train[0][1])} time steps')
# Out:
# Train waveforms:
# Processed 1147/1147 waveforms for 2294/2294 new augmented samples
#
# Validation waveforms:
# Processed 143/143 waveforms for 286/286 new augmented samples
#
# Test waveforms:
# Processed 150/150 waveforms for 300/300 new augmented samples
#
# Native + Augmented Features set: 4320 total, 3441 train, 429 validation, 450 test samples
# 3441 training sample labels, 429 validation sample labels, 450 test sample labels
# Features (MFCC matrix) shape: 40 mel frequency coefficients x 282 time steps

# %% [markdown]
# ### Check Augmented Waveforms:

# %%
# pick a random waveform, but same one from native and augmented set for easier comparison
plt.figure(figsize=(15,4))
plt.subplot(1, 2, 1)
librosa.display.waveshow(waveforms[12], sr=sample_rate)
plt.title('Native')

plt.subplot(1, 2, 2)
# augmented waveforms are 2D len 1440 list with 2 waveforms in each position
librosa.display.waveshow(augmented_waveforms_temp[0][0], sr=sample_rate)
plt.title('AWGN Augmented')
plt.show()

plt.figure(figsize=(15,4))
plt.subplot(1, 2, 1)
librosa.display.waveshow(augmented_waveforms_temp[2][0], sr=sample_rate)
plt.title('AWGN Augmented')

plt.subplot(1, 2, 2)
librosa.display.waveshow(augmented_waveforms_temp[7][0], sr=sample_rate)
plt.title('AWGN Augmented')
plt.show()

# %% [markdown]
# Looks noisy alright. Noise is clearly visible in otherwise-silent regions of the waveform. We can see the variability of the noise, which should have an SNR between 15 and 30.
#
# **Note that augmentation was only done after splitting data into train, validation, and test sets - and we processed each set separately.**
#
# **When we augmented the data before splitting it, test and validation data leaked into the training set giving a 97% test accuracy after training.**
#
# ## Format Data into Tensor Ready 4D Arrays
# We don't have a colour channel in our MFCC feature array of dim (#samples, #MFC coefficients, time steps). **We have an analog of a black and white image: instead of 3 colour channels, we have 1 signal intensity channel: magnitude of each of 40 mel frequency coefficients at time t.**
#
# **We need an input channel dim to expand to output channels using CNN filters. We create a dummy channel dim to expand features into 2D-CNN-ready 4D tensor format: N x C x H x W.**

# %%
# need to make dummy input channel for CNN input feature tensor
X_train = np.expand_dims(features_train,1)
X_valid = np.expand_dims(features_valid, 1)
X_test = np.expand_dims(features_test,1)

# convert emotion labels from list back to numpy arrays for PyTorch to work with
y_train = np.array(y_train)
y_valid = np.array(y_valid)
y_test = np.array(y_test)

# confiorm that we have tensor-ready 4D data array
# should print (batch, channel, width, height) == (4320, 1, 128, 282) when multiples==2
print(f'Shape of 4D feature array for input tensor: {X_train.shape} train, {X_valid.shape} validation, {X_test.shape} test')
print(f'Shape of emotion labels: {y_train.shape} train, {y_valid.shape} validation, {y_test.shape} test')
# Out:
# Shape of 4D feature array for input tensor: (3441, 1, 40, 282) train, (429, 1, 40, 282) validation, (450, 1, 40, 282) test
# Shape of emotion labels: (3441,) train, (429,) validation, (450,) test

# %%
# free up some RAM - no longer need full feature set or any waveforms
del features_train, features_valid, features_test, waveforms, augmented_waveforms_temp

# %% [markdown]
# ## Feature Scaling
# Scaling will drastically decrease the length of time the model needs to train to convergence - it will have easier computations to perform on smaller magnitudes. **For reference, scaling reduces the time to convergence from about 500 to 200 epochs for this model.**
#
# **Standard Scaling makes the most sense because we have features whose target distribution we don't know.** When I performed classification on this dataset with an MLP classifier standard scaling was best across a variety of conditions and features.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

#### Scale the training data ####
# store shape so we can transform it back
N,C,H,W = X_train.shape
# Reshape to 1D because StandardScaler operates on a 1D array
# tell numpy to infer shape of 1D array with '-1' argument
X_train = np.reshape(X_train, (N,-1))
X_train = scaler.fit_transform(X_train)
# Transform back to NxCxHxW 4D tensor format
X_train = np.reshape(X_train, (N,C,H,W))

##### Scale the validation set ####
N,C,H,W = X_valid.shape
X_valid = np.reshape(X_valid, (N,-1))
X_valid = scaler.transform(X_valid)
X_valid = np.reshape(X_valid, (N,C,H,W))

#### Scale the test set ####
N,C,H,W = X_test.shape
X_test = np.reshape(X_test, (N,-1))
X_test = scaler.transform(X_test)
X_test = np.reshape(X_test, (N,C,H,W))

# check shape of each set again
print(f'X_train scaled:{X_train.shape}, y_train:{y_train.shape}')
print(f'X_valid scaled:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'X_test scaled:{X_test.shape}, y_test:{y_test.shape}')
# Out:
# X_train scaled:(3441, 1, 40, 282), y_train:(3441,)
# X_valid scaled:(429, 1, 40, 282), y_valid:(429,)
# X_test scaled:(450, 1, 40, 282), y_test:(450,)

# %% [markdown]
# ## Save and Reload Data as NumPy Arrays
# We can save the training/validation/test data as numpy arrays to enable faster loading in case the notebook kernel crashes / google colab runtime crashes / any number of reasons the training data might be cleared from memory. This is much faster than loading 1440 files and computing their features again - not to mention augmented features.

# %%
###### SAVE #########
# choose save file name
filename = 'features+labels.npy'

# open file in write mode and write data
with open(filename, 'wb') as f:
    np.save(f, X_train)
    np.save(f, X_valid)
    np.save(f, X_test)
    np.save(f, y_train)
    np.save(f, y_valid)
    np.save(f, y_test)

print(f'Features and labels saved to {filename}')
# Out:
# Features and labels saved to features+labels.npy

# %%
##### LOAD #########
# choose load file name
filename = 'features+labels.npy'

# open file in read mode and read data
with open(filename, 'rb') as f:
    X_train = np.load(f)
    X_valid = np.load(f)
    X_test = np.load(f)
    y_train = np.load(f)
    y_valid = np.load(f)
    y_test = np.load(f)

# Check that we've recovered the right data
print(f'X_train:{X_train.shape}, y_train:{y_train.shape}')
print(f'X_valid:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'X_test:{X_test.shape}, y_test:{y_test.shape}')
# Out:
# X_train:(3441, 1, 40, 282), y_train:(3441,)
# X_valid:(429, 1, 40, 282), y_valid:(429,)
# X_test:(450, 1, 40, 282), y_test:(450,)

# %%
X_train.min()
# Out:
# -9.717920097528179

# %%
import torch
import torch.nn as nn

class Encoder1(nn.Module):
    def __init__(self):
        super(Encoder1, self).__init__()

        self.encoder1 = nn.Sequential(
            # 1st 2D convolution layer
            nn.Conv2d(1, 16, kernel_size=3, stride=2),
            nn.BatchNorm2d(16),
            nn.SELU(),
            nn.Dropout(p=0.3),

            # 2nd 2D convolution layer
            nn.Conv2d(16, 32, kernel_size=3, stride=2),
            nn.BatchNorm2d(32),
            nn.SELU(),
            nn.Dropout(p=0.3),

            # # 3rd 2D convolution layer
            # nn.Conv2d(32, 64, kernel_size=3, stride=2),
            # nn.BatchNorm2d(64),
            # nn.SELU(),


            # nn.Conv2d(64, 128, kernel_size=3, stride=2),
            # # nn.BatchNorm2d(128),



        )

    def forward(self, x):
        return self.encoder1(x)


input_data = torch.randn(1, 1, 40, 282)  # Replace with your input shape
encoded1 = Encoder1()
e1 = encoded1(input_data)
e1.shape
# re1 = e1.reshape(-1, 128, 8, 2)
# re1.shape
# p = nn.Conv2d(128, 128, kernel_size=2, stride=2)
# p(re1).shape
transformer_maxpool = nn.MaxPool2d(kernel_size=[1, 4], stride=[1, 4])
transformer_maxpool(e1).shape
# Out:
# torch.Size([1, 32, 9, 17])

# %%
class Decoder1(nn.Module):
    def __init__(self):
        super(Decoder1, self).__init__()

        self.decoder1 = nn.Sequential(
            # 1st 2D transpose convolution layer
            nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2 ),
            nn.BatchNorm2d(64),
            nn.SELU(),

            # 2nd 2D transpose convolution layer
            nn.ConvTranspose2d(64, 32, kernel_size=3, stride=2),
            nn.BatchNorm2d(32),
            nn.SELU(),

            # 3nd 2D transpose convolution layer
            nn.ConvTranspose2d(32, 16, kernel_size=3, stride=2, output_padding=(0,1)),
            nn.BatchNorm2d(16),
            nn.SELU(),

            # 3rd 2D transpose convolution layer
            nn.ConvTranspose2d(16, 1, kernel_size=4, stride=2)
         )

    def forward(self, x):
        return self.decoder1(x)

input_data = torch.randn(1, 128, 1, 16)  # Replace with your input shape
decoded1 = Decoder1()
decoded1(input_data).shape
# Out:
# torch.Size([1, 1, 40, 282])

# %%
class Decoderr1(nn.Module):
    def __init__(self):
        super(Decoderr1, self).__init__()

        self.decoder1 = nn.Sequential(
            # 1st 2D convolutional layer
            nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True),

            nn.Conv2d(128, 64, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.SELU(),
            # 2nd 2D convolutional layer
            nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True),

            nn.Conv2d(64, 32, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(32),
            nn.SELU(),
            # 3rd 2D convolutional layer
            nn.Conv2d(32, 16, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(16),
            nn.SELU(),
            # Upsampling (2x)
            nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True),
            # 4th 2D convolutional layer
            nn.Conv2d(16, 1, kernel_size=3, padding=1),
        )

    def forward(self, x):
        x = self.decoder1(x)
        return x

input_data = torch.randn(1, 128, 1, 16)  # Replace with your input shape
decoded1 = Decoderr1()
decoded1(input_data).shape
# Out:
# torch.Size([1, 1, 2, 16])

# %%
class Autoencoder1(nn.Module):
    def __init__(self):
        super(Autoencoder1, self).__init__()
        self.encoder = Encoder1()
        self.decoder = Decoder1()

    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return encoded, decoded

# %%
# Example usage
autoencoder = Autoencoder1()
input_data = torch.randn(1, 1, 40, 282)  # Replace with your input shape
encoded1, decoded1 = autoencoder(input_data)
encoded1.shape, decoded1.shape
# Out:
# (torch.Size([1, 128, 1, 16]), torch.Size([1, 1, 40, 282]))

# %%
import torch.nn as nn

class Encoder2(nn.Module):
    def __init__(self):
        super(Encoder2, self).__init__()

        # Define the 2D convolutional layers
        self.conv2Dblock = nn.Sequential(
            # 1st 2D convolution layer
            nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(16),
            nn.SELU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(p=0.3),

            # 2nd 2D convolution layer
            nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(32),
            nn.SELU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),

            # 3rd 2D convolution layer
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.SELU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3)
        )

    def forward(self, x):
        # Pass the input through the convolutional layers
        return self.conv2Dblock(x)

# %%
import torch.nn as nn

class Decoder2(nn.Module):
    def __init__(self):
        super(Decoder2, self).__init__()

        # Define the 2D transposed convolutional layers for the decoder
        self.decoder2 = nn.Sequential(
            # 1st 2D transposed convolution layer
            nn.ConvTranspose2d(64, 32, kernel_size=5, stride=(1, 4), padding=0, output_padding=(0, 2)),
            nn.BatchNorm2d(32),
            nn.SELU(),

            # 2nd 2D transposed convolution layer
            nn.ConvTranspose2d(32, 16, kernel_size=3, stride=4, padding=0, output_padding=(1, 2)),
            nn.BatchNorm2d(16),
            nn.SELU(),

            # 3rd 2D transposed convolution layer
            nn.ConvTranspose2d(16, 1, kernel_size=3, stride=2, padding=1, output_padding=1)
        )

    def forward(self, x):
        # Pass the input through the decoder's transposed convolutional layers
        return self.decoder2(x)

# %%
class Autoencoder2(nn.Module):
    def __init__(self):
        super(Autoencoder1, self).__init__()
        self.encoder = Encoder1()
        self.decoder = Decoder1()

    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return encoded, decoded

# %%
import torch.nn as nn

class TransformerBlock(nn.Module):
    def __init__(self):
        super(TransformerBlock, self).__init__()

        # Maxpool the input feature map/tensor to the transformer
        self.transformer_maxpool = nn.MaxPool2d(kernel_size=[1, 4], stride=[1, 4])

        # Define a single transformer encoder layer
        transformer_layer = nn.TransformerEncoderLayer(
            d_model=40,            # Input feature (frequency) dim after max-pooling: 40*282 -> 40*70 (MFC * time)
            nhead=4,               # Number of self-attention layers in each multi-head self-attention layer in each encoder block
            dim_feedforward=512,   # Dimension for the feedforward network in each encoder block: 40 -> 512 -> 40
            dropout=0.4,
            activation='relu'      # Activation function (e.g., ReLU) for feedforward network
        )

        # The complete transformer block contains 4 full transformer encoder layers
        self.transformer_encoder = nn.TransformerEncoder(transformer_layer, num_layers=4)

    def forward(self, x):


                ########## 4-encoder-layer Transformer block w/ 40-->512-->40 feedfwd network ##############
        # maxpool input feature map: 1*40*282 w/ 1*4 kernel --> 1*40*70
        x_maxpool = self.transformer_maxpool(x)

        # remove channel dim: 1*40*70 --> 40*70
        x_maxpool_reduced = torch.squeeze(x_maxpool,1)

        # convert maxpooled feature map format: batch * freq * time ---> time * batch * freq format
        # because transformer encoder layer requires tensor in format: time * batch * embedding (freq)
        x = x_maxpool_reduced.permute(2,0,1)

        # finally, pass reduced input feature map x into transformer encoder layers
        transformer_output = self.transformer_encoder(x)

        # create final feature emedding from transformer layer by taking mean in the time dimension (now the 0th dim)
        # transformer outputs 2x40 (MFCC embedding*time) feature map, take mean of columns i.e. take time average
        transformer_embedding = torch.mean(transformer_output, dim=0) # dim 40x70 --> 40
        return transformer_embedding

# You can use this TransformerBlock within your larger model as needed.

# %%
import torch.nn as nn

class EmotionClassifier(nn.Module):
    def __init__(self, num_emotions):
        super(EmotionClassifier, self).__init__()

        # Linear softmax layer to take the final concatenated embedding tensor
        # from parallel 2D convolutional and transformer blocks, output 8 logits
        # Each full convolution block outputs (64*1*8) embedding flattened to dim 512 1D array
        # Full transformer block outputs 40*70 feature map, which we time-avg to dim 40 1D array
        # 512*2 + 40 == 1064 input features --> 8 output emotions
        self.fc1_linear = nn.Linear(512*2 + 40, num_emotions)

        # Softmax layer for the 8 output logits from the final FC linear layer
        self.softmax_out = nn.Softmax(dim=1)  # dim==1 refers to the frequency embedding

    def forward(self,x):

        # Pass the concatenated features through the final linear layer
        output = self.fc1_linear(x)

        # Apply softmax to get the class probabilities
        class_probs = self.softmax_out(output)

        return output , class_probs

# You can use this EmotionClassifier as part of your larger model to perform emotion classification.

# %%
# Combine the models
class MultiTaskModel(nn.Module):
    def __init__(self,num_emotions):
        super(MultiTaskModel, self).__init__()
        self.autoencoder1 = Autoencoder1()
        self.autoencoder2 = Autoencoder1()
        self.transformerblock = TransformerBlock()
        self.emotion_classifier = EmotionClassifier(num_emotions)
        self.encoder_maxpool = nn.MaxPool2d(kernel_size=[1, 4], stride=[1, 4])


    def forward(self, x):
        encoded1, decoded1 = self.autoencoder1(x)
        encoded1 = self.encoder_maxpool(encoded1)
        encoded1_embedding1 = torch.flatten(encoded1, start_dim=1)

        encoded2, decoded2= self.autoencoder2(x)
        encoded2 = self.encoder_maxpool(encoded2)
        encoded2_embedding2 = torch.flatten(encoded2, start_dim=1)

        transformer_embedding = self.transformerblock(x)

        complete_embedding = torch.cat([encoded1_embedding1, encoded2_embedding2,transformer_embedding], dim=1)

        output_logits, output_softmax = self.emotion_classifier(complete_embedding)

        return decoded1, decoded2, output_logits, output_softmax

# %%
# Example usage
model = MultiTaskModel(num_emotions=8)
input_data = torch.randn(1, 1, 40, 282)  # Replace with your input shape
decoded1, decoded2, output_logits, output_softmax = model(input_data)
decoded1.shape, decoded2.shape, output_logits, output_softmax
# Out:
# (torch.Size([1, 1, 40, 282]),
#  torch.Size([1, 1, 40, 282]),
#  tensor([[ 0.1978, -0.1272,  0.3502, -0.3549,  0.4367, -0.0379, -0.3382,  0.3666]],
#         grad_fn=<AddmmBackward0>),
#  tensor([[0.1372, 0.0991, 0.1597, 0.0789, 0.1741, 0.1084, 0.0802, 0.1624]],
#         grad_fn=<SoftmaxBackward0>))

# %%
# Loss functions
autoencoder_criterion = nn.MSELoss()  # Use Mean Squared Error for autoencoder loss
classifier_criterion = nn.CrossEntropyLoss()  # Use Cross-Entropy for emotion classification loss
optimizer = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

# %%
# define function to create a single step of the training phase
def make_train_step(model, autoencoder_criterion, classifier_criterion, optimizer):

    # define the training step of the training phase
    def train_step(X,Y):

        # forward pass
        decoded1, decoded2, output_logits, output_softmax  = model(X)
        predictions = torch.argmax(output_softmax,dim=1)
        accuracy = torch.sum(Y==predictions)/float(len(Y))

        # Compute losses
        autoencoder_loss1 = autoencoder_criterion(decoded1, X)
        autoencoder_loss2 = autoencoder_criterion(decoded2, X)
        classifier_loss = classifier_criterion(output_logits, Y)

        # Define a trade-off parameter to balance losses
        tradeoff = 1 # Adjust as needed

        # Calculate the combined loss
        loss = tradeoff * (autoencoder_loss1 + autoencoder_loss2) + (1 - tradeoff) * classifier_loss

        # compute gradients for the optimizer to use
        loss.backward()

        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()

        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad()

        return loss.item(), accuracy*100, autoencoder_loss1.item(), autoencoder_loss2.item(), classifier_loss.item()
    return train_step

# %%
def make_validate_fnc(model,autoencoder_criterion, classifier_criterion):
    def validate(X,Y):

        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase:
        with torch.no_grad():

            # set model to validation phase i.e. turn off dropout and batchnorm layers
            model.eval()

            # get the model's predictions on the validation set
            decoded1, decoded2, output_logits, output_softmax  = model(X)
            predictions = torch.argmax(output_softmax,dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y==predictions)/float(len(Y))

            # Compute losses
            autoencoder_loss1 = autoencoder_criterion(decoded1, X)
            autoencoder_loss2 = autoencoder_criterion(decoded2, X)
            classifier_loss = classifier_criterion(output_logits, Y)

            # compute error from logits (nn.crossentropy implements softmax)
            # Define a trade-off parameter to balance losses
            tradeoff = 1 # Adjust as needed

            # Calculate the combined loss
            loss = tradeoff * (autoencoder_loss1 + autoencoder_loss2) + (1 - tradeoff) * classifier_loss


        return loss.item(), accuracy*100, autoencoder_loss1.item(), autoencoder_loss2.item(), classifier_loss.item(), predictions
    return validate

# %%
def make_save_checkpoint():
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint

def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
# get training set size to calculate # iterations and minibatch indices
train_size = X_train.shape[0]

# pick minibatch size (of 32... always)
minibatch = 32

# set device to GPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'{device} selected')
# Out:
# cuda selected

# %%
# instantiate model and move to GPU for training
model = MultiTaskModel(num_emotions=len(emotions_dict)).to(device)
print('Number of trainable params: ',sum(p.numel() for p in model.parameters()) )
# Out:
# Number of trainable params:  705610

# %%
# encountered bugs in google colab only, unless I explicitly defined optimizer in this cell...
optimizer = torch.optim.SGD(model.parameters(),lr=0.0001, weight_decay=1e-3, momentum=0.8)
# Loss functions
autoencoder_criterion = nn.MSELoss()  # Use Mean Squared Error for autoencoder loss
classifier_criterion = nn.CrossEntropyLoss()  # Use Cross-Entropy for emotion classification loss

# %%
# instantiate the checkpoint save function
save_checkpoint = make_save_checkpoint()

# instantiate the training step function
train_step = make_train_step(model, autoencoder_criterion, classifier_criterion, optimizer=optimizer)

# instantiate the validation loop function
validate = make_validate_fnc(model,autoencoder_criterion, classifier_criterion)

# %%
# instantiate lists to hold scalar performance metrics to plot later
train_losses=[]
valid_losses = []
train_autoencoder_losses1=[]
train_autoencoder_losses2=[]
train_classifier_losses=[]


valid_autoencoder_losses1=[]
valid_autoencoder_losses2=[]
valid_classifier_losses=[]

# %%
# create training loop for one complete epoch (entire training set)
def train(optimizer, model, num_epochs, X_train, Y_train, X_valid, Y_valid):

    for epoch in range(num_epochs):

        # set model to train phase
        model.train()

        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size)

        # shuffle the training set for each epoch:
        X_train = X_train[train_indices,:,:,:]
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate
        epoch_acc = 0
        epoch_loss = 0
        epoch_autoencoder_loss1 = 0
        epoch_autoencoder_loss2 = 0
        epoch_classifier_loss = 0




        num_iterations = int(train_size / minibatch)

        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):

            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size)
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start

            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end,:,:,:]
            # get training minibatch labels
            Y = Y_train[batch_start:batch_end]

            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float()
            Y_tensor = torch.tensor(Y, dtype=torch.long,device=device)
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc, autoencoder_loss1, autoencoder_loss2, classifier_loss = train_step(X_tensor,Y_tensor)

            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size
            epoch_autoencoder_loss1 += autoencoder_loss1 * actual_batch_size / train_size
            epoch_autoencoder_loss2 += autoencoder_loss2 * actual_batch_size / train_size
            epoch_classifier_loss += classifier_loss * actual_batch_size / train_size



            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}',end='')

        # create tensors from validation set
        X_valid_tensor = torch.tensor(X_valid,device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid,dtype=torch.long,device=device)

        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, valid_autoencoder_loss1, valid_autoencoder_loss2, valid_classifier_loss, _ = validate(X_valid_tensor,
                                                                                                                     Y_valid_tensor)

        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        train_autoencoder_losses1.append(epoch_autoencoder_loss1)
        train_autoencoder_losses2.append(epoch_autoencoder_loss2)
        train_classifier_losses.append(epoch_classifier_loss)

        valid_losses.append(valid_loss)
        valid_autoencoder_losses1.append(valid_autoencoder_loss1)
        valid_autoencoder_losses2.append(valid_autoencoder_loss2)
        valid_classifier_losses.append(valid_classifier_loss)


        # Save checkpoint of the model
        checkpoint_filename = '/content/parallel_all_you_wantFINAL.pkl'.format(epoch)
        save_checkpoint(optimizer, model, epoch, checkpoint_filename)

        # keep track of each epoch's progress
        print(f'\nEpoch {epoch} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')
        print(f'\nEpoch {epoch} --- epoch_autoencoder_loss1:{epoch_autoencoder_loss1:.3f}, epoch_autoencoder_loss2:{epoch_autoencoder_loss2:.2f}, epoch_classifier_loss:{epoch_classifier_loss:.3f}')
        print(f'\nEpoch {epoch} --- valid_autoencoder_loss1:{valid_autoencoder_loss1:.3f}, valid_autoencoder_loss2:{valid_autoencoder_loss2:.2f}, valid_classifier_loss:{valid_classifier_loss:.3f}\n\n')

# %%
# choose number of epochs higher than reasonable so we can manually stop training
num_epochs = 500

# train it!
train(optimizer, model, num_epochs, X_train, y_train, X_valid, y_valid)
# Out:
# Epoch 0: iteration 106/107
# Epoch 0 --- loss:4.129, Epoch accuracy:8.28%, Validation loss:3.516, Validation accuracy:9.32%
#
# Epoch 0 --- epoch_autoencoder_loss1:2.148, epoch_autoencoder_loss2:1.98, epoch_classifier_loss:2.195
#
# Epoch 0 --- valid_autoencoder_loss1:1.816, valid_autoencoder_loss2:1.70, valid_classifier_loss:2.164
#
#
# Epoch 1: iteration 106/107
# Epoch 1 --- loss:3.838, Epoch accuracy:7.50%, Validation loss:3.309, Validation accuracy:9.09%
#
# Epoch 1 --- epoch_autoencoder_loss1:1.987, epoch_autoencoder_loss2:1.85, epoch_classifier_loss:2.204
#
# Epoch 1 --- valid_autoencoder_loss1:1.702, valid_autoencoder_loss2:1.61, valid_classifier_loss:2.165
#
#
# Epoch 2: iteration 106/107
# Epoch 2 --- loss:3.604, Epoch accuracy:7.93%, Validation loss:3.141, Validation accuracy:9.09%
#
# Epoch 2 --- epoch_autoencoder_loss1:1.859, epoch_autoencoder_loss2:1.75, epoch_classifier_loss:2.203
#
# Epoch 2 --- valid_autoencoder_loss1:1.611, valid_autoencoder_loss2:1.53, valid_classifier_loss:2.165
#
#
# Epoch 3: iteration 106/107
# Epoch 3 --- loss:3.413, Epoch accuracy:7.56%, Validation loss:2.999, Validation accuracy:9.32%
#
# Epoch 3 --- epoch_autoencoder_loss1:1.755, epoch_autoencoder_loss2:1.66, epoch_classifier_loss:2.201
#
# Epoch 3 --- valid_autoencoder_loss1:1.534, valid_autoencoder_loss2:1.47, valid_classifier_loss:2.165
#
#
# Epoch 4: iteration 106/107
# Epoch 4 --- loss:3.257, Epoch accuracy:8.20%, Validation loss:2.887, Validation accuracy:8.86%
#
# Epoch 4 --- epoch_autoencoder_loss1:1.670, epoch_autoencoder_loss2:1.59, epoch_classifier_loss:2.194
#
# Epoch 4 --- valid_autoencoder_loss1:1.473, valid_autoencoder_loss2:1.41, valid_classifier_loss:2.166
#
#
# Epoch 5: iteration 106/107
# Epoch 5 --- loss:3.122, Epoch accuracy:8.08%, Validation loss:2.791, Validation accuracy:8.86%
#
# Epoch 5 --- epoch_autoencoder_loss1:1.598, epoch_autoencoder_loss2:1.52, epoch_classifier_loss:2.201
#
# Epoch 5 --- valid_autoencoder_loss1:1.422, valid_autoencoder_loss2:1.37, valid_classifier_loss:2.166
#
#
# Epoch 6: iteration 106/107
# Epoch 6 --- loss:3.012, Epoch accuracy:8.05%, Validation loss:2.707, Validation accuracy:8.62%
#
# Epoch 6 --- epoch_autoencoder_loss1:1.539, epoch_autoencoder_loss2:1.47, epoch_classifier_loss:2.194
#
# Epoch 6 --- valid_autoencoder_loss1:1.377, valid_autoencoder_loss2:1.33, valid_classifier_loss:2.167
#
#
# Epoch 7: iteration 106/107
# Epoch 7 --- loss:2.911, Epoch accuracy:7.88%, Validation loss:2.632, Validation accuracy:8.39%
#
# Epoch 7 --- epoch_autoencoder_loss1:1.486, epoch_autoencoder_loss2:1.43, epoch_classifier_loss:2.204
#
# Epoch 7 --- valid_autoencoder_loss1:1.338, valid_autoencoder_loss2:1.29, valid_classifier_loss:2.167
#
#
# Epoch 8: iteration 106/107
# Epoch 8 --- loss:2.826, Epoch accuracy:7.76%, Validation loss:2.568, Validation accuracy:8.39%
#
# Epoch 8 --- epoch_autoencoder_loss1:1.441, epoch_autoencoder_loss2:1.39, epoch_classifier_loss:2.205
#
# Epoch 8 --- valid_autoencoder_loss1:1.304, valid_autoencoder_loss2:1.26, valid_classifier_loss:2.167
#
#
# Epoch 9: iteration 106/107
# Epoch 9 --- loss:2.750, Epoch accuracy:8.28%, Validation loss:2.514, Validation accuracy:8.39%
#
# Epoch 9 --- epoch_autoencoder_loss1:1.401, epoch_autoencoder_loss2:1.35, epoch_classifier_loss:2.199
#
# Epoch 9 --- valid_autoencoder_loss1:1.275, valid_autoencoder_loss2:1.24, valid_classifier_loss:2.169
#
#
# Epoch 10: iteration 106/107
# Epoch 10 --- loss:2.683, Epoch accuracy:7.21%, Validation loss:2.461, Validation accuracy:8.39%
#
# Epoch 10 --- epoch_autoencoder_loss1:1.366, epoch_autoencoder_loss2:1.32, epoch_classifier_loss:2.206
#
# Epoch 10 --- valid_autoencoder_loss1:1.248, valid_autoencoder_loss2:1.21, valid_classifier_loss:2.169
#
#
# Epoch 11: iteration 106/107
# Epoch 11 --- loss:2.623, Epoch accuracy:7.73%, Validation loss:2.418, Validation accuracy:8.62%
#
# Epoch 11 --- epoch_autoencoder_loss1:1.334, epoch_autoencoder_loss2:1.29, epoch_classifier_loss:2.204
#
# Epoch 11 --- valid_autoencoder_loss1:1.225, valid_autoencoder_loss2:1.19, valid_classifier_loss:2.170
#
#
# Epoch 12: iteration 106/107
# Epoch 12 --- loss:2.567, Epoch accuracy:7.53%, Validation loss:2.377, Validation accuracy:8.62%
#
# Epoch 12 --- epoch_autoencoder_loss1:1.305, epoch_autoencoder_loss2:1.26, epoch_classifier_loss:2.204
#
# Epoch 12 --- valid_autoencoder_loss1:1.203, valid_autoencoder_loss2:1.17, valid_classifier_loss:2.171
#
#
# Epoch 13: iteration 106/107
# Epoch 13 --- loss:2.518, Epoch accuracy:7.99%, Validation loss:2.337, Validation accuracy:8.39%
#
# Epoch 13 --- epoch_autoencoder_loss1:1.279, epoch_autoencoder_loss2:1.24, epoch_classifier_loss:2.204
#
# Epoch 13 --- valid_autoencoder_loss1:1.182, valid_autoencoder_loss2:1.16, valid_classifier_loss:2.170
#
#
# Epoch 14: iteration 106/107
# Epoch 14 --- loss:2.473, Epoch accuracy:7.96%, Validation loss:2.304, Validation accuracy:8.39%
#
# Epoch 14 --- epoch_autoencoder_loss1:1.256, epoch_autoencoder_loss2:1.22, epoch_classifier_loss:2.200
#
# Epoch 14 --- valid_autoencoder_loss1:1.164, valid_autoencoder_loss2:1.14, valid_classifier_loss:2.171
#
#
# Epoch 15: iteration 106/107
# Epoch 15 --- loss:2.432, Epoch accuracy:7.82%, Validation loss:2.278, Validation accuracy:8.39%
#
# Epoch 15 --- epoch_autoencoder_loss1:1.234, epoch_autoencoder_loss2:1.20, epoch_classifier_loss:2.207
#
# Epoch 15 --- valid_autoencoder_loss1:1.149, valid_autoencoder_loss2:1.13, valid_classifier_loss:2.173
#
#
# Epoch 16: iteration 106/107
# Epoch 16 --- loss:2.395, Epoch accuracy:7.61%, Validation loss:2.249, Validation accuracy:8.39%
#
# Epoch 16 --- epoch_autoencoder_loss1:1.215, epoch_autoencoder_loss2:1.18, epoch_classifier_loss:2.210
#
# Epoch 16 --- valid_autoencoder_loss1:1.134, valid_autoencoder_loss2:1.11, valid_classifier_loss:2.174
#
#
# Epoch 17: iteration 106/107
# Epoch 17 --- loss:2.361, Epoch accuracy:7.24%, Validation loss:2.222, Validation accuracy:8.39%
#
# Epoch 17 --- epoch_autoencoder_loss1:1.196, epoch_autoencoder_loss2:1.16, epoch_classifier_loss:2.211
#
# Epoch 17 --- valid_autoencoder_loss1:1.120, valid_autoencoder_loss2:1.10, valid_classifier_loss:2.173
#
#
# Epoch 18: iteration 106/107
# Epoch 18 --- loss:2.329, Epoch accuracy:6.97%, Validation loss:2.201, Validation accuracy:8.39%
#
# Epoch 18 --- epoch_autoencoder_loss1:1.179, epoch_autoencoder_loss2:1.15, epoch_classifier_loss:2.209
#
# Epoch 18 --- valid_autoencoder_loss1:1.108, valid_autoencoder_loss2:1.09, valid_classifier_loss:2.175
#
#
# Epoch 19: iteration 106/107
# Epoch 19 --- loss:2.299, Epoch accuracy:7.15%, Validation loss:2.180, Validation accuracy:8.39%
#
# Epoch 19 --- epoch_autoencoder_loss1:1.163, epoch_autoencoder_loss2:1.14, epoch_classifier_loss:2.207
#
# Epoch 19 --- valid_autoencoder_loss1:1.097, valid_autoencoder_loss2:1.08, valid_classifier_loss:2.175
#
#
# Epoch 20: iteration 106/107
# Epoch 20 --- loss:2.274, Epoch accuracy:7.27%, Validation loss:2.161, Validation accuracy:8.39%
#
# Epoch 20 --- epoch_autoencoder_loss1:1.150, epoch_autoencoder_loss2:1.12, epoch_classifier_loss:2.210
#
# Epoch 20 --- valid_autoencoder_loss1:1.087, valid_autoencoder_loss2:1.07, valid_classifier_loss:2.175
#
#
# Epoch 21: iteration 106/107
# Epoch 21 --- loss:2.249, Epoch accuracy:7.73%, Validation loss:2.144, Validation accuracy:8.16%
#
# Epoch 21 --- epoch_autoencoder_loss1:1.136, epoch_autoencoder_loss2:1.11, epoch_classifier_loss:2.207
#
# Epoch 21 --- valid_autoencoder_loss1:1.078, valid_autoencoder_loss2:1.07, valid_classifier_loss:2.177
#
#
# Epoch 22: iteration 106/107
# Epoch 22 --- loss:2.227, Epoch accuracy:7.15%, Validation loss:2.130, Validation accuracy:8.39%
#
# Epoch 22 --- epoch_autoencoder_loss1:1.125, epoch_autoencoder_loss2:1.10, epoch_classifier_loss:2.210
#
# Epoch 22 --- valid_autoencoder_loss1:1.070, valid_autoencoder_loss2:1.06, valid_classifier_loss:2.177
#
#
# Epoch 23: iteration 106/107
# Epoch 23 --- loss:2.206, Epoch accuracy:7.82%, Validation loss:2.112, Validation accuracy:8.62%
#
# Epoch 23 --- epoch_autoencoder_loss1:1.113, epoch_autoencoder_loss2:1.09, epoch_classifier_loss:2.206
#
# Epoch 23 --- valid_autoencoder_loss1:1.061, valid_autoencoder_loss2:1.05, valid_classifier_loss:2.178
#
#
# Epoch 24: iteration 106/107
# Epoch 24 --- loss:2.187, Epoch accuracy:7.09%, Validation loss:2.100, Validation accuracy:8.39%
#
# Epoch 24 --- epoch_autoencoder_loss1:1.103, epoch_autoencoder_loss2:1.08, epoch_classifier_loss:2.213
#
# Epoch 24 --- valid_autoencoder_loss1:1.054, valid_autoencoder_loss2:1.05, valid_classifier_loss:2.178
#
#
# Epoch 25: iteration 106/107
# Epoch 25 --- loss:2.170, Epoch accuracy:7.03%, Validation loss:2.087, Validation accuracy:8.39%
#
# Epoch 25 --- epoch_autoencoder_loss1:1.094, epoch_autoencoder_loss2:1.08, epoch_classifier_loss:2.212
#
# Epoch 25 --- valid_autoencoder_loss1:1.048, valid_autoencoder_loss2:1.04, valid_classifier_loss:2.179
#
#
# Epoch 26: iteration 106/107
# Epoch 26 --- loss:2.154, Epoch accuracy:7.64%, Validation loss:2.076, Validation accuracy:8.39%
#
# Epoch 26 --- epoch_autoencoder_loss1:1.085, epoch_autoencoder_loss2:1.07, epoch_classifier_loss:2.210
#
# Epoch 26 --- valid_autoencoder_loss1:1.042, valid_autoencoder_loss2:1.03, valid_classifier_loss:2.180
#
#
# Epoch 27: iteration 106/107
# Epoch 27 --- loss:2.140, Epoch accuracy:7.24%, Validation loss:2.064, Validation accuracy:8.16%
#
# Epoch 27 --- epoch_autoencoder_loss1:1.078, epoch_autoencoder_loss2:1.06, epoch_classifier_loss:2.211
#
# Epoch 27 --- valid_autoencoder_loss1:1.036, valid_autoencoder_loss2:1.03, valid_classifier_loss:2.181
#
#
# Epoch 28: iteration 106/107
# Epoch 28 --- loss:2.125, Epoch accuracy:7.64%, Validation loss:2.050, Validation accuracy:7.93%
#
# Epoch 28 --- epoch_autoencoder_loss1:1.070, epoch_autoencoder_loss2:1.06, epoch_classifier_loss:2.211
#
# Epoch 28 --- valid_autoencoder_loss1:1.029, valid_autoencoder_loss2:1.02, valid_classifier_loss:2.179
#
#
# Epoch 29: iteration 106/107
# Epoch 29 --- loss:2.111, Epoch accuracy:6.92%, Validation loss:2.046, Validation accuracy:7.93%
#
# Epoch 29 --- epoch_autoencoder_loss1:1.063, epoch_autoencoder_loss2:1.05, epoch_classifier_loss:2.216
#
# Epoch 29 --- valid_autoencoder_loss1:1.026, valid_autoencoder_loss2:1.02, valid_classifier_loss:2.182
#
#
# Epoch 30: iteration 106/107
# Epoch 30 --- loss:2.099, Epoch accuracy:6.95%, Validation loss:2.034, Validation accuracy:7.93%
#
# Epoch 30 --- epoch_autoencoder_loss1:1.056, epoch_autoencoder_loss2:1.04, epoch_classifier_loss:2.209
#
# Epoch 30 --- valid_autoencoder_loss1:1.020, valid_autoencoder_loss2:1.01, valid_classifier_loss:2.182
#
#
# Epoch 31: iteration 106/107
# Epoch 31 --- loss:2.089, Epoch accuracy:7.24%, Validation loss:2.027, Validation accuracy:8.16%
#
# Epoch 31 --- epoch_autoencoder_loss1:1.051, epoch_autoencoder_loss2:1.04, epoch_classifier_loss:2.215
#
# Epoch 31 --- valid_autoencoder_loss1:1.016, valid_autoencoder_loss2:1.01, valid_classifier_loss:2.183
#
#
# Epoch 32: iteration 106/107
# Epoch 32 --- loss:2.077, Epoch accuracy:7.41%, Validation loss:2.020, Validation accuracy:8.16%
#
# Epoch 32 --- epoch_autoencoder_loss1:1.045, epoch_autoencoder_loss2:1.03, epoch_classifier_loss:2.205
#
# Epoch 32 --- valid_autoencoder_loss1:1.012, valid_autoencoder_loss2:1.01, valid_classifier_loss:2.184
#
#
# Epoch 33: iteration 106/107
# Epoch 33 --- loss:2.069, Epoch accuracy:7.27%, Validation loss:2.012, Validation accuracy:8.16%
#
# Epoch 33 --- epoch_autoencoder_loss1:1.040, epoch_autoencoder_loss2:1.03, epoch_classifier_loss:2.216
#
# Epoch 33 --- valid_autoencoder_loss1:1.009, valid_autoencoder_loss2:1.00, valid_classifier_loss:2.184
#
#
# Epoch 34: iteration 106/107
# Epoch 34 --- loss:2.059, Epoch accuracy:7.67%, Validation loss:2.005, Validation accuracy:7.93%
#
# Epoch 34 --- epoch_autoencoder_loss1:1.035, epoch_autoencoder_loss2:1.02, epoch_classifier_loss:2.210
#
# Epoch 34 --- valid_autoencoder_loss1:1.005, valid_autoencoder_loss2:1.00, valid_classifier_loss:2.185
#
#
# Epoch 35: iteration 106/107
# Epoch 35 --- loss:2.050, Epoch accuracy:7.27%, Validation loss:1.996, Validation accuracy:7.93%
#
# Epoch 35 --- epoch_autoencoder_loss1:1.030, epoch_autoencoder_loss2:1.02, epoch_classifier_loss:2.216
#
# Epoch 35 --- valid_autoencoder_loss1:1.000, valid_autoencoder_loss2:1.00, valid_classifier_loss:2.185
#
#
# Epoch 36: iteration 106/107
# Epoch 36 --- loss:2.041, Epoch accuracy:7.56%, Validation loss:1.990, Validation accuracy:7.93%
#
# Epoch 36 --- epoch_autoencoder_loss1:1.025, epoch_autoencoder_loss2:1.02, epoch_classifier_loss:2.213
#
# Epoch 36 --- valid_autoencoder_loss1:0.997, valid_autoencoder_loss2:0.99, valid_classifier_loss:2.186
#
#
# Epoch 37: iteration 106/107
# Epoch 37 --- loss:2.033, Epoch accuracy:7.47%, Validation loss:1.986, Validation accuracy:7.93%
#
# Epoch 37 --- epoch_autoencoder_loss1:1.021, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:2.220
#
# Epoch 37 --- valid_autoencoder_loss1:0.995, valid_autoencoder_loss2:0.99, valid_classifier_loss:2.187
#
#
# Epoch 38: iteration 106/107
# Epoch 38 --- loss:2.026, Epoch accuracy:6.89%, Validation loss:1.979, Validation accuracy:8.16%
#
# Epoch 38 --- epoch_autoencoder_loss1:1.017, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:2.212
#
# Epoch 38 --- valid_autoencoder_loss1:0.991, valid_autoencoder_loss2:0.99, valid_classifier_loss:2.188
#
#
# Epoch 39: iteration 106/107
# Epoch 39 --- loss:2.017, Epoch accuracy:7.18%, Validation loss:1.972, Validation accuracy:8.16%
#
# Epoch 39 --- epoch_autoencoder_loss1:1.013, epoch_autoencoder_loss2:1.00, epoch_classifier_loss:2.217
#
# Epoch 39 --- valid_autoencoder_loss1:0.987, valid_autoencoder_loss2:0.98, valid_classifier_loss:2.187
#
#
# Epoch 40: iteration 106/107
# Epoch 40 --- loss:2.010, Epoch accuracy:7.44%, Validation loss:1.969, Validation accuracy:7.93%
#
# Epoch 40 --- epoch_autoencoder_loss1:1.009, epoch_autoencoder_loss2:1.00, epoch_classifier_loss:2.217
#
# Epoch 40 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.98, valid_classifier_loss:2.189
#
#
# Epoch 41: iteration 106/107
# Epoch 41 --- loss:2.006, Epoch accuracy:7.56%, Validation loss:1.961, Validation accuracy:8.39%
#
# Epoch 41 --- epoch_autoencoder_loss1:1.007, epoch_autoencoder_loss2:1.00, epoch_classifier_loss:2.209
#
# Epoch 41 --- valid_autoencoder_loss1:0.982, valid_autoencoder_loss2:0.98, valid_classifier_loss:2.189
#
#
# Epoch 42: iteration 106/107
# Epoch 42 --- loss:1.998, Epoch accuracy:7.09%, Validation loss:1.960, Validation accuracy:8.39%
#
# Epoch 42 --- epoch_autoencoder_loss1:1.003, epoch_autoencoder_loss2:1.00, epoch_classifier_loss:2.214
#
# Epoch 42 --- valid_autoencoder_loss1:0.981, valid_autoencoder_loss2:0.98, valid_classifier_loss:2.191
#
#
# Epoch 43: iteration 106/107
# Epoch 43 --- loss:1.992, Epoch accuracy:7.12%, Validation loss:1.953, Validation accuracy:8.16%
#
# Epoch 43 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:0.99, epoch_classifier_loss:2.221
#
# Epoch 43 --- valid_autoencoder_loss1:0.978, valid_autoencoder_loss2:0.98, valid_classifier_loss:2.191
#
#
# Epoch 44: iteration 106/107
# Epoch 44 --- loss:1.987, Epoch accuracy:7.29%, Validation loss:1.953, Validation accuracy:8.16%
#
# Epoch 44 --- epoch_autoencoder_loss1:0.997, epoch_autoencoder_loss2:0.99, epoch_classifier_loss:2.214
#
# Epoch 44 --- valid_autoencoder_loss1:0.978, valid_autoencoder_loss2:0.98, valid_classifier_loss:2.193
#
#
# Epoch 45: iteration 106/107
# Epoch 45 --- loss:1.981, Epoch accuracy:7.47%, Validation loss:1.946, Validation accuracy:7.93%
#
# Epoch 45 --- epoch_autoencoder_loss1:0.994, epoch_autoencoder_loss2:0.99, epoch_classifier_loss:2.213
#
# Epoch 45 --- valid_autoencoder_loss1:0.974, valid_autoencoder_loss2:0.97, valid_classifier_loss:2.193
#
#
# Epoch 46: iteration 106/107
# Epoch 46 --- loss:1.977, Epoch accuracy:7.32%, Validation loss:1.940, Validation accuracy:7.93%
#
# Epoch 46 --- epoch_autoencoder_loss1:0.992, epoch_autoencoder_loss2:0.99, epoch_classifier_loss:2.214
#
# Epoch 46 --- valid_autoencoder_loss1:0.971, valid_autoencoder_loss2:0.97, valid_classifier_loss:2.193
#
#
# Epoch 47: iteration 106/107
# Epoch 47 --- loss:1.972, Epoch accuracy:7.56%, Validation loss:1.936, Validation accuracy:8.16%
#
# Epoch 47 --- epoch_autoencoder_loss1:0.989, epoch_autoencoder_loss2:0.98, epoch_classifier_loss:2.216
#
# Epoch 47 --- valid_autoencoder_loss1:0.969, valid_autoencoder_loss2:0.97, valid_classifier_loss:2.193
#
#
# Epoch 48: iteration 106/107
# Epoch 48 --- loss:1.969, Epoch accuracy:7.44%, Validation loss:1.933, Validation accuracy:8.16%
#
# Epoch 48 --- epoch_autoencoder_loss1:0.987, epoch_autoencoder_loss2:0.98, epoch_classifier_loss:2.215
#
# Epoch 48 --- valid_autoencoder_loss1:0.967, valid_autoencoder_loss2:0.97, valid_classifier_loss:2.195
#
#
# Epoch 49: iteration 106/107
# Epoch 49 --- loss:1.964, Epoch accuracy:7.29%, Validation loss:1.929, Validation accuracy:7.69%
#
# Epoch 49 --- epoch_autoencoder_loss1:0.985, epoch_autoencoder_loss2:0.98, epoch_classifier_loss:2.219
#
# Epoch 49 --- valid_autoencoder_loss1:0.965, valid_autoencoder_loss2:0.96, valid_classifier_loss:2.195
#
#
# Epoch 50: iteration 106/107
# Epoch 50 --- loss:1.959, Epoch accuracy:7.38%, Validation loss:1.924, Validation accuracy:7.69%
#
# Epoch 50 --- epoch_autoencoder_loss1:0.982, epoch_autoencoder_loss2:0.98, epoch_classifier_loss:2.218
#
# Epoch 50 --- valid_autoencoder_loss1:0.963, valid_autoencoder_loss2:0.96, valid_classifier_loss:2.195
#
#
# Epoch 51: iteration 106/107
# Epoch 51 --- loss:1.954, Epoch accuracy:7.38%, Validation loss:1.921, Validation accuracy:8.16%
#
# Epoch 51 --- epoch_autoencoder_loss1:0.980, epoch_autoencoder_loss2:0.97, epoch_classifier_loss:2.217
#
# Epoch 51 --- valid_autoencoder_loss1:0.961, valid_autoencoder_loss2:0.96, valid_classifier_loss:2.196
#
#
# Epoch 52: iteration 106/107
# Epoch 52 --- loss:1.951, Epoch accuracy:7.35%, Validation loss:1.920, Validation accuracy:7.93%
#
# Epoch 52 --- epoch_autoencoder_loss1:0.978, epoch_autoencoder_loss2:0.97, epoch_classifier_loss:2.218
#
# Epoch 52 --- valid_autoencoder_loss1:0.961, valid_autoencoder_loss2:0.96, valid_classifier_loss:2.198
#
#
# Epoch 53: iteration 106/107
# Epoch 53 --- loss:1.947, Epoch accuracy:7.73%, Validation loss:1.915, Validation accuracy:7.46%
#
# Epoch 53 --- epoch_autoencoder_loss1:0.976, epoch_autoencoder_loss2:0.97, epoch_classifier_loss:2.218
#
# Epoch 53 --- valid_autoencoder_loss1:0.958, valid_autoencoder_loss2:0.96, valid_classifier_loss:2.197
#
#
# Epoch 54: iteration 106/107
# Epoch 54 --- loss:1.942, Epoch accuracy:7.24%, Validation loss:1.913, Validation accuracy:7.69%
#
# Epoch 54 --- epoch_autoencoder_loss1:0.973, epoch_autoencoder_loss2:0.97, epoch_classifier_loss:2.221
#
# Epoch 54 --- valid_autoencoder_loss1:0.957, valid_autoencoder_loss2:0.96, valid_classifier_loss:2.199
#
#
# Epoch 55: iteration 106/107
# Epoch 55 --- loss:1.939, Epoch accuracy:7.61%, Validation loss:1.910, Validation accuracy:7.23%
#
# Epoch 55 --- epoch_autoencoder_loss1:0.971, epoch_autoencoder_loss2:0.97, epoch_classifier_loss:2.216
#
# Epoch 55 --- valid_autoencoder_loss1:0.955, valid_autoencoder_loss2:0.95, valid_classifier_loss:2.198
#
#
# Epoch 56: iteration 106/107
# Epoch 56 --- loss:1.936, Epoch accuracy:6.92%, Validation loss:1.907, Validation accuracy:7.23%
#
# Epoch 56 --- epoch_autoencoder_loss1:0.970, epoch_autoencoder_loss2:0.97, epoch_classifier_loss:2.223
#
# Epoch 56 --- valid_autoencoder_loss1:0.954, valid_autoencoder_loss2:0.95, valid_classifier_loss:2.199
#
#
# Epoch 57: iteration 106/107
# Epoch 57 --- loss:1.931, Epoch accuracy:7.67%, Validation loss:1.903, Validation accuracy:7.46%
#
# Epoch 57 --- epoch_autoencoder_loss1:0.967, epoch_autoencoder_loss2:0.96, epoch_classifier_loss:2.219
#
# Epoch 57 --- valid_autoencoder_loss1:0.951, valid_autoencoder_loss2:0.95, valid_classifier_loss:2.199
#
#
# Epoch 58: iteration 106/107
# Epoch 58 --- loss:1.928, Epoch accuracy:7.27%, Validation loss:1.902, Validation accuracy:7.46%
#
# Epoch 58 --- epoch_autoencoder_loss1:0.966, epoch_autoencoder_loss2:0.96, epoch_classifier_loss:2.218
#
# Epoch 58 --- valid_autoencoder_loss1:0.951, valid_autoencoder_loss2:0.95, valid_classifier_loss:2.201
#
#
# Epoch 59: iteration 106/107
# Epoch 59 --- loss:1.926, Epoch accuracy:6.95%, Validation loss:1.898, Validation accuracy:7.23%
#
# Epoch 59 --- epoch_autoencoder_loss1:0.965, epoch_autoencoder_loss2:0.96, epoch_classifier_loss:2.222
#
# Epoch 59 --- valid_autoencoder_loss1:0.949, valid_autoencoder_loss2:0.95, valid_classifier_loss:2.201
#
#
# Epoch 60: iteration 106/107
# Epoch 60 --- loss:1.922, Epoch accuracy:7.35%, Validation loss:1.895, Validation accuracy:7.46%
#
# Epoch 60 --- epoch_autoencoder_loss1:0.963, epoch_autoencoder_loss2:0.96, epoch_classifier_loss:2.220
#
# Epoch 60 --- valid_autoencoder_loss1:0.947, valid_autoencoder_loss2:0.95, valid_classifier_loss:2.201
#
#
# Epoch 61: iteration 106/107
# Epoch 61 --- loss:1.919, Epoch accuracy:7.24%, Validation loss:1.894, Validation accuracy:7.69%
#
# Epoch 61 --- epoch_autoencoder_loss1:0.961, epoch_autoencoder_loss2:0.96, epoch_classifier_loss:2.227
#
# Epoch 61 --- valid_autoencoder_loss1:0.947, valid_autoencoder_loss2:0.95, valid_classifier_loss:2.202
#
#
# Epoch 62: iteration 106/107
# Epoch 62 --- loss:1.915, Epoch accuracy:8.22%, Validation loss:1.892, Validation accuracy:7.46%
#
# Epoch 62 --- epoch_autoencoder_loss1:0.959, epoch_autoencoder_loss2:0.96, epoch_classifier_loss:2.219
#
# Epoch 62 --- valid_autoencoder_loss1:0.946, valid_autoencoder_loss2:0.95, valid_classifier_loss:2.203
#
#
# Epoch 63: iteration 106/107
# Epoch 63 --- loss:1.914, Epoch accuracy:7.03%, Validation loss:1.888, Validation accuracy:7.69%
#
# Epoch 63 --- epoch_autoencoder_loss1:0.959, epoch_autoencoder_loss2:0.96, epoch_classifier_loss:2.220
#
# Epoch 63 --- valid_autoencoder_loss1:0.944, valid_autoencoder_loss2:0.94, valid_classifier_loss:2.203
#
#
# Epoch 64: iteration 106/107
# Epoch 64 --- loss:1.910, Epoch accuracy:7.50%, Validation loss:1.886, Validation accuracy:7.69%
#
# Epoch 64 --- epoch_autoencoder_loss1:0.957, epoch_autoencoder_loss2:0.95, epoch_classifier_loss:2.219
#
# Epoch 64 --- valid_autoencoder_loss1:0.942, valid_autoencoder_loss2:0.94, valid_classifier_loss:2.203
#
#
# Epoch 65: iteration 106/107
# Epoch 65 --- loss:1.908, Epoch accuracy:7.56%, Validation loss:1.882, Validation accuracy:7.69%
#
# Epoch 65 --- epoch_autoencoder_loss1:0.956, epoch_autoencoder_loss2:0.95, epoch_classifier_loss:2.218
#
# Epoch 65 --- valid_autoencoder_loss1:0.941, valid_autoencoder_loss2:0.94, valid_classifier_loss:2.203
#
#
# Epoch 66: iteration 106/107
# Epoch 66 --- loss:1.905, Epoch accuracy:7.12%, Validation loss:1.882, Validation accuracy:7.69%
#
# Epoch 66 --- epoch_autoencoder_loss1:0.954, epoch_autoencoder_loss2:0.95, epoch_classifier_loss:2.221
#
# Epoch 66 --- valid_autoencoder_loss1:0.941, valid_autoencoder_loss2:0.94, valid_classifier_loss:2.205
#
#
# Epoch 67: iteration 106/107
# Epoch 67 --- loss:1.903, Epoch accuracy:6.77%, Validation loss:1.879, Validation accuracy:7.69%
#
# Epoch 67 --- epoch_autoencoder_loss1:0.953, epoch_autoencoder_loss2:0.95, epoch_classifier_loss:2.220
#
# Epoch 67 --- valid_autoencoder_loss1:0.939, valid_autoencoder_loss2:0.94, valid_classifier_loss:2.206
#
#
# Epoch 68: iteration 106/107
# Epoch 68 --- loss:1.900, Epoch accuracy:7.03%, Validation loss:1.875, Validation accuracy:7.69%
#
# Epoch 68 --- epoch_autoencoder_loss1:0.951, epoch_autoencoder_loss2:0.95, epoch_classifier_loss:2.217
#
# Epoch 68 --- valid_autoencoder_loss1:0.937, valid_autoencoder_loss2:0.94, valid_classifier_loss:2.204
#
#
# Epoch 69: iteration 106/107
# Epoch 69 --- loss:1.897, Epoch accuracy:7.35%, Validation loss:1.875, Validation accuracy:7.46%
#
# Epoch 69 --- epoch_autoencoder_loss1:0.950, epoch_autoencoder_loss2:0.95, epoch_classifier_loss:2.223
#
# Epoch 69 --- valid_autoencoder_loss1:0.937, valid_autoencoder_loss2:0.94, valid_classifier_loss:2.206
#
#
# Epoch 70: iteration 106/107
# Epoch 70 --- loss:1.896, Epoch accuracy:7.35%, Validation loss:1.873, Validation accuracy:7.23%
#
# Epoch 70 --- epoch_autoencoder_loss1:0.949, epoch_autoencoder_loss2:0.95, epoch_classifier_loss:2.230
#
# Epoch 70 --- valid_autoencoder_loss1:0.936, valid_autoencoder_loss2:0.94, valid_classifier_loss:2.206
#
#
# Epoch 71: iteration 106/107
# Epoch 71 --- loss:1.894, Epoch accuracy:6.68%, Validation loss:1.871, Validation accuracy:6.99%
#
# Epoch 71 --- epoch_autoencoder_loss1:0.948, epoch_autoencoder_loss2:0.95, epoch_classifier_loss:2.228
#
# Epoch 71 --- valid_autoencoder_loss1:0.935, valid_autoencoder_loss2:0.94, valid_classifier_loss:2.207
#
#
# Epoch 72: iteration 106/107
# Epoch 72 --- loss:1.891, Epoch accuracy:7.09%, Validation loss:1.869, Validation accuracy:7.23%
#
# Epoch 72 --- epoch_autoencoder_loss1:0.946, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:2.222
#
# Epoch 72 --- valid_autoencoder_loss1:0.934, valid_autoencoder_loss2:0.94, valid_classifier_loss:2.208
#
#
# Epoch 73: iteration 106/107
# Epoch 73 --- loss:1.889, Epoch accuracy:7.09%, Validation loss:1.868, Validation accuracy:6.99%
#
# Epoch 73 --- epoch_autoencoder_loss1:0.945, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:2.222
#
# Epoch 73 --- valid_autoencoder_loss1:0.933, valid_autoencoder_loss2:0.93, valid_classifier_loss:2.208
#
#
# Epoch 74: iteration 106/107
# Epoch 74 --- loss:1.886, Epoch accuracy:7.41%, Validation loss:1.866, Validation accuracy:6.76%
#
# Epoch 74 --- epoch_autoencoder_loss1:0.944, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:2.220
#
# Epoch 74 --- valid_autoencoder_loss1:0.932, valid_autoencoder_loss2:0.93, valid_classifier_loss:2.209
#
#
# Epoch 75: iteration 106/107
# Epoch 75 --- loss:1.884, Epoch accuracy:7.47%, Validation loss:1.862, Validation accuracy:6.99%
#
# Epoch 75 --- epoch_autoencoder_loss1:0.943, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:2.228
#
# Epoch 75 --- valid_autoencoder_loss1:0.930, valid_autoencoder_loss2:0.93, valid_classifier_loss:2.209
#
#
# Epoch 76: iteration 106/107
# Epoch 76 --- loss:1.882, Epoch accuracy:6.89%, Validation loss:1.861, Validation accuracy:6.76%
#
# Epoch 76 --- epoch_autoencoder_loss1:0.942, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:2.221
#
# Epoch 76 --- valid_autoencoder_loss1:0.930, valid_autoencoder_loss2:0.93, valid_classifier_loss:2.209
#
#
# Epoch 77: iteration 106/107
# Epoch 77 --- loss:1.881, Epoch accuracy:6.97%, Validation loss:1.859, Validation accuracy:6.76%
#
# Epoch 77 --- epoch_autoencoder_loss1:0.941, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:2.223
#
# Epoch 77 --- valid_autoencoder_loss1:0.928, valid_autoencoder_loss2:0.93, valid_classifier_loss:2.208
#
#
# Epoch 78: iteration 106/107
# Epoch 78 --- loss:1.879, Epoch accuracy:7.18%, Validation loss:1.856, Validation accuracy:6.76%
#
# Epoch 78 --- epoch_autoencoder_loss1:0.940, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:2.224
#
# Epoch 78 --- valid_autoencoder_loss1:0.927, valid_autoencoder_loss2:0.93, valid_classifier_loss:2.210
#
#
# Epoch 79: iteration 106/107
# Epoch 79 --- loss:1.875, Epoch accuracy:7.27%, Validation loss:1.855, Validation accuracy:6.06%
#
# Epoch 79 --- epoch_autoencoder_loss1:0.938, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:2.229
#
# Epoch 79 --- valid_autoencoder_loss1:0.926, valid_autoencoder_loss2:0.93, valid_classifier_loss:2.210
#
#
# Epoch 80: iteration 106/107
# Epoch 80 --- loss:1.874, Epoch accuracy:7.41%, Validation loss:1.854, Validation accuracy:6.06%
#
# Epoch 80 --- epoch_autoencoder_loss1:0.937, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:2.229
#
# Epoch 80 --- valid_autoencoder_loss1:0.926, valid_autoencoder_loss2:0.93, valid_classifier_loss:2.212
#
#
# Epoch 81: iteration 106/107
# Epoch 81 --- loss:1.872, Epoch accuracy:7.41%, Validation loss:1.851, Validation accuracy:6.06%
#
# Epoch 81 --- epoch_autoencoder_loss1:0.937, epoch_autoencoder_loss2:0.94, epoch_classifier_loss:2.223
#
# Epoch 81 --- valid_autoencoder_loss1:0.924, valid_autoencoder_loss2:0.93, valid_classifier_loss:2.211
#
#
# Epoch 82: iteration 106/107
# Epoch 82 --- loss:1.871, Epoch accuracy:7.21%, Validation loss:1.851, Validation accuracy:6.06%
#
# Epoch 82 --- epoch_autoencoder_loss1:0.936, epoch_autoencoder_loss2:0.93, epoch_classifier_loss:2.230
#
# Epoch 82 --- valid_autoencoder_loss1:0.925, valid_autoencoder_loss2:0.93, valid_classifier_loss:2.211
#
#
# Epoch 83: iteration 106/107
# Epoch 83 --- loss:1.869, Epoch accuracy:7.29%, Validation loss:1.850, Validation accuracy:6.53%
#
# Epoch 83 --- epoch_autoencoder_loss1:0.935, epoch_autoencoder_loss2:0.93, epoch_classifier_loss:2.221
#
# Epoch 83 --- valid_autoencoder_loss1:0.924, valid_autoencoder_loss2:0.93, valid_classifier_loss:2.213
#
#
# Epoch 84: iteration 106/107
# Epoch 84 --- loss:1.867, Epoch accuracy:7.56%, Validation loss:1.851, Validation accuracy:6.29%
#
# Epoch 84 --- epoch_autoencoder_loss1:0.934, epoch_autoencoder_loss2:0.93, epoch_classifier_loss:2.227
#
# Epoch 84 --- valid_autoencoder_loss1:0.924, valid_autoencoder_loss2:0.93, valid_classifier_loss:2.214
#
#
# Epoch 85: iteration 106/107
# Epoch 85 --- loss:1.866, Epoch accuracy:7.29%, Validation loss:1.846, Validation accuracy:6.53%
#
# Epoch 85 --- epoch_autoencoder_loss1:0.933, epoch_autoencoder_loss2:0.93, epoch_classifier_loss:2.233
#
# Epoch 85 --- valid_autoencoder_loss1:0.922, valid_autoencoder_loss2:0.92, valid_classifier_loss:2.213
#
#
# Epoch 86: iteration 106/107
# Epoch 86 --- loss:1.864, Epoch accuracy:7.24%, Validation loss:1.843, Validation accuracy:6.53%
#
# Epoch 86 --- epoch_autoencoder_loss1:0.932, epoch_autoencoder_loss2:0.93, epoch_classifier_loss:2.229
#
# Epoch 86 --- valid_autoencoder_loss1:0.920, valid_autoencoder_loss2:0.92, valid_classifier_loss:2.213
#
#
# Epoch 87: iteration 106/107
# Epoch 87 --- loss:1.861, Epoch accuracy:6.77%, Validation loss:1.841, Validation accuracy:6.53%
#
# Epoch 87 --- epoch_autoencoder_loss1:0.931, epoch_autoencoder_loss2:0.93, epoch_classifier_loss:2.230
#
# Epoch 87 --- valid_autoencoder_loss1:0.919, valid_autoencoder_loss2:0.92, valid_classifier_loss:2.213
#
#
# Epoch 88: iteration 106/107
# Epoch 88 --- loss:1.860, Epoch accuracy:7.82%, Validation loss:1.840, Validation accuracy:6.53%
#
# Epoch 88 --- epoch_autoencoder_loss1:0.930, epoch_autoencoder_loss2:0.93, epoch_classifier_loss:2.227
#
# Epoch 88 --- valid_autoencoder_loss1:0.918, valid_autoencoder_loss2:0.92, valid_classifier_loss:2.213
#
#
# Epoch 89: iteration 106/107
# Epoch 89 --- loss:1.859, Epoch accuracy:6.77%, Validation loss:1.838, Validation accuracy:6.53%
#
# Epoch 89 --- epoch_autoencoder_loss1:0.929, epoch_autoencoder_loss2:0.93, epoch_classifier_loss:2.225
#
# Epoch 89 --- valid_autoencoder_loss1:0.917, valid_autoencoder_loss2:0.92, valid_classifier_loss:2.213
#
#
# Epoch 90: iteration 106/107
# Epoch 90 --- loss:1.856, Epoch accuracy:6.80%, Validation loss:1.838, Validation accuracy:6.53%
#
# Epoch 90 --- epoch_autoencoder_loss1:0.928, epoch_autoencoder_loss2:0.93, epoch_classifier_loss:2.222
#
# Epoch 90 --- valid_autoencoder_loss1:0.918, valid_autoencoder_loss2:0.92, valid_classifier_loss:2.214
#
#
# Epoch 91: iteration 106/107
# Epoch 91 --- loss:1.855, Epoch accuracy:7.44%, Validation loss:1.836, Validation accuracy:6.53%
#
# Epoch 91 --- epoch_autoencoder_loss1:0.927, epoch_autoencoder_loss2:0.93, epoch_classifier_loss:2.229
#
# Epoch 91 --- valid_autoencoder_loss1:0.917, valid_autoencoder_loss2:0.92, valid_classifier_loss:2.216
#
#
# Epoch 92: iteration 106/107
# Epoch 92 --- loss:1.852, Epoch accuracy:7.27%, Validation loss:1.835, Validation accuracy:6.76%
#
# Epoch 92 --- epoch_autoencoder_loss1:0.926, epoch_autoencoder_loss2:0.93, epoch_classifier_loss:2.228
#
# Epoch 92 --- valid_autoencoder_loss1:0.916, valid_autoencoder_loss2:0.92, valid_classifier_loss:2.216
#
#
# Epoch 93: iteration 106/107
# Epoch 93 --- loss:1.852, Epoch accuracy:7.29%, Validation loss:1.834, Validation accuracy:6.76%
#
# Epoch 93 --- epoch_autoencoder_loss1:0.926, epoch_autoencoder_loss2:0.93, epoch_classifier_loss:2.232
#
# Epoch 93 --- valid_autoencoder_loss1:0.915, valid_autoencoder_loss2:0.92, valid_classifier_loss:2.216
#
#
# Epoch 94: iteration 106/107
# Epoch 94 --- loss:1.849, Epoch accuracy:7.09%, Validation loss:1.831, Validation accuracy:6.76%
#
# Epoch 94 --- epoch_autoencoder_loss1:0.925, epoch_autoencoder_loss2:0.92, epoch_classifier_loss:2.233
#
# Epoch 94 --- valid_autoencoder_loss1:0.914, valid_autoencoder_loss2:0.92, valid_classifier_loss:2.215
#
#
# Epoch 95: iteration 106/107
# Epoch 95 --- loss:1.849, Epoch accuracy:6.97%, Validation loss:1.830, Validation accuracy:6.99%
#
# Epoch 95 --- epoch_autoencoder_loss1:0.924, epoch_autoencoder_loss2:0.92, epoch_classifier_loss:2.224
#
# Epoch 95 --- valid_autoencoder_loss1:0.913, valid_autoencoder_loss2:0.92, valid_classifier_loss:2.216
#
#
# Epoch 96: iteration 106/107
# Epoch 96 --- loss:1.847, Epoch accuracy:7.00%, Validation loss:1.829, Validation accuracy:6.99%
#
# Epoch 96 --- epoch_autoencoder_loss1:0.923, epoch_autoencoder_loss2:0.92, epoch_classifier_loss:2.233
#
# Epoch 96 --- valid_autoencoder_loss1:0.913, valid_autoencoder_loss2:0.92, valid_classifier_loss:2.217
#
#
# Epoch 97: iteration 106/107
# Epoch 97 --- loss:1.844, Epoch accuracy:7.21%, Validation loss:1.827, Validation accuracy:6.76%
#
# Epoch 97 --- epoch_autoencoder_loss1:0.922, epoch_autoencoder_loss2:0.92, epoch_classifier_loss:2.230
#
# Epoch 97 --- valid_autoencoder_loss1:0.912, valid_autoencoder_loss2:0.92, valid_classifier_loss:2.216
#
#
# Epoch 98: iteration 106/107
# Epoch 98 --- loss:1.844, Epoch accuracy:7.61%, Validation loss:1.826, Validation accuracy:6.99%
#
# Epoch 98 --- epoch_autoencoder_loss1:0.922, epoch_autoencoder_loss2:0.92, epoch_classifier_loss:2.231
#
# Epoch 98 --- valid_autoencoder_loss1:0.911, valid_autoencoder_loss2:0.91, valid_classifier_loss:2.217
#
#
# Epoch 99: iteration 106/107
# Epoch 99 --- loss:1.842, Epoch accuracy:7.44%, Validation loss:1.825, Validation accuracy:6.99%
#
# Epoch 99 --- epoch_autoencoder_loss1:0.921, epoch_autoencoder_loss2:0.92, epoch_classifier_loss:2.229
#
# Epoch 99 --- valid_autoencoder_loss1:0.911, valid_autoencoder_loss2:0.91, valid_classifier_loss:2.219
#
#
# Epoch 100: iteration 106/107
# Epoch 100 --- loss:1.841, Epoch accuracy:7.53%, Validation loss:1.825, Validation accuracy:6.99%
#
# Epoch 100 --- epoch_autoencoder_loss1:0.920, epoch_autoencoder_loss2:0.92, epoch_classifier_loss:2.230
#
# Epoch 100 --- valid_autoencoder_loss1:0.910, valid_autoencoder_loss2:0.91, valid_classifier_loss:2.219
#
#
# Epoch 101: iteration 106/107
# Epoch 101 --- loss:1.839, Epoch accuracy:7.47%, Validation loss:1.821, Validation accuracy:6.76%
#
# Epoch 101 --- epoch_autoencoder_loss1:0.919, epoch_autoencoder_loss2:0.92, epoch_classifier_loss:2.227
#
# Epoch 101 --- valid_autoencoder_loss1:0.909, valid_autoencoder_loss2:0.91, valid_classifier_loss:2.216
#
#
# Epoch 102: iteration 106/107
# Epoch 102 --- loss:1.838, Epoch accuracy:7.56%, Validation loss:1.820, Validation accuracy:6.99%
#
# Epoch 102 --- epoch_autoencoder_loss1:0.918, epoch_autoencoder_loss2:0.92, epoch_classifier_loss:2.230
#
# Epoch 102 --- valid_autoencoder_loss1:0.908, valid_autoencoder_loss2:0.91, valid_classifier_loss:2.217
#
#
# Epoch 103: iteration 106/107
# Epoch 103 --- loss:1.835, Epoch accuracy:7.18%, Validation loss:1.819, Validation accuracy:6.76%
#
# Epoch 103 --- epoch_autoencoder_loss1:0.917, epoch_autoencoder_loss2:0.92, epoch_classifier_loss:2.232
#
# Epoch 103 --- valid_autoencoder_loss1:0.907, valid_autoencoder_loss2:0.91, valid_classifier_loss:2.218
#
#
# Epoch 104: iteration 106/107
# Epoch 104 --- loss:1.835, Epoch accuracy:7.64%, Validation loss:1.816, Validation accuracy:6.76%
#
# Epoch 104 --- epoch_autoencoder_loss1:0.917, epoch_autoencoder_loss2:0.92, epoch_classifier_loss:2.226
#
# Epoch 104 --- valid_autoencoder_loss1:0.906, valid_autoencoder_loss2:0.91, valid_classifier_loss:2.218
#
#
# Epoch 105: iteration 106/107
# Epoch 105 --- loss:1.833, Epoch accuracy:7.35%, Validation loss:1.816, Validation accuracy:6.76%
#
# Epoch 105 --- epoch_autoencoder_loss1:0.916, epoch_autoencoder_loss2:0.92, epoch_classifier_loss:2.232
#
# Epoch 105 --- valid_autoencoder_loss1:0.906, valid_autoencoder_loss2:0.91, valid_classifier_loss:2.219
#
#
# Epoch 106: iteration 106/107
# Epoch 106 --- loss:1.832, Epoch accuracy:7.21%, Validation loss:1.816, Validation accuracy:6.99%
#
# Epoch 106 --- epoch_autoencoder_loss1:0.916, epoch_autoencoder_loss2:0.92, epoch_classifier_loss:2.232
#
# Epoch 106 --- valid_autoencoder_loss1:0.906, valid_autoencoder_loss2:0.91, valid_classifier_loss:2.221
#
#
# Epoch 107: iteration 106/107
# Epoch 107 --- loss:1.830, Epoch accuracy:7.53%, Validation loss:1.814, Validation accuracy:6.76%
#
# Epoch 107 --- epoch_autoencoder_loss1:0.914, epoch_autoencoder_loss2:0.92, epoch_classifier_loss:2.231
#
# Epoch 107 --- valid_autoencoder_loss1:0.905, valid_autoencoder_loss2:0.91, valid_classifier_loss:2.219
#
#
# Epoch 108: iteration 106/107
# Epoch 108 --- loss:1.829, Epoch accuracy:7.21%, Validation loss:1.813, Validation accuracy:6.76%
#
# Epoch 108 --- epoch_autoencoder_loss1:0.914, epoch_autoencoder_loss2:0.92, epoch_classifier_loss:2.233
#
# Epoch 108 --- valid_autoencoder_loss1:0.904, valid_autoencoder_loss2:0.91, valid_classifier_loss:2.220
#
#
# Epoch 109: iteration 106/107
# Epoch 109 --- loss:1.829, Epoch accuracy:7.35%, Validation loss:1.811, Validation accuracy:6.99%
#
# Epoch 109 --- epoch_autoencoder_loss1:0.913, epoch_autoencoder_loss2:0.92, epoch_classifier_loss:2.235
#
# Epoch 109 --- valid_autoencoder_loss1:0.903, valid_autoencoder_loss2:0.91, valid_classifier_loss:2.221
#
#
# Epoch 110: iteration 106/107
# Epoch 110 --- loss:1.825, Epoch accuracy:7.21%, Validation loss:1.810, Validation accuracy:6.99%
#
# Epoch 110 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.91, epoch_classifier_loss:2.232
#
# Epoch 110 --- valid_autoencoder_loss1:0.903, valid_autoencoder_loss2:0.91, valid_classifier_loss:2.221
#
#
# Epoch 111: iteration 106/107
# Epoch 111 --- loss:1.825, Epoch accuracy:7.67%, Validation loss:1.808, Validation accuracy:6.99%
#
# Epoch 111 --- epoch_autoencoder_loss1:0.912, epoch_autoencoder_loss2:0.91, epoch_classifier_loss:2.229
#
# Epoch 111 --- valid_autoencoder_loss1:0.902, valid_autoencoder_loss2:0.91, valid_classifier_loss:2.221
#
#
# Epoch 112: iteration 106/107
# Epoch 112 --- loss:1.823, Epoch accuracy:7.61%, Validation loss:1.807, Validation accuracy:6.99%
#
# Epoch 112 --- epoch_autoencoder_loss1:0.911, epoch_autoencoder_loss2:0.91, epoch_classifier_loss:2.226
#
# Epoch 112 --- valid_autoencoder_loss1:0.901, valid_autoencoder_loss2:0.91, valid_classifier_loss:2.221
#
#
# Epoch 113: iteration 106/107
# Epoch 113 --- loss:1.822, Epoch accuracy:7.38%, Validation loss:1.807, Validation accuracy:6.99%
#
# Epoch 113 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.91, epoch_classifier_loss:2.229
#
# Epoch 113 --- valid_autoencoder_loss1:0.901, valid_autoencoder_loss2:0.91, valid_classifier_loss:2.222
#
#
# Epoch 114: iteration 106/107
# Epoch 114 --- loss:1.821, Epoch accuracy:6.86%, Validation loss:1.805, Validation accuracy:6.99%
#
# Epoch 114 --- epoch_autoencoder_loss1:0.910, epoch_autoencoder_loss2:0.91, epoch_classifier_loss:2.230
#
# Epoch 114 --- valid_autoencoder_loss1:0.900, valid_autoencoder_loss2:0.91, valid_classifier_loss:2.221
#
#
# Epoch 115: iteration 106/107
# Epoch 115 --- loss:1.820, Epoch accuracy:7.90%, Validation loss:1.804, Validation accuracy:6.76%
#
# Epoch 115 --- epoch_autoencoder_loss1:0.909, epoch_autoencoder_loss2:0.91, epoch_classifier_loss:2.232
#
# Epoch 115 --- valid_autoencoder_loss1:0.899, valid_autoencoder_loss2:0.90, valid_classifier_loss:2.222
#
#
# Epoch 116: iteration 106/107
# Epoch 116 --- loss:1.820, Epoch accuracy:7.90%, Validation loss:1.802, Validation accuracy:6.99%
#
# Epoch 116 --- epoch_autoencoder_loss1:0.909, epoch_autoencoder_loss2:0.91, epoch_classifier_loss:2.229
#
# Epoch 116 --- valid_autoencoder_loss1:0.898, valid_autoencoder_loss2:0.90, valid_classifier_loss:2.221
#
#
# Epoch 117: iteration 106/107
# Epoch 117 --- loss:1.818, Epoch accuracy:6.92%, Validation loss:1.801, Validation accuracy:6.99%
#
# Epoch 117 --- epoch_autoencoder_loss1:0.908, epoch_autoencoder_loss2:0.91, epoch_classifier_loss:2.233
#
# Epoch 117 --- valid_autoencoder_loss1:0.898, valid_autoencoder_loss2:0.90, valid_classifier_loss:2.223
#
#
# Epoch 118: iteration 106/107
# Epoch 118 --- loss:1.817, Epoch accuracy:7.27%, Validation loss:1.801, Validation accuracy:6.76%
#
# Epoch 118 --- epoch_autoencoder_loss1:0.907, epoch_autoencoder_loss2:0.91, epoch_classifier_loss:2.229
#
# Epoch 118 --- valid_autoencoder_loss1:0.898, valid_autoencoder_loss2:0.90, valid_classifier_loss:2.223
#
#
# Epoch 119: iteration 106/107
# Epoch 119 --- loss:1.816, Epoch accuracy:7.53%, Validation loss:1.799, Validation accuracy:6.76%
#
# Epoch 119 --- epoch_autoencoder_loss1:0.907, epoch_autoencoder_loss2:0.91, epoch_classifier_loss:2.234
#
# Epoch 119 --- valid_autoencoder_loss1:0.897, valid_autoencoder_loss2:0.90, valid_classifier_loss:2.222
#
#
# Epoch 120: iteration 106/107
# Epoch 120 --- loss:1.814, Epoch accuracy:6.97%, Validation loss:1.798, Validation accuracy:6.76%
#
# Epoch 120 --- epoch_autoencoder_loss1:0.906, epoch_autoencoder_loss2:0.91, epoch_classifier_loss:2.234
#
# Epoch 120 --- valid_autoencoder_loss1:0.896, valid_autoencoder_loss2:0.90, valid_classifier_loss:2.223
#
#
# Epoch 121: iteration 106/107
# Epoch 121 --- loss:1.813, Epoch accuracy:7.03%, Validation loss:1.798, Validation accuracy:6.76%
#
# Epoch 121 --- epoch_autoencoder_loss1:0.905, epoch_autoencoder_loss2:0.91, epoch_classifier_loss:2.232
#
# Epoch 121 --- valid_autoencoder_loss1:0.896, valid_autoencoder_loss2:0.90, valid_classifier_loss:2.224
#
#
# Epoch 122: iteration 106/107
# Epoch 122 --- loss:1.812, Epoch accuracy:7.21%, Validation loss:1.796, Validation accuracy:6.76%
#
# Epoch 122 --- epoch_autoencoder_loss1:0.905, epoch_autoencoder_loss2:0.91, epoch_classifier_loss:2.237
#
# Epoch 122 --- valid_autoencoder_loss1:0.895, valid_autoencoder_loss2:0.90, valid_classifier_loss:2.225
#
#
# Epoch 123: iteration 106/107
# Epoch 123 --- loss:1.811, Epoch accuracy:7.06%, Validation loss:1.794, Validation accuracy:6.76%
#
# Epoch 123 --- epoch_autoencoder_loss1:0.904, epoch_autoencoder_loss2:0.91, epoch_classifier_loss:2.232
#
# Epoch 123 --- valid_autoencoder_loss1:0.894, valid_autoencoder_loss2:0.90, valid_classifier_loss:2.224
#
#
# Epoch 124: iteration 106/107
# Epoch 124 --- loss:1.810, Epoch accuracy:7.18%, Validation loss:1.793, Validation accuracy:6.53%
#
# Epoch 124 --- epoch_autoencoder_loss1:0.904, epoch_autoencoder_loss2:0.91, epoch_classifier_loss:2.231
#
# Epoch 124 --- valid_autoencoder_loss1:0.893, valid_autoencoder_loss2:0.90, valid_classifier_loss:2.224
#
#
# Epoch 125: iteration 106/107
# Epoch 125 --- loss:1.807, Epoch accuracy:7.44%, Validation loss:1.792, Validation accuracy:6.53%
#
# Epoch 125 --- epoch_autoencoder_loss1:0.902, epoch_autoencoder_loss2:0.91, epoch_classifier_loss:2.230
#
# Epoch 125 --- valid_autoencoder_loss1:0.893, valid_autoencoder_loss2:0.90, valid_classifier_loss:2.224
#
#
# Epoch 126: iteration 106/107
# Epoch 126 --- loss:1.807, Epoch accuracy:7.24%, Validation loss:1.791, Validation accuracy:6.53%
#
# Epoch 126 --- epoch_autoencoder_loss1:0.902, epoch_autoencoder_loss2:0.90, epoch_classifier_loss:2.237
#
# Epoch 126 --- valid_autoencoder_loss1:0.892, valid_autoencoder_loss2:0.90, valid_classifier_loss:2.224
#
#
# Epoch 127: iteration 106/107
# Epoch 127 --- loss:1.807, Epoch accuracy:6.71%, Validation loss:1.789, Validation accuracy:6.53%
#
# Epoch 127 --- epoch_autoencoder_loss1:0.902, epoch_autoencoder_loss2:0.90, epoch_classifier_loss:2.236
#
# Epoch 127 --- valid_autoencoder_loss1:0.891, valid_autoencoder_loss2:0.90, valid_classifier_loss:2.224
#
#
# Epoch 128: iteration 106/107
# Epoch 128 --- loss:1.804, Epoch accuracy:7.61%, Validation loss:1.789, Validation accuracy:6.53%
#
# Epoch 128 --- epoch_autoencoder_loss1:0.901, epoch_autoencoder_loss2:0.90, epoch_classifier_loss:2.234
#
# Epoch 128 --- valid_autoencoder_loss1:0.891, valid_autoencoder_loss2:0.90, valid_classifier_loss:2.224
#
#
# Epoch 129: iteration 106/107
# Epoch 129 --- loss:1.803, Epoch accuracy:6.86%, Validation loss:1.788, Validation accuracy:6.53%
#
# Epoch 129 --- epoch_autoencoder_loss1:0.900, epoch_autoencoder_loss2:0.90, epoch_classifier_loss:2.237
#
# Epoch 129 --- valid_autoencoder_loss1:0.891, valid_autoencoder_loss2:0.90, valid_classifier_loss:2.225
#
#
# Epoch 130: iteration 106/107
# Epoch 130 --- loss:1.802, Epoch accuracy:7.00%, Validation loss:1.788, Validation accuracy:6.53%
#
# Epoch 130 --- epoch_autoencoder_loss1:0.899, epoch_autoencoder_loss2:0.90, epoch_classifier_loss:2.232
#
# Epoch 130 --- valid_autoencoder_loss1:0.891, valid_autoencoder_loss2:0.90, valid_classifier_loss:2.227
#
#
# Epoch 131: iteration 106/107
# Epoch 131 --- loss:1.802, Epoch accuracy:7.64%, Validation loss:1.786, Validation accuracy:6.53%
#
# Epoch 131 --- epoch_autoencoder_loss1:0.899, epoch_autoencoder_loss2:0.90, epoch_classifier_loss:2.230
#
# Epoch 131 --- valid_autoencoder_loss1:0.889, valid_autoencoder_loss2:0.90, valid_classifier_loss:2.225
#
#
# Epoch 132: iteration 106/107
# Epoch 132 --- loss:1.800, Epoch accuracy:7.29%, Validation loss:1.784, Validation accuracy:6.53%
#
# Epoch 132 --- epoch_autoencoder_loss1:0.898, epoch_autoencoder_loss2:0.90, epoch_classifier_loss:2.233
#
# Epoch 132 --- valid_autoencoder_loss1:0.889, valid_autoencoder_loss2:0.90, valid_classifier_loss:2.226
#
#
# Epoch 133: iteration 106/107
# Epoch 133 --- loss:1.799, Epoch accuracy:7.09%, Validation loss:1.782, Validation accuracy:6.53%
#
# Epoch 133 --- epoch_autoencoder_loss1:0.898, epoch_autoencoder_loss2:0.90, epoch_classifier_loss:2.238
#
# Epoch 133 --- valid_autoencoder_loss1:0.888, valid_autoencoder_loss2:0.89, valid_classifier_loss:2.224
#
#
# Epoch 134: iteration 106/107
# Epoch 134 --- loss:1.798, Epoch accuracy:6.74%, Validation loss:1.782, Validation accuracy:6.53%
#
# Epoch 134 --- epoch_autoencoder_loss1:0.897, epoch_autoencoder_loss2:0.90, epoch_classifier_loss:2.237
#
# Epoch 134 --- valid_autoencoder_loss1:0.887, valid_autoencoder_loss2:0.89, valid_classifier_loss:2.226
#
#
# Epoch 135: iteration 106/107
# Epoch 135 --- loss:1.798, Epoch accuracy:7.38%, Validation loss:1.782, Validation accuracy:6.53%
#
# Epoch 135 --- epoch_autoencoder_loss1:0.897, epoch_autoencoder_loss2:0.90, epoch_classifier_loss:2.231
#
# Epoch 135 --- valid_autoencoder_loss1:0.888, valid_autoencoder_loss2:0.89, valid_classifier_loss:2.227
#
#
# Epoch 136: iteration 106/107
# Epoch 136 --- loss:1.796, Epoch accuracy:7.61%, Validation loss:1.780, Validation accuracy:6.53%
#
# Epoch 136 --- epoch_autoencoder_loss1:0.896, epoch_autoencoder_loss2:0.90, epoch_classifier_loss:2.236
#
# Epoch 136 --- valid_autoencoder_loss1:0.886, valid_autoencoder_loss2:0.89, valid_classifier_loss:2.226
#
#
# Epoch 137: iteration 106/107
# Epoch 137 --- loss:1.795, Epoch accuracy:7.70%, Validation loss:1.779, Validation accuracy:6.53%
#
# Epoch 137 --- epoch_autoencoder_loss1:0.895, epoch_autoencoder_loss2:0.90, epoch_classifier_loss:2.237
#
# Epoch 137 --- valid_autoencoder_loss1:0.886, valid_autoencoder_loss2:0.89, valid_classifier_loss:2.226
#
#
# Epoch 138: iteration 106/107
# Epoch 138 --- loss:1.794, Epoch accuracy:7.38%, Validation loss:1.779, Validation accuracy:6.53%
#
# Epoch 138 --- epoch_autoencoder_loss1:0.895, epoch_autoencoder_loss2:0.90, epoch_classifier_loss:2.232
#
# Epoch 138 --- valid_autoencoder_loss1:0.886, valid_autoencoder_loss2:0.89, valid_classifier_loss:2.227
#
#
# Epoch 139: iteration 106/107
# Epoch 139 --- loss:1.793, Epoch accuracy:6.83%, Validation loss:1.777, Validation accuracy:6.53%
#
# Epoch 139 --- epoch_autoencoder_loss1:0.895, epoch_autoencoder_loss2:0.90, epoch_classifier_loss:2.236
#
# Epoch 139 --- valid_autoencoder_loss1:0.885, valid_autoencoder_loss2:0.89, valid_classifier_loss:2.228
#
#
# Epoch 140: iteration 106/107
# Epoch 140 --- loss:1.791, Epoch accuracy:7.32%, Validation loss:1.777, Validation accuracy:6.53%
#
# Epoch 140 --- epoch_autoencoder_loss1:0.894, epoch_autoencoder_loss2:0.90, epoch_classifier_loss:2.237
#
# Epoch 140 --- valid_autoencoder_loss1:0.885, valid_autoencoder_loss2:0.89, valid_classifier_loss:2.227
#
#
# Epoch 141: iteration 106/107
# Epoch 141 --- loss:1.791, Epoch accuracy:7.09%, Validation loss:1.777, Validation accuracy:6.53%
#
# Epoch 141 --- epoch_autoencoder_loss1:0.893, epoch_autoencoder_loss2:0.90, epoch_classifier_loss:2.238
#
# Epoch 141 --- valid_autoencoder_loss1:0.885, valid_autoencoder_loss2:0.89, valid_classifier_loss:2.229
#
#
# Epoch 142: iteration 106/107
# Epoch 142 --- loss:1.789, Epoch accuracy:7.21%, Validation loss:1.774, Validation accuracy:6.53%
#
# Epoch 142 --- epoch_autoencoder_loss1:0.892, epoch_autoencoder_loss2:0.90, epoch_classifier_loss:2.238
#
# Epoch 142 --- valid_autoencoder_loss1:0.883, valid_autoencoder_loss2:0.89, valid_classifier_loss:2.228
#
#
# Epoch 143: iteration 106/107
# Epoch 143 --- loss:1.789, Epoch accuracy:7.09%, Validation loss:1.773, Validation accuracy:6.53%
#
# Epoch 143 --- epoch_autoencoder_loss1:0.892, epoch_autoencoder_loss2:0.90, epoch_classifier_loss:2.235
#
# Epoch 143 --- valid_autoencoder_loss1:0.883, valid_autoencoder_loss2:0.89, valid_classifier_loss:2.227
#
#
# Epoch 144: iteration 106/107
# ...
#
#
# Epoch 255: iteration 106/107
# Epoch 255 --- loss:1.701, Epoch accuracy:6.95%, Validation loss:1.686, Validation accuracy:6.29%
#
# Epoch 255 --- epoch_autoencoder_loss1:0.846, epoch_autoencoder_loss2:0.86, epoch_classifier_loss:2.239
#
# Epoch 255 --- valid_autoencoder_loss1:0.836, valid_autoencoder_loss2:0.85, valid_classifier_loss:2.241
#
#
# Epoch 256: iteration 106/107
# Epoch 256 --- loss:1.701, Epoch accuracy:6.95%, Validation loss:1.685, Validation accuracy:6.53%
#
# Epoch 256 --- epoch_autoencoder_loss1:0.846, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.247
#
# Epoch 256 --- valid_autoencoder_loss1:0.836, valid_autoencoder_loss2:0.85, valid_classifier_loss:2.242
#
#
# Epoch 257: iteration 106/107
# Epoch 257 --- loss:1.699, Epoch accuracy:7.18%, Validation loss:1.683, Validation accuracy:6.53%
#
# Epoch 257 --- epoch_autoencoder_loss1:0.845, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.243
#
# Epoch 257 --- valid_autoencoder_loss1:0.835, valid_autoencoder_loss2:0.85, valid_classifier_loss:2.241
#
#
# Epoch 258: iteration 106/107
# Epoch 258 --- loss:1.700, Epoch accuracy:7.32%, Validation loss:1.683, Validation accuracy:6.53%
#
# Epoch 258 --- epoch_autoencoder_loss1:0.845, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.243
#
# Epoch 258 --- valid_autoencoder_loss1:0.835, valid_autoencoder_loss2:0.85, valid_classifier_loss:2.242
#
#
# Epoch 259: iteration 106/107
# Epoch 259 --- loss:1.699, Epoch accuracy:7.06%, Validation loss:1.682, Validation accuracy:6.53%
#
# Epoch 259 --- epoch_autoencoder_loss1:0.845, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.242
#
# Epoch 259 --- valid_autoencoder_loss1:0.835, valid_autoencoder_loss2:0.85, valid_classifier_loss:2.240
#
#
# Epoch 260: iteration 106/107
# Epoch 260 --- loss:1.698, Epoch accuracy:7.32%, Validation loss:1.682, Validation accuracy:6.29%
#
# Epoch 260 --- epoch_autoencoder_loss1:0.844, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.242
#
# Epoch 260 --- valid_autoencoder_loss1:0.835, valid_autoencoder_loss2:0.85, valid_classifier_loss:2.243
#
#
# Epoch 261: iteration 106/107
# Epoch 261 --- loss:1.697, Epoch accuracy:6.97%, Validation loss:1.681, Validation accuracy:6.53%
#
# Epoch 261 --- epoch_autoencoder_loss1:0.844, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.239
#
# Epoch 261 --- valid_autoencoder_loss1:0.834, valid_autoencoder_loss2:0.85, valid_classifier_loss:2.240
#
#
# Epoch 262: iteration 106/107
# Epoch 262 --- loss:1.696, Epoch accuracy:7.06%, Validation loss:1.681, Validation accuracy:6.53%
#
# Epoch 262 --- epoch_autoencoder_loss1:0.843, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.244
#
# Epoch 262 --- valid_autoencoder_loss1:0.834, valid_autoencoder_loss2:0.85, valid_classifier_loss:2.241
#
#
# Epoch 263: iteration 106/107
# Epoch 263 --- loss:1.696, Epoch accuracy:6.97%, Validation loss:1.681, Validation accuracy:6.53%
#
# Epoch 263 --- epoch_autoencoder_loss1:0.843, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.241
#
# Epoch 263 --- valid_autoencoder_loss1:0.834, valid_autoencoder_loss2:0.85, valid_classifier_loss:2.242
#
#
# Epoch 264: iteration 106/107
# Epoch 264 --- loss:1.696, Epoch accuracy:6.77%, Validation loss:1.679, Validation accuracy:6.29%
#
# Epoch 264 --- epoch_autoencoder_loss1:0.843, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.245
#
# Epoch 264 --- valid_autoencoder_loss1:0.833, valid_autoencoder_loss2:0.85, valid_classifier_loss:2.242
#
#
# Epoch 265: iteration 106/107
# Epoch 265 --- loss:1.695, Epoch accuracy:7.09%, Validation loss:1.679, Validation accuracy:6.53%
#
# Epoch 265 --- epoch_autoencoder_loss1:0.843, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.243
#
# Epoch 265 --- valid_autoencoder_loss1:0.833, valid_autoencoder_loss2:0.85, valid_classifier_loss:2.242
#
#
# Epoch 266: iteration 106/107
# Epoch 266 --- loss:1.693, Epoch accuracy:7.47%, Validation loss:1.677, Validation accuracy:6.29%
#
# Epoch 266 --- epoch_autoencoder_loss1:0.842, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.240
#
# Epoch 266 --- valid_autoencoder_loss1:0.832, valid_autoencoder_loss2:0.85, valid_classifier_loss:2.242
#
#
# Epoch 267: iteration 106/107
# Epoch 267 --- loss:1.694, Epoch accuracy:7.12%, Validation loss:1.677, Validation accuracy:6.53%
#
# Epoch 267 --- epoch_autoencoder_loss1:0.842, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.246
#
# Epoch 267 --- valid_autoencoder_loss1:0.832, valid_autoencoder_loss2:0.85, valid_classifier_loss:2.241
#
#
# Epoch 268: iteration 106/107
# Epoch 268 --- loss:1.692, Epoch accuracy:7.27%, Validation loss:1.677, Validation accuracy:6.53%
#
# Epoch 268 --- epoch_autoencoder_loss1:0.841, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.243
#
# Epoch 268 --- valid_autoencoder_loss1:0.832, valid_autoencoder_loss2:0.85, valid_classifier_loss:2.242
#
#
# Epoch 269: iteration 106/107
# Epoch 269 --- loss:1.693, Epoch accuracy:7.00%, Validation loss:1.676, Validation accuracy:6.53%
#
# Epoch 269 --- epoch_autoencoder_loss1:0.842, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.239
#
# Epoch 269 --- valid_autoencoder_loss1:0.831, valid_autoencoder_loss2:0.84, valid_classifier_loss:2.241
#
#
# Epoch 270: iteration 106/107
# Epoch 270 --- loss:1.691, Epoch accuracy:6.97%, Validation loss:1.675, Validation accuracy:6.53%
#
# Epoch 270 --- epoch_autoencoder_loss1:0.840, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.245
#
# Epoch 270 --- valid_autoencoder_loss1:0.831, valid_autoencoder_loss2:0.84, valid_classifier_loss:2.242
#
#
# Epoch 271: iteration 106/107
# Epoch 271 --- loss:1.691, Epoch accuracy:6.66%, Validation loss:1.675, Validation accuracy:6.29%
#
# Epoch 271 --- epoch_autoencoder_loss1:0.841, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.246
#
# Epoch 271 --- valid_autoencoder_loss1:0.831, valid_autoencoder_loss2:0.84, valid_classifier_loss:2.242
#
#
# Epoch 272: iteration 106/107
# Epoch 272 --- loss:1.691, Epoch accuracy:6.36%, Validation loss:1.674, Validation accuracy:6.29%
#
# Epoch 272 --- epoch_autoencoder_loss1:0.841, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.248
#
# Epoch 272 --- valid_autoencoder_loss1:0.830, valid_autoencoder_loss2:0.84, valid_classifier_loss:2.241
#
#
# Epoch 273: iteration 106/107
# Epoch 273 --- loss:1.690, Epoch accuracy:7.18%, Validation loss:1.674, Validation accuracy:6.53%
#
# Epoch 273 --- epoch_autoencoder_loss1:0.840, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.243
#
# Epoch 273 --- valid_autoencoder_loss1:0.830, valid_autoencoder_loss2:0.84, valid_classifier_loss:2.242
#
#
# Epoch 274: iteration 106/107
# Epoch 274 --- loss:1.689, Epoch accuracy:6.86%, Validation loss:1.673, Validation accuracy:6.53%
#
# Epoch 274 --- epoch_autoencoder_loss1:0.839, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.242
#
# Epoch 274 --- valid_autoencoder_loss1:0.830, valid_autoencoder_loss2:0.84, valid_classifier_loss:2.242
#
#
# Epoch 275: iteration 106/107
# Epoch 275 --- loss:1.689, Epoch accuracy:6.48%, Validation loss:1.673, Validation accuracy:6.53%
#
# Epoch 275 --- epoch_autoencoder_loss1:0.839, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.246
#
# Epoch 275 --- valid_autoencoder_loss1:0.830, valid_autoencoder_loss2:0.84, valid_classifier_loss:2.242
#
#
# Epoch 276: iteration 106/107
# Epoch 276 --- loss:1.688, Epoch accuracy:6.92%, Validation loss:1.671, Validation accuracy:6.29%
#
# Epoch 276 --- epoch_autoencoder_loss1:0.839, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.246
#
# Epoch 276 --- valid_autoencoder_loss1:0.829, valid_autoencoder_loss2:0.84, valid_classifier_loss:2.241
#
#
# Epoch 277: iteration 106/107
# Epoch 277 --- loss:1.687, Epoch accuracy:7.24%, Validation loss:1.671, Validation accuracy:6.53%
#
# Epoch 277 --- epoch_autoencoder_loss1:0.838, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.241
#
# Epoch 277 --- valid_autoencoder_loss1:0.829, valid_autoencoder_loss2:0.84, valid_classifier_loss:2.241
#
#
# Epoch 278: iteration 106/107
# Epoch 278 --- loss:1.687, Epoch accuracy:7.00%, Validation loss:1.670, Validation accuracy:6.53%
#
# Epoch 278 --- epoch_autoencoder_loss1:0.838, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.243
#
# Epoch 278 --- valid_autoencoder_loss1:0.828, valid_autoencoder_loss2:0.84, valid_classifier_loss:2.242
#
#
# Epoch 279: iteration 106/107
# Epoch 279 --- loss:1.685, Epoch accuracy:6.63%, Validation loss:1.670, Validation accuracy:6.29%
#
# Epoch 279 --- epoch_autoencoder_loss1:0.837, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.242
#
# Epoch 279 --- valid_autoencoder_loss1:0.828, valid_autoencoder_loss2:0.84, valid_classifier_loss:2.242
#
#
# Epoch 280: iteration 106/107
# Epoch 280 --- loss:1.685, Epoch accuracy:7.29%, Validation loss:1.670, Validation accuracy:6.29%
#
# Epoch 280 --- epoch_autoencoder_loss1:0.837, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.245
#
# Epoch 280 --- valid_autoencoder_loss1:0.828, valid_autoencoder_loss2:0.84, valid_classifier_loss:2.243
#
#
# Epoch 281: iteration 106/107
# Epoch 281 --- loss:1.684, Epoch accuracy:7.44%, Validation loss:1.669, Validation accuracy:6.53%
#
# Epoch 281 --- epoch_autoencoder_loss1:0.837, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.243
#
# Epoch 281 --- valid_autoencoder_loss1:0.827, valid_autoencoder_loss2:0.84, valid_classifier_loss:2.243
#
#
# Epoch 282: iteration 106/107
# Epoch 282 --- loss:1.685, Epoch accuracy:6.74%, Validation loss:1.668, Validation accuracy:6.53%
#
# Epoch 282 --- epoch_autoencoder_loss1:0.837, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.245
#
# Epoch 282 --- valid_autoencoder_loss1:0.827, valid_autoencoder_loss2:0.84, valid_classifier_loss:2.241
#
#
# Epoch 283: iteration 106/107
# Epoch 283 --- loss:1.684, Epoch accuracy:7.21%, Validation loss:1.668, Validation accuracy:6.29%
#
# Epoch 283 --- epoch_autoencoder_loss1:0.836, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.247
#
# Epoch 283 --- valid_autoencoder_loss1:0.827, valid_autoencoder_loss2:0.84, valid_classifier_loss:2.242
#
#
# Epoch 284: iteration 106/107
# Epoch 284 --- loss:1.684, Epoch accuracy:6.89%, Validation loss:1.668, Validation accuracy:6.29%
#
# Epoch 284 --- epoch_autoencoder_loss1:0.837, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.247
#
# Epoch 284 --- valid_autoencoder_loss1:0.827, valid_autoencoder_loss2:0.84, valid_classifier_loss:2.243
#
#
# Epoch 285: iteration 106/107
# Epoch 285 --- loss:1.682, Epoch accuracy:6.83%, Validation loss:1.667, Validation accuracy:6.29%
#
# Epoch 285 --- epoch_autoencoder_loss1:0.836, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.247
#
# Epoch 285 --- valid_autoencoder_loss1:0.826, valid_autoencoder_loss2:0.84, valid_classifier_loss:2.243
#
#
# Epoch 286: iteration 106/107
# Epoch 286 --- loss:1.681, Epoch accuracy:7.09%, Validation loss:1.666, Validation accuracy:6.06%
#
# Epoch 286 --- epoch_autoencoder_loss1:0.835, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.242
#
# Epoch 286 --- valid_autoencoder_loss1:0.826, valid_autoencoder_loss2:0.84, valid_classifier_loss:2.243
#
#
# Epoch 287: iteration 106/107
# Epoch 287 --- loss:1.681, Epoch accuracy:6.51%, Validation loss:1.665, Validation accuracy:6.06%
#
# Epoch 287 --- epoch_autoencoder_loss1:0.835, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.237
#
# Epoch 287 --- valid_autoencoder_loss1:0.825, valid_autoencoder_loss2:0.84, valid_classifier_loss:2.243
#
#
# Epoch 288: iteration 106/107
# Epoch 288 --- loss:1.680, Epoch accuracy:6.97%, Validation loss:1.664, Validation accuracy:6.06%
#
# Epoch 288 --- epoch_autoencoder_loss1:0.835, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.245
#
# Epoch 288 --- valid_autoencoder_loss1:0.825, valid_autoencoder_loss2:0.84, valid_classifier_loss:2.242
#
#
# Epoch 289: iteration 106/107
# Epoch 289 --- loss:1.681, Epoch accuracy:7.09%, Validation loss:1.665, Validation accuracy:6.29%
#
# Epoch 289 --- epoch_autoencoder_loss1:0.835, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.249
#
# Epoch 289 --- valid_autoencoder_loss1:0.825, valid_autoencoder_loss2:0.84, valid_classifier_loss:2.244
#
#
# Epoch 290: iteration 106/107
# Epoch 290 --- loss:1.680, Epoch accuracy:7.03%, Validation loss:1.663, Validation accuracy:6.06%
#
# Epoch 290 --- epoch_autoencoder_loss1:0.834, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.242
#
# Epoch 290 --- valid_autoencoder_loss1:0.824, valid_autoencoder_loss2:0.84, valid_classifier_loss:2.241
#
#
# Epoch 291: iteration 106/107
# Epoch 291 --- loss:1.679, Epoch accuracy:6.57%, Validation loss:1.663, Validation accuracy:6.53%
#
# Epoch 291 --- epoch_autoencoder_loss1:0.834, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.242
#
# Epoch 291 --- valid_autoencoder_loss1:0.824, valid_autoencoder_loss2:0.84, valid_classifier_loss:2.243
#
#
# Epoch 292: iteration 106/107
# Epoch 292 --- loss:1.678, Epoch accuracy:6.80%, Validation loss:1.663, Validation accuracy:6.06%
#
# Epoch 292 --- epoch_autoencoder_loss1:0.834, epoch_autoencoder_loss2:0.84, epoch_classifier_loss:2.245
#
# Epoch 292 --- valid_autoencoder_loss1:0.824, valid_autoencoder_loss2:0.84, valid_classifier_loss:2.244
#
#
# Epoch 293: iteration 106/107
# Epoch 293 --- loss:1.679, Epoch accuracy:6.63%, Validation loss:1.661, Validation accuracy:6.06%
#
# Epoch 293 --- epoch_autoencoder_loss1:0.834, epoch_autoencoder_loss2:0.85, epoch_classifier_loss:2.246
#
# Epoch 293 --- valid_autoencoder_loss1:0.823, valid_autoencoder_loss2:0.84, valid_classifier_loss:2.242
#
#
# Epoch 294: iteration 106/107
# Epoch 294 --- loss:1.679, Epoch accuracy:6.80%, Validation loss:1.661, Validation accuracy:6.06%
#
# Epoch 294 --- epoch_autoencoder_loss1:0.834, epoch_autoencoder_loss2:0.84, epoch_classifier_loss:2.247
#
# Epoch 294 --- valid_autoencoder_loss1:0.823, valid_autoencoder_loss2:0.84, valid_classifier_loss:2.244
#
#
# Epoch 295: iteration 106/107
# Epoch 295 --- loss:1.677, Epoch accuracy:6.89%, Validation loss:1.661, Validation accuracy:6.06%
#
# Epoch 295 --- epoch_autoencoder_loss1:0.833, epoch_autoencoder_loss2:0.84, epoch_classifier_loss:2.247
#
# Epoch 295 --- valid_autoencoder_loss1:0.823, valid_autoencoder_loss2:0.84, valid_classifier_loss:2.244
#
#
# Epoch 296: iteration 106/107
# Epoch 296 --- loss:1.676, Epoch accuracy:7.61%, Validation loss:1.660, Validation accuracy:6.06%
#
# Epoch 296 --- epoch_autoencoder_loss1:0.832, epoch_autoencoder_loss2:0.84, epoch_classifier_loss:2.245
#
# Epoch 296 --- valid_autoencoder_loss1:0.823, valid_autoencoder_loss2:0.84, valid_classifier_loss:2.244
#
#
# Epoch 297: iteration 106/107
# Epoch 297 --- loss:1.676, Epoch accuracy:6.45%, Validation loss:1.659, Validation accuracy:6.06%
#
# Epoch 297 --- epoch_autoencoder_loss1:0.832, epoch_autoencoder_loss2:0.84, epoch_classifier_loss:2.246
#
# Epoch 297 --- valid_autoencoder_loss1:0.822, valid_autoencoder_loss2:0.84, valid_classifier_loss:2.243
#
#
# Epoch 298: iteration 1/107
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-a3e7b86a405c> in <cell line: 5>()
#       3
#       4 # train it!
# ----> 5 train(optimizer, model, num_epochs, X_train, y_train, X_valid, y_valid)
#
# <ipython-input-40-ea29976a49ea> in train(optimizer, model, num_epochs, X_train, Y_train, X_valid, Y_valid)
#      47             Y_tensor = torch.tensor(Y, dtype=torch.long,device=device)
#      48             # Pass input tensors thru 1 training step (fwd+backwards pass)
# ---> 49             loss, acc, autoencoder_loss1, autoencoder_loss2, classifier_loss = train_step(X_tensor,Y_tensor)
#      50
#      51             # aggregate batch accuracy to measure progress of entire epoch
#
# <ipython-input-32-58ec8d2324c5> in train_step(X, Y)
#      25
#      26         # update network parameters based on gradient stored (by calling loss.backward())
# ---> 27         optimizer.step()
#      28
#      29         # zero out gradients for next pass
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#     375
#     376                 # call optimizer step post hooks
# --> 377                 for post_hook in chain(self._optimizer_step_post_hooks.values(), _global_optimizer_post_hooks.values()):
#     378                     post_hook(self, args, kwargs)
#     379
#
# KeyboardInterrupt:

# %%
optimizer = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

# %%
# choose number of epochs higher than reasonable so we can manually stop training
num_epochs = 1500

# train it!
train(optimizer, model, num_epochs, X_train, y_train, X_valid, y_valid)
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 875: iteration 106/107
# Epoch 875 --- loss:1.404, Epoch accuracy:6.68%, Validation loss:1.375, Validation accuracy:7.46%
#
# Epoch 875 --- epoch_autoencoder_loss1:0.693, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.241
#
# Epoch 875 --- valid_autoencoder_loss1:0.678, valid_autoencoder_loss2:0.70, valid_classifier_loss:2.242
#
#
# Epoch 876: iteration 106/107
# Epoch 876 --- loss:1.404, Epoch accuracy:6.39%, Validation loss:1.374, Validation accuracy:7.46%
#
# Epoch 876 --- epoch_autoencoder_loss1:0.693, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.240
#
# Epoch 876 --- valid_autoencoder_loss1:0.678, valid_autoencoder_loss2:0.70, valid_classifier_loss:2.244
#
#
# Epoch 877: iteration 106/107
# Epoch 877 --- loss:1.404, Epoch accuracy:6.48%, Validation loss:1.374, Validation accuracy:7.46%
#
# Epoch 877 --- epoch_autoencoder_loss1:0.693, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.243
#
# Epoch 877 --- valid_autoencoder_loss1:0.678, valid_autoencoder_loss2:0.70, valid_classifier_loss:2.243
#
#
# Epoch 878: iteration 106/107
# Epoch 878 --- loss:1.403, Epoch accuracy:5.96%, Validation loss:1.374, Validation accuracy:7.46%
#
# Epoch 878 --- epoch_autoencoder_loss1:0.693, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.242
#
# Epoch 878 --- valid_autoencoder_loss1:0.678, valid_autoencoder_loss2:0.70, valid_classifier_loss:2.242
#
#
# Epoch 879: iteration 106/107
# Epoch 879 --- loss:1.403, Epoch accuracy:6.89%, Validation loss:1.374, Validation accuracy:7.46%
#
# Epoch 879 --- epoch_autoencoder_loss1:0.693, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.243
#
# Epoch 879 --- valid_autoencoder_loss1:0.678, valid_autoencoder_loss2:0.70, valid_classifier_loss:2.243
#
#
# Epoch 880: iteration 106/107
# Epoch 880 --- loss:1.404, Epoch accuracy:6.02%, Validation loss:1.374, Validation accuracy:7.46%
#
# Epoch 880 --- epoch_autoencoder_loss1:0.693, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.241
#
# Epoch 880 --- valid_autoencoder_loss1:0.678, valid_autoencoder_loss2:0.70, valid_classifier_loss:2.245
#
#
# Epoch 881: iteration 106/107
# Epoch 881 --- loss:1.403, Epoch accuracy:6.10%, Validation loss:1.373, Validation accuracy:7.46%
#
# Epoch 881 --- epoch_autoencoder_loss1:0.693, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.241
#
# Epoch 881 --- valid_autoencoder_loss1:0.678, valid_autoencoder_loss2:0.70, valid_classifier_loss:2.244
#
#
# Epoch 882: iteration 106/107
# Epoch 882 --- loss:1.403, Epoch accuracy:6.39%, Validation loss:1.373, Validation accuracy:7.46%
#
# Epoch 882 --- epoch_autoencoder_loss1:0.693, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.240
#
# Epoch 882 --- valid_autoencoder_loss1:0.677, valid_autoencoder_loss2:0.70, valid_classifier_loss:2.244
#
#
# Epoch 883: iteration 106/107
# Epoch 883 --- loss:1.404, Epoch accuracy:6.42%, Validation loss:1.373, Validation accuracy:7.46%
#
# Epoch 883 --- epoch_autoencoder_loss1:0.693, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.240
#
# Epoch 883 --- valid_autoencoder_loss1:0.677, valid_autoencoder_loss2:0.70, valid_classifier_loss:2.244
#
#
# Epoch 884: iteration 106/107
# Epoch 884 --- loss:1.403, Epoch accuracy:6.34%, Validation loss:1.373, Validation accuracy:7.46%
#
# Epoch 884 --- epoch_autoencoder_loss1:0.693, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.240
#
# Epoch 884 --- valid_autoencoder_loss1:0.677, valid_autoencoder_loss2:0.70, valid_classifier_loss:2.243
#
#
# Epoch 885: iteration 106/107
# Epoch 885 --- loss:1.403, Epoch accuracy:6.19%, Validation loss:1.373, Validation accuracy:7.46%
#
# Epoch 885 --- epoch_autoencoder_loss1:0.693, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.240
#
# Epoch 885 --- valid_autoencoder_loss1:0.677, valid_autoencoder_loss2:0.70, valid_classifier_loss:2.244
#
#
# Epoch 886: iteration 106/107
# Epoch 886 --- loss:1.402, Epoch accuracy:6.19%, Validation loss:1.372, Validation accuracy:7.46%
#
# Epoch 886 --- epoch_autoencoder_loss1:0.693, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.242
#
# Epoch 886 --- valid_autoencoder_loss1:0.677, valid_autoencoder_loss2:0.70, valid_classifier_loss:2.245
#
#
# Epoch 887: iteration 106/107
# Epoch 887 --- loss:1.402, Epoch accuracy:6.68%, Validation loss:1.372, Validation accuracy:7.46%
#
# Epoch 887 --- epoch_autoencoder_loss1:0.693, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.241
#
# Epoch 887 --- valid_autoencoder_loss1:0.677, valid_autoencoder_loss2:0.70, valid_classifier_loss:2.243
#
#
# Epoch 888: iteration 106/107
# Epoch 888 --- loss:1.402, Epoch accuracy:6.39%, Validation loss:1.372, Validation accuracy:7.46%
#
# Epoch 888 --- epoch_autoencoder_loss1:0.692, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.240
#
# Epoch 888 --- valid_autoencoder_loss1:0.677, valid_autoencoder_loss2:0.70, valid_classifier_loss:2.244
#
#
# Epoch 889: iteration 106/107
# Epoch 889 --- loss:1.402, Epoch accuracy:6.28%, Validation loss:1.372, Validation accuracy:7.46%
#
# Epoch 889 --- epoch_autoencoder_loss1:0.693, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.239
#
# Epoch 889 --- valid_autoencoder_loss1:0.677, valid_autoencoder_loss2:0.70, valid_classifier_loss:2.243
#
#
# Epoch 890: iteration 106/107
# Epoch 890 --- loss:1.401, Epoch accuracy:6.13%, Validation loss:1.372, Validation accuracy:7.46%
#
# Epoch 890 --- epoch_autoencoder_loss1:0.692, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.240
#
# Epoch 890 --- valid_autoencoder_loss1:0.677, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.243
#
#
# Epoch 891: iteration 106/107
# Epoch 891 --- loss:1.402, Epoch accuracy:6.31%, Validation loss:1.372, Validation accuracy:7.46%
#
# Epoch 891 --- epoch_autoencoder_loss1:0.692, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.239
#
# Epoch 891 --- valid_autoencoder_loss1:0.677, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.244
#
#
# Epoch 892: iteration 106/107
# Epoch 892 --- loss:1.402, Epoch accuracy:5.96%, Validation loss:1.371, Validation accuracy:7.46%
#
# Epoch 892 --- epoch_autoencoder_loss1:0.692, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.240
#
# Epoch 892 --- valid_autoencoder_loss1:0.677, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.244
#
#
# Epoch 893: iteration 106/107
# Epoch 893 --- loss:1.401, Epoch accuracy:7.18%, Validation loss:1.371, Validation accuracy:7.46%
#
# Epoch 893 --- epoch_autoencoder_loss1:0.692, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.241
#
# Epoch 893 --- valid_autoencoder_loss1:0.677, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.243
#
#
# Epoch 894: iteration 106/107
# Epoch 894 --- loss:1.401, Epoch accuracy:6.31%, Validation loss:1.371, Validation accuracy:7.69%
#
# Epoch 894 --- epoch_autoencoder_loss1:0.692, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.239
#
# Epoch 894 --- valid_autoencoder_loss1:0.677, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 895: iteration 106/107
# Epoch 895 --- loss:1.400, Epoch accuracy:6.71%, Validation loss:1.371, Validation accuracy:7.46%
#
# Epoch 895 --- epoch_autoencoder_loss1:0.692, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.241
#
# Epoch 895 --- valid_autoencoder_loss1:0.677, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.243
#
#
# Epoch 896: iteration 106/107
# Epoch 896 --- loss:1.400, Epoch accuracy:6.22%, Validation loss:1.371, Validation accuracy:7.46%
#
# Epoch 896 --- epoch_autoencoder_loss1:0.692, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.243
#
# Epoch 896 --- valid_autoencoder_loss1:0.677, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.245
#
#
# Epoch 897: iteration 106/107
# Epoch 897 --- loss:1.400, Epoch accuracy:6.54%, Validation loss:1.370, Validation accuracy:7.46%
#
# Epoch 897 --- epoch_autoencoder_loss1:0.692, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.240
#
# Epoch 897 --- valid_autoencoder_loss1:0.676, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 898: iteration 106/107
# Epoch 898 --- loss:1.401, Epoch accuracy:5.90%, Validation loss:1.370, Validation accuracy:7.69%
#
# Epoch 898 --- epoch_autoencoder_loss1:0.692, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.242
#
# Epoch 898 --- valid_autoencoder_loss1:0.676, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.243
#
#
# Epoch 899: iteration 106/107
# Epoch 899 --- loss:1.401, Epoch accuracy:6.60%, Validation loss:1.370, Validation accuracy:7.46%
#
# Epoch 899 --- epoch_autoencoder_loss1:0.692, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.238
#
# Epoch 899 --- valid_autoencoder_loss1:0.676, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.243
#
#
# Epoch 900: iteration 106/107
# Epoch 900 --- loss:1.400, Epoch accuracy:6.19%, Validation loss:1.370, Validation accuracy:7.46%
#
# Epoch 900 --- epoch_autoencoder_loss1:0.692, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.240
#
# Epoch 900 --- valid_autoencoder_loss1:0.676, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.243
#
#
# Epoch 901: iteration 106/107
# Epoch 901 --- loss:1.400, Epoch accuracy:6.74%, Validation loss:1.370, Validation accuracy:7.46%
#
# Epoch 901 --- epoch_autoencoder_loss1:0.692, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.240
#
# Epoch 901 --- valid_autoencoder_loss1:0.676, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.243
#
#
# Epoch 902: iteration 106/107
# Epoch 902 --- loss:1.400, Epoch accuracy:6.45%, Validation loss:1.370, Validation accuracy:7.46%
#
# Epoch 902 --- epoch_autoencoder_loss1:0.692, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.242
#
# Epoch 902 --- valid_autoencoder_loss1:0.676, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.244
#
#
# Epoch 903: iteration 106/107
# Epoch 903 --- loss:1.399, Epoch accuracy:6.04%, Validation loss:1.370, Validation accuracy:7.46%
#
# Epoch 903 --- epoch_autoencoder_loss1:0.691, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.241
#
# Epoch 903 --- valid_autoencoder_loss1:0.676, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 904: iteration 106/107
# Epoch 904 --- loss:1.400, Epoch accuracy:6.31%, Validation loss:1.369, Validation accuracy:7.69%
#
# Epoch 904 --- epoch_autoencoder_loss1:0.691, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.242
#
# Epoch 904 --- valid_autoencoder_loss1:0.676, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.243
#
#
# Epoch 905: iteration 106/107
# Epoch 905 --- loss:1.398, Epoch accuracy:6.16%, Validation loss:1.369, Validation accuracy:7.46%
#
# Epoch 905 --- epoch_autoencoder_loss1:0.691, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.242
#
# Epoch 905 --- valid_autoencoder_loss1:0.676, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.244
#
#
# Epoch 906: iteration 106/107
# Epoch 906 --- loss:1.398, Epoch accuracy:6.42%, Validation loss:1.369, Validation accuracy:7.46%
#
# Epoch 906 --- epoch_autoencoder_loss1:0.691, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.239
#
# Epoch 906 --- valid_autoencoder_loss1:0.676, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.244
#
#
# Epoch 907: iteration 106/107
# Epoch 907 --- loss:1.398, Epoch accuracy:6.39%, Validation loss:1.369, Validation accuracy:7.46%
#
# Epoch 907 --- epoch_autoencoder_loss1:0.691, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.240
#
# Epoch 907 --- valid_autoencoder_loss1:0.676, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.241
#
#
# Epoch 908: iteration 106/107
# Epoch 908 --- loss:1.398, Epoch accuracy:6.16%, Validation loss:1.369, Validation accuracy:7.46%
#
# Epoch 908 --- epoch_autoencoder_loss1:0.691, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.238
#
# Epoch 908 --- valid_autoencoder_loss1:0.676, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 909: iteration 106/107
# Epoch 909 --- loss:1.398, Epoch accuracy:6.51%, Validation loss:1.369, Validation accuracy:7.46%
#
# Epoch 909 --- epoch_autoencoder_loss1:0.691, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.240
#
# Epoch 909 --- valid_autoencoder_loss1:0.676, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 910: iteration 106/107
# Epoch 910 --- loss:1.398, Epoch accuracy:6.34%, Validation loss:1.368, Validation accuracy:7.46%
#
# Epoch 910 --- epoch_autoencoder_loss1:0.691, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.240
#
# Epoch 910 --- valid_autoencoder_loss1:0.675, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.245
#
#
# Epoch 911: iteration 106/107
# Epoch 911 --- loss:1.398, Epoch accuracy:6.25%, Validation loss:1.368, Validation accuracy:7.46%
#
# Epoch 911 --- epoch_autoencoder_loss1:0.691, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.236
#
# Epoch 911 --- valid_autoencoder_loss1:0.675, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.243
#
#
# Epoch 912: iteration 106/107
# Epoch 912 --- loss:1.398, Epoch accuracy:6.07%, Validation loss:1.368, Validation accuracy:7.46%
#
# Epoch 912 --- epoch_autoencoder_loss1:0.691, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.242
#
# Epoch 912 --- valid_autoencoder_loss1:0.675, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.243
#
#
# Epoch 913: iteration 106/107
# Epoch 913 --- loss:1.397, Epoch accuracy:6.34%, Validation loss:1.368, Validation accuracy:7.46%
#
# Epoch 913 --- epoch_autoencoder_loss1:0.691, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.240
#
# Epoch 913 --- valid_autoencoder_loss1:0.675, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 914: iteration 106/107
# Epoch 914 --- loss:1.398, Epoch accuracy:6.25%, Validation loss:1.368, Validation accuracy:7.69%
#
# Epoch 914 --- epoch_autoencoder_loss1:0.691, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.242
#
# Epoch 914 --- valid_autoencoder_loss1:0.675, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.243
#
#
# Epoch 915: iteration 106/107
# Epoch 915 --- loss:1.398, Epoch accuracy:6.36%, Validation loss:1.368, Validation accuracy:7.46%
#
# Epoch 915 --- epoch_autoencoder_loss1:0.691, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.240
#
# Epoch 915 --- valid_autoencoder_loss1:0.675, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 916: iteration 106/107
# Epoch 916 --- loss:1.397, Epoch accuracy:6.48%, Validation loss:1.367, Validation accuracy:7.69%
#
# Epoch 916 --- epoch_autoencoder_loss1:0.691, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.240
#
# Epoch 916 --- valid_autoencoder_loss1:0.675, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 917: iteration 106/107
# Epoch 917 --- loss:1.397, Epoch accuracy:6.13%, Validation loss:1.367, Validation accuracy:7.46%
#
# Epoch 917 --- epoch_autoencoder_loss1:0.690, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.241
#
# Epoch 917 --- valid_autoencoder_loss1:0.675, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 918: iteration 106/107
# Epoch 918 --- loss:1.397, Epoch accuracy:6.22%, Validation loss:1.367, Validation accuracy:7.46%
#
# Epoch 918 --- epoch_autoencoder_loss1:0.690, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.240
#
# Epoch 918 --- valid_autoencoder_loss1:0.675, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.244
#
#
# Epoch 919: iteration 106/107
# Epoch 919 --- loss:1.396, Epoch accuracy:6.39%, Validation loss:1.367, Validation accuracy:7.46%
#
# Epoch 919 --- epoch_autoencoder_loss1:0.690, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.240
#
# Epoch 919 --- valid_autoencoder_loss1:0.675, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 920: iteration 106/107
# Epoch 920 --- loss:1.396, Epoch accuracy:6.04%, Validation loss:1.367, Validation accuracy:7.46%
#
# Epoch 920 --- epoch_autoencoder_loss1:0.690, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.243
#
# Epoch 920 --- valid_autoencoder_loss1:0.675, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 921: iteration 106/107
# Epoch 921 --- loss:1.397, Epoch accuracy:6.34%, Validation loss:1.366, Validation accuracy:7.69%
#
# Epoch 921 --- epoch_autoencoder_loss1:0.690, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.239
#
# Epoch 921 --- valid_autoencoder_loss1:0.675, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 922: iteration 106/107
# Epoch 922 --- loss:1.396, Epoch accuracy:6.19%, Validation loss:1.366, Validation accuracy:7.46%
#
# Epoch 922 --- epoch_autoencoder_loss1:0.690, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.245
#
# Epoch 922 --- valid_autoencoder_loss1:0.675, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.241
#
#
# Epoch 923: iteration 106/107
# Epoch 923 --- loss:1.396, Epoch accuracy:6.45%, Validation loss:1.366, Validation accuracy:7.23%
#
# Epoch 923 --- epoch_autoencoder_loss1:0.690, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.241
#
# Epoch 923 --- valid_autoencoder_loss1:0.675, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 924: iteration 106/107
# Epoch 924 --- loss:1.396, Epoch accuracy:6.34%, Validation loss:1.366, Validation accuracy:7.69%
#
# Epoch 924 --- epoch_autoencoder_loss1:0.690, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.241
#
# Epoch 924 --- valid_autoencoder_loss1:0.674, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 925: iteration 106/107
# Epoch 925 --- loss:1.395, Epoch accuracy:5.93%, Validation loss:1.366, Validation accuracy:7.69%
#
# Epoch 925 --- epoch_autoencoder_loss1:0.690, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.239
#
# Epoch 925 --- valid_autoencoder_loss1:0.675, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 926: iteration 106/107
# Epoch 926 --- loss:1.395, Epoch accuracy:5.55%, Validation loss:1.365, Validation accuracy:7.46%
#
# Epoch 926 --- epoch_autoencoder_loss1:0.690, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.243
#
# Epoch 926 --- valid_autoencoder_loss1:0.674, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.243
#
#
# Epoch 927: iteration 106/107
# Epoch 927 --- loss:1.395, Epoch accuracy:6.77%, Validation loss:1.365, Validation accuracy:7.69%
#
# Epoch 927 --- epoch_autoencoder_loss1:0.690, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.240
#
# Epoch 927 --- valid_autoencoder_loss1:0.674, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 928: iteration 106/107
# Epoch 928 --- loss:1.396, Epoch accuracy:6.51%, Validation loss:1.365, Validation accuracy:7.46%
#
# Epoch 928 --- epoch_autoencoder_loss1:0.690, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.239
#
# Epoch 928 --- valid_autoencoder_loss1:0.674, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 929: iteration 106/107
# Epoch 929 --- loss:1.395, Epoch accuracy:6.51%, Validation loss:1.365, Validation accuracy:7.69%
#
# Epoch 929 --- epoch_autoencoder_loss1:0.690, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.238
#
# Epoch 929 --- valid_autoencoder_loss1:0.674, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.241
#
#
# Epoch 930: iteration 106/107
# Epoch 930 --- loss:1.395, Epoch accuracy:6.25%, Validation loss:1.365, Validation accuracy:7.69%
#
# Epoch 930 --- epoch_autoencoder_loss1:0.689, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.238
#
# Epoch 930 --- valid_autoencoder_loss1:0.674, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 931: iteration 106/107
# Epoch 931 --- loss:1.395, Epoch accuracy:6.16%, Validation loss:1.364, Validation accuracy:7.69%
#
# Epoch 931 --- epoch_autoencoder_loss1:0.690, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.241
#
# Epoch 931 --- valid_autoencoder_loss1:0.674, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.241
#
#
# Epoch 932: iteration 106/107
# Epoch 932 --- loss:1.394, Epoch accuracy:6.16%, Validation loss:1.364, Validation accuracy:7.46%
#
# Epoch 932 --- epoch_autoencoder_loss1:0.689, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.241
#
# Epoch 932 --- valid_autoencoder_loss1:0.674, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 933: iteration 106/107
# Epoch 933 --- loss:1.396, Epoch accuracy:6.02%, Validation loss:1.364, Validation accuracy:7.46%
#
# Epoch 933 --- epoch_autoencoder_loss1:0.690, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.241
#
# Epoch 933 --- valid_autoencoder_loss1:0.674, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.244
#
#
# Epoch 934: iteration 106/107
# Epoch 934 --- loss:1.394, Epoch accuracy:6.45%, Validation loss:1.364, Validation accuracy:7.69%
#
# Epoch 934 --- epoch_autoencoder_loss1:0.689, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.240
#
# Epoch 934 --- valid_autoencoder_loss1:0.674, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.241
#
#
# Epoch 935: iteration 106/107
# Epoch 935 --- loss:1.395, Epoch accuracy:6.89%, Validation loss:1.364, Validation accuracy:7.69%
#
# Epoch 935 --- epoch_autoencoder_loss1:0.690, epoch_autoencoder_loss2:0.71, epoch_classifier_loss:2.241
#
# Epoch 935 --- valid_autoencoder_loss1:0.674, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.241
#
#
# Epoch 936: iteration 106/107
# Epoch 936 --- loss:1.393, Epoch accuracy:6.71%, Validation loss:1.364, Validation accuracy:7.69%
#
# Epoch 936 --- epoch_autoencoder_loss1:0.689, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.238
#
# Epoch 936 --- valid_autoencoder_loss1:0.674, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.243
#
#
# Epoch 937: iteration 106/107
# Epoch 937 --- loss:1.393, Epoch accuracy:6.57%, Validation loss:1.364, Validation accuracy:7.69%
#
# Epoch 937 --- epoch_autoencoder_loss1:0.689, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.240
#
# Epoch 937 --- valid_autoencoder_loss1:0.674, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 938: iteration 106/107
# Epoch 938 --- loss:1.394, Epoch accuracy:6.71%, Validation loss:1.364, Validation accuracy:7.23%
#
# Epoch 938 --- epoch_autoencoder_loss1:0.689, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.239
#
# Epoch 938 --- valid_autoencoder_loss1:0.674, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.241
#
#
# Epoch 939: iteration 106/107
# Epoch 939 --- loss:1.394, Epoch accuracy:6.68%, Validation loss:1.364, Validation accuracy:7.23%
#
# Epoch 939 --- epoch_autoencoder_loss1:0.689, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.239
#
# Epoch 939 --- valid_autoencoder_loss1:0.674, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.243
#
#
# Epoch 940: iteration 106/107
# Epoch 940 --- loss:1.393, Epoch accuracy:6.31%, Validation loss:1.363, Validation accuracy:7.69%
#
# Epoch 940 --- epoch_autoencoder_loss1:0.689, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.241
#
# Epoch 940 --- valid_autoencoder_loss1:0.673, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 941: iteration 106/107
# Epoch 941 --- loss:1.393, Epoch accuracy:5.70%, Validation loss:1.363, Validation accuracy:7.69%
#
# Epoch 941 --- epoch_autoencoder_loss1:0.689, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.241
#
# Epoch 941 --- valid_autoencoder_loss1:0.674, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.244
#
#
# Epoch 942: iteration 106/107
# Epoch 942 --- loss:1.394, Epoch accuracy:6.28%, Validation loss:1.363, Validation accuracy:7.46%
#
# Epoch 942 --- epoch_autoencoder_loss1:0.689, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.240
#
# Epoch 942 --- valid_autoencoder_loss1:0.673, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.245
#
#
# Epoch 943: iteration 106/107
# Epoch 943 --- loss:1.393, Epoch accuracy:6.34%, Validation loss:1.363, Validation accuracy:7.69%
#
# Epoch 943 --- epoch_autoencoder_loss1:0.689, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.239
#
# Epoch 943 --- valid_autoencoder_loss1:0.673, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.243
#
#
# Epoch 944: iteration 106/107
# Epoch 944 --- loss:1.392, Epoch accuracy:6.02%, Validation loss:1.362, Validation accuracy:7.69%
#
# Epoch 944 --- epoch_autoencoder_loss1:0.689, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.240
#
# Epoch 944 --- valid_autoencoder_loss1:0.673, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.243
#
#
# Epoch 945: iteration 106/107
# Epoch 945 --- loss:1.393, Epoch accuracy:6.22%, Validation loss:1.363, Validation accuracy:7.69%
#
# Epoch 945 --- epoch_autoencoder_loss1:0.689, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.240
#
# Epoch 945 --- valid_autoencoder_loss1:0.673, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.240
#
#
# Epoch 946: iteration 106/107
# Epoch 946 --- loss:1.392, Epoch accuracy:6.66%, Validation loss:1.362, Validation accuracy:7.69%
#
# Epoch 946 --- epoch_autoencoder_loss1:0.689, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.239
#
# Epoch 946 --- valid_autoencoder_loss1:0.673, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.241
#
#
# Epoch 947: iteration 106/107
# Epoch 947 --- loss:1.393, Epoch accuracy:6.34%, Validation loss:1.362, Validation accuracy:7.69%
#
# Epoch 947 --- epoch_autoencoder_loss1:0.689, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.238
#
# Epoch 947 --- valid_autoencoder_loss1:0.673, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 948: iteration 106/107
# Epoch 948 --- loss:1.391, Epoch accuracy:6.39%, Validation loss:1.362, Validation accuracy:7.69%
#
# Epoch 948 --- epoch_autoencoder_loss1:0.688, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.240
#
# Epoch 948 --- valid_autoencoder_loss1:0.673, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.243
#
#
# Epoch 949: iteration 106/107
# Epoch 949 --- loss:1.392, Epoch accuracy:6.13%, Validation loss:1.362, Validation accuracy:7.69%
#
# Epoch 949 --- epoch_autoencoder_loss1:0.688, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.238
#
# Epoch 949 --- valid_autoencoder_loss1:0.673, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 950: iteration 106/107
# Epoch 950 --- loss:1.392, Epoch accuracy:6.22%, Validation loss:1.361, Validation accuracy:7.69%
#
# Epoch 950 --- epoch_autoencoder_loss1:0.688, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.240
#
# Epoch 950 --- valid_autoencoder_loss1:0.673, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 951: iteration 106/107
# Epoch 951 --- loss:1.391, Epoch accuracy:5.96%, Validation loss:1.361, Validation accuracy:7.69%
#
# Epoch 951 --- epoch_autoencoder_loss1:0.688, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.241
#
# Epoch 951 --- valid_autoencoder_loss1:0.673, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 952: iteration 106/107
# Epoch 952 --- loss:1.392, Epoch accuracy:6.74%, Validation loss:1.361, Validation accuracy:7.69%
#
# Epoch 952 --- epoch_autoencoder_loss1:0.688, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.241
#
# Epoch 952 --- valid_autoencoder_loss1:0.673, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 953: iteration 106/107
# Epoch 953 --- loss:1.391, Epoch accuracy:6.60%, Validation loss:1.361, Validation accuracy:7.69%
#
# Epoch 953 --- epoch_autoencoder_loss1:0.688, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.241
#
# Epoch 953 --- valid_autoencoder_loss1:0.673, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.241
#
#
# Epoch 954: iteration 106/107
# Epoch 954 --- loss:1.392, Epoch accuracy:5.96%, Validation loss:1.361, Validation accuracy:7.69%
#
# Epoch 954 --- epoch_autoencoder_loss1:0.688, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.241
#
# Epoch 954 --- valid_autoencoder_loss1:0.673, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.243
#
#
# Epoch 955: iteration 106/107
# Epoch 955 --- loss:1.391, Epoch accuracy:6.10%, Validation loss:1.361, Validation accuracy:7.23%
#
# Epoch 955 --- epoch_autoencoder_loss1:0.688, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.239
#
# Epoch 955 --- valid_autoencoder_loss1:0.673, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 956: iteration 106/107
# Epoch 956 --- loss:1.390, Epoch accuracy:6.10%, Validation loss:1.360, Validation accuracy:7.23%
#
# Epoch 956 --- epoch_autoencoder_loss1:0.688, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.240
#
# Epoch 956 --- valid_autoencoder_loss1:0.672, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 957: iteration 106/107
# Epoch 957 --- loss:1.390, Epoch accuracy:6.22%, Validation loss:1.360, Validation accuracy:7.69%
#
# Epoch 957 --- epoch_autoencoder_loss1:0.687, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.240
#
# Epoch 957 --- valid_autoencoder_loss1:0.672, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 958: iteration 106/107
# Epoch 958 --- loss:1.391, Epoch accuracy:6.16%, Validation loss:1.360, Validation accuracy:7.69%
#
# Epoch 958 --- epoch_autoencoder_loss1:0.688, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.242
#
# Epoch 958 --- valid_autoencoder_loss1:0.672, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 959: iteration 106/107
# Epoch 959 --- loss:1.390, Epoch accuracy:5.99%, Validation loss:1.360, Validation accuracy:7.69%
#
# Epoch 959 --- epoch_autoencoder_loss1:0.688, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.237
#
# Epoch 959 --- valid_autoencoder_loss1:0.672, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 960: iteration 106/107
# Epoch 960 --- loss:1.390, Epoch accuracy:6.19%, Validation loss:1.360, Validation accuracy:7.46%
#
# Epoch 960 --- epoch_autoencoder_loss1:0.688, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.241
#
# Epoch 960 --- valid_autoencoder_loss1:0.672, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.243
#
#
# Epoch 961: iteration 106/107
# Epoch 961 --- loss:1.390, Epoch accuracy:6.80%, Validation loss:1.360, Validation accuracy:7.23%
#
# Epoch 961 --- epoch_autoencoder_loss1:0.687, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.241
#
# Epoch 961 --- valid_autoencoder_loss1:0.672, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 962: iteration 106/107
# Epoch 962 --- loss:1.390, Epoch accuracy:6.19%, Validation loss:1.360, Validation accuracy:7.46%
#
# Epoch 962 --- epoch_autoencoder_loss1:0.688, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.240
#
# Epoch 962 --- valid_autoencoder_loss1:0.672, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.240
#
#
# Epoch 963: iteration 106/107
# Epoch 963 --- loss:1.389, Epoch accuracy:6.51%, Validation loss:1.359, Validation accuracy:7.69%
#
# Epoch 963 --- epoch_autoencoder_loss1:0.687, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.239
#
# Epoch 963 --- valid_autoencoder_loss1:0.672, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 964: iteration 106/107
# Epoch 964 --- loss:1.390, Epoch accuracy:6.04%, Validation loss:1.359, Validation accuracy:7.23%
#
# Epoch 964 --- epoch_autoencoder_loss1:0.687, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.239
#
# Epoch 964 --- valid_autoencoder_loss1:0.672, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.243
#
#
# Epoch 965: iteration 106/107
# Epoch 965 --- loss:1.390, Epoch accuracy:5.78%, Validation loss:1.359, Validation accuracy:7.46%
#
# Epoch 965 --- epoch_autoencoder_loss1:0.688, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.243
#
# Epoch 965 --- valid_autoencoder_loss1:0.672, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 966: iteration 106/107
# Epoch 966 --- loss:1.389, Epoch accuracy:6.28%, Validation loss:1.359, Validation accuracy:7.46%
#
# Epoch 966 --- epoch_autoencoder_loss1:0.687, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.241
#
# Epoch 966 --- valid_autoencoder_loss1:0.672, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.243
#
#
# Epoch 967: iteration 106/107
# Epoch 967 --- loss:1.389, Epoch accuracy:6.31%, Validation loss:1.359, Validation accuracy:7.69%
#
# Epoch 967 --- epoch_autoencoder_loss1:0.687, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.238
#
# Epoch 967 --- valid_autoencoder_loss1:0.672, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 968: iteration 106/107
# Epoch 968 --- loss:1.388, Epoch accuracy:6.60%, Validation loss:1.358, Validation accuracy:7.46%
#
# Epoch 968 --- epoch_autoencoder_loss1:0.687, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.237
#
# Epoch 968 --- valid_autoencoder_loss1:0.672, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 969: iteration 106/107
# Epoch 969 --- loss:1.389, Epoch accuracy:6.74%, Validation loss:1.359, Validation accuracy:7.69%
#
# Epoch 969 --- epoch_autoencoder_loss1:0.687, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.238
#
# Epoch 969 --- valid_autoencoder_loss1:0.672, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 970: iteration 106/107
# Epoch 970 --- loss:1.387, Epoch accuracy:6.42%, Validation loss:1.358, Validation accuracy:7.69%
#
# Epoch 970 --- epoch_autoencoder_loss1:0.686, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.239
#
# Epoch 970 --- valid_autoencoder_loss1:0.672, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 971: iteration 106/107
# Epoch 971 --- loss:1.388, Epoch accuracy:6.31%, Validation loss:1.358, Validation accuracy:7.46%
#
# Epoch 971 --- epoch_autoencoder_loss1:0.687, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.237
#
# Epoch 971 --- valid_autoencoder_loss1:0.671, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.241
#
#
# Epoch 972: iteration 106/107
# Epoch 972 --- loss:1.388, Epoch accuracy:6.28%, Validation loss:1.358, Validation accuracy:7.46%
#
# Epoch 972 --- epoch_autoencoder_loss1:0.686, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.239
#
# Epoch 972 --- valid_autoencoder_loss1:0.671, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 973: iteration 106/107
# Epoch 973 --- loss:1.388, Epoch accuracy:6.10%, Validation loss:1.358, Validation accuracy:7.46%
#
# Epoch 973 --- epoch_autoencoder_loss1:0.687, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.241
#
# Epoch 973 --- valid_autoencoder_loss1:0.671, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.241
#
#
# Epoch 974: iteration 106/107
# Epoch 974 --- loss:1.388, Epoch accuracy:6.31%, Validation loss:1.358, Validation accuracy:7.46%
#
# Epoch 974 --- epoch_autoencoder_loss1:0.687, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.239
#
# Epoch 974 --- valid_autoencoder_loss1:0.671, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.239
#
#
# Epoch 975: iteration 106/107
# Epoch 975 --- loss:1.387, Epoch accuracy:6.22%, Validation loss:1.358, Validation accuracy:7.46%
#
# Epoch 975 --- epoch_autoencoder_loss1:0.686, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.240
#
# Epoch 975 --- valid_autoencoder_loss1:0.671, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.241
#
#
# Epoch 976: iteration 106/107
# Epoch 976 --- loss:1.387, Epoch accuracy:6.39%, Validation loss:1.357, Validation accuracy:7.46%
#
# Epoch 976 --- epoch_autoencoder_loss1:0.687, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.240
#
# Epoch 976 --- valid_autoencoder_loss1:0.671, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 977: iteration 106/107
# Epoch 977 --- loss:1.388, Epoch accuracy:6.42%, Validation loss:1.357, Validation accuracy:7.46%
#
# Epoch 977 --- epoch_autoencoder_loss1:0.687, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.239
#
# Epoch 977 --- valid_autoencoder_loss1:0.671, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 978: iteration 106/107
# Epoch 978 --- loss:1.388, Epoch accuracy:6.07%, Validation loss:1.357, Validation accuracy:7.46%
#
# Epoch 978 --- epoch_autoencoder_loss1:0.687, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.242
#
# Epoch 978 --- valid_autoencoder_loss1:0.671, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.241
#
#
# Epoch 979: iteration 106/107
# Epoch 979 --- loss:1.387, Epoch accuracy:6.83%, Validation loss:1.357, Validation accuracy:7.46%
#
# Epoch 979 --- epoch_autoencoder_loss1:0.686, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.239
#
# Epoch 979 --- valid_autoencoder_loss1:0.671, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.240
#
#
# Epoch 980: iteration 106/107
# Epoch 980 --- loss:1.387, Epoch accuracy:6.68%, Validation loss:1.357, Validation accuracy:7.46%
#
# Epoch 980 --- epoch_autoencoder_loss1:0.686, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.242
#
# Epoch 980 --- valid_autoencoder_loss1:0.671, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.241
#
#
# Epoch 981: iteration 106/107
# Epoch 981 --- loss:1.387, Epoch accuracy:6.45%, Validation loss:1.357, Validation accuracy:7.46%
#
# Epoch 981 --- epoch_autoencoder_loss1:0.686, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.239
#
# Epoch 981 --- valid_autoencoder_loss1:0.671, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.241
#
#
# Epoch 982: iteration 106/107
# Epoch 982 --- loss:1.387, Epoch accuracy:6.16%, Validation loss:1.357, Validation accuracy:7.69%
#
# Epoch 982 --- epoch_autoencoder_loss1:0.686, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.240
#
# Epoch 982 --- valid_autoencoder_loss1:0.671, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.241
#
#
# Epoch 983: iteration 106/107
# Epoch 983 --- loss:1.387, Epoch accuracy:6.77%, Validation loss:1.356, Validation accuracy:7.46%
#
# Epoch 983 --- epoch_autoencoder_loss1:0.686, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.238
#
# Epoch 983 --- valid_autoencoder_loss1:0.671, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.242
#
#
# Epoch 984: iteration 106/107
# Epoch 984 --- loss:1.386, Epoch accuracy:6.71%, Validation loss:1.356, Validation accuracy:7.46%
#
# Epoch 984 --- epoch_autoencoder_loss1:0.686, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.241
#
# Epoch 984 --- valid_autoencoder_loss1:0.671, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.241
#
#
# Epoch 985: iteration 106/107
# Epoch 985 --- loss:1.386, Epoch accuracy:6.16%, Validation loss:1.356, Validation accuracy:7.46%
#
# Epoch 985 --- epoch_autoencoder_loss1:0.686, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.237
#
# Epoch 985 --- valid_autoencoder_loss1:0.671, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.240
#
#
# Epoch 986: iteration 106/107
# Epoch 986 --- loss:1.386, Epoch accuracy:6.68%, Validation loss:1.356, Validation accuracy:7.46%
#
# Epoch 986 --- epoch_autoencoder_loss1:0.686, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.238
#
# Epoch 986 --- valid_autoencoder_loss1:0.671, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.241
#
#
# Epoch 987: iteration 106/107
# Epoch 987 --- loss:1.386, Epoch accuracy:6.66%, Validation loss:1.356, Validation accuracy:7.69%
#
# Epoch 987 --- epoch_autoencoder_loss1:0.686, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.239
#
# Epoch 987 --- valid_autoencoder_loss1:0.670, valid_autoencoder_loss2:0.69, valid_classifier_loss:2.241
#
#
# Epoch 988: iteration 106/107
# Epoch 988 --- loss:1.385, Epoch accuracy:6.51%, Validation loss:1.355, Validation accuracy:7.46%
#
# Epoch 988 --- epoch_autoencoder_loss1:0.686, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.240
#
# Epoch 988 --- valid_autoencoder_loss1:0.670, valid_autoencoder_loss2:0.68, valid_classifier_loss:2.241
#
#
# Epoch 989: iteration 106/107
# Epoch 989 --- loss:1.385, Epoch accuracy:6.74%, Validation loss:1.355, Validation accuracy:7.46%
#
# Epoch 989 --- epoch_autoencoder_loss1:0.686, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.238
#
# Epoch 989 --- valid_autoencoder_loss1:0.670, valid_autoencoder_loss2:0.68, valid_classifier_loss:2.240
#
#
# Epoch 990: iteration 106/107
# Epoch 990 --- loss:1.385, Epoch accuracy:6.28%, Validation loss:1.355, Validation accuracy:7.46%
#
# Epoch 990 --- epoch_autoencoder_loss1:0.685, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.239
#
# Epoch 990 --- valid_autoencoder_loss1:0.670, valid_autoencoder_loss2:0.68, valid_classifier_loss:2.241
#
#
# Epoch 991: iteration 106/107
# Epoch 991 --- loss:1.386, Epoch accuracy:6.07%, Validation loss:1.355, Validation accuracy:7.46%
#
# Epoch 991 --- epoch_autoencoder_loss1:0.686, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.245
#
# Epoch 991 --- valid_autoencoder_loss1:0.670, valid_autoencoder_loss2:0.68, valid_classifier_loss:2.240
#
#
# Epoch 992: iteration 106/107
# Epoch 992 --- loss:1.385, Epoch accuracy:6.86%, Validation loss:1.355, Validation accuracy:7.69%
#
# Epoch 992 --- epoch_autoencoder_loss1:0.685, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.239
#
# Epoch 992 --- valid_autoencoder_loss1:0.670, valid_autoencoder_loss2:0.68, valid_classifier_loss:2.240
#
#
# Epoch 993: iteration 106/107
# Epoch 993 --- loss:1.385, Epoch accuracy:6.04%, Validation loss:1.355, Validation accuracy:7.46%
#
# Epoch 993 --- epoch_autoencoder_loss1:0.686, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.240
#
# Epoch 993 --- valid_autoencoder_loss1:0.670, valid_autoencoder_loss2:0.68, valid_classifier_loss:2.241
#
#
# Epoch 994: iteration 106/107
# Epoch 994 --- loss:1.385, Epoch accuracy:6.28%, Validation loss:1.355, Validation accuracy:7.46%
#
# Epoch 994 --- epoch_autoencoder_loss1:0.685, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.239
#
# Epoch 994 --- valid_autoencoder_loss1:0.670, valid_autoencoder_loss2:0.68, valid_classifier_loss:2.241
#
#
# Epoch 995: iteration 106/107
# Epoch 995 --- loss:1.384, Epoch accuracy:6.34%, Validation loss:1.355, Validation accuracy:7.46%
#
# Epoch 995 --- epoch_autoencoder_loss1:0.685, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.240
#
# Epoch 995 --- valid_autoencoder_loss1:0.670, valid_autoencoder_loss2:0.68, valid_classifier_loss:2.242
#
#
# Epoch 996: iteration 106/107
# Epoch 996 --- loss:1.385, Epoch accuracy:6.48%, Validation loss:1.354, Validation accuracy:7.46%
#
# Epoch 996 --- epoch_autoencoder_loss1:0.685, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.240
#
# Epoch 996 --- valid_autoencoder_loss1:0.670, valid_autoencoder_loss2:0.68, valid_classifier_loss:2.241
#
#
# Epoch 997: iteration 106/107
# Epoch 997 --- loss:1.385, Epoch accuracy:6.39%, Validation loss:1.354, Validation accuracy:7.46%
#
# Epoch 997 --- epoch_autoencoder_loss1:0.685, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.239
#
# Epoch 997 --- valid_autoencoder_loss1:0.670, valid_autoencoder_loss2:0.68, valid_classifier_loss:2.240
#
#
# Epoch 998: iteration 106/107
# Epoch 998 --- loss:1.384, Epoch accuracy:5.90%, Validation loss:1.354, Validation accuracy:7.46%
#
# Epoch 998 --- epoch_autoencoder_loss1:0.685, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.239
#
# Epoch 998 --- valid_autoencoder_loss1:0.670, valid_autoencoder_loss2:0.68, valid_classifier_loss:2.241
#
#
# Epoch 999: iteration 106/107
# Epoch 999 --- loss:1.385, Epoch accuracy:6.45%, Validation loss:1.354, Validation accuracy:7.46%
#
# Epoch 999 --- epoch_autoencoder_loss1:0.685, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.240
#
# Epoch 999 --- valid_autoencoder_loss1:0.670, valid_autoencoder_loss2:0.68, valid_classifier_loss:2.240
#
#
# Epoch 1000: iteration 106/107
# Epoch 1000 --- loss:1.384, Epoch accuracy:6.22%, Validation loss:1.354, Validation accuracy:7.46%
#
# Epoch 1000 --- epoch_autoencoder_loss1:0.685, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.241
#
# Epoch 1000 --- valid_autoencoder_loss1:0.670, valid_autoencoder_loss2:0.68, valid_classifier_loss:2.240
#
#
# Epoch 1001: iteration 106/107
# Epoch 1001 --- loss:1.384, Epoch accuracy:6.04%, Validation loss:1.353, Validation accuracy:7.46%
#
# Epoch 1001 --- epoch_autoencoder_loss1:0.685, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.240
#
# Epoch 1001 --- valid_autoencoder_loss1:0.670, valid_autoencoder_loss2:0.68, valid_classifier_loss:2.241
#
#
# Epoch 1002: iteration 106/107
# Epoch 1002 --- loss:1.384, Epoch accuracy:6.71%, Validation loss:1.354, Validation accuracy:7.69%
#
# Epoch 1002 --- epoch_autoencoder_loss1:0.685, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.239
#
# Epoch 1002 --- valid_autoencoder_loss1:0.670, valid_autoencoder_loss2:0.68, valid_classifier_loss:2.238
#
#
# Epoch 1003: iteration 106/107
# Epoch 1003 --- loss:1.383, Epoch accuracy:6.22%, Validation loss:1.353, Validation accuracy:7.69%
#
# Epoch 1003 --- epoch_autoencoder_loss1:0.685, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.238
#
# Epoch 1003 --- valid_autoencoder_loss1:0.670, valid_autoencoder_loss2:0.68, valid_classifier_loss:2.240
#
#
# Epoch 1004: iteration 106/107
# Epoch 1004 --- loss:1.383, Epoch accuracy:6.07%, Validation loss:1.353, Validation accuracy:7.46%
#
# Epoch 1004 --- epoch_autoencoder_loss1:0.685, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.239
#
# Epoch 1004 --- valid_autoencoder_loss1:0.669, valid_autoencoder_loss2:0.68, valid_classifier_loss:2.242
#
#
# Epoch 1005: iteration 106/107
# Epoch 1005 --- loss:1.383, Epoch accuracy:6.68%, Validation loss:1.353, Validation accuracy:7.69%
#
# Epoch 1005 --- epoch_autoencoder_loss1:0.685, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.237
#
# Epoch 1005 --- valid_autoencoder_loss1:0.669, valid_autoencoder_loss2:0.68, valid_classifier_loss:2.241
#
#
# Epoch 1006: iteration 106/107
# Epoch 1006 --- loss:1.383, Epoch accuracy:5.75%, Validation loss:1.353, Validation accuracy:7.46%
#
# Epoch 1006 --- epoch_autoencoder_loss1:0.685, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.242
#
# Epoch 1006 --- valid_autoencoder_loss1:0.669, valid_autoencoder_loss2:0.68, valid_classifier_loss:2.242
#
#
# Epoch 1007: iteration 106/107
# Epoch 1007 --- loss:1.382, Epoch accuracy:6.16%, Validation loss:1.353, Validation accuracy:7.46%
#
# Epoch 1007 --- epoch_autoencoder_loss1:0.684, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.240
#
# Epoch 1007 --- valid_autoencoder_loss1:0.669, valid_autoencoder_loss2:0.68, valid_classifier_loss:2.240
#
#
# Epoch 1008: iteration 106/107
# Epoch 1008 --- loss:1.383, Epoch accuracy:6.68%, Validation loss:1.352, Validation accuracy:7.69%
#
# Epoch 1008 --- epoch_autoencoder_loss1:0.685, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.237
#
# Epoch 1008 --- valid_autoencoder_loss1:0.669, valid_autoencoder_loss2:0.68, valid_classifier_loss:2.240
#
#
# Epoch 1009: iteration 106/107
# Epoch 1009 --- loss:1.382, Epoch accuracy:6.10%, Validation loss:1.352, Validation accuracy:7.46%
#
# Epoch 1009 --- epoch_autoencoder_loss1:0.684, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.241
#
# Epoch 1009 --- valid_autoencoder_loss1:0.669, valid_autoencoder_loss2:0.68, valid_classifier_loss:2.240
#
#
# Epoch 1010: iteration 106/107
# Epoch 1010 --- loss:1.382, Epoch accuracy:6.07%, Validation loss:1.352, Validation accuracy:7.69%
#
# Epoch 1010 --- epoch_autoencoder_loss1:0.684, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.240
#
# Epoch 1010 --- valid_autoencoder_loss1:0.669, valid_autoencoder_loss2:0.68, valid_classifier_loss:2.241
#
#
# Epoch 1011: iteration 106/107
# Epoch 1011 --- loss:1.382, Epoch accuracy:6.45%, Validation loss:1.352, Validation accuracy:7.46%
#
# Epoch 1011 --- epoch_autoencoder_loss1:0.684, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.239
#
# Epoch 1011 --- valid_autoencoder_loss1:0.669, valid_autoencoder_loss2:0.68, valid_classifier_loss:2.239
#
#
# Epoch 1012: iteration 106/107
# Epoch 1012 --- loss:1.383, Epoch accuracy:6.02%, Validation loss:1.352, Validation accuracy:7.46%
#
# Epoch 1012 --- epoch_autoencoder_loss1:0.685, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.237
#
# Epoch 1012 --- valid_autoencoder_loss1:0.669, valid_autoencoder_loss2:0.68, valid_classifier_loss:2.240
#
#
# Epoch 1013: iteration 106/107
# Epoch 1013 --- loss:1.383, Epoch accuracy:6.02%, Validation loss:1.352, Validation accuracy:7.93%
#
# Epoch 1013 --- epoch_autoencoder_loss1:0.685, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.242
#
# Epoch 1013 --- valid_autoencoder_loss1:0.669, valid_autoencoder_loss2:0.68, valid_classifier_loss:2.239
#
#
# Epoch 1014: iteration 106/107
# Epoch 1014 --- loss:1.382, Epoch accuracy:6.31%, Validation loss:1.352, Validation accuracy:7.46%
#
# Epoch 1014 --- epoch_autoencoder_loss1:0.684, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.238
#
# Epoch 1014 --- valid_autoencoder_loss1:0.669, valid_autoencoder_loss2:0.68, valid_classifier_loss:2.241
#
#
# Epoch 1015: iteration 106/107
# Epoch 1015 --- loss:1.382, Epoch accuracy:6.34%, Validation loss:1.352, Validation accuracy:7.46%
#
# Epoch 1015 --- epoch_autoencoder_loss1:0.684, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.240
#
# Epoch 1015 --- valid_autoencoder_loss1:0.669, valid_autoencoder_loss2:0.68, valid_classifier_loss:2.240
#
#
# Epoch 1016: iteration 106/107
# Epoch 1016 --- loss:1.382, Epoch accuracy:6.48%, Validation loss:1.351, Validation accuracy:7.46%
#
# Epoch 1016 --- epoch_autoencoder_loss1:0.685, epoch_autoencoder_loss2:0.70, epoch_classifier_loss:2.238
#
# Epoch 1016 --- valid_autoencoder_loss1:0.669, valid_autoencoder_loss2:0.68, valid_classifier_loss:2.240
#
#
# Epoch 1017: iteration 106/107
# Epoch 1017 --- loss:1.381, Epoch accuracy:6.34%, Validation loss:1.351, Validation accuracy:7.69%
#
# ...
#
#
# Epoch 1453: iteration 106/107
# Epoch 1453 --- loss:1.333, Epoch accuracy:6.48%, Validation loss:1.302, Validation accuracy:7.23%
#
# Epoch 1453 --- epoch_autoencoder_loss1:0.663, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.231
#
# Epoch 1453 --- valid_autoencoder_loss1:0.648, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.229
#
#
# Epoch 1454: iteration 106/107
# Epoch 1454 --- loss:1.332, Epoch accuracy:6.83%, Validation loss:1.302, Validation accuracy:6.99%
#
# Epoch 1454 --- epoch_autoencoder_loss1:0.663, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.227
#
# Epoch 1454 --- valid_autoencoder_loss1:0.648, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.230
#
#
# Epoch 1455: iteration 106/107
# Epoch 1455 --- loss:1.333, Epoch accuracy:6.13%, Validation loss:1.302, Validation accuracy:7.46%
#
# Epoch 1455 --- epoch_autoencoder_loss1:0.663, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.229
#
# Epoch 1455 --- valid_autoencoder_loss1:0.647, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.230
#
#
# Epoch 1456: iteration 106/107
# Epoch 1456 --- loss:1.333, Epoch accuracy:6.39%, Validation loss:1.302, Validation accuracy:6.99%
#
# Epoch 1456 --- epoch_autoencoder_loss1:0.663, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.228
#
# Epoch 1456 --- valid_autoencoder_loss1:0.647, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.230
#
#
# Epoch 1457: iteration 106/107
# Epoch 1457 --- loss:1.333, Epoch accuracy:6.16%, Validation loss:1.302, Validation accuracy:7.46%
#
# Epoch 1457 --- epoch_autoencoder_loss1:0.663, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.231
#
# Epoch 1457 --- valid_autoencoder_loss1:0.647, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.230
#
#
# Epoch 1458: iteration 106/107
# Epoch 1458 --- loss:1.332, Epoch accuracy:6.36%, Validation loss:1.302, Validation accuracy:7.46%
#
# Epoch 1458 --- epoch_autoencoder_loss1:0.663, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.231
#
# Epoch 1458 --- valid_autoencoder_loss1:0.647, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.230
#
#
# Epoch 1459: iteration 106/107
# Epoch 1459 --- loss:1.332, Epoch accuracy:6.22%, Validation loss:1.301, Validation accuracy:7.46%
#
# Epoch 1459 --- epoch_autoencoder_loss1:0.662, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.227
#
# Epoch 1459 --- valid_autoencoder_loss1:0.647, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.230
#
#
# Epoch 1460: iteration 106/107
# Epoch 1460 --- loss:1.332, Epoch accuracy:6.25%, Validation loss:1.301, Validation accuracy:7.46%
#
# Epoch 1460 --- epoch_autoencoder_loss1:0.663, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.228
#
# Epoch 1460 --- valid_autoencoder_loss1:0.647, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.232
#
#
# Epoch 1461: iteration 106/107
# Epoch 1461 --- loss:1.332, Epoch accuracy:6.45%, Validation loss:1.301, Validation accuracy:6.99%
#
# Epoch 1461 --- epoch_autoencoder_loss1:0.663, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.229
#
# Epoch 1461 --- valid_autoencoder_loss1:0.647, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.230
#
#
# Epoch 1462: iteration 106/107
# Epoch 1462 --- loss:1.332, Epoch accuracy:6.36%, Validation loss:1.301, Validation accuracy:7.23%
#
# Epoch 1462 --- epoch_autoencoder_loss1:0.663, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.231
#
# Epoch 1462 --- valid_autoencoder_loss1:0.647, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.230
#
#
# Epoch 1463: iteration 106/107
# Epoch 1463 --- loss:1.332, Epoch accuracy:6.39%, Validation loss:1.301, Validation accuracy:6.99%
#
# Epoch 1463 --- epoch_autoencoder_loss1:0.663, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.228
#
# Epoch 1463 --- valid_autoencoder_loss1:0.647, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.231
#
#
# Epoch 1464: iteration 106/107
# Epoch 1464 --- loss:1.332, Epoch accuracy:6.60%, Validation loss:1.301, Validation accuracy:7.23%
#
# Epoch 1464 --- epoch_autoencoder_loss1:0.662, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.227
#
# Epoch 1464 --- valid_autoencoder_loss1:0.647, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.232
#
#
# Epoch 1465: iteration 106/107
# Epoch 1465 --- loss:1.332, Epoch accuracy:6.45%, Validation loss:1.301, Validation accuracy:6.99%
#
# Epoch 1465 --- epoch_autoencoder_loss1:0.662, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.229
#
# Epoch 1465 --- valid_autoencoder_loss1:0.647, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.231
#
#
# Epoch 1466: iteration 106/107
# Epoch 1466 --- loss:1.332, Epoch accuracy:5.99%, Validation loss:1.301, Validation accuracy:7.23%
#
# Epoch 1466 --- epoch_autoencoder_loss1:0.662, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.228
#
# Epoch 1466 --- valid_autoencoder_loss1:0.647, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.229
#
#
# Epoch 1467: iteration 106/107
# Epoch 1467 --- loss:1.332, Epoch accuracy:6.57%, Validation loss:1.301, Validation accuracy:7.46%
#
# Epoch 1467 --- epoch_autoencoder_loss1:0.662, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.228
#
# Epoch 1467 --- valid_autoencoder_loss1:0.647, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.229
#
#
# Epoch 1468: iteration 106/107
# Epoch 1468 --- loss:1.332, Epoch accuracy:6.51%, Validation loss:1.300, Validation accuracy:7.23%
#
# Epoch 1468 --- epoch_autoencoder_loss1:0.662, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.230
#
# Epoch 1468 --- valid_autoencoder_loss1:0.647, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.228
#
#
# Epoch 1469: iteration 106/107
# Epoch 1469 --- loss:1.332, Epoch accuracy:6.77%, Validation loss:1.301, Validation accuracy:7.46%
#
# Epoch 1469 --- epoch_autoencoder_loss1:0.662, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.231
#
# Epoch 1469 --- valid_autoencoder_loss1:0.647, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.229
#
#
# Epoch 1470: iteration 106/107
# Epoch 1470 --- loss:1.331, Epoch accuracy:6.57%, Validation loss:1.300, Validation accuracy:6.99%
#
# Epoch 1470 --- epoch_autoencoder_loss1:0.662, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.228
#
# Epoch 1470 --- valid_autoencoder_loss1:0.647, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.230
#
#
# Epoch 1471: iteration 106/107
# Epoch 1471 --- loss:1.331, Epoch accuracy:6.25%, Validation loss:1.301, Validation accuracy:6.99%
#
# Epoch 1471 --- epoch_autoencoder_loss1:0.662, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.230
#
# Epoch 1471 --- valid_autoencoder_loss1:0.647, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.229
#
#
# Epoch 1472: iteration 106/107
# Epoch 1472 --- loss:1.331, Epoch accuracy:6.74%, Validation loss:1.300, Validation accuracy:7.23%
#
# Epoch 1472 --- epoch_autoencoder_loss1:0.662, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.231
#
# Epoch 1472 --- valid_autoencoder_loss1:0.647, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.229
#
#
# Epoch 1473: iteration 106/107
# Epoch 1473 --- loss:1.331, Epoch accuracy:6.48%, Validation loss:1.300, Validation accuracy:7.46%
#
# Epoch 1473 --- epoch_autoencoder_loss1:0.662, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.226
#
# Epoch 1473 --- valid_autoencoder_loss1:0.647, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.230
#
#
# Epoch 1474: iteration 106/107
# Epoch 1474 --- loss:1.331, Epoch accuracy:6.54%, Validation loss:1.300, Validation accuracy:7.23%
#
# Epoch 1474 --- epoch_autoencoder_loss1:0.662, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.227
#
# Epoch 1474 --- valid_autoencoder_loss1:0.647, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.229
#
#
# Epoch 1475: iteration 106/107
# Epoch 1475 --- loss:1.331, Epoch accuracy:6.48%, Validation loss:1.300, Validation accuracy:7.46%
#
# Epoch 1475 --- epoch_autoencoder_loss1:0.662, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.226
#
# Epoch 1475 --- valid_autoencoder_loss1:0.647, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.229
#
#
# Epoch 1476: iteration 106/107
# Epoch 1476 --- loss:1.331, Epoch accuracy:6.45%, Validation loss:1.300, Validation accuracy:6.99%
#
# Epoch 1476 --- epoch_autoencoder_loss1:0.662, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.229
#
# Epoch 1476 --- valid_autoencoder_loss1:0.646, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.230
#
#
# Epoch 1477: iteration 106/107
# Epoch 1477 --- loss:1.331, Epoch accuracy:6.19%, Validation loss:1.300, Validation accuracy:7.46%
#
# Epoch 1477 --- epoch_autoencoder_loss1:0.662, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.228
#
# Epoch 1477 --- valid_autoencoder_loss1:0.647, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.229
#
#
# Epoch 1478: iteration 106/107
# Epoch 1478 --- loss:1.330, Epoch accuracy:6.66%, Validation loss:1.300, Validation accuracy:7.46%
#
# Epoch 1478 --- epoch_autoencoder_loss1:0.662, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.228
#
# Epoch 1478 --- valid_autoencoder_loss1:0.646, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.230
#
#
# Epoch 1479: iteration 106/107
# Epoch 1479 --- loss:1.330, Epoch accuracy:6.80%, Validation loss:1.300, Validation accuracy:6.99%
#
# Epoch 1479 --- epoch_autoencoder_loss1:0.662, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.225
#
# Epoch 1479 --- valid_autoencoder_loss1:0.646, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.230
#
#
# Epoch 1480: iteration 106/107
# Epoch 1480 --- loss:1.331, Epoch accuracy:6.66%, Validation loss:1.300, Validation accuracy:7.23%
#
# Epoch 1480 --- epoch_autoencoder_loss1:0.662, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.227
#
# Epoch 1480 --- valid_autoencoder_loss1:0.646, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.229
#
#
# Epoch 1481: iteration 106/107
# Epoch 1481 --- loss:1.330, Epoch accuracy:6.74%, Validation loss:1.300, Validation accuracy:6.99%
#
# Epoch 1481 --- epoch_autoencoder_loss1:0.662, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.227
#
# Epoch 1481 --- valid_autoencoder_loss1:0.646, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.230
#
#
# Epoch 1482: iteration 106/107
# Epoch 1482 --- loss:1.330, Epoch accuracy:6.34%, Validation loss:1.300, Validation accuracy:6.99%
#
# Epoch 1482 --- epoch_autoencoder_loss1:0.662, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.227
#
# Epoch 1482 --- valid_autoencoder_loss1:0.646, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.231
#
#
# Epoch 1483: iteration 106/107
# Epoch 1483 --- loss:1.331, Epoch accuracy:5.90%, Validation loss:1.299, Validation accuracy:6.99%
#
# Epoch 1483 --- epoch_autoencoder_loss1:0.662, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.230
#
# Epoch 1483 --- valid_autoencoder_loss1:0.646, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.230
#
#
# Epoch 1484: iteration 106/107
# Epoch 1484 --- loss:1.330, Epoch accuracy:6.13%, Validation loss:1.299, Validation accuracy:7.46%
#
# Epoch 1484 --- epoch_autoencoder_loss1:0.661, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.227
#
# Epoch 1484 --- valid_autoencoder_loss1:0.646, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.229
#
#
# Epoch 1485: iteration 106/107
# Epoch 1485 --- loss:1.330, Epoch accuracy:6.66%, Validation loss:1.299, Validation accuracy:7.46%
#
# Epoch 1485 --- epoch_autoencoder_loss1:0.662, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.226
#
# Epoch 1485 --- valid_autoencoder_loss1:0.646, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.230
#
#
# Epoch 1486: iteration 106/107
# Epoch 1486 --- loss:1.330, Epoch accuracy:6.83%, Validation loss:1.299, Validation accuracy:7.46%
#
# Epoch 1486 --- epoch_autoencoder_loss1:0.661, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.226
#
# Epoch 1486 --- valid_autoencoder_loss1:0.646, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.230
#
#
# Epoch 1487: iteration 106/107
# Epoch 1487 --- loss:1.330, Epoch accuracy:6.54%, Validation loss:1.299, Validation accuracy:7.23%
#
# Epoch 1487 --- epoch_autoencoder_loss1:0.662, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.226
#
# Epoch 1487 --- valid_autoencoder_loss1:0.646, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.230
#
#
# Epoch 1488: iteration 106/107
# Epoch 1488 --- loss:1.330, Epoch accuracy:6.60%, Validation loss:1.299, Validation accuracy:7.23%
#
# Epoch 1488 --- epoch_autoencoder_loss1:0.662, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.229
#
# Epoch 1488 --- valid_autoencoder_loss1:0.646, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.228
#
#
# Epoch 1489: iteration 106/107
# Epoch 1489 --- loss:1.329, Epoch accuracy:6.48%, Validation loss:1.299, Validation accuracy:7.23%
#
# Epoch 1489 --- epoch_autoencoder_loss1:0.661, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.230
#
# Epoch 1489 --- valid_autoencoder_loss1:0.646, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.229
#
#
# Epoch 1490: iteration 106/107
# Epoch 1490 --- loss:1.330, Epoch accuracy:6.77%, Validation loss:1.299, Validation accuracy:7.46%
#
# Epoch 1490 --- epoch_autoencoder_loss1:0.661, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.228
#
# Epoch 1490 --- valid_autoencoder_loss1:0.646, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.228
#
#
# Epoch 1491: iteration 106/107
# Epoch 1491 --- loss:1.329, Epoch accuracy:6.66%, Validation loss:1.298, Validation accuracy:7.23%
#
# Epoch 1491 --- epoch_autoencoder_loss1:0.661, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.227
#
# Epoch 1491 --- valid_autoencoder_loss1:0.646, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.230
#
#
# Epoch 1492: iteration 106/107
# Epoch 1492 --- loss:1.328, Epoch accuracy:6.45%, Validation loss:1.299, Validation accuracy:6.99%
#
# Epoch 1492 --- epoch_autoencoder_loss1:0.661, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.231
#
# Epoch 1492 --- valid_autoencoder_loss1:0.646, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.229
#
#
# Epoch 1493: iteration 106/107
# Epoch 1493 --- loss:1.329, Epoch accuracy:6.39%, Validation loss:1.298, Validation accuracy:7.23%
#
# Epoch 1493 --- epoch_autoencoder_loss1:0.661, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.227
#
# Epoch 1493 --- valid_autoencoder_loss1:0.646, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.229
#
#
# Epoch 1494: iteration 106/107
# Epoch 1494 --- loss:1.328, Epoch accuracy:6.42%, Validation loss:1.298, Validation accuracy:7.23%
#
# Epoch 1494 --- epoch_autoencoder_loss1:0.661, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.234
#
# Epoch 1494 --- valid_autoencoder_loss1:0.646, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.229
#
#
# Epoch 1495: iteration 106/107
# Epoch 1495 --- loss:1.330, Epoch accuracy:6.68%, Validation loss:1.298, Validation accuracy:7.46%
#
# Epoch 1495 --- epoch_autoencoder_loss1:0.662, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.230
#
# Epoch 1495 --- valid_autoencoder_loss1:0.646, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.230
#
#
# Epoch 1496: iteration 106/107
# Epoch 1496 --- loss:1.329, Epoch accuracy:7.03%, Validation loss:1.298, Validation accuracy:7.23%
#
# Epoch 1496 --- epoch_autoencoder_loss1:0.661, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.230
#
# Epoch 1496 --- valid_autoencoder_loss1:0.646, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.229
#
#
# Epoch 1497: iteration 106/107
# Epoch 1497 --- loss:1.329, Epoch accuracy:6.77%, Validation loss:1.298, Validation accuracy:6.99%
#
# Epoch 1497 --- epoch_autoencoder_loss1:0.661, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.230
#
# Epoch 1497 --- valid_autoencoder_loss1:0.646, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.227
#
#
# Epoch 1498: iteration 106/107
# Epoch 1498 --- loss:1.330, Epoch accuracy:6.92%, Validation loss:1.298, Validation accuracy:6.99%
#
# Epoch 1498 --- epoch_autoencoder_loss1:0.661, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.230
#
# Epoch 1498 --- valid_autoencoder_loss1:0.646, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.229
#
#
# Epoch 1499: iteration 106/107
# Epoch 1499 --- loss:1.329, Epoch accuracy:6.45%, Validation loss:1.298, Validation accuracy:7.23%
#
# Epoch 1499 --- epoch_autoencoder_loss1:0.661, epoch_autoencoder_loss2:0.67, epoch_classifier_loss:2.228
#
# Epoch 1499 --- valid_autoencoder_loss1:0.646, valid_autoencoder_loss2:0.65, valid_classifier_loss:2.229

# %%
plt.title('Loss Curve for Parallel is All You Want Model')
plt.ylabel('Loss', fontsize=16)
plt.xlabel('Epoch', fontsize=16)
plt.plot(train_autoencoder_losses1[:],'b')
plt.plot(valid_autoencoder_losses1[:],'r')
plt.legend(['Training loss','Validation loss'])
plt.show()

# %%
plt.title('Loss Curve for Parallel is All You Want Model')
plt.ylabel('Loss', fontsize=16)
plt.xlabel('Epoch', fontsize=16)
plt.plot(train_autoencoder_losses2[:],'b')
plt.plot(valid_autoencoder_losses2[:],'r')
plt.legend(['Training loss','Validation loss'])
plt.show()

# %%
# pick load folder
load_folder = '/content'

# pick the epoch to load
epoch = '429'
model_name = f'parallel_all_you_wantFINAL.pkl'

# make full load path
load_path = os.path.join(load_folder, model_name)

## instantiate empty model and populate with params from binary
model = MultiTaskModel(len(emotions_dict)).to(device)
load_checkpoint(optimizer, model, load_path)

print(f'Loaded model from {load_path}')
# Out:
# Loaded model from /content/parallel_all_you_wantFINAL.pkl

# %%
# reinitialize validation function with model from chosen checkpoint
validate = make_validate_fnc(model,autoencoder_criterion, classifier_criterion)

# Convert 4D test feature set array to tensor and move to GPU
X_test_tensor = torch.tensor(X_test,device=device).float()
# Convert 4D test label set array to tensor and move to GPU
y_test_tensor = torch.tensor(y_test,dtype=torch.long,device=device)

# Get the model's performance metrics using the validation function we defined
test_loss, test_acc, test_autoencoder_loss1, test_autoencoder_loss2, test_classifier_loss, predicted_emotions = validate(X_test_tensor,y_test_tensor)


print(f'Test accuracy is {test_acc:.2f}%')
# Out:
# Test accuracy is 6.67%

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn

# because model tested on GPU, move prediction tensor to CPU then convert to array
predicted_emotions = predicted_emotions.cpu().numpy()
# use labels from test set
emotions_groundtruth = y_test

# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(emotions_groundtruth, predicted_emotions)
conf_matrix_norm = confusion_matrix(emotions_groundtruth, predicted_emotions,normalize='true')

# set labels for matrix axes from emotions
emotion_names = [emotion for emotion in emotions_dict.values()]

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font

plt.show()

# %%
from sklearn.model_selection import KFold
kfold = KFold(n_splits=10, shuffle=True, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

for train_index, test_index in kfold.split(X_train, y_train):
    Xtrain, Xtest = X_train[train_index], X_train[test_index]
    ytrain, ytest = y_train[train_index], y_train[test_index]
    print(Xtrain.shape,train_index), print(Xtest.shape)
# Out:
# (3096, 1, 40, 282) [   0    1    2 ... 3437 3438 3440]
# (345, 1, 40, 282)
# (3097, 1, 40, 282) [   1    2    3 ... 3438 3439 3440]
# (344, 1, 40, 282)
# (3097, 1, 40, 282) [   0    1    2 ... 3438 3439 3440]
# (344, 1, 40, 282)
# (3097, 1, 40, 282) [   0    1    2 ... 3438 3439 3440]
# (344, 1, 40, 282)
# (3097, 1, 40, 282) [   0    1    2 ... 3438 3439 3440]
# (344, 1, 40, 282)
# (3097, 1, 40, 282) [   0    1    3 ... 3436 3439 3440]
# (344, 1, 40, 282)
# (3097, 1, 40, 282) [   0    1    2 ... 3438 3439 3440]
# (344, 1, 40, 282)
# (3097, 1, 40, 282) [   0    1    2 ... 3438 3439 3440]
# (344, 1, 40, 282)
# (3097, 1, 40, 282) [   0    1    2 ... 3437 3438 3439]
# (344, 1, 40, 282)
# (3097, 1, 40, 282) [   0    2    3 ... 3438 3439 3440]
# (344, 1, 40, 282)

# %% [markdown]
# #visual

# %%
Xtensor = torch.tensor(X_train[1], device=device).float()
Ytensor = torch.tensor(y_train[1], dtype=torch.long,device=device)

# %%
Xtensor.unsqueeze(dim=0).shape
# Out:
# torch.Size([1, 1, 40, 282])

# %%
decoded1, decoded2, output_logits, output_softmax = model(Xtensor.unsqueeze(dim=0))

# %%
d = decoded1.squeeze(dim=0)
d = d.squeeze(dim=0)
d=d.cpu().detach().numpy()
d.shape
# Out:
# (40, 282)

# %%
d2 = decoded2.squeeze(dim=0)
d2 = d2.squeeze(dim=0)
d2=d2.cpu().detach().numpy()
d2.shape
# Out:
# (40, 282)

# %%
i=Xtensor.squeeze(dim=0)
i=i.cpu().detach().numpy()
i.shape
# Out:
# (40, 282)

# %%
# Plot MFCCs
plt.figure(figsize=(10, 4))
librosa.display.specshow(i, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('MFCC')
plt.show()

# %%
# Plot MFCCs
plt.figure(figsize=(10, 4))
librosa.display.specshow(d, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('MFCC')
plt.show()

# %%
# Plot MFCCs
plt.figure(figsize=(10, 4))
librosa.display.specshow(d2, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('MFCC')
plt.show()

# %% [markdown]
# #visual2

# %%
Xtensor = torch.tensor(X_train[2], device=device).float()
Ytensor = torch.tensor(y_train[2], dtype=torch.long,device=device)

# %%
Xtensor.unsqueeze(dim=0).shape
# Out:
# torch.Size([1, 1, 40, 282])

# %%
decoded1, decoded2, output_logits, output_softmax = model(Xtensor.unsqueeze(dim=0))

# %%
d = decoded1.squeeze(dim=0)
d = d.squeeze(dim=0)
d=d.cpu().detach().numpy()
d.shape
# Out:
# (40, 282)

# %%
d2 = decoded2.squeeze(dim=0)
d2 = d2.squeeze(dim=0)
d2=d2.cpu().detach().numpy()
d2.shape
# Out:
# (40, 282)

# %%
i=Xtensor.squeeze(dim=0)
i=i.cpu().detach().numpy()
i.shape
# Out:
# (40, 282)

# %%
# Plot MFCCs
plt.figure(figsize=(10, 4))
librosa.display.specshow(i, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('MFCC')
plt.show()

# %%
# Plot MFCCs
plt.figure(figsize=(10, 4))
librosa.display.specshow(d, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('MFCC')
plt.show()

# %%
# Plot MFCCs
plt.figure(figsize=(10, 4))
librosa.display.specshow(d2, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('MFCC')
plt.show()

# %% [markdown]
# #visual3

# %%
Xtensor = torch.tensor(X_train[3], device=device).float()
Ytensor = torch.tensor(y_train[3], dtype=torch.long,device=device)

# %%
Xtensor.unsqueeze(dim=0).shape
# Out:
# torch.Size([1, 1, 40, 282])

# %%
decoded1, decoded2, output_logits, output_softmax = model(Xtensor.unsqueeze(dim=0))

# %%
d = decoded1.squeeze(dim=0)
d = d.squeeze(dim=0)
d=d.cpu().detach().numpy()
d.shape
# Out:
# (40, 282)

# %%
d2 = decoded2.squeeze(dim=0)
d2 = d2.squeeze(dim=0)
d2=d2.cpu().detach().numpy()
d2.shape
# Out:
# (40, 282)

# %%
i=Xtensor.squeeze(dim=0)
i=i.cpu().detach().numpy()
i.shape
# Out:
# (40, 282)

# %%
# Plot MFCCs
plt.figure(figsize=(10, 4))
librosa.display.specshow(i, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('MFCC')
plt.show()

# %%
# Plot MFCCs
plt.figure(figsize=(10, 4))
librosa.display.specshow(d, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('MFCC')
plt.show()

# %%
# Plot MFCCs
plt.figure(figsize=(10, 4))
librosa.display.specshow(d2, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('MFCC')
plt.show()

# %% [markdown]
# #visual4

# %%
Xtensor = torch.tensor(X_train[4], device=device).float()
Ytensor = torch.tensor(y_train[4], dtype=torch.long,device=device)

# %%
Xtensor.unsqueeze(dim=0).shape
# Out:
# torch.Size([1, 1, 40, 282])

# %%
decoded1, decoded2, output_logits, output_softmax = model(Xtensor.unsqueeze(dim=0))

# %%
d = decoded1.squeeze(dim=0)
d = d.squeeze(dim=0)
d=d.cpu().detach().numpy()
d.shape
# Out:
# (40, 282)

# %%
d2 = decoded2.squeeze(dim=0)
d2 = d2.squeeze(dim=0)
d2=d2.cpu().detach().numpy()
d2.shape
# Out:
# (40, 282)

# %%
i=Xtensor.squeeze(dim=0)
i=i.cpu().detach().numpy()
i.shape
# Out:
# (40, 282)

# %%
# Plot MFCCs
plt.figure(figsize=(10, 4))
librosa.display.specshow(i, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('MFCC')
plt.show()

# %%
# Plot MFCCs
plt.figure(figsize=(10, 4))
librosa.display.specshow(d, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('MFCC')
plt.show()

# %%
# Plot MFCCs
plt.figure(figsize=(10, 4))
librosa.display.specshow(d2, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('MFCC')
plt.show()

# %% [markdown]
# #visual5

# %%
Xtensor = torch.tensor(X_train[5], device=device).float()
Ytensor = torch.tensor(y_train[5], dtype=torch.long,device=device)

# %%
Xtensor.unsqueeze(dim=0).shape
# Out:
# torch.Size([1, 1, 40, 282])

# %%
decoded1, decoded2, output_logits, output_softmax = model(Xtensor.unsqueeze(dim=0))

# %%
d = decoded1.squeeze(dim=0)
d = d.squeeze(dim=0)
d=d.cpu().detach().numpy()
d.shape
# Out:
# (40, 282)

# %%
d2 = decoded2.squeeze(dim=0)
d2 = d2.squeeze(dim=0)
d2=d2.cpu().detach().numpy()
d2.shape
# Out:
# (40, 282)

# %%
i=Xtensor.squeeze(dim=0)
i=i.cpu().detach().numpy()
i.shape
# Out:
# (40, 282)

# %%
# Plot MFCCs
plt.figure(figsize=(10, 4))
librosa.display.specshow(i, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('MFCC')
plt.show()

# %%
# Plot MFCCs
plt.figure(figsize=(10, 4))
librosa.display.specshow(d, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('MFCC')
plt.show()

# %%
# Plot MFCCs
plt.figure(figsize=(10, 4))
librosa.display.specshow(d2, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('MFCC')
plt.show()

# %% [markdown]
# #visual6

# %%
Xtensor = torch.tensor(X_train[6], device=device).float()
Ytensor = torch.tensor(y_train[6], dtype=torch.long,device=device)

# %%
Xtensor.unsqueeze(dim=0).shape
# Out:
# torch.Size([1, 1, 40, 282])

# %%
decoded1, decoded2, output_logits, output_softmax = model(Xtensor.unsqueeze(dim=0))

# %%
d = decoded1.squeeze(dim=0)
d = d.squeeze(dim=0)
d=d.cpu().detach().numpy()
d.shape
# Out:
# (40, 282)

# %%
d2 = decoded2.squeeze(dim=0)
d2 = d2.squeeze(dim=0)
d2=d2.cpu().detach().numpy()
d2.shape
# Out:
# (40, 282)

# %%
i=Xtensor.squeeze(dim=0)
i=i.cpu().detach().numpy()
i.shape
# Out:
# (40, 282)

# %%
# Plot MFCCs
plt.figure(figsize=(10, 4))
librosa.display.specshow(i, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('MFCC')
plt.show()

# %%
# Plot MFCCs
plt.figure(figsize=(10, 4))
librosa.display.specshow(d, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('MFCC')
plt.show()

# %%
# Plot MFCCs
plt.figure(figsize=(10, 4))
librosa.display.specshow(d2, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('MFCC')
plt.show()

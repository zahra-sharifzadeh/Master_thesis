# %% [markdown]
# <a href="https://colab.research.google.com/github/zahra-sharifzadeh/Master_thesis/blob/main/RAVDESS/mel_spectrograms_one_AE_cnn_attention_lstm_Ravdess.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# copy RAVDESS dataset from gdrive and unzip
# !cp '/content/drive/MyDrive/RAVDESS.zip' .
# !unzip -q RAVDESS.zip

# %% [markdown]
# # Load file names

# %%
import torch

# %%
SAMPLE_RATE = 48000

# %%
import numpy as np
import pandas as pd
import os
import librosa
import librosa.display
import IPython
from IPython.display import Audio
from IPython.display import Image
import matplotlib.pyplot as plt

EMOTIONS = {1:'neutral', 2:'calm', 3:'happy', 4:'sad', 5:'angry', 6:'fear', 7:'disgust', 0:'surprise'} # surprise je promenjen sa 8 na 0
DATA_PATH = '/content/audio_speech_actors_01-24'


data = pd.DataFrame(columns=['Emotion', 'Emotion intensity', 'Gender','Path'])
for dirname, _, filenames in os.walk(DATA_PATH):
    for filename in filenames:
        file_path = os.path.join('/content/drive/MyDrive/',dirname, filename)
        identifiers = filename.split('.')[0].split('-')
        emotion = (int(identifiers[2]))
        if emotion == 8: # promeni surprise sa 8 na 0
            emotion = 0
        if int(identifiers[3]) == 1:
            emotion_intensity = 'normal'
        else:
            emotion_intensity = 'strong'
        if int(identifiers[6])%2 == 0:
            gender = 'female'
        else:
            gender = 'male'

        data = data._append({"Emotion": emotion,
                            "Emotion intensity": emotion_intensity,
                            "Gender": gender,
                            "Path": file_path
                             },
                             ignore_index = True
                          )

# %%
print("number of files is {}".format(len(data)))
data.head()
# Out:
# number of files is 1440
#   Emotion Emotion intensity Gender  \
# 0       6            strong   male
# 1       4            normal   male
# 2       5            strong   male
# 3       3            normal   male
# 4       4            normal   male
#
#                                                 Path
# 0  /content/audio_speech_actors_01-24/Actor_01/03...
# 1  /content/audio_speech_actors_01-24/Actor_01/03...
# 2  /content/audio_speech_actors_01-24/Actor_01/03...
# 3  /content/audio_speech_actors_01-24/Actor_01/03...
# 4  /content/audio_speech_actors_01-24/Actor_01/03...

# %% [markdown]
# Number of examples per emotion

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.bar(x=range(8), height=data['Emotion'].value_counts())
ax.set_xticks(ticks=range(8))
ax.set_xticklabels([EMOTIONS[i] for i in range(8)],fontsize=10)
ax.set_xlabel('Emotions')
ax.set_ylabel('Number of examples')
# Out:
# Text(0, 0.5, 'Number of examples')

# %% [markdown]
# number of examples per gender

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
counts = data['Gender'].value_counts()
ax.bar(x=[0,1], height=counts.values)
ax.set_xticks(ticks=[0,1])
ax.set_xticklabels(list(counts.index))
ax.set_xlabel('Gender')
ax.set_ylabel('Number of examples')
# Out:
# Text(0, 0.5, 'Number of examples')

# %% [markdown]
# number of examples per emotion intensity

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
counts = data['Emotion intensity'].value_counts()
ax.bar(x=[0,1], height=counts.values)
ax.set_xticks(ticks=[0,1])
ax.set_xticklabels(list(counts.index))
ax.set_xlabel('Gender')
ax.set_ylabel('Number of examples')
# Out:
# Text(0, 0.5, 'Number of examples')

# %% [markdown]
# # Load the signals

# %%
mel_spectrograms = []
signals = []
for i, file_path in enumerate(data.Path):
    audio, sample_rate = librosa.load(file_path, duration=3, offset=0.5, sr=SAMPLE_RATE)
    signal = np.zeros((int(SAMPLE_RATE*3,)))
    signal[:len(audio)] = audio
    signals.append(signal)
    print("\r Processed {}/{} files".format(i,len(data)),end='')
signals = np.stack(signals,axis=0)
# Out:
#  Processed 1439/1440 files

# %% [markdown]
# # Split the data

# %%
X = signals
train_ind,test_ind,val_ind = [],[],[]
X_train,X_val,X_test = [],[],[]
Y_train,Y_val,Y_test = [],[],[]
for emotion in range(len(EMOTIONS)):
    emotion_ind = list(data.loc[data.Emotion==emotion,'Emotion'].index)
    emotion_ind = np.random.permutation(emotion_ind)
    m = len(emotion_ind)
    ind_train = emotion_ind[:int(0.8*m)]
    ind_val = emotion_ind[int(0.8*m):int(0.9*m)]
    ind_test = emotion_ind[int(0.9*m):]
    X_train.append(X[ind_train,:])
    Y_train.append(np.array([emotion]*len(ind_train),dtype=np.int32))
    X_val.append(X[ind_val,:])
    Y_val.append(np.array([emotion]*len(ind_val),dtype=np.int32))
    X_test.append(X[ind_test,:])
    Y_test.append(np.array([emotion]*len(ind_test),dtype=np.int32))
    train_ind.append(ind_train)
    test_ind.append(ind_test)
    val_ind.append(ind_val)
X_train = np.concatenate(X_train,0)
X_val = np.concatenate(X_val,0)
X_test = np.concatenate(X_test,0)
Y_train = np.concatenate(Y_train,0)
Y_val = np.concatenate(Y_val,0)
Y_test = np.concatenate(Y_test,0)
train_ind = np.concatenate(train_ind,0)
val_ind = np.concatenate(val_ind,0)
test_ind = np.concatenate(test_ind,0)
print(f'X_train:{X_train.shape}, Y_train:{Y_train.shape}')
print(f'X_val:{X_val.shape}, Y_val:{Y_val.shape}')
print(f'X_test:{X_test.shape}, Y_test:{Y_test.shape}')
# check if all are unique
unique, count = np.unique(np.concatenate([train_ind,test_ind,val_ind],0), return_counts=True)
print("Number of unique indexes is {}, out of {}".format(sum(count==1), X.shape[0]))

del X
# Out:
# X_train:(1147, 144000), Y_train:(1147,)
# X_val:(143, 144000), Y_val:(143,)
# X_test:(150, 144000), Y_test:(150,)
# Number of unique indexes is 1440, out of 1440

# %% [markdown]
# # Augment signals by adding AWGN

# %%
def addAWGN(signal, num_bits=16, augmented_num=2, snr_low=15, snr_high=30):
    signal_len = len(signal)
    # Generate White Gaussian noise
    noise = np.random.normal(size=(augmented_num, signal_len))
    # Normalize signal and noise
    norm_constant = 2.0**(num_bits-1)
    signal_norm = signal / norm_constant
    noise_norm = noise / norm_constant
    # Compute signal and noise power
    s_power = np.sum(signal_norm ** 2) / signal_len
    n_power = np.sum(noise_norm ** 2, axis=1) / signal_len
    # Random SNR: Uniform [15, 30] in dB
    target_snr = np.random.randint(snr_low, snr_high)
    # Compute K (covariance matrix) for each noise
    K = np.sqrt((s_power / n_power) * 10 ** (- target_snr / 10))
    K = np.ones((signal_len, augmented_num)) * K
    # Generate noisy signal
    return signal + K.T * noise

# %%
aug_signals = []
aug_labels = []
for i in range(X_train.shape[0]):
    signal = X_train[i,:]
    augmented_signals = addAWGN(signal)
    for j in range(augmented_signals.shape[0]):
        aug_labels.append(data.loc[i,"Emotion"])
        aug_signals.append(augmented_signals[j,:])
        # data = data.append(data.iloc[i], ignore_index=True)
    print("\r Processed {}/{} files".format(i,X_train.shape[0]),end='')
aug_signals = np.stack(aug_signals,axis=0)
X_train = np.concatenate([X_train,aug_signals],axis=0)
aug_labels = np.stack(aug_labels,axis=0)
Y_train = np.concatenate([Y_train,aug_labels])
print('')
print(f'X_train:{X_train.shape}, Y_train:{Y_train.shape}')
# Out:
#  Processed 1146/1147 files
# X_train:(3441, 144000), Y_train:(3441,)

# %% [markdown]
# # Calculate mel spectrograms

# %%
def getMELspectrogram(audio, sample_rate):
    mel_spec = librosa.feature.melspectrogram(y=audio,
                                              sr=sample_rate,
                                              n_fft=1024,
                                              win_length = 512,
                                              window='hamming',
                                              hop_length = 256,
                                              n_mels=128,
                                              fmax=sample_rate/2
                                             )
    mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)
    return mel_spec_db

# test function
audio, sample_rate = librosa.load(data.loc[0,'Path'], duration=3, offset=0.5,sr=SAMPLE_RATE)
signal = np.zeros((int(SAMPLE_RATE*3,)))
signal[:len(audio)] = audio
mel_spectrogram = getMELspectrogram(signal, SAMPLE_RATE)
librosa.display.specshow(mel_spectrogram, y_axis='mel', x_axis='time')
print('MEL spectrogram shape: ',mel_spectrogram.shape)
# Out:
# MEL spectrogram shape:  (128, 563)

# %%
mel_train = []
print("Calculatin mel spectrograms for train set")
for i in range(X_train.shape[0]):
    mel_spectrogram = getMELspectrogram(X_train[i,:], sample_rate=SAMPLE_RATE)
    mel_train.append(mel_spectrogram)
    print("\r Processed {}/{} files".format(i,X_train.shape[0]),end='')
print('')
mel_train = np.stack(mel_train,axis=0)
del X_train
X_train = mel_train
# Out:
# Calculatin mel spectrograms for train set
#  Processed 3440/3441 files

# %%
mel_val = []
print("Calculatin mel spectrograms for val set")
for i in range(X_val.shape[0]):
    mel_spectrogram = getMELspectrogram(X_val[i,:], sample_rate=SAMPLE_RATE)
    mel_val.append(mel_spectrogram)
    print("\r Processed {}/{} files".format(i,X_val.shape[0]),end='')
print('')
mel_val = np.stack(mel_val,axis=0)
del X_val
X_val = mel_val
# Out:
# Calculatin mel spectrograms for val set
#  Processed 142/143 files

# %%
mel_test = []
print("Calculatin mel spectrograms for test set")
for i in range(X_test.shape[0]):
    mel_spectrogram = getMELspectrogram(X_test[i,:], sample_rate=SAMPLE_RATE)
    mel_test.append(mel_spectrogram)
    print("\r Processed {}/{} files".format(i,X_test.shape[0]),end='')
print('')
mel_test = np.stack(mel_test,axis=0)
del X_test
X_test = mel_test
# Out:
# Calculatin mel spectrograms for test set
#  Processed 149/150 files

# %%
print(f'X_train:{X_train.shape}, Y_train:{Y_train.shape}')
print(f'X_val:{X_val.shape}, Y_val:{Y_val.shape}')
print(f'X_test:{X_test.shape}, Y_test:{Y_test.shape}')
# Out:
# X_train:(3441, 128, 563), Y_train:(3441,)
# X_val:(143, 128, 563), Y_val:(143,)
# X_test:(150, 128, 563), Y_test:(150,)

# %% [markdown]
# # Create the model

# %%
import torch.nn as nn

class Encoder(nn.Module):
    def __init__(self):
        super(Encoder, self).__init__()
          #input_shape = [batches, 1, 128, 563] -> output_ conv block1 = [batches, 16, 128, 563]
          # ...->  output_ conv block2 = [batches, 32, 16, 70] ->  output_ conv block3 = [batches , 64, 4, 17]
          #...->  output_ conv block4 = [batches, 64, 1, 4]

        self.encoder = nn.Sequential(
            # 1. conv block
            nn.Conv2d(in_channels=1,
                       out_channels=16,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(p=0.3),
            # 2. conv block
            nn.Conv2d(in_channels=16,
                       out_channels=32,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
            # 3. conv block
            nn.Conv2d(in_channels=32,
                       out_channels=64,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
            # 4. conv block
            nn.Conv2d(in_channels=64,
                       out_channels=64,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3)
        )

    def forward(self, x):
        return self.encoder(x)

# %%
import torch.nn as nn
          #input_shape = [batches, 1, 128, 563] -> output_ conv block1 = [batches, 16, 128, 563]
          # ...->  output_ conv block2 = [batches, 32, 16, 70] ->  output_ conv block3 = [batches , 64, 4, 17]
          #...->  output_ conv block4 = [batches, 64, 1, 4]

class Decoder(nn.Module):
    def __init__(self):
        super(Decoder, self).__init__()

        self.decoder = nn.Sequential(
            # Transposed convolution layer
            nn.ConvTranspose2d(64, 64, kernel_size=(1, 5), stride=(1, 4)),
            nn.BatchNorm2d(64),
            nn.ReLU(),

            nn.ConvTranspose2d(64, 32, kernel_size=(16, 6), stride=(1, 4)),
            nn.BatchNorm2d(32),
            nn.ReLU(),

            nn.ConvTranspose2d(32, 16, kernel_size=(8,11), stride=(8,8)),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.ConvTranspose2d(16, 1, kernel_size=(1,1), stride=(1,1)),

        )

    def forward(self, x):
        return self.decoder(x)

decoder = Decoder()
input_data = torch.randn(1, 64, 1, 4)  # Replace with your input shape
decoded = decoder(input_data)
input_data.shape , decoded.shape
# Out:
# (torch.Size([1, 64, 1, 4]), torch.Size([1, 1, 128, 563]))

# %%
class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()

        # Define the encoder and decoder
        self.encoder = Encoder()
        self.decoder = Decoder()

    def forward(self, x):
        # Encode the input
        encoded = self.encoder(x)

        # Decode the encoded representation
        decoded = self.decoder(encoded)

        return encoded, decoded


autoencoder = Autoencoder()
input_data = torch.randn(1, 1, 128, 563)  # Replace with your input shape
encoded, decoded = autoencoder(input_data)
encoded.shape, decoded.shape
# Out:
# (torch.Size([1, 64, 1, 4]), torch.Size([1, 1, 128, 563]))

# %%
class LSTM_Feature_Extractor(nn.Module):
    def __init__(self,hidden_size=128):
        super(LSTM_Feature_Extractor, self).__init__()
         # LSTM block
        # self.hidden_size = hidden_size
        self.lstm_maxpool = nn.MaxPool2d(kernel_size=[2,4], stride=[2,4])
        self.lstm = nn.LSTM(input_size=64,hidden_size=hidden_size,bidirectional=True, batch_first=True)
        self.dropout_lstm = nn.Dropout(0.1)
        self.attention_linear = nn.Linear(2*hidden_size,1) # 2*hidden_size for the 2 outputs of bidir LSTM



    def forward(self, x):
             # lstm embedding
        x_reduced = self.lstm_maxpool(x)
        x_reduced = torch.squeeze(x_reduced,1)
        x_reduced = x_reduced.permute(0,2,1) # (b,t,freq)
        lstm_embedding, (h,c) = self.lstm(x_reduced) # (b, time, hidden_size*2)
        lstm_embedding = self.dropout_lstm(lstm_embedding)
        batch_size,T,_ = lstm_embedding.shape
        attention_weights = [None]*T
        for t in range(T):
            embedding = lstm_embedding[:,t,:]
            attention_weights[t] = self.attention_linear(embedding)
        attention_weights_norm = nn.functional.softmax(torch.stack(attention_weights,-1),-1)
        attention = torch.bmm(attention_weights_norm,lstm_embedding) # (Bx1xT)*(B,T,hidden_size*2)=(B,1,2*hidden_size)
        attention = torch.squeeze(attention, 1)

        return attention, attention_weights_norm

# %%
class Classifier(nn.Module):
  def __init__(self, num_emotions, hidden_size):
    super().__init__()

    self.out_linear = nn.Linear(2*hidden_size+256,num_emotions)
    self.dropout_linear = nn.Dropout(p=0)
    self.out_softmax = nn.Softmax(dim=1)

  def forward(self, x):

    output_logits = self.out_linear(x)
    output_logits = self.dropout_linear(output_logits)
    output_softmax = self.out_softmax(output_logits)

    return output_logits, output_softmax

# %%
import torch
import torch.nn as nn

class AE_CNN_LSTM_Model(nn.Module):
    def __init__(self,num_emotions):
        super().__init__()

        hidden_size = 128
        self.autoencoder1 = Autoencoder()
        self.lstm_block = LSTM_Feature_Extractor(hidden_size = hidden_size)
        self.classifier = Classifier(num_emotions, hidden_size)

    def forward(self,x):
        # conv embedding
        encoded, decoded = self.autoencoder1(x) #(b,channel,freq,time) , input shape

        encoded_embedding = torch.flatten(encoded, start_dim=1) # do not flatten batch dimension

        # lstm embedding

        attention, attention_weights_norm = self.lstm_block(x)

        # concatenate
        complete_embedding = torch.cat([encoded_embedding, attention], dim=1)
        output_logits, output_softmax = self.classifier(complete_embedding)


        return output_logits, output_softmax, attention_weights_norm, decoded, encoded

# %%
# def loss_fnc(predictions, targets):
#     return nn.CrossEntropyLoss()(input=predictions,target=targets)

loss_fnc_classification = nn.CrossEntropyLoss()
AE_loss_fnc = nn.MSELoss()

# %% [markdown]
# # TRAINING

# %%
def make_train_step(model, loss_fnc_classification, AE_loss_fnc, optimizer):
    def train_step(X,Y):
        # set model to train mode
        model.train()
        # forward pass
        output_logits, output_softmax, attention_weights_norm, decoded, encoded = model(X)
        predictions = torch.argmax(output_softmax,dim=1)
        accuracy = torch.sum(Y==predictions)/float(len(Y))
        # compute loss
        LC = loss_fnc_classification(output_logits, Y)
        LA = AE_loss_fnc(decoded, X)
        TH = 0.3
        loss = TH * (LA) + (1-TH) * (LC)
        # compute gradients
        loss.backward()
        # update parameters and zero gradients
        optimizer.step()
        optimizer.zero_grad()
        return loss.item(), accuracy*100, LC.item(), LA.item(), decoded, encoded
    return train_step

# %%
def make_validate_fnc(model,loss_fnc_classification, AE_loss_fnc):
    def validate(X,Y):
        with torch.no_grad():
            model.eval()
            output_logits, output_softmax, attention_weights_norm, decoded, encoded = model(X)
            predictions = torch.argmax(output_softmax,dim=1)
            accuracy = torch.sum(Y==predictions)/float(len(Y))
            LC = loss_fnc_classification(output_logits, Y)
            LA = AE_loss_fnc(decoded, X)
            TH = 0.3
            loss = TH * (LA) + (1-TH) * (LC)
        return loss.item(), accuracy*100, predictions, LC.item(), LA.item(), decoded, encoded
    return validate

# %% [markdown]
# scale data

# %%
from sklearn.preprocessing import StandardScaler

X_train = np.expand_dims(X_train,1)
X_val = np.expand_dims(X_val,1)
X_test = np.expand_dims(X_test,1)

scaler = StandardScaler()

b,c,h,w = X_train.shape
X_train = np.reshape(X_train, newshape=(b,-1))
X_train = scaler.fit_transform(X_train)
X_train = np.reshape(X_train, newshape=(b,c,h,w))

b,c,h,w = X_test.shape
X_test = np.reshape(X_test, newshape=(b,-1))
X_test = scaler.transform(X_test)
X_test = np.reshape(X_test, newshape=(b,c,h,w))

b,c,h,w = X_val.shape
X_val = np.reshape(X_val, newshape=(b,-1))
X_val = scaler.transform(X_val)
X_val = np.reshape(X_val, newshape=(b,c,h,w))

# %%
X_train.shape
# Out:
# (3441, 1, 128, 563)

# %%
X_train.min(), X_train.max()
# Out:
# (-5.843901823353885, 5.214140781121329)

# %% [markdown]
# Train the model

# %%
EPOCHS=500
DATASET_SIZE = X_train.shape[0]
BATCH_SIZE = 32

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Selected device is {}'.format(device))
# Out:
# Selected device is cuda

# %%
model = AE_CNN_LSTM_Model(num_emotions=len(EMOTIONS)).to(device)
print('Number of trainable params: ',sum(p.numel() for p in model.parameters()) )
# Out:
# Number of trainable params:  526090

# %%
OPTIMIZER = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

# %%
train_step = make_train_step(model, loss_fnc_classification, AE_loss_fnc, optimizer=OPTIMIZER)
validate = make_validate_fnc(model,loss_fnc_classification, AE_loss_fnc)

#####
losses = []
LAs = []
LCs = []
val_losses = []
val_LAs = []
val_LCs = []
#####

for epoch in range(EPOCHS):
    # schuffle data
    ind = np.random.permutation(DATASET_SIZE)

    X_train = X_train[ind,:,:,:]
    Y_train = Y_train[ind]

    epoch_acc = 0
    epoch_loss = 0
    epoch_LA = 0
    epoch_LC = 0

    iters = int(DATASET_SIZE / BATCH_SIZE)

    for i in range(iters):
        batch_start = i * BATCH_SIZE
        batch_end = min(batch_start + BATCH_SIZE, DATASET_SIZE)
        actual_batch_size = batch_end-batch_start
        X = X_train[batch_start:batch_end,:,:,:]
        Y = Y_train[batch_start:batch_end]
        X_tensor = torch.tensor(X,device=device).float()
        Y_tensor = torch.tensor(Y, dtype=torch.long,device=device)
        loss, acc, LC, LA, decoded, encoded = train_step(X_tensor,Y_tensor)

        epoch_acc += acc*actual_batch_size/DATASET_SIZE

        epoch_loss += loss * actual_batch_size/DATASET_SIZE
        epoch_LA   += LA * actual_batch_size/DATASET_SIZE
        epoch_LC   += LC * actual_batch_size/DATASET_SIZE

        print(f"\r Epoch {epoch}: iteration {i}/{iters}",end='')
    X_val_tensor = torch.tensor(X_val,device=device).float()
    Y_val_tensor = torch.tensor(Y_val,dtype=torch.long,device=device)
    val_loss, val_acc, predictions, val_LC, val_LA, val_decoded, val_encode = validate(X_val_tensor,Y_val_tensor)


    losses.append(epoch_loss)
    LAs.append(epoch_LA)
    LCs.append(epoch_LC)


    val_losses.append(val_loss)
    val_LAs.append(val_LA)
    val_LCs.append(val_LC)


    print('')
    print(f"Epoch {epoch} --> loss:{epoch_loss:.4f}, acc:{epoch_acc:.2f}%, val_loss:{val_loss:.4f}, val_acc:{val_acc:.2f}%")
    print(f"Epoch {epoch} --> epoch_LA:{epoch_LA:.4f}, epoch_LC:{epoch_LC:.4f}, val_LC:{val_LC:.4f}, val_LA:{val_LA:.4f}%")
# Out:
#  Epoch 0: iteration 106/107
# Epoch 0 --> loss:1.9474, acc:14.36%, val_loss:1.9464, val_acc:13.29%
# Epoch 0 --> epoch_LA:1.1670, epoch_LC:2.2819, val_LC:2.1136, val_LA:1.5560%
#  Epoch 1: iteration 106/107
# Epoch 1 --> loss:1.8084, acc:14.56%, val_loss:1.8871, val_acc:13.29%
# Epoch 1 --> epoch_LA:0.9772, epoch_LC:2.1645, val_LC:2.1180, val_LA:1.3483%
#  Epoch 2: iteration 106/107
# Epoch 2 --> loss:1.7359, acc:17.15%, val_loss:1.8203, val_acc:13.29%
# Epoch 2 --> epoch_LA:0.8898, epoch_LC:2.0985, val_LC:2.0799, val_LA:1.2148%
#  Epoch 3: iteration 106/107
# Epoch 3 --> loss:1.7199, acc:16.27%, val_loss:1.7956, val_acc:18.88%
# Epoch 3 --> epoch_LA:0.7900, epoch_LC:2.1184, val_LC:2.0801, val_LA:1.1319%
#  Epoch 4: iteration 106/107
# Epoch 4 --> loss:1.6840, acc:16.42%, val_loss:1.8575, val_acc:13.29%
# Epoch 4 --> epoch_LA:0.6981, epoch_LC:2.1066, val_LC:2.1855, val_LA:1.0923%
#  Epoch 5: iteration 106/107
# Epoch 5 --> loss:1.6445, acc:17.44%, val_loss:1.7020, val_acc:20.98%
# Epoch 5 --> epoch_LA:0.6482, epoch_LC:2.0715, val_LC:1.9875, val_LA:1.0358%
#  Epoch 6: iteration 106/107
# Epoch 6 --> loss:1.6400, acc:17.35%, val_loss:1.6951, val_acc:25.87%
# Epoch 6 --> epoch_LA:0.6280, epoch_LC:2.0737, val_LC:1.9897, val_LA:1.0077%
#  Epoch 7: iteration 106/107
# Epoch 7 --> loss:1.6198, acc:18.72%, val_loss:1.6748, val_acc:16.08%
# Epoch 7 --> epoch_LA:0.6136, epoch_LC:2.0511, val_LC:1.9725, val_LA:0.9802%
#  Epoch 8: iteration 106/107
# Epoch 8 --> loss:1.6039, acc:18.40%, val_loss:1.6531, val_acc:21.68%
# Epoch 8 --> epoch_LA:0.6018, epoch_LC:2.0333, val_LC:1.9475, val_LA:0.9660%
#  Epoch 9: iteration 106/107
# Epoch 9 --> loss:1.5984, acc:18.19%, val_loss:1.6484, val_acc:24.48%
# Epoch 9 --> epoch_LA:0.5894, epoch_LC:2.0308, val_LC:1.9583, val_LA:0.9253%
#  Epoch 10: iteration 106/107
# Epoch 10 --> loss:1.5828, acc:18.98%, val_loss:1.6063, val_acc:33.57%
# Epoch 10 --> epoch_LA:0.5810, epoch_LC:2.0121, val_LC:1.9076, val_LA:0.9034%
#  Epoch 11: iteration 106/107
# Epoch 11 --> loss:1.5724, acc:20.11%, val_loss:1.6092, val_acc:26.57%
# Epoch 11 --> epoch_LA:0.5741, epoch_LC:2.0002, val_LC:1.9200, val_LA:0.8841%
#  Epoch 12: iteration 106/107
# Epoch 12 --> loss:1.5637, acc:20.81%, val_loss:1.6116, val_acc:23.08%
# Epoch 12 --> epoch_LA:0.5708, epoch_LC:1.9892, val_LC:1.9290, val_LA:0.8709%
#  Epoch 13: iteration 106/107
# Epoch 13 --> loss:1.5540, acc:21.80%, val_loss:1.5476, val_acc:30.07%
# Epoch 13 --> epoch_LA:0.5660, epoch_LC:1.9774, val_LC:1.8474, val_LA:0.8482%
#  Epoch 14: iteration 106/107
# Epoch 14 --> loss:1.5384, acc:22.00%, val_loss:1.5191, val_acc:29.37%
# Epoch 14 --> epoch_LA:0.5600, epoch_LC:1.9577, val_LC:1.8157, val_LA:0.8271%
#  Epoch 15: iteration 106/107
# Epoch 15 --> loss:1.5495, acc:20.26%, val_loss:1.5391, val_acc:27.27%
# Epoch 15 --> epoch_LA:0.5582, epoch_LC:1.9743, val_LC:1.8504, val_LA:0.8128%
#  Epoch 16: iteration 106/107
# Epoch 16 --> loss:1.5332, acc:22.03%, val_loss:1.4996, val_acc:34.97%
# Epoch 16 --> epoch_LA:0.5560, epoch_LC:1.9520, val_LC:1.7990, val_LA:0.8011%
#  Epoch 17: iteration 106/107
# Epoch 17 --> loss:1.5331, acc:22.49%, val_loss:1.5467, val_acc:32.87%
# Epoch 17 --> epoch_LA:0.5519, epoch_LC:1.9536, val_LC:1.8612, val_LA:0.8128%
#  Epoch 18: iteration 106/107
# Epoch 18 --> loss:1.5277, acc:22.87%, val_loss:1.5011, val_acc:30.77%
# Epoch 18 --> epoch_LA:0.5487, epoch_LC:1.9473, val_LC:1.8020, val_LA:0.7991%
#  Epoch 19: iteration 106/107
# Epoch 19 --> loss:1.5134, acc:23.02%, val_loss:1.5455, val_acc:30.77%
# Epoch 19 --> epoch_LA:0.5465, epoch_LC:1.9278, val_LC:1.8711, val_LA:0.7857%
#  Epoch 20: iteration 106/107
# Epoch 20 --> loss:1.5078, acc:23.07%, val_loss:1.4776, val_acc:32.87%
# Epoch 20 --> epoch_LA:0.5450, epoch_LC:1.9204, val_LC:1.7770, val_LA:0.7788%
#  Epoch 21: iteration 106/107
# Epoch 21 --> loss:1.4957, acc:24.00%, val_loss:1.4683, val_acc:34.97%
# Epoch 21 --> epoch_LA:0.5398, epoch_LC:1.9054, val_LC:1.7677, val_LA:0.7697%
#  Epoch 22: iteration 106/107
# Epoch 22 --> loss:1.4945, acc:24.15%, val_loss:1.4697, val_acc:29.37%
# Epoch 22 --> epoch_LA:0.5391, epoch_LC:1.9039, val_LC:1.7686, val_LA:0.7722%
#  Epoch 23: iteration 106/107
# Epoch 23 --> loss:1.4851, acc:24.73%, val_loss:1.4767, val_acc:36.36%
# Epoch 23 --> epoch_LA:0.5385, epoch_LC:1.8908, val_LC:1.7822, val_LA:0.7638%
#  Epoch 24: iteration 106/107
# Epoch 24 --> loss:1.4832, acc:24.85%, val_loss:1.4753, val_acc:30.07%
# Epoch 24 --> epoch_LA:0.5334, epoch_LC:1.8903, val_LC:1.7819, val_LA:0.7601%
#  Epoch 25: iteration 106/107
# Epoch 25 --> loss:1.4710, acc:25.92%, val_loss:1.4603, val_acc:35.66%
# Epoch 25 --> epoch_LA:0.5387, epoch_LC:1.8706, val_LC:1.7610, val_LA:0.7588%
#  Epoch 26: iteration 106/107
# Epoch 26 --> loss:1.4677, acc:26.74%, val_loss:1.4356, val_acc:37.06%
# Epoch 26 --> epoch_LA:0.5311, epoch_LC:1.8690, val_LC:1.7328, val_LA:0.7422%
#  Epoch 27: iteration 106/107
# Epoch 27 --> loss:1.4665, acc:26.91%, val_loss:1.4531, val_acc:29.37%
# Epoch 27 --> epoch_LA:0.5314, epoch_LC:1.8673, val_LC:1.7574, val_LA:0.7430%
#  Epoch 28: iteration 106/107
# Epoch 28 --> loss:1.4603, acc:27.09%, val_loss:1.4394, val_acc:37.76%
# Epoch 28 --> epoch_LA:0.5298, epoch_LC:1.8590, val_LC:1.7357, val_LA:0.7479%
#  Epoch 29: iteration 106/107
# Epoch 29 --> loss:1.4539, acc:26.79%, val_loss:1.4133, val_acc:35.66%
# Epoch 29 --> epoch_LA:0.5279, epoch_LC:1.8508, val_LC:1.6988, val_LA:0.7470%
#  Epoch 30: iteration 106/107
# Epoch 30 --> loss:1.4493, acc:28.16%, val_loss:1.4687, val_acc:30.07%
# Epoch 30 --> epoch_LA:0.5250, epoch_LC:1.8454, val_LC:1.7790, val_LA:0.7446%
#  Epoch 31: iteration 106/107
# Epoch 31 --> loss:1.4422, acc:27.58%, val_loss:1.4006, val_acc:37.06%
# Epoch 31 --> epoch_LA:0.5277, epoch_LC:1.8341, val_LC:1.6838, val_LA:0.7398%
#  Epoch 32: iteration 106/107
# Epoch 32 --> loss:1.4393, acc:27.70%, val_loss:1.3982, val_acc:34.97%
# Epoch 32 --> epoch_LA:0.5230, epoch_LC:1.8319, val_LC:1.6791, val_LA:0.7430%
#  Epoch 33: iteration 106/107
# Epoch 33 --> loss:1.4419, acc:26.94%, val_loss:1.4202, val_acc:32.87%
# Epoch 33 --> epoch_LA:0.5237, epoch_LC:1.8354, val_LC:1.7092, val_LA:0.7457%
#  Epoch 34: iteration 106/107
# Epoch 34 --> loss:1.4273, acc:29.61%, val_loss:1.4038, val_acc:32.87%
# Epoch 34 --> epoch_LA:0.5259, epoch_LC:1.8136, val_LC:1.6910, val_LA:0.7336%
#  Epoch 35: iteration 106/107
# Epoch 35 --> loss:1.4265, acc:28.71%, val_loss:1.3644, val_acc:37.06%
# Epoch 35 --> epoch_LA:0.5201, epoch_LC:1.8150, val_LC:1.6378, val_LA:0.7265%
#  Epoch 36: iteration 106/107
# Epoch 36 --> loss:1.4200, acc:29.15%, val_loss:1.3806, val_acc:37.76%
# Epoch 36 --> epoch_LA:0.5192, epoch_LC:1.8060, val_LC:1.6598, val_LA:0.7292%
#  Epoch 37: iteration 106/107
# Epoch 37 --> loss:1.4192, acc:29.38%, val_loss:1.3923, val_acc:39.86%
# Epoch 37 --> epoch_LA:0.5188, epoch_LC:1.8051, val_LC:1.6746, val_LA:0.7334%
#  Epoch 38: iteration 106/107
# Epoch 38 --> loss:1.4065, acc:30.37%, val_loss:1.3331, val_acc:38.46%
# Epoch 38 --> epoch_LA:0.5190, epoch_LC:1.7869, val_LC:1.5898, val_LA:0.7340%
#  Epoch 39: iteration 106/107
# Epoch 39 --> loss:1.3967, acc:31.21%, val_loss:1.3718, val_acc:33.57%
# Epoch 39 --> epoch_LA:0.5171, epoch_LC:1.7737, val_LC:1.6460, val_LA:0.7318%
#  Epoch 40: iteration 106/107
# Epoch 40 --> loss:1.4006, acc:30.66%, val_loss:1.3576, val_acc:34.97%
# Epoch 40 --> epoch_LA:0.5143, epoch_LC:1.7805, val_LC:1.6260, val_LA:0.7315%
#  Epoch 41: iteration 106/107
# Epoch 41 --> loss:1.3971, acc:30.54%, val_loss:1.3383, val_acc:35.66%
# Epoch 41 --> epoch_LA:0.5158, epoch_LC:1.7748, val_LC:1.6022, val_LA:0.7224%
#  Epoch 42: iteration 106/107
# Epoch 42 --> loss:1.3873, acc:31.79%, val_loss:1.3029, val_acc:41.26%
# Epoch 42 --> epoch_LA:0.5169, epoch_LC:1.7603, val_LC:1.5483, val_LA:0.7304%
#  Epoch 43: iteration 106/107
# Epoch 43 --> loss:1.3826, acc:30.75%, val_loss:1.3205, val_acc:38.46%
# Epoch 43 --> epoch_LA:0.5122, epoch_LC:1.7556, val_LC:1.5823, val_LA:0.7095%
#  Epoch 44: iteration 106/107
# Epoch 44 --> loss:1.3745, acc:33.13%, val_loss:1.2918, val_acc:41.26%
# Epoch 44 --> epoch_LA:0.5152, epoch_LC:1.7428, val_LC:1.5424, val_LA:0.7072%
#  Epoch 45: iteration 106/107
# Epoch 45 --> loss:1.3667, acc:33.16%, val_loss:1.2661, val_acc:41.26%
# Epoch 45 --> epoch_LA:0.5112, epoch_LC:1.7334, val_LC:1.5024, val_LA:0.7146%
#  Epoch 46: iteration 106/107
# Epoch 46 --> loss:1.3647, acc:33.62%, val_loss:1.2335, val_acc:47.55%
# Epoch 46 --> epoch_LA:0.5136, epoch_LC:1.7294, val_LC:1.4571, val_LA:0.7120%
#  Epoch 47: iteration 106/107
# Epoch 47 --> loss:1.3555, acc:32.87%, val_loss:1.2268, val_acc:45.45%
# Epoch 47 --> epoch_LA:0.5083, epoch_LC:1.7186, val_LC:1.4508, val_LA:0.7041%
#  Epoch 48: iteration 106/107
# Epoch 48 --> loss:1.3590, acc:33.57%, val_loss:1.2610, val_acc:42.66%
# Epoch 48 --> epoch_LA:0.5104, epoch_LC:1.7226, val_LC:1.5002, val_LA:0.7031%
#  Epoch 49: iteration 106/107
# Epoch 49 --> loss:1.3447, acc:34.32%, val_loss:1.2010, val_acc:46.15%
# Epoch 49 --> epoch_LA:0.5108, epoch_LC:1.7021, val_LC:1.4167, val_LA:0.6975%
#  Epoch 50: iteration 106/107
# Epoch 50 --> loss:1.3397, acc:34.35%, val_loss:1.1845, val_acc:44.76%
# Epoch 50 --> epoch_LA:0.5077, epoch_LC:1.6963, val_LC:1.3928, val_LA:0.6987%
#  Epoch 51: iteration 106/107
# Epoch 51 --> loss:1.3362, acc:35.14%, val_loss:1.1861, val_acc:46.85%
# Epoch 51 --> epoch_LA:0.5037, epoch_LC:1.6930, val_LC:1.3934, val_LA:0.7024%
#  Epoch 52: iteration 106/107
# Epoch 52 --> loss:1.3288, acc:34.70%, val_loss:1.1680, val_acc:46.15%
# Epoch 52 --> epoch_LA:0.5079, epoch_LC:1.6806, val_LC:1.3684, val_LA:0.7004%
#  Epoch 53: iteration 106/107
# Epoch 53 --> loss:1.3324, acc:34.99%, val_loss:1.2074, val_acc:43.36%
# Epoch 53 --> epoch_LA:0.5042, epoch_LC:1.6873, val_LC:1.4247, val_LA:0.7002%
#  Epoch 54: iteration 106/107
# Epoch 54 --> loss:1.3164, acc:36.01%, val_loss:1.1372, val_acc:55.24%
# Epoch 54 --> epoch_LA:0.5036, epoch_LC:1.6647, val_LC:1.3260, val_LA:0.6967%
#  Epoch 55: iteration 106/107
# Epoch 55 --> loss:1.3111, acc:36.65%, val_loss:1.1675, val_acc:48.25%
# Epoch 55 --> epoch_LA:0.5054, epoch_LC:1.6564, val_LC:1.3697, val_LA:0.6957%
#  Epoch 56: iteration 106/107
# Epoch 56 --> loss:1.3077, acc:36.47%, val_loss:1.1189, val_acc:51.75%
# Epoch 56 --> epoch_LA:0.5020, epoch_LC:1.6529, val_LC:1.3021, val_LA:0.6914%
#  Epoch 57: iteration 106/107
# Epoch 57 --> loss:1.2980, acc:38.54%, val_loss:1.1406, val_acc:47.55%
# Epoch 57 --> epoch_LA:0.4998, epoch_LC:1.6400, val_LC:1.3312, val_LA:0.6960%
#  Epoch 58: iteration 106/107
# Epoch 58 --> loss:1.2972, acc:37.20%, val_loss:1.1171, val_acc:49.65%
# Epoch 58 --> epoch_LA:0.5060, epoch_LC:1.6363, val_LC:1.3020, val_LA:0.6858%
#  Epoch 59: iteration 106/107
# Epoch 59 --> loss:1.2912, acc:38.22%, val_loss:1.1099, val_acc:55.94%
# Epoch 59 --> epoch_LA:0.5033, epoch_LC:1.6289, val_LC:1.2896, val_LA:0.6906%
#  Epoch 60: iteration 106/107
# Epoch 60 --> loss:1.2819, acc:37.49%, val_loss:1.0967, val_acc:53.15%
# Epoch 60 --> epoch_LA:0.5029, epoch_LC:1.6157, val_LC:1.2694, val_LA:0.6938%
#  Epoch 61: iteration 106/107
# Epoch 61 --> loss:1.2905, acc:38.19%, val_loss:1.1248, val_acc:48.25%
# Epoch 61 --> epoch_LA:0.4999, epoch_LC:1.6293, val_LC:1.3138, val_LA:0.6838%
#  Epoch 62: iteration 106/107
# Epoch 62 --> loss:1.2765, acc:37.81%, val_loss:1.1443, val_acc:46.85%
# Epoch 62 --> epoch_LA:0.5031, epoch_LC:1.6080, val_LC:1.3414, val_LA:0.6845%
#  Epoch 63: iteration 106/107
# Epoch 63 --> loss:1.2673, acc:38.88%, val_loss:1.0566, val_acc:53.85%
# Epoch 63 --> epoch_LA:0.4988, epoch_LC:1.5966, val_LC:1.2140, val_LA:0.6893%
#  Epoch 64: iteration 106/107
# Epoch 64 --> loss:1.2696, acc:39.32%, val_loss:1.1198, val_acc:51.75%
# Epoch 64 --> epoch_LA:0.4968, epoch_LC:1.6008, val_LC:1.3008, val_LA:0.6976%
#  Epoch 65: iteration 106/107
# Epoch 65 --> loss:1.2673, acc:40.02%, val_loss:1.1250, val_acc:51.05%
# Epoch 65 --> epoch_LA:0.4975, epoch_LC:1.5972, val_LC:1.3168, val_LA:0.6775%
#  Epoch 66: iteration 106/107
# Epoch 66 --> loss:1.2575, acc:40.02%, val_loss:1.0783, val_acc:55.24%
# Epoch 66 --> epoch_LA:0.4953, epoch_LC:1.5842, val_LC:1.2458, val_LA:0.6874%
#  Epoch 67: iteration 106/107
# Epoch 67 --> loss:1.2448, acc:39.61%, val_loss:1.0831, val_acc:55.94%
# Epoch 67 --> epoch_LA:0.4974, epoch_LC:1.5651, val_LC:1.2577, val_LA:0.6759%
#  Epoch 68: iteration 106/107
# Epoch 68 --> loss:1.2414, acc:40.13%, val_loss:1.0019, val_acc:60.14%
# Epoch 68 --> epoch_LA:0.4971, epoch_LC:1.5603, val_LC:1.1406, val_LA:0.6783%
#  Epoch 69: iteration 106/107
# Epoch 69 --> loss:1.2385, acc:39.81%, val_loss:1.0244, val_acc:56.64%
# Epoch 69 --> epoch_LA:0.4971, epoch_LC:1.5563, val_LC:1.1759, val_LA:0.6710%
#  Epoch 70: iteration 106/107
# Epoch 70 --> loss:1.2305, acc:41.64%, val_loss:1.0168, val_acc:59.44%
# Epoch 70 --> epoch_LA:0.4949, epoch_LC:1.5458, val_LC:1.1595, val_LA:0.6838%
#  Epoch 71: iteration 106/107
# Epoch 71 --> loss:1.2222, acc:41.01%, val_loss:1.0266, val_acc:55.24%
# Epoch 71 --> epoch_LA:0.4941, epoch_LC:1.5342, val_LC:1.1746, val_LA:0.6813%
#  Epoch 72: iteration 106/107
# Epoch 72 --> loss:1.2275, acc:41.27%, val_loss:0.9954, val_acc:58.74%
# Epoch 72 --> epoch_LA:0.4964, epoch_LC:1.5409, val_LC:1.1313, val_LA:0.6782%
#  Epoch 73: iteration 106/107
# Epoch 73 --> loss:1.2092, acc:42.92%, val_loss:1.0546, val_acc:53.85%
# Epoch 73 --> epoch_LA:0.4949, epoch_LC:1.5153, val_LC:1.2200, val_LA:0.6687%
#  Epoch 74: iteration 106/107
# Epoch 74 --> loss:1.2134, acc:42.95%, val_loss:1.0026, val_acc:62.94%
# Epoch 74 --> epoch_LA:0.4944, epoch_LC:1.5216, val_LC:1.1402, val_LA:0.6814%
#  Epoch 75: iteration 106/107
# Epoch 75 --> loss:1.2076, acc:42.05%, val_loss:0.9945, val_acc:59.44%
# Epoch 75 --> epoch_LA:0.4959, epoch_LC:1.5126, val_LC:1.1329, val_LA:0.6716%
#  Epoch 76: iteration 106/107
# Epoch 76 --> loss:1.1994, acc:43.39%, val_loss:1.0027, val_acc:58.74%
# Epoch 76 --> epoch_LA:0.4917, epoch_LC:1.5027, val_LC:1.1408, val_LA:0.6804%
#  Epoch 77: iteration 106/107
# Epoch 77 --> loss:1.1884, acc:43.65%, val_loss:1.0139, val_acc:61.54%
# Epoch 77 --> epoch_LA:0.4904, epoch_LC:1.4875, val_LC:1.1617, val_LA:0.6692%
#  Epoch 78: iteration 106/107
# Epoch 78 --> loss:1.1796, acc:44.09%, val_loss:0.9589, val_acc:60.14%
# Epoch 78 --> epoch_LA:0.4944, epoch_LC:1.4733, val_LC:1.0822, val_LA:0.6712%
#  Epoch 79: iteration 106/107
# Epoch 79 --> loss:1.1877, acc:43.19%, val_loss:1.0108, val_acc:60.84%
# Epoch 79 --> epoch_LA:0.4932, epoch_LC:1.4854, val_LC:1.1527, val_LA:0.6795%
#  Epoch 80: iteration 106/107
# Epoch 80 --> loss:1.1795, acc:44.55%, val_loss:0.9967, val_acc:56.64%
# Epoch 80 --> epoch_LA:0.4930, epoch_LC:1.4738, val_LC:1.1358, val_LA:0.6723%
#  Epoch 81: iteration 106/107
# Epoch 81 --> loss:1.1660, acc:43.68%, val_loss:0.9499, val_acc:62.94%
# Epoch 81 --> epoch_LA:0.4923, epoch_LC:1.4548, val_LC:1.0642, val_LA:0.6833%
#  Epoch 82: iteration 106/107
# Epoch 82 --> loss:1.1594, acc:45.13%, val_loss:1.0029, val_acc:55.24%
# Epoch 82 --> epoch_LA:0.4897, epoch_LC:1.4463, val_LC:1.1379, val_LA:0.6881%
#  Epoch 83: iteration 106/107
# Epoch 83 --> loss:1.1499, acc:46.00%, val_loss:1.0268, val_acc:58.04%
# Epoch 83 --> epoch_LA:0.4919, epoch_LC:1.4318, val_LC:1.1797, val_LA:0.6701%
#  Epoch 84: iteration 106/107
# Epoch 84 --> loss:1.1472, acc:46.64%, val_loss:0.9926, val_acc:60.14%
# Epoch 84 --> epoch_LA:0.4922, epoch_LC:1.4279, val_LC:1.1365, val_LA:0.6568%
#  Epoch 85: iteration 106/107
# Epoch 85 --> loss:1.1383, acc:46.61%, val_loss:1.0012, val_acc:60.84%
# Epoch 85 --> epoch_LA:0.4890, epoch_LC:1.4165, val_LC:1.1493, val_LA:0.6557%
#  Epoch 86: iteration 106/107
# Epoch 86 --> loss:1.1360, acc:47.28%, val_loss:1.0449, val_acc:59.44%
# Epoch 86 --> epoch_LA:0.4908, epoch_LC:1.4125, val_LC:1.2095, val_LA:0.6608%
#  Epoch 87: iteration 106/107
# Epoch 87 --> loss:1.1422, acc:46.24%, val_loss:1.0137, val_acc:60.14%
# Epoch 87 --> epoch_LA:0.4912, epoch_LC:1.4211, val_LC:1.1671, val_LA:0.6558%
#  Epoch 88: iteration 106/107
# Epoch 88 --> loss:1.1363, acc:47.46%, val_loss:0.9473, val_acc:64.34%
# Epoch 88 --> epoch_LA:0.4871, epoch_LC:1.4145, val_LC:1.0720, val_LA:0.6563%
#  Epoch 89: iteration 106/107
# Epoch 89 --> loss:1.1209, acc:48.10%, val_loss:1.0224, val_acc:56.64%
# Epoch 89 --> epoch_LA:0.4892, epoch_LC:1.3917, val_LC:1.1708, val_LA:0.6760%
#  Epoch 90: iteration 106/107
# Epoch 90 --> loss:1.1259, acc:47.22%, val_loss:0.9543, val_acc:62.94%
# Epoch 90 --> epoch_LA:0.4900, epoch_LC:1.3985, val_LC:1.0763, val_LA:0.6696%
#  Epoch 91: iteration 106/107
# Epoch 91 --> loss:1.1187, acc:48.13%, val_loss:0.9615, val_acc:62.24%
# Epoch 91 --> epoch_LA:0.4891, epoch_LC:1.3886, val_LC:1.0925, val_LA:0.6558%
#  Epoch 92: iteration 106/107
# Epoch 92 --> loss:1.0963, acc:49.20%, val_loss:0.9757, val_acc:61.54%
# Epoch 92 --> epoch_LA:0.4886, epoch_LC:1.3568, val_LC:1.1119, val_LA:0.6581%
#  Epoch 93: iteration 106/107
# Epoch 93 --> loss:1.0951, acc:49.87%, val_loss:0.9195, val_acc:67.13%
# Epoch 93 --> epoch_LA:0.4882, epoch_LC:1.3551, val_LC:1.0331, val_LA:0.6543%
#  Epoch 94: iteration 106/107
# Epoch 94 --> loss:1.0917, acc:48.91%, val_loss:0.9736, val_acc:64.34%
# Epoch 94 --> epoch_LA:0.4863, epoch_LC:1.3512, val_LC:1.1072, val_LA:0.6619%
#  Epoch 95: iteration 106/107
# Epoch 95 --> loss:1.0753, acc:49.81%, val_loss:0.9669, val_acc:65.03%
# Epoch 95 --> epoch_LA:0.4866, epoch_LC:1.3277, val_LC:1.0990, val_LA:0.6589%
#  Epoch 96: iteration 106/107
# Epoch 96 --> loss:1.0809, acc:50.07%, val_loss:0.9481, val_acc:59.44%
# Epoch 96 --> epoch_LA:0.4885, epoch_LC:1.3348, val_LC:1.0662, val_LA:0.6724%
#  Epoch 97: iteration 106/107
# Epoch 97 --> loss:1.0614, acc:52.02%, val_loss:0.9470, val_acc:62.94%
# Epoch 97 --> epoch_LA:0.4879, epoch_LC:1.3072, val_LC:1.0719, val_LA:0.6555%
#  Epoch 98: iteration 106/107
# Epoch 98 --> loss:1.0515, acc:52.51%, val_loss:0.9498, val_acc:65.73%
# Epoch 98 --> epoch_LA:0.4878, epoch_LC:1.2931, val_LC:1.0715, val_LA:0.6658%
#  Epoch 99: iteration 106/107
# Epoch 99 --> loss:1.0550, acc:50.48%, val_loss:0.9454, val_acc:62.94%
# Epoch 99 --> epoch_LA:0.4884, epoch_LC:1.2978, val_LC:1.0746, val_LA:0.6439%
#  Epoch 100: iteration 106/107
# Epoch 100 --> loss:1.0500, acc:52.11%, val_loss:0.9135, val_acc:65.73%
# Epoch 100 --> epoch_LA:0.4853, epoch_LC:1.2921, val_LC:1.0286, val_LA:0.6450%
#  Epoch 101: iteration 106/107
# Epoch 101 --> loss:1.0404, acc:52.95%, val_loss:1.0081, val_acc:60.14%
# Epoch 101 --> epoch_LA:0.4860, epoch_LC:1.2781, val_LC:1.1568, val_LA:0.6612%
#  Epoch 102: iteration 106/107
# Epoch 102 --> loss:1.0227, acc:53.85%, val_loss:0.9565, val_acc:62.24%
# Epoch 102 --> epoch_LA:0.4848, epoch_LC:1.2533, val_LC:1.0877, val_LA:0.6506%
#  Epoch 103: iteration 106/107
# Epoch 103 --> loss:1.0229, acc:53.50%, val_loss:1.0163, val_acc:62.24%
# Epoch 103 --> epoch_LA:0.4843, epoch_LC:1.2537, val_LC:1.1717, val_LA:0.6539%
#  Epoch 104: iteration 106/107
# Epoch 104 --> loss:1.0112, acc:55.27%, val_loss:0.9583, val_acc:61.54%
# Epoch 104 --> epoch_LA:0.4858, epoch_LC:1.2364, val_LC:1.0850, val_LA:0.6627%
#  Epoch 105: iteration 106/107
# Epoch 105 --> loss:1.0068, acc:54.43%, val_loss:0.9914, val_acc:60.14%
# Epoch 105 --> epoch_LA:0.4829, epoch_LC:1.2314, val_LC:1.1377, val_LA:0.6500%
#  Epoch 106: iteration 106/107
# Epoch 106 --> loss:1.0134, acc:54.08%, val_loss:0.9088, val_acc:67.83%
# Epoch 106 --> epoch_LA:0.4847, epoch_LC:1.2400, val_LC:1.0201, val_LA:0.6490%
#  Epoch 107: iteration 106/107
# Epoch 107 --> loss:0.9916, acc:55.77%, val_loss:0.9936, val_acc:65.03%
# Epoch 107 --> epoch_LA:0.4851, epoch_LC:1.2087, val_LC:1.1382, val_LA:0.6560%
#  Epoch 108: iteration 106/107
# Epoch 108 --> loss:0.9749, acc:56.44%, val_loss:1.0052, val_acc:63.64%
# Epoch 108 --> epoch_LA:0.4852, epoch_LC:1.1848, val_LC:1.1617, val_LA:0.6401%
#  Epoch 109: iteration 106/107
# Epoch 109 --> loss:0.9721, acc:56.61%, val_loss:0.9069, val_acc:66.43%
# Epoch 109 --> epoch_LA:0.4858, epoch_LC:1.1805, val_LC:1.0165, val_LA:0.6512%
#  Epoch 110: iteration 106/107
# Epoch 110 --> loss:0.9690, acc:56.41%, val_loss:1.0477, val_acc:58.04%
# Epoch 110 --> epoch_LA:0.4818, epoch_LC:1.1778, val_LC:1.2201, val_LA:0.6454%
#  Epoch 111: iteration 106/107
# Epoch 111 --> loss:0.9646, acc:56.93%, val_loss:0.9634, val_acc:64.34%
# Epoch 111 --> epoch_LA:0.4848, epoch_LC:1.1703, val_LC:1.0892, val_LA:0.6698%
#  Epoch 112: iteration 106/107
# Epoch 112 --> loss:0.9381, acc:59.17%, val_loss:0.9560, val_acc:65.73%
# Epoch 112 --> epoch_LA:0.4832, epoch_LC:1.1330, val_LC:1.0848, val_LA:0.6553%
#  Epoch 113: iteration 106/107
# Epoch 113 --> loss:0.9271, acc:59.43%, val_loss:1.0104, val_acc:60.84%
# Epoch 113 --> epoch_LA:0.4842, epoch_LC:1.1170, val_LC:1.1689, val_LA:0.6407%
#  Epoch 114: iteration 106/107
# Epoch 114 --> loss:0.9255, acc:59.17%, val_loss:0.9659, val_acc:62.24%
# Epoch 114 --> epoch_LA:0.4845, epoch_LC:1.1144, val_LC:1.1034, val_LA:0.6451%
#  Epoch 115: iteration 106/107
# Epoch 115 --> loss:0.9141, acc:60.30%, val_loss:1.0027, val_acc:62.24%
# Epoch 115 --> epoch_LA:0.4854, epoch_LC:1.0978, val_LC:1.1577, val_LA:0.6410%
#  Epoch 116: iteration 106/107
# Epoch 116 --> loss:0.9128, acc:60.42%, val_loss:1.0083, val_acc:62.94%
# Epoch 116 --> epoch_LA:0.4840, epoch_LC:1.0966, val_LC:1.1586, val_LA:0.6577%
#  Epoch 117: iteration 106/107
# Epoch 117 --> loss:0.9092, acc:61.06%, val_loss:0.9829, val_acc:66.43%
# Epoch 117 --> epoch_LA:0.4834, epoch_LC:1.0916, val_LC:1.1235, val_LA:0.6547%
#  Epoch 118: iteration 106/107
# Epoch 118 --> loss:0.8865, acc:62.71%, val_loss:1.0737, val_acc:65.73%
# Epoch 118 --> epoch_LA:0.4860, epoch_LC:1.0581, val_LC:1.2605, val_LA:0.6377%
#  Epoch 119: iteration 106/107
# Epoch 119 --> loss:0.8714, acc:62.77%, val_loss:0.9558, val_acc:64.34%
# Epoch 119 --> epoch_LA:0.4816, epoch_LC:1.0385, val_LC:1.0889, val_LA:0.6453%
#  Epoch 120: iteration 106/107
# Epoch 120 --> loss:0.8686, acc:63.32%, val_loss:0.9680, val_acc:62.94%
# Epoch 120 --> epoch_LA:0.4832, epoch_LC:1.0338, val_LC:1.1044, val_LA:0.6496%
#  Epoch 121: iteration 106/107
# Epoch 121 --> loss:0.8920, acc:61.23%, val_loss:1.1702, val_acc:56.64%
# Epoch 121 --> epoch_LA:0.4831, epoch_LC:1.0672, val_LC:1.3929, val_LA:0.6506%
#  Epoch 122: iteration 106/107
# Epoch 122 --> loss:0.8832, acc:62.69%, val_loss:0.9301, val_acc:65.03%
# Epoch 122 --> epoch_LA:0.4828, epoch_LC:1.0548, val_LC:1.0563, val_LA:0.6357%
#  Epoch 123: iteration 106/107
# Epoch 123 --> loss:0.8387, acc:64.31%, val_loss:1.0040, val_acc:62.94%
# Epoch 123 --> epoch_LA:0.4820, epoch_LC:0.9915, val_LC:1.1600, val_LA:0.6400%
#  Epoch 124: iteration 106/107
# Epoch 124 --> loss:0.8441, acc:64.02%, val_loss:1.0103, val_acc:64.34%
# Epoch 124 --> epoch_LA:0.4858, epoch_LC:0.9977, val_LC:1.1692, val_LA:0.6394%
#  Epoch 125: iteration 106/107
# Epoch 125 --> loss:0.8502, acc:64.84%, val_loss:0.9901, val_acc:61.54%
# Epoch 125 --> epoch_LA:0.4843, epoch_LC:1.0070, val_LC:1.1400, val_LA:0.6405%
#  Epoch 126: iteration 106/107
# Epoch 126 --> loss:0.8523, acc:63.35%, val_loss:0.9601, val_acc:65.73%
# Epoch 126 --> epoch_LA:0.4841, epoch_LC:1.0101, val_LC:1.0925, val_LA:0.6513%
#  Epoch 127: iteration 106/107
# Epoch 127 --> loss:0.8084, acc:67.54%, val_loss:1.1593, val_acc:60.14%
# Epoch 127 --> epoch_LA:0.4787, epoch_LC:0.9497, val_LC:1.3626, val_LA:0.6849%
#  Epoch 128: iteration 106/107
# Epoch 128 --> loss:0.8332, acc:64.23%, val_loss:0.9652, val_acc:65.73%
# Epoch 128 --> epoch_LA:0.4824, epoch_LC:0.9835, val_LC:1.1047, val_LA:0.6398%
#  Epoch 129: iteration 106/107
# Epoch 129 --> loss:0.7988, acc:67.39%, val_loss:1.0582, val_acc:60.84%
# Epoch 129 --> epoch_LA:0.4849, epoch_LC:0.9333, val_LC:1.2427, val_LA:0.6278%
#  Epoch 130: iteration 106/107
# Epoch 130 --> loss:0.8170, acc:65.71%, val_loss:1.0654, val_acc:66.43%
# Epoch 130 --> epoch_LA:0.4865, epoch_LC:0.9587, val_LC:1.2384, val_LA:0.6617%
#  Epoch 131: iteration 106/107
# Epoch 131 --> loss:0.7705, acc:69.22%, val_loss:1.0282, val_acc:65.03%
# Epoch 131 --> epoch_LA:0.4847, epoch_LC:0.8930, val_LC:1.1917, val_LA:0.6468%
#  Epoch 132: iteration 106/107
# Epoch 132 --> loss:0.7703, acc:68.99%, val_loss:1.0454, val_acc:62.24%
# Epoch 132 --> epoch_LA:0.4835, epoch_LC:0.8932, val_LC:1.2145, val_LA:0.6509%
#  Epoch 133: iteration 106/107
# Epoch 133 --> loss:0.7849, acc:67.95%, val_loss:1.0679, val_acc:58.04%
# Epoch 133 --> epoch_LA:0.4835, epoch_LC:0.9140, val_LC:1.2372, val_LA:0.6727%
#  Epoch 134: iteration 106/107
# Epoch 134 --> loss:0.7459, acc:69.89%, val_loss:0.9153, val_acc:69.93%
# Epoch 134 --> epoch_LA:0.4822, epoch_LC:0.8589, val_LC:1.0208, val_LA:0.6689%
#  Epoch 135: iteration 106/107
# Epoch 135 --> loss:0.7198, acc:71.96%, val_loss:0.9639, val_acc:69.23%
# Epoch 135 --> epoch_LA:0.4865, epoch_LC:0.8198, val_LC:1.0954, val_LA:0.6572%
#  Epoch 136: iteration 106/107
# Epoch 136 --> loss:0.7089, acc:72.54%, val_loss:1.1599, val_acc:59.44%
# Epoch 136 --> epoch_LA:0.4824, epoch_LC:0.8060, val_LC:1.3687, val_LA:0.6727%
#  Epoch 137: iteration 106/107
# Epoch 137 --> loss:0.7329, acc:71.05%, val_loss:0.9940, val_acc:63.64%
# Epoch 137 --> epoch_LA:0.4873, epoch_LC:0.8382, val_LC:1.1457, val_LA:0.6399%
#  Epoch 138: iteration 106/107
# Epoch 138 --> loss:0.7058, acc:71.96%, val_loss:1.1644, val_acc:58.74%
# Epoch 138 --> epoch_LA:0.4830, epoch_LC:0.8013, val_LC:1.3854, val_LA:0.6488%
#  Epoch 139: iteration 106/107
# Epoch 139 --> loss:0.6937, acc:72.83%, val_loss:1.0167, val_acc:66.43%
# Epoch 139 --> epoch_LA:0.4842, epoch_LC:0.7835, val_LC:1.1735, val_LA:0.6508%
#  Epoch 140: iteration 106/107
# Epoch 140 --> loss:0.6851, acc:73.53%, val_loss:1.0479, val_acc:67.83%
# Epoch 140 --> epoch_LA:0.4819, epoch_LC:0.7722, val_LC:1.2127, val_LA:0.6634%
#  Epoch 141: iteration 106/107
# Epoch 141 --> loss:0.6824, acc:73.84%, val_loss:1.0616, val_acc:60.84%
# Epoch 141 --> epoch_LA:0.4873, epoch_LC:0.7661, val_LC:1.2464, val_LA:0.6303%
#  Epoch 142: iteration 106/107
# Epoch 142 --> loss:0.7228, acc:71.05%, val_loss:1.0791, val_acc:60.84%
# Epoch 142 --> epoch_LA:0.4850, epoch_LC:0.8246, val_LC:1.2680, val_LA:0.6385%
#  Epoch 143: iteration 106/107
# Epoch 143 --> loss:0.6628, acc:75.44%, val_loss:0.9813, val_acc:63.64%
# Epoch 143 --> epoch_LA:0.4867, epoch_LC:0.7383, val_LC:1.1183, val_LA:0.6616%
#  Epoch 144: iteration 106/107
# Epoch 144 --> loss:0.6497, acc:75.36%, val_loss:0.9511, val_acc:69.93%
# Epoch 144 --> epoch_LA:0.4849, epoch_LC:0.7203, val_LC:1.0880, val_LA:0.6319%
#  Epoch 145: iteration 106/107
# Epoch 145 --> loss:0.6420, acc:76.61%, val_loss:0.9701, val_acc:65.73%
# Epoch 145 --> epoch_LA:0.4855, epoch_LC:0.7091, val_LC:1.1040, val_LA:0.6577%
#  Epoch 146: iteration 106/107
# Epoch 146 --> loss:0.6446, acc:75.85%, val_loss:0.9703, val_acc:67.13%
# Epoch 146 --> epoch_LA:0.4847, epoch_LC:0.7132, val_LC:1.0975, val_LA:0.6737%
#  Epoch 147: iteration 106/107
# Epoch 147 --> loss:0.6162, acc:77.54%, val_loss:1.0689, val_acc:67.13%
# Epoch 147 --> epoch_LA:0.4825, epoch_LC:0.6735, val_LC:1.2442, val_LA:0.6600%
#  Epoch 148: iteration 106/107
# Epoch 148 --> loss:0.6125, acc:77.71%, val_loss:1.0563, val_acc:66.43%
# Epoch 148 --> epoch_LA:0.4839, epoch_LC:0.6676, val_LC:1.2378, val_LA:0.6330%
#  Epoch 149: iteration 106/107
# Epoch 149 --> loss:0.5866, acc:79.02%, val_loss:0.9867, val_acc:67.83%
# Epoch 149 --> epoch_LA:0.4807, epoch_LC:0.6320, val_LC:1.1351, val_LA:0.6405%
#  Epoch 150: iteration 106/107
# Epoch 150 --> loss:0.6090, acc:77.68%, val_loss:1.0527, val_acc:67.13%
# Epoch 150 --> epoch_LA:0.4807, epoch_LC:0.6640, val_LC:1.2120, val_LA:0.6808%
#  Epoch 151: iteration 106/107
# Epoch 151 --> loss:0.5810, acc:78.64%, val_loss:0.9605, val_acc:69.23%
# Epoch 151 --> epoch_LA:0.4801, epoch_LC:0.6243, val_LC:1.0923, val_LA:0.6529%
#  Epoch 152: iteration 106/107
# Epoch 152 --> loss:0.5700, acc:79.86%, val_loss:1.0267, val_acc:63.64%
# Epoch 152 --> epoch_LA:0.4813, epoch_LC:0.6080, val_LC:1.1889, val_LA:0.6481%
#  Epoch 153: iteration 106/107
# Epoch 153 --> loss:0.5614, acc:80.85%, val_loss:1.0051, val_acc:67.13%
# Epoch 153 --> epoch_LA:0.4805, epoch_LC:0.5961, val_LC:1.1450, val_LA:0.6786%
#  Epoch 154: iteration 106/107
# Epoch 154 --> loss:0.5514, acc:80.99%, val_loss:1.0335, val_acc:66.43%
# Epoch 154 --> epoch_LA:0.4826, epoch_LC:0.5809, val_LC:1.1986, val_LA:0.6485%
#  Epoch 155: iteration 106/107
# Epoch 155 --> loss:0.5799, acc:79.25%, val_loss:1.0614, val_acc:67.83%
# Epoch 155 --> epoch_LA:0.4798, epoch_LC:0.6228, val_LC:1.2331, val_LA:0.6608%
#  Epoch 156: iteration 106/107
# Epoch 156 --> loss:0.5506, acc:81.23%, val_loss:0.9767, val_acc:64.34%
# Epoch 156 --> epoch_LA:0.4848, epoch_LC:0.5788, val_LC:1.1137, val_LA:0.6569%
#  Epoch 157: iteration 106/107
# Epoch 157 --> loss:0.5350, acc:81.60%, val_loss:1.0727, val_acc:65.73%
# Epoch 157 --> epoch_LA:0.4792, epoch_LC:0.5588, val_LC:1.2599, val_LA:0.6359%
#  Epoch 158: iteration 106/107
# Epoch 158 --> loss:0.5806, acc:79.60%, val_loss:1.0503, val_acc:66.43%
# Epoch 158 --> epoch_LA:0.4843, epoch_LC:0.6219, val_LC:1.2167, val_LA:0.6620%
#  Epoch 159: iteration 106/107
# Epoch 159 --> loss:0.5426, acc:81.87%, val_loss:1.2960, val_acc:58.04%
# Epoch 159 --> epoch_LA:0.4798, epoch_LC:0.5696, val_LC:1.5739, val_LA:0.6475%
#  Epoch 160: iteration 106/107
# Epoch 160 --> loss:0.6033, acc:77.94%, val_loss:1.1148, val_acc:59.44%
# Epoch 160 --> epoch_LA:0.4806, epoch_LC:0.6559, val_LC:1.3161, val_LA:0.6451%
#  Epoch 161: iteration 106/107
# Epoch 161 --> loss:0.5585, acc:80.33%, val_loss:1.1200, val_acc:62.94%
# Epoch 161 --> epoch_LA:0.4815, epoch_LC:0.5915, val_LC:1.3264, val_LA:0.6387%
#  Epoch 162: iteration 106/107
# Epoch 162 --> loss:0.5379, acc:80.88%, val_loss:1.1382, val_acc:62.24%
# Epoch 162 --> epoch_LA:0.4809, epoch_LC:0.5624, val_LC:1.3423, val_LA:0.6619%
#  Epoch 163: iteration 106/107
# Epoch 163 --> loss:0.5142, acc:82.56%, val_loss:1.1601, val_acc:63.64%
# Epoch 163 --> epoch_LA:0.4792, epoch_LC:0.5292, val_LC:1.3681, val_LA:0.6749%
#  Epoch 164: iteration 106/107
# Epoch 164 --> loss:0.4848, acc:84.60%, val_loss:0.9835, val_acc:71.33%
# Epoch 164 --> epoch_LA:0.4815, epoch_LC:0.4863, val_LC:1.1175, val_LA:0.6707%
#  Epoch 165: iteration 106/107
# Epoch 165 --> loss:0.4671, acc:85.91%, val_loss:1.1663, val_acc:63.64%
# Epoch 165 --> epoch_LA:0.4777, epoch_LC:0.4626, val_LC:1.3910, val_LA:0.6418%
#  Epoch 166: iteration 106/107
# Epoch 166 --> loss:0.5282, acc:81.63%, val_loss:1.0111, val_acc:69.23%
# Epoch 166 --> epoch_LA:0.4811, epoch_LC:0.5483, val_LC:1.1557, val_LA:0.6738%
#  Epoch 167: iteration 106/107
# Epoch 167 --> loss:0.4698, acc:85.44%, val_loss:1.0626, val_acc:66.43%
# Epoch 167 --> epoch_LA:0.4797, epoch_LC:0.4656, val_LC:1.2284, val_LA:0.6756%
#  Epoch 168: iteration 106/107
# Epoch 168 --> loss:0.4583, acc:85.96%, val_loss:1.0730, val_acc:65.73%
# Epoch 168 --> epoch_LA:0.4762, epoch_LC:0.4506, val_LC:1.2559, val_LA:0.6461%
#  Epoch 169: iteration 106/107
# Epoch 169 --> loss:0.4939, acc:83.09%, val_loss:1.1811, val_acc:64.34%
# Epoch 169 --> epoch_LA:0.4812, epoch_LC:0.4993, val_LC:1.4060, val_LA:0.6564%
#  Epoch 170: iteration 106/107
# Epoch 170 --> loss:0.4836, acc:84.42%, val_loss:1.0763, val_acc:66.43%
# Epoch 170 --> epoch_LA:0.4780, epoch_LC:0.4860, val_LC:1.2574, val_LA:0.6538%
#  Epoch 171: iteration 106/107
# Epoch 171 --> loss:0.4327, acc:87.36%, val_loss:1.0176, val_acc:70.63%
# Epoch 171 --> epoch_LA:0.4801, epoch_LC:0.4123, val_LC:1.1798, val_LA:0.6390%
#  Epoch 172: iteration 106/107
# Epoch 172 --> loss:0.4302, acc:87.07%, val_loss:1.0211, val_acc:71.33%
# Epoch 172 --> epoch_LA:0.4789, epoch_LC:0.4093, val_LC:1.1813, val_LA:0.6474%
#  Epoch 173: iteration 106/107
# Epoch 173 --> loss:0.4452, acc:85.85%, val_loss:1.1694, val_acc:61.54%
# Epoch 173 --> epoch_LA:0.4822, epoch_LC:0.4293, val_LC:1.3866, val_LA:0.6627%
#  Epoch 174: iteration 106/107
# Epoch 174 --> loss:0.4382, acc:86.89%, val_loss:1.0055, val_acc:69.23%
# Epoch 174 --> epoch_LA:0.4796, epoch_LC:0.4204, val_LC:1.1535, val_LA:0.6604%
#  Epoch 175: iteration 106/107
# Epoch 175 --> loss:0.4419, acc:85.93%, val_loss:0.9902, val_acc:70.63%
# Epoch 175 --> epoch_LA:0.4745, epoch_LC:0.4279, val_LC:1.1330, val_LA:0.6568%
#  Epoch 176: iteration 106/107
# Epoch 176 --> loss:0.4090, acc:88.14%, val_loss:1.1156, val_acc:67.83%
# Epoch 176 --> epoch_LA:0.4760, epoch_LC:0.3803, val_LC:1.3094, val_LA:0.6636%
#  Epoch 177: iteration 106/107
# Epoch 177 --> loss:0.3852, acc:89.77%, val_loss:1.0289, val_acc:67.83%
# Epoch 177 --> epoch_LA:0.4754, epoch_LC:0.3466, val_LC:1.1948, val_LA:0.6418%
#  Epoch 178: iteration 106/107
# Epoch 178 --> loss:0.3861, acc:90.00%, val_loss:1.1074, val_acc:64.34%
# Epoch 178 --> epoch_LA:0.4762, epoch_LC:0.3475, val_LC:1.3059, val_LA:0.6443%
#  Epoch 179: iteration 106/107
# Epoch 179 --> loss:0.4350, acc:86.63%, val_loss:1.1423, val_acc:65.73%
# Epoch 179 --> epoch_LA:0.4799, epoch_LC:0.4158, val_LC:1.3579, val_LA:0.6393%
#  Epoch 180: iteration 106/107
# Epoch 180 --> loss:0.3704, acc:90.29%, val_loss:1.1205, val_acc:69.93%
# Epoch 180 --> epoch_LA:0.4753, epoch_LC:0.3254, val_LC:1.3254, val_LA:0.6424%
#  Epoch 181: iteration 106/107
# Epoch 181 --> loss:0.3844, acc:89.65%, val_loss:1.1354, val_acc:63.64%
# Epoch 181 --> epoch_LA:0.4772, epoch_LC:0.3447, val_LC:1.3468, val_LA:0.6420%
#  Epoch 182: iteration 106/107
# Epoch 182 --> loss:0.3639, acc:90.79%, val_loss:1.0806, val_acc:68.53%
# Epoch 182 --> epoch_LA:0.4767, epoch_LC:0.3156, val_LC:1.2649, val_LA:0.6506%
#  Epoch 183: iteration 106/107
# Epoch 183 --> loss:0.3729, acc:89.97%, val_loss:1.0467, val_acc:68.53%
# Epoch 183 --> epoch_LA:0.4792, epoch_LC:0.3274, val_LC:1.2227, val_LA:0.6359%
#  Epoch 184: iteration 106/107
# Epoch 184 --> loss:0.3816, acc:89.54%, val_loss:1.2134, val_acc:60.84%
# Epoch 184 --> epoch_LA:0.4777, epoch_LC:0.3403, val_LC:1.4606, val_LA:0.6367%
#  Epoch 185: iteration 106/107
# Epoch 185 --> loss:0.4201, acc:87.36%, val_loss:1.0287, val_acc:67.83%
# Epoch 185 --> epoch_LA:0.4751, epoch_LC:0.3966, val_LC:1.1937, val_LA:0.6436%
#  Epoch 186: iteration 106/107
# Epoch 186 --> loss:0.3925, acc:88.90%, val_loss:1.0331, val_acc:69.23%
# Epoch 186 --> epoch_LA:0.4744, epoch_LC:0.3574, val_LC:1.1974, val_LA:0.6497%
#  Epoch 187: iteration 106/107
# Epoch 187 --> loss:0.3802, acc:89.68%, val_loss:1.1015, val_acc:62.24%
# Epoch 187 --> epoch_LA:0.4746, epoch_LC:0.3397, val_LC:1.3007, val_LA:0.6367%
#  Epoch 188: iteration 106/107
# Epoch 188 --> loss:0.3920, acc:89.51%, val_loss:1.1523, val_acc:67.13%
# Epoch 188 --> epoch_LA:0.4731, epoch_LC:0.3572, val_LC:1.3717, val_LA:0.6405%
#  Epoch 189: iteration 106/107
# Epoch 189 --> loss:0.3762, acc:89.80%, val_loss:1.0422, val_acc:72.73%
# Epoch 189 --> epoch_LA:0.4736, epoch_LC:0.3344, val_LC:1.2125, val_LA:0.6449%
#  Epoch 190: iteration 106/107
# Epoch 190 --> loss:0.3597, acc:90.35%, val_loss:1.2111, val_acc:62.94%
# Epoch 190 --> epoch_LA:0.4696, epoch_LC:0.3126, val_LC:1.4444, val_LA:0.6667%
#  Epoch 191: iteration 106/107
# Epoch 191 --> loss:0.3364, acc:92.12%, val_loss:1.1978, val_acc:64.34%
# Epoch 191 --> epoch_LA:0.4730, epoch_LC:0.2778, val_LC:1.4345, val_LA:0.6454%
#  Epoch 192: iteration 106/107
# Epoch 192 --> loss:0.3659, acc:90.24%, val_loss:1.1721, val_acc:64.34%
# Epoch 192 --> epoch_LA:0.4719, epoch_LC:0.3205, val_LC:1.3792, val_LA:0.6888%
#  Epoch 193: iteration 106/107
# Epoch 193 --> loss:0.3284, acc:92.68%, val_loss:1.1210, val_acc:67.13%
# Epoch 193 --> epoch_LA:0.4738, epoch_LC:0.2661, val_LC:1.3305, val_LA:0.6321%
#  Epoch 194: iteration 106/107
# Epoch 194 --> loss:0.3044, acc:93.78%, val_loss:1.0101, val_acc:68.53%
# Epoch 194 --> epoch_LA:0.4701, epoch_LC:0.2333, val_LC:1.1733, val_LA:0.6292%
#  Epoch 195: iteration 106/107
# Epoch 195 --> loss:0.3008, acc:94.01%, val_loss:1.1322, val_acc:69.93%
# Epoch 195 --> epoch_LA:0.4702, epoch_LC:0.2282, val_LC:1.3525, val_LA:0.6181%
#  Epoch 196: iteration 106/107
# Epoch 196 --> loss:0.3162, acc:92.85%, val_loss:1.1120, val_acc:67.13%
# Epoch 196 --> epoch_LA:0.4680, epoch_LC:0.2511, val_LC:1.3017, val_LA:0.6695%
#  Epoch 197: iteration 106/107
# Epoch 197 --> loss:0.3156, acc:92.73%, val_loss:1.1064, val_acc:74.13%
# Epoch 197 --> epoch_LA:0.4703, epoch_LC:0.2493, val_LC:1.3039, val_LA:0.6455%
#  Epoch 198: iteration 106/107
# Epoch 198 --> loss:0.3371, acc:91.54%, val_loss:1.1343, val_acc:68.53%
# Epoch 198 --> epoch_LA:0.4712, epoch_LC:0.2797, val_LC:1.3507, val_LA:0.6293%
#  Epoch 199: iteration 106/107
# Epoch 199 --> loss:0.3555, acc:90.82%, val_loss:1.0988, val_acc:69.93%
# Epoch 199 --> epoch_LA:0.4703, epoch_LC:0.3063, val_LC:1.2887, val_LA:0.6557%
#  Epoch 200: iteration 106/107
# Epoch 200 --> loss:0.3478, acc:91.25%, val_loss:1.1917, val_acc:63.64%
# Epoch 200 --> epoch_LA:0.4720, epoch_LC:0.2946, val_LC:1.4170, val_LA:0.6662%
#  Epoch 201: iteration 106/107
# Epoch 201 --> loss:0.3036, acc:93.55%, val_loss:1.0765, val_acc:68.53%
# Epoch 201 --> epoch_LA:0.4721, epoch_LC:0.2313, val_LC:1.2634, val_LA:0.6404%
#  Epoch 202: iteration 106/107
# Epoch 202 --> loss:0.2901, acc:94.42%, val_loss:1.0494, val_acc:68.53%
# Epoch 202 --> epoch_LA:0.4663, epoch_LC:0.2146, val_LC:1.2210, val_LA:0.6490%
#  Epoch 203: iteration 106/107
# Epoch 203 --> loss:0.2716, acc:95.55%, val_loss:1.0220, val_acc:71.33%
# Epoch 203 --> epoch_LA:0.4692, epoch_LC:0.1869, val_LC:1.1918, val_LA:0.6259%
#  Epoch 204: iteration 106/107
# Epoch 204 --> loss:0.2615, acc:95.73%, val_loss:1.0723, val_acc:67.83%
# Epoch 204 --> epoch_LA:0.4655, epoch_LC:0.1740, val_LC:1.2643, val_LA:0.6244%
#  Epoch 205: iteration 106/107
# Epoch 205 --> loss:0.2516, acc:96.13%, val_loss:0.9809, val_acc:72.03%
# Epoch 205 --> epoch_LA:0.4657, epoch_LC:0.1598, val_LC:1.1335, val_LA:0.6247%
#  Epoch 206: iteration 106/107
# Epoch 206 --> loss:0.2591, acc:95.82%, val_loss:1.1150, val_acc:70.63%
# Epoch 206 --> epoch_LA:0.4652, epoch_LC:0.1708, val_LC:1.3164, val_LA:0.6450%
#  Epoch 207: iteration 106/107
# Epoch 207 --> loss:0.2983, acc:93.32%, val_loss:1.1645, val_acc:62.94%
# Epoch 207 --> epoch_LA:0.4691, epoch_LC:0.2252, val_LC:1.3921, val_LA:0.6334%
#  Epoch 208: iteration 106/107
# Epoch 208 --> loss:0.3971, acc:88.08%, val_loss:1.2511, val_acc:58.74%
# Epoch 208 --> epoch_LA:0.4667, epoch_LC:0.3673, val_LC:1.5217, val_LA:0.6198%
#  Epoch 209: iteration 106/107
# Epoch 209 --> loss:0.3091, acc:92.79%, val_loss:1.1710, val_acc:63.64%
# Epoch 209 --> epoch_LA:0.4665, epoch_LC:0.2417, val_LC:1.4039, val_LA:0.6275%
#  Epoch 210: iteration 106/107
# Epoch 210 --> loss:0.2617, acc:95.58%, val_loss:1.0510, val_acc:70.63%
# Epoch 210 --> epoch_LA:0.4657, epoch_LC:0.1743, val_LC:1.2224, val_LA:0.6509%
#  Epoch 211: iteration 106/107
# Epoch 211 --> loss:0.2621, acc:95.15%, val_loss:1.0089, val_acc:70.63%
# Epoch 211 --> epoch_LA:0.4641, epoch_LC:0.1755, val_LC:1.1556, val_LA:0.6667%
#  Epoch 212: iteration 106/107
# Epoch 212 --> loss:0.2445, acc:96.72%, val_loss:1.0646, val_acc:71.33%
# Epoch 212 --> epoch_LA:0.4610, epoch_LC:0.1517, val_LC:1.2430, val_LA:0.6484%
#  Epoch 213: iteration 106/107
# Epoch 213 --> loss:0.2390, acc:96.60%, val_loss:1.0512, val_acc:71.33%
# Epoch 213 --> epoch_LA:0.4654, epoch_LC:0.1419, val_LC:1.2255, val_LA:0.6444%
#  Epoch 214: iteration 106/107
# Epoch 214 --> loss:0.2636, acc:95.38%, val_loss:1.0083, val_acc:69.23%
# Epoch 214 --> epoch_LA:0.4619, epoch_LC:0.1786, val_LC:1.1701, val_LA:0.6307%
#  Epoch 215: iteration 106/107
# Epoch 215 --> loss:0.2886, acc:94.19%, val_loss:1.0390, val_acc:69.23%
# Epoch 215 --> epoch_LA:0.4612, epoch_LC:0.2147, val_LC:1.1985, val_LA:0.6670%
#  Epoch 216: iteration 106/107
# Epoch 216 --> loss:0.3360, acc:91.25%, val_loss:1.0351, val_acc:69.93%
# Epoch 216 --> epoch_LA:0.4661, epoch_LC:0.2802, val_LC:1.2121, val_LA:0.6221%
#  Epoch 217: iteration 106/107
# Epoch 217 --> loss:0.2523, acc:96.22%, val_loss:1.1905, val_acc:70.63%
# Epoch 217 --> epoch_LA:0.4618, epoch_LC:0.1626, val_LC:1.4315, val_LA:0.6280%
#  Epoch 218: iteration 106/107
# Epoch 218 --> loss:0.2397, acc:96.80%, val_loss:1.0342, val_acc:72.73%
# Epoch 218 --> epoch_LA:0.4611, epoch_LC:0.1448, val_LC:1.2072, val_LA:0.6304%
#  Epoch 219: iteration 106/107
# Epoch 219 --> loss:0.2344, acc:96.75%, val_loss:1.1485, val_acc:65.03%
# Epoch 219 --> epoch_LA:0.4568, epoch_LC:0.1391, val_LC:1.3665, val_LA:0.6398%
#  Epoch 220: iteration 106/107
# Epoch 220 --> loss:0.3266, acc:92.07%, val_loss:1.1299, val_acc:69.23%
# Epoch 220 --> epoch_LA:0.4620, epoch_LC:0.2686, val_LC:1.3384, val_LA:0.6435%
#  Epoch 221: iteration 106/107
# Epoch 221 --> loss:0.2920, acc:93.87%, val_loss:1.0711, val_acc:70.63%
# Epoch 221 --> epoch_LA:0.4639, epoch_LC:0.2183, val_LC:1.2613, val_LA:0.6274%
#  Epoch 222: iteration 106/107
# Epoch 222 --> loss:0.2558, acc:96.34%, val_loss:1.0835, val_acc:70.63%
# Epoch 222 --> epoch_LA:0.4613, epoch_LC:0.1677, val_LC:1.2716, val_LA:0.6447%
#  Epoch 223: iteration 106/107
# Epoch 223 --> loss:0.2439, acc:96.28%, val_loss:1.0547, val_acc:73.43%
# Epoch 223 --> epoch_LA:0.4615, epoch_LC:0.1506, val_LC:1.2358, val_LA:0.6322%
#  Epoch 224: iteration 106/107
# Epoch 224 --> loss:0.2311, acc:96.51%, val_loss:1.1080, val_acc:67.83%
# Epoch 224 --> epoch_LA:0.4563, epoch_LC:0.1346, val_LC:1.3088, val_LA:0.6394%
#  Epoch 225: iteration 106/107
# Epoch 225 --> loss:0.2154, acc:97.91%, val_loss:1.0667, val_acc:72.03%
# Epoch 225 --> epoch_LA:0.4563, epoch_LC:0.1121, val_LC:1.2493, val_LA:0.6407%
#  Epoch 226: iteration 106/107
# Epoch 226 --> loss:0.2124, acc:97.85%, val_loss:1.0650, val_acc:70.63%
# Epoch 226 --> epoch_LA:0.4562, epoch_LC:0.1079, val_LC:1.2543, val_LA:0.6231%
#  Epoch 227: iteration 106/107
# Epoch 227 --> loss:0.2082, acc:97.73%, val_loss:1.0632, val_acc:68.53%
# Epoch 227 --> epoch_LA:0.4529, epoch_LC:0.1034, val_LC:1.2478, val_LA:0.6325%
#  Epoch 228: iteration 106/107
# Epoch 228 --> loss:0.2093, acc:97.85%, val_loss:1.0881, val_acc:72.03%
# Epoch 228 --> epoch_LA:0.4536, epoch_LC:0.1047, val_LC:1.2771, val_LA:0.6470%
#  Epoch 229: iteration 106/107
# Epoch 229 --> loss:0.2363, acc:96.40%, val_loss:1.1263, val_acc:65.73%
# Epoch 229 --> epoch_LA:0.4554, epoch_LC:0.1425, val_LC:1.3422, val_LA:0.6225%
#  Epoch 230: iteration 106/107
# Epoch 230 --> loss:0.2234, acc:97.04%, val_loss:1.0368, val_acc:70.63%
# Epoch 230 --> epoch_LA:0.4556, epoch_LC:0.1239, val_LC:1.2060, val_LA:0.6420%
#  Epoch 231: iteration 106/107
# Epoch 231 --> loss:0.2414, acc:96.48%, val_loss:1.4260, val_acc:59.44%
# Epoch 231 --> epoch_LA:0.4531, epoch_LC:0.1506, val_LC:1.7510, val_LA:0.6677%
#  Epoch 232: iteration 106/107
# Epoch 232 --> loss:0.3507, acc:90.56%, val_loss:1.2940, val_acc:64.34%
# Epoch 232 --> epoch_LA:0.4584, epoch_LC:0.3045, val_LC:1.5714, val_LA:0.6469%
#  Epoch 233: iteration 106/107
# Epoch 233 --> loss:0.3195, acc:92.07%, val_loss:1.2713, val_acc:63.64%
# Epoch 233 --> epoch_LA:0.4600, epoch_LC:0.2593, val_LC:1.5424, val_LA:0.6386%
#  Epoch 234: iteration 106/107
# Epoch 234 --> loss:0.2628, acc:95.09%, val_loss:1.4026, val_acc:59.44%
# Epoch 234 --> epoch_LA:0.4556, epoch_LC:0.1802, val_LC:1.7274, val_LA:0.6448%
#  Epoch 235: iteration 106/107
# Epoch 235 --> loss:0.2854, acc:94.13%, val_loss:1.0875, val_acc:65.73%
# Epoch 235 --> epoch_LA:0.4599, epoch_LC:0.2107, val_LC:1.2808, val_LA:0.6365%
#  Epoch 236: iteration 106/107
# Epoch 236 --> loss:0.2554, acc:95.55%, val_loss:1.0850, val_acc:69.23%
# Epoch 236 --> epoch_LA:0.4582, epoch_LC:0.1684, val_LC:1.2767, val_LA:0.6377%
#  Epoch 237: iteration 106/107
# Epoch 237 --> loss:0.2480, acc:95.90%, val_loss:1.1855, val_acc:65.73%
# Epoch 237 --> epoch_LA:0.4559, epoch_LC:0.1590, val_LC:1.4272, val_LA:0.6215%
#  Epoch 238: iteration 106/107
# Epoch 238 --> loss:0.2206, acc:97.12%, val_loss:1.1262, val_acc:65.03%
# Epoch 238 --> epoch_LA:0.4543, epoch_LC:0.1205, val_LC:1.3337, val_LA:0.6421%
#  Epoch 239: iteration 106/107
# Epoch 239 --> loss:0.2256, acc:97.12%, val_loss:1.0675, val_acc:69.93%
# Epoch 239 --> epoch_LA:0.4526, epoch_LC:0.1283, val_LC:1.2345, val_LA:0.6777%
#  Epoch 240: iteration 106/107
# Epoch 240 --> loss:0.2047, acc:97.99%, val_loss:1.0445, val_acc:69.93%
# Epoch 240 --> epoch_LA:0.4505, epoch_LC:0.0994, val_LC:1.2190, val_LA:0.6374%
#  Epoch 241: iteration 106/107
# Epoch 241 --> loss:0.2107, acc:97.41%, val_loss:1.1583, val_acc:64.34%
# Epoch 241 --> epoch_LA:0.4516, epoch_LC:0.1075, val_LC:1.3904, val_LA:0.6165%
#  Epoch 242: iteration 106/107
# Epoch 242 --> loss:0.2329, acc:96.37%, val_loss:0.9874, val_acc:72.03%
# Epoch 242 --> epoch_LA:0.4500, epoch_LC:0.1398, val_LC:1.1415, val_LA:0.6277%
#  Epoch 243: iteration 106/107
# Epoch 243 --> loss:0.2182, acc:97.27%, val_loss:1.1260, val_acc:67.13%
# Epoch 243 --> epoch_LA:0.4496, epoch_LC:0.1190, val_LC:1.3303, val_LA:0.6491%
#  Epoch 244: iteration 106/107
# Epoch 244 --> loss:0.2091, acc:97.53%, val_loss:1.0039, val_acc:70.63%
# Epoch 244 --> epoch_LA:0.4483, epoch_LC:0.1065, val_LC:1.1673, val_LA:0.6226%
#  Epoch 245: iteration 106/107
# Epoch 245 --> loss:0.1914, acc:98.52%, val_loss:1.0663, val_acc:72.03%
# Epoch 245 --> epoch_LA:0.4494, epoch_LC:0.0808, val_LC:1.2572, val_LA:0.6209%
#  Epoch 246: iteration 106/107
# Epoch 246 --> loss:0.1820, acc:98.78%, val_loss:0.9718, val_acc:72.03%
# Epoch 246 --> epoch_LA:0.4488, epoch_LC:0.0677, val_LC:1.1133, val_LA:0.6416%
#  Epoch 247: iteration 106/107
# Epoch 247 --> loss:0.2297, acc:96.48%, val_loss:1.2853, val_acc:61.54%
# Epoch 247 --> epoch_LA:0.4470, epoch_LC:0.1365, val_LC:1.5726, val_LA:0.6150%
#  Epoch 248: iteration 106/107
# Epoch 248 --> loss:0.3392, acc:90.85%, val_loss:1.1101, val_acc:67.83%
# Epoch 248 --> epoch_LA:0.4508, epoch_LC:0.2913, val_LC:1.3138, val_LA:0.6347%
#  Epoch 249: iteration 106/107
# Epoch 249 --> loss:0.2919, acc:93.75%, val_loss:1.1395, val_acc:62.24%
# Epoch 249 --> epoch_LA:0.4509, epoch_LC:0.2238, val_LC:1.3601, val_LA:0.6248%
#  Epoch 250: iteration 106/107
# Epoch 250 --> loss:0.3481, acc:90.29%, val_loss:0.9992, val_acc:69.93%
# Epoch 250 --> epoch_LA:0.4553, epoch_LC:0.3021, val_LC:1.1649, val_LA:0.6126%
#  Epoch 251: iteration 106/107
# Epoch 251 --> loss:0.2508, acc:95.52%, val_loss:1.0169, val_acc:69.93%
# Epoch 251 --> epoch_LA:0.4520, epoch_LC:0.1645, val_LC:1.1890, val_LA:0.6152%
#  Epoch 252: iteration 106/107
# Epoch 252 --> loss:0.2045, acc:98.26%, val_loss:0.9765, val_acc:72.03%
# Epoch 252 --> epoch_LA:0.4502, epoch_LC:0.0992, val_LC:1.1260, val_LA:0.6278%
#  Epoch 253: iteration 106/107
# Epoch 253 --> loss:0.1827, acc:98.98%, val_loss:0.9523, val_acc:72.03%
# Epoch 253 --> epoch_LA:0.4480, epoch_LC:0.0690, val_LC:1.0967, val_LA:0.6153%
#  Epoch 254: iteration 106/107
# Epoch 254 --> loss:0.1900, acc:98.46%, val_loss:1.0182, val_acc:73.43%
# Epoch 254 --> epoch_LA:0.4467, epoch_LC:0.0800, val_LC:1.1737, val_LA:0.6554%
#  Epoch 255: iteration 106/107
# Epoch 255 --> loss:0.1989, acc:98.08%, val_loss:1.0375, val_acc:71.33%
# Epoch 255 --> epoch_LA:0.4469, epoch_LC:0.0927, val_LC:1.2160, val_LA:0.6209%
#  Epoch 256: iteration 106/107
# Epoch 256 --> loss:0.1846, acc:98.63%, val_loss:0.9999, val_acc:72.73%
# Epoch 256 --> epoch_LA:0.4438, epoch_LC:0.0735, val_LC:1.1579, val_LA:0.6312%
#  Epoch 257: iteration 106/107
# Epoch 257 --> loss:0.1772, acc:99.16%, val_loss:0.9465, val_acc:75.52%
# Epoch 257 --> epoch_LA:0.4427, epoch_LC:0.0634, val_LC:1.0821, val_LA:0.6303%
#  Epoch 258: iteration 106/107
# Epoch 258 --> loss:0.1845, acc:98.31%, val_loss:0.9810, val_acc:73.43%
# Epoch 258 --> epoch_LA:0.4426, epoch_LC:0.0738, val_LC:1.1365, val_LA:0.6182%
#  Epoch 259: iteration 106/107
# Epoch 259 --> loss:0.1989, acc:97.88%, val_loss:1.0171, val_acc:76.92%
# Epoch 259 --> epoch_LA:0.4417, epoch_LC:0.0949, val_LC:1.1800, val_LA:0.6369%
#  Epoch 260: iteration 106/107
# Epoch 260 --> loss:0.1990, acc:98.11%, val_loss:1.0838, val_acc:70.63%
# Epoch 260 --> epoch_LA:0.4414, epoch_LC:0.0951, val_LC:1.2736, val_LA:0.6409%
#  Epoch 261: iteration 106/107
# Epoch 261 --> loss:0.2103, acc:97.47%, val_loss:1.2262, val_acc:63.64%
# Epoch 261 --> epoch_LA:0.4418, epoch_LC:0.1110, val_LC:1.4879, val_LA:0.6154%
#  Epoch 262: iteration 106/107
# Epoch 262 --> loss:0.2705, acc:94.59%, val_loss:1.0921, val_acc:67.83%
# Epoch 262 --> epoch_LA:0.4477, epoch_LC:0.1945, val_LC:1.2840, val_LA:0.6441%
#  Epoch 263: iteration 106/107
# Epoch 263 --> loss:0.2891, acc:93.72%, val_loss:1.1271, val_acc:71.33%
# Epoch 263 --> epoch_LA:0.4472, epoch_LC:0.2214, val_LC:1.3314, val_LA:0.6505%
#  Epoch 264: iteration 106/107
# Epoch 264 --> loss:0.2981, acc:93.11%, val_loss:1.0928, val_acc:70.63%
# Epoch 264 --> epoch_LA:0.4542, epoch_LC:0.2313, val_LC:1.2944, val_LA:0.6223%
#  Epoch 265: iteration 106/107
# Epoch 265 --> loss:0.2350, acc:96.16%, val_loss:1.0318, val_acc:72.03%
# Epoch 265 --> epoch_LA:0.4492, epoch_LC:0.1432, val_LC:1.2062, val_LA:0.6248%
#  Epoch 266: iteration 106/107
# Epoch 266 --> loss:0.2020, acc:97.79%, val_loss:1.1567, val_acc:65.73%
# Epoch 266 --> epoch_LA:0.4415, epoch_LC:0.0993, val_LC:1.3746, val_LA:0.6484%
#  Epoch 267: iteration 106/107
# Epoch 267 --> loss:0.2524, acc:95.52%, val_loss:1.1271, val_acc:65.03%
# Epoch 267 --> epoch_LA:0.4481, epoch_LC:0.1686, val_LC:1.3445, val_LA:0.6198%
#  Epoch 268: iteration 106/107
# Epoch 268 --> loss:0.2358, acc:96.40%, val_loss:1.0844, val_acc:69.93%
# Epoch 268 --> epoch_LA:0.4437, epoch_LC:0.1467, val_LC:1.2809, val_LA:0.6259%
#  Epoch 269: iteration 106/107
# Epoch 269 --> loss:0.1926, acc:98.17%, val_loss:1.0465, val_acc:73.43%
# Epoch 269 --> epoch_LA:0.4433, epoch_LC:0.0852, val_LC:1.2300, val_LA:0.6184%
# ...
#  Epoch 411: iteration 106/107
# Epoch 411 --> loss:0.1448, acc:99.42%, val_loss:1.0651, val_acc:71.33%
# Epoch 411 --> epoch_LA:0.3998, epoch_LC:0.0355, val_LC:1.2691, val_LA:0.5889%
#  Epoch 412: iteration 106/107
# Epoch 412 --> loss:0.1425, acc:99.42%, val_loss:1.0638, val_acc:72.03%
# Epoch 412 --> epoch_LA:0.3985, epoch_LC:0.0328, val_LC:1.2531, val_LA:0.6219%
#  Epoch 413: iteration 106/107
# Epoch 413 --> loss:0.1387, acc:99.42%, val_loss:1.0530, val_acc:73.43%
# Epoch 413 --> epoch_LA:0.3945, epoch_LC:0.0291, val_LC:1.2334, val_LA:0.6320%
#  Epoch 414: iteration 106/107
# Epoch 414 --> loss:0.1387, acc:99.45%, val_loss:1.0562, val_acc:74.13%
# Epoch 414 --> epoch_LA:0.3923, epoch_LC:0.0300, val_LC:1.2473, val_LA:0.6105%
#  Epoch 415: iteration 106/107
# Epoch 415 --> loss:0.1371, acc:99.48%, val_loss:1.0458, val_acc:73.43%
# Epoch 415 --> epoch_LA:0.3930, epoch_LC:0.0275, val_LC:1.2252, val_LA:0.6272%
#  Epoch 416: iteration 106/107
# Epoch 416 --> loss:0.1430, acc:99.33%, val_loss:1.0444, val_acc:73.43%
# Epoch 416 --> epoch_LA:0.3930, epoch_LC:0.0358, val_LC:1.2296, val_LA:0.6123%
#  Epoch 417: iteration 106/107
# Epoch 417 --> loss:0.1356, acc:99.51%, val_loss:1.0708, val_acc:72.73%
# Epoch 417 --> epoch_LA:0.3901, epoch_LC:0.0265, val_LC:1.2611, val_LA:0.6267%
#  Epoch 418: iteration 106/107
# Epoch 418 --> loss:0.1354, acc:99.51%, val_loss:1.0490, val_acc:72.73%
# Epoch 418 --> epoch_LA:0.3890, epoch_LC:0.0268, val_LC:1.2371, val_LA:0.6102%
#  Epoch 419: iteration 106/107
# Epoch 419 --> loss:0.1337, acc:99.48%, val_loss:1.0666, val_acc:73.43%
# Epoch 419 --> epoch_LA:0.3890, epoch_LC:0.0243, val_LC:1.2643, val_LA:0.6053%
#  Epoch 420: iteration 106/107
# Epoch 420 --> loss:0.1347, acc:99.42%, val_loss:1.0531, val_acc:73.43%
# Epoch 420 --> epoch_LA:0.3889, epoch_LC:0.0258, val_LC:1.2447, val_LA:0.6060%
#  Epoch 421: iteration 106/107
# Epoch 421 --> loss:0.1351, acc:99.45%, val_loss:1.0540, val_acc:73.43%
# Epoch 421 --> epoch_LA:0.3881, epoch_LC:0.0267, val_LC:1.2526, val_LA:0.5906%
#  Epoch 422: iteration 106/107
# Epoch 422 --> loss:0.2222, acc:95.96%, val_loss:1.1951, val_acc:66.43%
# Epoch 422 --> epoch_LA:0.3916, epoch_LC:0.1496, val_LC:1.4328, val_LA:0.6404%
#  Epoch 423: iteration 106/107
# Epoch 423 --> loss:0.4728, acc:83.52%, val_loss:1.2227, val_acc:62.24%
# Epoch 423 --> epoch_LA:0.4077, epoch_LC:0.5007, val_LC:1.4379, val_LA:0.7206%
#  Epoch 424: iteration 106/107
# Epoch 424 --> loss:0.4244, acc:86.40%, val_loss:1.1386, val_acc:67.13%
# Epoch 424 --> epoch_LA:0.4125, epoch_LC:0.4296, val_LC:1.3633, val_LA:0.6145%
#  Epoch 425: iteration 106/107
# Epoch 425 --> loss:0.3502, acc:90.15%, val_loss:1.0887, val_acc:68.53%
# Epoch 425 --> epoch_LA:0.4166, epoch_LC:0.3217, val_LC:1.2905, val_LA:0.6179%
#  Epoch 426: iteration 106/107
# Epoch 426 --> loss:0.2168, acc:96.77%, val_loss:1.1356, val_acc:67.83%
# Epoch 426 --> epoch_LA:0.4086, epoch_LC:0.1346, val_LC:1.3615, val_LA:0.6084%
#  Epoch 427: iteration 106/107
# Epoch 427 --> loss:0.1886, acc:97.97%, val_loss:1.0981, val_acc:72.03%
# Epoch 427 --> epoch_LA:0.4030, epoch_LC:0.0968, val_LC:1.2749, val_LA:0.6854%
#  Epoch 428: iteration 106/107
# Epoch 428 --> loss:0.1762, acc:98.49%, val_loss:0.9859, val_acc:74.83%
# Epoch 428 --> epoch_LA:0.4010, epoch_LC:0.0798, val_LC:1.1474, val_LA:0.6090%
#  Epoch 429: iteration 106/107
# Epoch 429 --> loss:0.1565, acc:99.16%, val_loss:1.0128, val_acc:72.73%
# Epoch 429 --> epoch_LA:0.4001, epoch_LC:0.0521, val_LC:1.1828, val_LA:0.6161%
#  Epoch 430: iteration 106/107
# Epoch 430 --> loss:0.1470, acc:99.42%, val_loss:0.9757, val_acc:72.73%
# Epoch 430 --> epoch_LA:0.3964, epoch_LC:0.0402, val_LC:1.1307, val_LA:0.6142%
#  Epoch 431: iteration 106/107
# Epoch 431 --> loss:0.1432, acc:99.45%, val_loss:1.0250, val_acc:69.93%
# Epoch 431 --> epoch_LA:0.3958, epoch_LC:0.0350, val_LC:1.2050, val_LA:0.6049%
#  Epoch 432: iteration 106/107
# Epoch 432 --> loss:0.1383, acc:99.51%, val_loss:0.9927, val_acc:71.33%
# Epoch 432 --> epoch_LA:0.3933, epoch_LC:0.0291, val_LC:1.1569, val_LA:0.6096%
#  Epoch 433: iteration 106/107
# Epoch 433 --> loss:0.1375, acc:99.48%, val_loss:0.9887, val_acc:71.33%
# Epoch 433 --> epoch_LA:0.3885, epoch_LC:0.0299, val_LC:1.1517, val_LA:0.6082%
#  Epoch 434: iteration 106/107
# Epoch 434 --> loss:0.1370, acc:99.51%, val_loss:0.9880, val_acc:72.03%
# Epoch 434 --> epoch_LA:0.3909, epoch_LC:0.0283, val_LC:1.1531, val_LA:0.6026%
#  Epoch 435: iteration 106/107
# Epoch 435 --> loss:0.1355, acc:99.48%, val_loss:1.0073, val_acc:72.03%
# Epoch 435 --> epoch_LA:0.3891, epoch_LC:0.0268, val_LC:1.1819, val_LA:0.6000%
#  Epoch 436: iteration 106/107
# Epoch 436 --> loss:0.1349, acc:99.51%, val_loss:1.0287, val_acc:70.63%
# Epoch 436 --> epoch_LA:0.3863, epoch_LC:0.0271, val_LC:1.2044, val_LA:0.6187%
#  Epoch 437: iteration 106/107
# Epoch 437 --> loss:0.1340, acc:99.51%, val_loss:1.0256, val_acc:69.93%
# Epoch 437 --> epoch_LA:0.3882, epoch_LC:0.0251, val_LC:1.2076, val_LA:0.6010%
#  Epoch 438: iteration 106/107
# Epoch 438 --> loss:0.1345, acc:99.48%, val_loss:1.0158, val_acc:73.43%
# Epoch 438 --> epoch_LA:0.3846, epoch_LC:0.0273, val_LC:1.1935, val_LA:0.6013%
#  Epoch 439: iteration 106/107
# Epoch 439 --> loss:0.1337, acc:99.45%, val_loss:1.0160, val_acc:70.63%
# Epoch 439 --> epoch_LA:0.3845, epoch_LC:0.0263, val_LC:1.1818, val_LA:0.6290%
#  Epoch 440: iteration 106/107
# Epoch 440 --> loss:0.1345, acc:99.45%, val_loss:0.9981, val_acc:72.73%
# Epoch 440 --> epoch_LA:0.3850, epoch_LC:0.0272, val_LC:1.1703, val_LA:0.5965%
#  Epoch 441: iteration 106/107
# Epoch 441 --> loss:0.1339, acc:99.48%, val_loss:0.9804, val_acc:72.73%
# Epoch 441 --> epoch_LA:0.3843, epoch_LC:0.0266, val_LC:1.1381, val_LA:0.6125%
#  Epoch 442: iteration 106/107
# Epoch 442 --> loss:0.1321, acc:99.51%, val_loss:0.9775, val_acc:73.43%
# Epoch 442 --> epoch_LA:0.3833, epoch_LC:0.0244, val_LC:1.1350, val_LA:0.6102%
#  Epoch 443: iteration 106/107
# Epoch 443 --> loss:0.1331, acc:99.42%, val_loss:0.9974, val_acc:72.73%
# Epoch 443 --> epoch_LA:0.3845, epoch_LC:0.0254, val_LC:1.1662, val_LA:0.6036%
#  Epoch 444: iteration 106/107
# Epoch 444 --> loss:0.1437, acc:99.22%, val_loss:0.9826, val_acc:74.13%
# Epoch 444 --> epoch_LA:0.3827, epoch_LC:0.0412, val_LC:1.1413, val_LA:0.6122%
#  Epoch 445: iteration 106/107
# Epoch 445 --> loss:0.1386, acc:99.48%, val_loss:0.9894, val_acc:73.43%
# Epoch 445 --> epoch_LA:0.3832, epoch_LC:0.0338, val_LC:1.1481, val_LA:0.6192%
#  Epoch 446: iteration 106/107
# Epoch 446 --> loss:0.1330, acc:99.51%, val_loss:1.0215, val_acc:72.03%
# Epoch 446 --> epoch_LA:0.3829, epoch_LC:0.0259, val_LC:1.1860, val_LA:0.6379%
#  Epoch 447: iteration 106/107
# Epoch 447 --> loss:0.1319, acc:99.51%, val_loss:0.9784, val_acc:73.43%
# Epoch 447 --> epoch_LA:0.3813, epoch_LC:0.0250, val_LC:1.1417, val_LA:0.5975%
#  Epoch 448: iteration 106/107
# Epoch 448 --> loss:0.1319, acc:99.51%, val_loss:1.0328, val_acc:71.33%
# Epoch 448 --> epoch_LA:0.3812, epoch_LC:0.0251, val_LC:1.2232, val_LA:0.5884%
#  Epoch 449: iteration 106/107
# Epoch 449 --> loss:0.1780, acc:97.53%, val_loss:1.3085, val_acc:65.03%
# Epoch 449 --> epoch_LA:0.3796, epoch_LC:0.0915, val_LC:1.5902, val_LA:0.6511%
#  Epoch 450: iteration 106/107
# Epoch 450 --> loss:0.5166, acc:81.58%, val_loss:1.1789, val_acc:65.03%
# Epoch 450 --> epoch_LA:0.4030, epoch_LC:0.5653, val_LC:1.3793, val_LA:0.7112%
#  Epoch 451: iteration 106/107
# Epoch 451 --> loss:0.2677, acc:94.22%, val_loss:1.0221, val_acc:69.93%
# Epoch 451 --> epoch_LA:0.4013, epoch_LC:0.2104, val_LC:1.1923, val_LA:0.6247%
#  Epoch 452: iteration 106/107
# Epoch 452 --> loss:0.2320, acc:95.99%, val_loss:1.0041, val_acc:72.03%
# Epoch 452 --> epoch_LA:0.3985, epoch_LC:0.1606, val_LC:1.1649, val_LA:0.6287%
#  Epoch 453: iteration 106/107
# Epoch 453 --> loss:0.2009, acc:97.33%, val_loss:0.9661, val_acc:73.43%
# Epoch 453 --> epoch_LA:0.3961, epoch_LC:0.1173, val_LC:1.1218, val_LA:0.6027%
#  Epoch 454: iteration 106/107
# Epoch 454 --> loss:0.1652, acc:98.61%, val_loss:0.9633, val_acc:74.83%
# Epoch 454 --> epoch_LA:0.3921, epoch_LC:0.0679, val_LC:1.1190, val_LA:0.6000%
#  Epoch 455: iteration 106/107
# Epoch 455 --> loss:0.1475, acc:99.33%, val_loss:0.9250, val_acc:73.43%
# Epoch 455 --> epoch_LA:0.3905, epoch_LC:0.0434, val_LC:1.0621, val_LA:0.6049%
#  Epoch 456: iteration 106/107
# Epoch 456 --> loss:0.1370, acc:99.51%, val_loss:0.9253, val_acc:75.52%
# Epoch 456 --> epoch_LA:0.3848, epoch_LC:0.0309, val_LC:1.0661, val_LA:0.5968%
#  Epoch 457: iteration 106/107
# Epoch 457 --> loss:0.1369, acc:99.45%, val_loss:0.9346, val_acc:75.52%
# Epoch 457 --> epoch_LA:0.3858, epoch_LC:0.0303, val_LC:1.0868, val_LA:0.5795%
#  Epoch 458: iteration 106/107
# Epoch 458 --> loss:0.1350, acc:99.48%, val_loss:0.9370, val_acc:72.73%
# Epoch 458 --> epoch_LA:0.3855, epoch_LC:0.0277, val_LC:1.0935, val_LA:0.5720%
#  Epoch 459: iteration 106/107
# Epoch 459 --> loss:0.1332, acc:99.51%, val_loss:0.9515, val_acc:72.73%
# Epoch 459 --> epoch_LA:0.3827, epoch_LC:0.0263, val_LC:1.1196, val_LA:0.5592%
#  Epoch 460: iteration 106/107
# Epoch 460 --> loss:0.1307, acc:99.51%, val_loss:0.9761, val_acc:74.83%
# Epoch 460 --> epoch_LA:0.3799, epoch_LC:0.0239, val_LC:1.1399, val_LA:0.5940%
#  Epoch 461: iteration 106/107
# Epoch 461 --> loss:0.1310, acc:99.51%, val_loss:0.9387, val_acc:74.83%
# Epoch 461 --> epoch_LA:0.3791, epoch_LC:0.0246, val_LC:1.0892, val_LA:0.5875%
#  Epoch 462: iteration 106/107
# Epoch 462 --> loss:0.1308, acc:99.51%, val_loss:0.9718, val_acc:75.52%
# Epoch 462 --> epoch_LA:0.3806, epoch_LC:0.0238, val_LC:1.1281, val_LA:0.6070%
#  Epoch 463: iteration 106/107
# Epoch 463 --> loss:0.1297, acc:99.51%, val_loss:0.9658, val_acc:75.52%
# Epoch 463 --> epoch_LA:0.3787, epoch_LC:0.0230, val_LC:1.1253, val_LA:0.5935%
#  Epoch 464: iteration 106/107
# Epoch 464 --> loss:0.1319, acc:99.48%, val_loss:0.9499, val_acc:76.22%
# Epoch 464 --> epoch_LA:0.3803, epoch_LC:0.0255, val_LC:1.1035, val_LA:0.5915%
#  Epoch 465: iteration 106/107
# Epoch 465 --> loss:0.1299, acc:99.51%, val_loss:0.9812, val_acc:74.13%
# Epoch 465 --> epoch_LA:0.3798, epoch_LC:0.0228, val_LC:1.1440, val_LA:0.6012%
#  Epoch 466: iteration 106/107
# Epoch 466 --> loss:0.1299, acc:99.51%, val_loss:0.9712, val_acc:74.83%
# Epoch 466 --> epoch_LA:0.3778, epoch_LC:0.0237, val_LC:1.1284, val_LA:0.6042%
#  Epoch 467: iteration 106/107
# Epoch 467 --> loss:0.1304, acc:99.45%, val_loss:1.0167, val_acc:74.13%
# Epoch 467 --> epoch_LA:0.3763, epoch_LC:0.0250, val_LC:1.1953, val_LA:0.6000%
#  Epoch 468: iteration 106/107
# Epoch 468 --> loss:0.1306, acc:99.51%, val_loss:1.0117, val_acc:72.03%
# Epoch 468 --> epoch_LA:0.3771, epoch_LC:0.0250, val_LC:1.1871, val_LA:0.6022%
#  Epoch 469: iteration 106/107
# Epoch 469 --> loss:0.1279, acc:99.51%, val_loss:0.9897, val_acc:74.13%
# Epoch 469 --> epoch_LA:0.3739, epoch_LC:0.0225, val_LC:1.1440, val_LA:0.6295%
#  Epoch 470: iteration 106/107
# Epoch 470 --> loss:0.4254, acc:85.64%, val_loss:1.2006, val_acc:65.73%
# Epoch 470 --> epoch_LA:0.3873, epoch_LC:0.4417, val_LC:1.4802, val_LA:0.5483%
#  Epoch 471: iteration 106/107
# Epoch 471 --> loss:0.5010, acc:81.92%, val_loss:1.0925, val_acc:68.53%
# Epoch 471 --> epoch_LA:0.4033, epoch_LC:0.5429, val_LC:1.3044, val_LA:0.5979%
#  Epoch 472: iteration 106/107
# Epoch 472 --> loss:0.4176, acc:86.40%, val_loss:1.0261, val_acc:67.83%
# Epoch 472 --> epoch_LA:0.4027, epoch_LC:0.4240, val_LC:1.1879, val_LA:0.6486%
#  Epoch 473: iteration 106/107
# Epoch 473 --> loss:0.2620, acc:94.36%, val_loss:1.0842, val_acc:69.23%
# Epoch 473 --> epoch_LA:0.3981, epoch_LC:0.2037, val_LC:1.2939, val_LA:0.5951%
#  Epoch 474: iteration 106/107
# Epoch 474 --> loss:0.2440, acc:94.89%, val_loss:1.0472, val_acc:73.43%
# Epoch 474 --> epoch_LA:0.3952, epoch_LC:0.1791, val_LC:1.2282, val_LA:0.6248%
#  Epoch 475: iteration 106/107
# Epoch 475 --> loss:0.3446, acc:90.29%, val_loss:0.9978, val_acc:69.93%
# Epoch 475 --> epoch_LA:0.3983, epoch_LC:0.3217, val_LC:1.1283, val_LA:0.6934%
#  Epoch 476: iteration 106/107
# Epoch 476 --> loss:0.2715, acc:94.27%, val_loss:0.8883, val_acc:75.52%
# Epoch 476 --> epoch_LA:0.4007, epoch_LC:0.2161, val_LC:0.9622, val_LA:0.7160%
#  Epoch 477: iteration 106/107
# Epoch 477 --> loss:0.1883, acc:97.97%, val_loss:0.9702, val_acc:70.63%
# Epoch 477 --> epoch_LA:0.3962, epoch_LC:0.0992, val_LC:1.1248, val_LA:0.6096%
#  Epoch 478: iteration 106/107
# Epoch 478 --> loss:0.1681, acc:98.61%, val_loss:0.9509, val_acc:72.73%
# Epoch 478 --> epoch_LA:0.3926, epoch_LC:0.0718, val_LC:1.0890, val_LA:0.6286%
#  Epoch 479: iteration 106/107
# Epoch 479 --> loss:0.1494, acc:99.27%, val_loss:0.9758, val_acc:73.43%
# Epoch 479 --> epoch_LA:0.3901, epoch_LC:0.0462, val_LC:1.1451, val_LA:0.5807%
#  Epoch 480: iteration 106/107
# Epoch 480 --> loss:0.1383, acc:99.48%, val_loss:0.9592, val_acc:74.83%
# Epoch 480 --> epoch_LA:0.3837, epoch_LC:0.0331, val_LC:1.1086, val_LA:0.6105%
#  Epoch 481: iteration 106/107
# Epoch 481 --> loss:0.1373, acc:99.48%, val_loss:0.9888, val_acc:73.43%
# Epoch 481 --> epoch_LA:0.3847, epoch_LC:0.0313, val_LC:1.1586, val_LA:0.5924%
#  Epoch 482: iteration 106/107
# Epoch 482 --> loss:0.1348, acc:99.42%, val_loss:1.0145, val_acc:74.13%
# Epoch 482 --> epoch_LA:0.3830, epoch_LC:0.0285, val_LC:1.1885, val_LA:0.6083%
#  Epoch 483: iteration 106/107
# Epoch 483 --> loss:0.1329, acc:99.48%, val_loss:0.9991, val_acc:74.13%
# Epoch 483 --> epoch_LA:0.3828, epoch_LC:0.0258, val_LC:1.1814, val_LA:0.5736%
#  Epoch 484: iteration 106/107
# Epoch 484 --> loss:0.1325, acc:99.51%, val_loss:0.9649, val_acc:76.92%
# Epoch 484 --> epoch_LA:0.3808, epoch_LC:0.0261, val_LC:1.1375, val_LA:0.5623%
#  Epoch 485: iteration 106/107
# Epoch 485 --> loss:0.1316, acc:99.51%, val_loss:1.0159, val_acc:74.13%
# Epoch 485 --> epoch_LA:0.3788, epoch_LC:0.0257, val_LC:1.2015, val_LA:0.5827%
#  Epoch 486: iteration 106/107
# Epoch 486 --> loss:0.1317, acc:99.51%, val_loss:1.0134, val_acc:74.13%
# Epoch 486 --> epoch_LA:0.3782, epoch_LC:0.0261, val_LC:1.1986, val_LA:0.5813%
#  Epoch 487: iteration 106/107
# Epoch 487 --> loss:0.1296, acc:99.51%, val_loss:1.0394, val_acc:72.73%
# Epoch 487 --> epoch_LA:0.3757, epoch_LC:0.0242, val_LC:1.2369, val_LA:0.5784%
#  Epoch 488: iteration 106/107
# Epoch 488 --> loss:0.1298, acc:99.48%, val_loss:1.0122, val_acc:72.73%
# Epoch 488 --> epoch_LA:0.3776, epoch_LC:0.0236, val_LC:1.1939, val_LA:0.5882%
#  Epoch 489: iteration 106/107
# Epoch 489 --> loss:0.1323, acc:99.36%, val_loss:1.0881, val_acc:70.63%
# Epoch 489 --> epoch_LA:0.3749, epoch_LC:0.0283, val_LC:1.2889, val_LA:0.6196%
#  Epoch 490: iteration 106/107
# Epoch 490 --> loss:0.1323, acc:99.48%, val_loss:0.9947, val_acc:74.83%
# Epoch 490 --> epoch_LA:0.3749, epoch_LC:0.0283, val_LC:1.1694, val_LA:0.5870%
#  Epoch 491: iteration 106/107
# Epoch 491 --> loss:0.1295, acc:99.51%, val_loss:1.0002, val_acc:74.13%
# Epoch 491 --> epoch_LA:0.3749, epoch_LC:0.0243, val_LC:1.1799, val_LA:0.5810%
#  Epoch 492: iteration 106/107
# Epoch 492 --> loss:0.1281, acc:99.51%, val_loss:1.0239, val_acc:72.73%
# Epoch 492 --> epoch_LA:0.3738, epoch_LC:0.0228, val_LC:1.2081, val_LA:0.5939%
#  Epoch 493: iteration 106/107
# Epoch 493 --> loss:0.1404, acc:98.98%, val_loss:1.0465, val_acc:71.33%
# Epoch 493 --> epoch_LA:0.3754, epoch_LC:0.0398, val_LC:1.2219, val_LA:0.6371%
#  Epoch 494: iteration 106/107
# Epoch 494 --> loss:0.2676, acc:93.64%, val_loss:1.1592, val_acc:70.63%
# Epoch 494 --> epoch_LA:0.3819, epoch_LC:0.2187, val_LC:1.3858, val_LA:0.6304%
#  Epoch 495: iteration 106/107
# Epoch 495 --> loss:0.2958, acc:92.44%, val_loss:1.1487, val_acc:69.93%
# Epoch 495 --> epoch_LA:0.3883, epoch_LC:0.2562, val_LC:1.3845, val_LA:0.5985%
#  Epoch 496: iteration 106/107
# Epoch 496 --> loss:0.3598, acc:89.33%, val_loss:1.1156, val_acc:69.23%
# Epoch 496 --> epoch_LA:0.3944, epoch_LC:0.3450, val_LC:1.3149, val_LA:0.6505%
#  Epoch 497: iteration 106/107
# Epoch 497 --> loss:0.3579, acc:88.72%, val_loss:1.1733, val_acc:65.73%
# Epoch 497 --> epoch_LA:0.3941, epoch_LC:0.3424, val_LC:1.4001, val_LA:0.6441%
#  Epoch 498: iteration 106/107
# Epoch 498 --> loss:0.1791, acc:98.46%, val_loss:1.0618, val_acc:69.93%
# Epoch 498 --> epoch_LA:0.3899, epoch_LC:0.0887, val_LC:1.2493, val_LA:0.6244%
#  Epoch 499: iteration 106/107
# Epoch 499 --> loss:0.1469, acc:99.36%, val_loss:1.0126, val_acc:72.73%
# Epoch 499 --> epoch_LA:0.3840, epoch_LC:0.0453, val_LC:1.1873, val_LA:0.6051%

# %% [markdown]
# # Save model

# %%
SAVE_PATH = os.path.join(os.getcwd(),'models')
os.makedirs('models',exist_ok=True)
torch.save(model.state_dict(),os.path.join(SAVE_PATH,'cnn_lstm_parallel_model.pt'))
print('Model is saved to {}'.format(os.path.join(SAVE_PATH,'cnn_lstm_parallel_model.pt')))
# Out:
# Model is saved to /content/models/cnn_lstm_parallel_model.pt

# %% [markdown]
# # Load model

# %%
LOAD_PATH = os.path.join(os.getcwd(),'models')
model = AE_CNN_LSTM_Model(len(EMOTIONS))
model.load_state_dict(torch.load(os.path.join(LOAD_PATH,'cnn_lstm_parallel_model.pt')))
print('Model is loaded from {}'.format(os.path.join(LOAD_PATH,'cnn_lstm_parallel_model.pt')))
# Out:
# Model is loaded from /content/models/cnn_lstm_parallel_model.pt

# %% [markdown]
# # Test

# %%
X_test_tensor = torch.tensor(X_test,device=device).float()
Y_test_tensor = torch.tensor(Y_test,dtype=torch.long,device=device)
test_loss, test_acc, predictions, test_LC, test_LA, test_decoded, test_encoded = validate(X_test_tensor,Y_test_tensor)
print(f'Test loss is {test_loss:.3f}')
print(f'Test accuracy is {test_acc:.2f}%')
# Out:
# Test loss is 1.218
# Test accuracy is 68.00%

# %% [markdown]
# confusion matrix

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn

predictions = predictions.cpu().numpy()
cm = confusion_matrix(Y_test, predictions)
names = [EMOTIONS[ind] for ind in range(len(EMOTIONS))]
df_cm = pd.DataFrame(cm, index=names, columns=names)
# plt.figure(figsize=(10,7))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}) # font size
plt.show()

# %% [markdown]
# correlation between emotion intensity and corectness

# %%
correct_strong = 0
correct_normal = 0
wrong_strong = 0
wrong_normal = 0
for i in range(len(X_test)):
    intensity = data.loc[test_ind[i],'Emotion intensity']
    if Y_test[i] == predictions[i]: # correct prediction
        if  intensity == 'normal':
            correct_normal += 1
        else:
            correct_strong += 1
    else: # wrong prediction
        if intensity == 'normal':
            wrong_normal += 1
        else:
            wrong_strong += 1
array = np.array([[wrong_normal,wrong_strong],[correct_normal,correct_strong]])
df = pd.DataFrame(array,['wrong','correct'],['normal','strong'])
sn.set(font_scale=1.4) # for label size
sn.heatmap(df, annot=True, annot_kws={"size": 16}) # font size
plt.show()

# %% [markdown]
# correlation between gender and corectness

# %%
correct_male = 0
correct_female = 0
wrong_male = 0
wrong_female = 0
for i in range(len(X_test)):
    gender = data.loc[test_ind[i],'Gender']
    if Y_test[i] == predictions[i]: # correct prediction
        if  gender == 'male':
            correct_male += 1
        else:
            correct_female += 1
    else: # wrong prediction
        if gender == 'male':
            wrong_male += 1
        else:
            wrong_female += 1
array = np.array([[wrong_male,wrong_female],[correct_male,correct_female]])
df = pd.DataFrame(array,['wrong','correct'],['male','female'])
sn.set(font_scale=1.4) # for label size
sn.heatmap(df, annot=True, annot_kws={"size": 16}) # font size
plt.show()

# %% [markdown]
# # Plot loss

# %%
plt.plot(losses,'b')
plt.plot(val_losses,'r')
plt.legend(['train loss','val loss'])

# %% [markdown]
# <a href="https://colab.research.google.com/github/zahra-sharifzadeh/Master_thesis/blob/main/RAVDESS/mfc_coefficients/mfc_coefficients_two_CNNAE_Parallel_transformer_Ravdess.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Setup

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os, glob
import librosa
import librosa.display
import IPython
from IPython.display import Audio
from IPython.display import Image
import warnings; warnings.filterwarnings('ignore') #matplot lib complains about librosa

# %%
# needed to import dataset from google drive into colab
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# copy RAVDESS dataset from gdrive and unzip
# !cp '/content/gdrive/MyDrive/RAVDESS.zip' .
# !unzip -q RAVDESS.zip

# %% [markdown]
# ## Define features
#
# Define features as in the previous notebook on this task from my ['sklearn-audio-classification' repo](https://github.com/IliaZenkov/sklearn-audio-classification). That notebook explains the motivation behind the Mel Spectrogram and its derivative MFCC, which we use as a feature. In short, we're looking for transitions in audible pitch frequencies.
#
# **MFCCs alone provide the best accuracy in this model with training considerations in mind - and provide as good an accuracy as using chromagrams + mel spectrograms + MFCCs. We don't want extra complexity in a highly parameterized deep neural net such as this one** (unless we absolutely need it).

# %%
# RAVDESS native sample rate is 16000
sample_rate = 48000

# Mel Spectrograms are not directly used as a feature in this model
# Mel Spectrograms are used in calculating MFCCs, which are a higher-level representation of pitch transition
# MFCCs work better - left the mel spectrogram function here in case anyone wants to experiment
def feature_melspectrogram(
    waveform,
    sample_rate,
    fft = 1024,
    winlen = 512,
    window='hamming',
    hop=256,
    mels=128,
    ):

    # Produce the mel spectrogram for all STFT frames and get the mean of each column of the resulting matrix to create a feature array
    # Using 8khz as upper frequency bound should be enough for most speech classification tasks
    melspectrogram = librosa.feature.melspectrogram(
        y=waveform,
        sr=sample_rate,
        n_fft=fft,
        win_length=winlen,
        window=window,
        hop_length=hop,
        n_mels=mels,
        fmax=sample_rate/2)

    # convert from power (amplitude**2) to decibels
    # necessary for network to learn - doesn't converge with raw power spectrograms
    melspectrogram = librosa.power_to_db(melspectrogram, ref=np.max)

    return melspectrogram

def feature_mfcc(
    waveform,
    sample_rate,
    n_mfcc = 40,
    fft = 1024,
    winlen = 512,
    window='hamming',
    #hop=256, # increases # of time steps; was not helpful
    mels=128
    ):

    # Compute the MFCCs for all STFT frames
    # 40 mel filterbanks (n_mfcc) = 40 coefficients
    mfc_coefficients=librosa.feature.mfcc(
        y=waveform,
        sr=sample_rate,
        n_mfcc=n_mfcc,
        n_fft=fft,
        win_length=winlen,
        window=window,
        #hop_length=hop,
        n_mels=mels,
        fmax=sample_rate/2
        )

    return mfc_coefficients

def get_features(waveforms, features, samplerate):

    # initialize counter to track progress
    file_count = 0

    # process each waveform individually to get its MFCCs
    for waveform in waveforms:
        mfccs = feature_mfcc(waveform, sample_rate)
        features.append(mfccs)
        file_count += 1
        # print progress
        print('\r'+f' Processed {file_count}/{len(waveforms)} waveforms',end='')

    # return all features from list of waveforms
    return features

def get_waveforms(file):

    # load an individual sample audio file
    # read the full 3 seconds of the file, cut off the first 0.5s of silence; native sample rate = 48k
    # don't need to store the sample rate that librosa.load returns
    waveform, _ = librosa.load(file, duration=3, offset=0.5, sr=sample_rate)

    # make sure waveform vectors are homogenous by defining explicitly
    waveform_homo = np.zeros((int(sample_rate*3,)))
    waveform_homo[:len(waveform)] = waveform

    # return a single file's waveform
    return waveform_homo

# RAVDESS dataset emotions
# shift emotions left to be 0 indexed for PyTorch
emotions_dict ={
    '0':'surprised',
    '1':'neutral',
    '2':'calm',
    '3':'happy',
    '4':'sad',
    '5':'angry',
    '6':'fearful',
    '7':'disgust'
}

# Additional attributes from RAVDESS to play with
emotion_attributes = {
    '01': 'normal',
    '02': 'strong'
}

# %% [markdown]
# ## Load Data and Extract Features
#
#
# We process each file in the dataset and extract its features.
#
# We return the waveforms and the labels (from the file names of the RAVDESS audio samples). We return the raw waveforms because we're going to do some extra processing.

# %%
# path to data for glob
data_path = '/content/Actor_*/*.wav'

def load_data():
    # features and labels
    emotions = []
    # raw waveforms to augment later
    waveforms = []
    # extra labels
    intensities, genders = [],[]
    # progress counter
    file_count = 0
    for file in glob.glob(data_path):
        # get file name with labels
        file_name = os.path.basename(file)

        # get emotion label from the sample's file
        emotion = int(file_name.split("-")[2])

        #  move surprise to 0 for cleaner behaviour with PyTorch/0-indexing
        if emotion == 8: emotion = 0 # surprise is now at 0 index; other emotion indeces unchanged

        # can convert emotion label to emotion string if desired, but
        # training on number is better; better convert to emotion string after predictions are ready
        # emotion = emotions_dict[str(emotion)]

        # get other labels we might want
        intensity = emotion_attributes[file_name.split("-")[3]]
        # even actors are female, odd are male
        if (int((file_name.split("-")[6]).split(".")[0]))%2==0:
            gender = 'female'
        else:
            gender = 'male'

        # get waveform from the sample
        waveform = get_waveforms(file)

        # store waveforms and labels
        waveforms.append(waveform)
        emotions.append(emotion)
        intensities.append(intensity) # store intensity in case we wish to predict
        genders.append(gender) # store gender in case we wish to predict

        file_count += 1
        # keep track of data loader's progress
        print('\r'+f' Processed {file_count}/{1440} audio samples',end='')

    return waveforms, emotions, intensities, genders

# %%
# load data
# init explicitly to prevent data leakage from past sessions, since load_data() appends
waveforms, emotions, intensities, genders = [],[],[],[]
waveforms, emotions, intensities, genders = load_data()
# Out:
#  Processed 1440/1440 audio samples

# %% [markdown]
# ## Check extracted audio waveforms and labels:

# %%
print(f'Waveforms set: {len(waveforms)} samples')
# we have 1440 waveforms but we need to know their length too; should be 3 sec * 48k = 144k
print(f'Waveform signal length: {len(waveforms[0])}')
print(f'Emotions set: {len(emotions)} sample labels')
# Out:
# Waveforms set: 1440 samples
# Waveform signal length: 144000
# Emotions set: 1440 sample labels

# %% [markdown]
# Looks good. 1440 samples and 1440 labels in total.
#
# **Waveforms are 144k long because 3 seconds * 48k sample rate = 144k length array representing the 3 second audio snippet.**

# %% [markdown]
# ## Split into Train/Validation/Test Sets
# We'll use an 80/10/10 train/validation/test split to maximize training data and keep a reasonable validation/test set.
#
# **We're splitting waveforms so we can process train/validation/test waveforms separately and avoid data leakage.**
#
# **Have to take care to split the sets proportionally w.r.t. emotion.**
#
# **Yes, we can use sklearn - but to convince myself I've eradicated data leakage issues I did this manually.**

# %%
# create storage for train, validation, test sets and their indices
train_set,valid_set,test_set = [],[],[]
X_train,X_valid,X_test = [],[],[]
y_train,y_valid,y_test = [],[],[]

# convert waveforms to array for processing
waveforms = np.array(waveforms)

# process each emotion separately to make sure we builf balanced train/valid/test sets
for emotion_num in range(len(emotions_dict)):

    # find all indices of a single unique emotion
    emotion_indices = [index for index, emotion in enumerate(emotions) if emotion==emotion_num]

    # seed for reproducibility
    np.random.seed(69)
    # shuffle indicies
    emotion_indices = np.random.permutation(emotion_indices)

    # store dim (length) of the emotion list to make indices
    dim = len(emotion_indices)

    # store indices of training, validation and test sets in 80/10/10 proportion
    # train set is first 80%
    train_indices = emotion_indices[:int(0.8*dim)]
    # validation set is next 10% (between 80% and 90%)
    valid_indices = emotion_indices[int(0.8*dim):int(0.9*dim)]
    # test set is last 10% (between 90% - end/100%)
    test_indices = emotion_indices[int(0.9*dim):]

    # create train waveforms/labels sets
    X_train.append(waveforms[train_indices,:])
    y_train.append(np.array([emotion_num]*len(train_indices),dtype=np.int32))
    # create validation waveforms/labels sets
    X_valid.append(waveforms[valid_indices,:])
    y_valid.append(np.array([emotion_num]*len(valid_indices),dtype=np.int32))
    # create test waveforms/labels sets
    X_test.append(waveforms[test_indices,:])
    y_test.append(np.array([emotion_num]*len(test_indices),dtype=np.int32))

    # store indices for each emotion set to verify uniqueness between sets
    train_set.append(train_indices)
    valid_set.append(valid_indices)
    test_set.append(test_indices)

# concatenate, in order, all waveforms back into one array
X_train = np.concatenate(X_train,axis=0)
X_valid = np.concatenate(X_valid,axis=0)
X_test = np.concatenate(X_test,axis=0)

# concatenate, in order, all emotions back into one array
y_train = np.concatenate(y_train,axis=0)
y_valid = np.concatenate(y_valid,axis=0)
y_test = np.concatenate(y_test,axis=0)

# combine and store indices for all emotions' train, validation, test sets to verify uniqueness of sets
train_set = np.concatenate(train_set,axis=0)
valid_set = np.concatenate(valid_set,axis=0)
test_set = np.concatenate(test_set,axis=0)

# check shape of each set
print(f'Training waveforms:{X_train.shape}, y_train:{y_train.shape}')
print(f'Validation waveforms:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'Test waveforms:{X_test.shape}, y_test:{y_test.shape}')

# make sure train, validation, test sets have no overlap/are unique
# get all unique indices across all sets and how many times each index appears (count)
uniques, count = np.unique(np.concatenate([train_set,test_set,valid_set],axis=0), return_counts=True)

# if each index appears just once, and we have 1440 such unique indices, then all sets are unique
if sum(count==1) == len(emotions):
    print(f'\nSets are unique: {sum(count==1)} samples out of {len(emotions)} are unique')
else:
    print(f'\nSets are NOT unique: {sum(count==1)} samples out of {len(emotions)} are unique')
# Out:
# Training waveforms:(1147, 144000), y_train:(1147,)
# Validation waveforms:(143, 144000), y_valid:(143,)
# Test waveforms:(150, 144000), y_test:(150,)
#
# Sets are unique: 1440 samples out of 1440 are unique

# %% [markdown]
# ## Extract Features

# %% [markdown]
# Extract the features from unaugmented waveforms first. In the next step, we'll append features from augmented waveforms to these 'native' features.

# %%
# initialize feature arrays
# We extract MFCC features from waveforms and store in respective 'features' array
features_train, features_valid, features_test = [],[],[]

print('Train waveforms:') # get training set features
features_train = get_features(X_train, features_train, sample_rate)

print('\n\nValidation waveforms:') # get validation set features
features_valid = get_features(X_valid, features_valid, sample_rate)

print('\n\nTest waveforms:') # get test set features
features_test = get_features(X_test, features_test, sample_rate)

print(f'\n\nFeatures set: {len(features_train)+len(features_test)+len(features_valid)} total, {len(features_train)} train, {len(features_valid)} validation, {len(features_test)} test samples')
print(f'Features (MFC coefficient matrix) shape: {len(features_train[0])} mel frequency coefficients x {len(features_train[0][1])} time steps')
# Out:
# Train waveforms:
#  Processed 1147/1147 waveforms
#
# Validation waveforms:
#  Processed 143/143 waveforms
#
# Test waveforms:
#  Processed 150/150 waveforms
#
# Features set: 1440 total, 1147 train, 143 validation, 150 test samples
# Features (MFC coefficient matrix) shape: 40 mel frequency coefficients x 282 time steps

# %% [markdown]
# ## Augmenting the Data with AWGN - Additive White Gaussian Noise
#
# ### Motivation
#
# Since our dataset is small, it is prone to overfitting - especially with highly parameterized deep neural net models
# such as the one we aim to build in this notebook. As such, we're going to want to augment our data. Generating more real samples will be immensely difficult. Instead, we can add white noise to the audio signals - not only to mask the effect of random noise present in the training set - but also **to create pseudo-new training samples and offset the impact of noise intrinsic to the dataset.**
#
# In addition, the RAVDESS dataset is extremely clean - we will likely want to make predictions on noisy, real-world data - yet another reason to augment the training data.
#
# We're going to use Additive White Gaussian Noise (AWGN). It's Additive because we're adding it to the source audio signal,
# **it's Gaussian because the noise vector will be sampled from a normal distribution and have a time average of zero (zero-mean), and it's white because after a whitening transformation the noise will add power to the audio signal uniformly across the frequency distribution.**
#
# We need a good balance of noise - too little will be useless, and too much will make it too difficult for the network to learn from the training data. **Note that this is just for training - we would _not_ need to add AWGN to real-world data on which we make predictions** (although we could).
#
# ### Math
# The key parameters in AWGN are the signal to noise ratio (SNR), defining the magnitude of the noise added w.r.t. the audio signal. We parameterize AWGN with the minimum and maximize SNR so we can pick a random SNR to use in augmenting each sample's waveform.
#
# We need to constrain covariance to make it true AWGN. **We make a zero-mean vector of Gaussian noises (np.random.normal) that are statistically dependent. We need to apply a [whitening transformation](https://en.wikipedia.org/wiki/Whitening_transformation)**, a linear transformation taking a vector of random normal (Gaussian) variables with a known covariance matrix and mapping it to a new vector whose covariance is the identity matrix, i.e. the vector is now perfectly uncorrelated with a diaganol covariance matrix, each point of noise having variance == stdev == 1. **The whitening transformation by definition transforms a vector into a white noise vector.**
#
# We're going to add the AWGN augmented waveforms as new samples to our dataset. **Since we generate AWGN which is random for each and every sample - random random noise - we can add multiples of our noise-augmented dataset. I'll add 2 extra identical, randomly noisy datasets with 1440 samples each to get a dataset with 1440 native + 1440x2 == 4320 noisy samples.**

# %%
def awgn_augmentation(waveform, multiples=2, bits=16, snr_min=15, snr_max=30):

    # get length of waveform (should be 3*48k = 144k)
    wave_len = len(waveform)

    # Generate normally distributed (Gaussian) noises
    # one for each waveform and multiple (i.e. wave_len*multiples noises)
    noise = np.random.normal(size=(multiples, wave_len))

    # Normalize waveform and noise
    norm_constant = 2.0**(bits-1)
    norm_wave = waveform / norm_constant
    norm_noise = noise / norm_constant

    # Compute power of waveform and power of noise
    signal_power = np.sum(norm_wave ** 2) / wave_len
    noise_power = np.sum(norm_noise ** 2, axis=1) / wave_len

    # Choose random SNR in decibels in range [15,30]
    snr = np.random.randint(snr_min, snr_max)

    # Apply whitening transformation: make the Gaussian noise into Gaussian white noise
    # Compute the covariance matrix used to whiten each noise
    # actual SNR = signal/noise (power)
    # actual noise power = 10**(-snr/10)
    covariance = np.sqrt((signal_power / noise_power) * 10 ** (- snr / 10))
    # Get covariance matrix with dim: (144000, 2) so we can transform 2 noises: dim (2, 144000)
    covariance = np.ones((wave_len, multiples)) * covariance

    # Since covariance and noise are arrays, * is the haddamard product
    # Take Haddamard product of covariance and noise to generate white noise
    multiple_augmented_waveforms = waveform + covariance.T * noise

    return multiple_augmented_waveforms

# %%
def augment_waveforms(waveforms, features, emotions, multiples):
    # keep track of how many waveforms we've processed so we can add correct emotion label in the same order
    emotion_count = 0
    # keep track of how many augmented samples we've added
    added_count = 0
    # convert emotion array to list for more efficient appending
    emotions = emotions.tolist()

    for waveform in waveforms:

        # Generate 2 augmented multiples of the dataset, i.e. 1440 native + 1440*2 noisy = 4320 samples total
        augmented_waveforms = awgn_augmentation(waveform, multiples=multiples)

        # compute spectrogram for each of 2 augmented waveforms
        for augmented_waveform in augmented_waveforms:

            # Compute MFCCs over augmented waveforms
            augmented_mfcc = feature_mfcc(augmented_waveform, sample_rate=sample_rate)

            # append the augmented spectrogram to the rest of the native data
            features.append(augmented_mfcc)
            emotions.append(emotions[emotion_count])

            # keep track of new augmented samples
            added_count += 1

            # check progress
            print('\r'+f'Processed {emotion_count + 1}/{len(waveforms)} waveforms for {added_count}/{len(waveforms)*multiples} new augmented samples',end='')

        # keep track of the emotion labels to append in order
        emotion_count += 1

        # store augmented waveforms to check their shape
        augmented_waveforms_temp.append(augmented_waveforms)

    return features, emotions

# %% [markdown]
# ### Compute AWGN-augmented features and add to the rest of the dataset

# %%
# store augmented waveforms to verify their shape and random-ness
augmented_waveforms_temp = []

# specify multiples of our dataset to add as augmented data
multiples = 2

print('Train waveforms:') # augment waveforms of training set
features_train , y_train = augment_waveforms(X_train, features_train, y_train, multiples)

print('\n\nValidation waveforms:') # augment waveforms of validation set
features_valid, y_valid = augment_waveforms(X_valid, features_valid, y_valid, multiples)

print('\n\nTest waveforms:') # augment waveforms of test set
features_test, y_test = augment_waveforms(X_test, features_test, y_test, multiples)

# Check new shape of extracted features and data:
print(f'\n\nNative + Augmented Features set: {len(features_train)+len(features_test)+len(features_valid)} total, {len(features_train)} train, {len(features_valid)} validation, {len(features_test)} test samples')
print(f'{len(y_train)} training sample labels, {len(y_valid)} validation sample labels, {len(y_test)} test sample labels')
print(f'Features (MFCC matrix) shape: {len(features_train[0])} mel frequency coefficients x {len(features_train[0][1])} time steps')
# Out:
# Train waveforms:
# Processed 1147/1147 waveforms for 2294/2294 new augmented samples
#
# Validation waveforms:
# Processed 143/143 waveforms for 286/286 new augmented samples
#
# Test waveforms:
# Processed 150/150 waveforms for 300/300 new augmented samples
#
# Native + Augmented Features set: 4320 total, 3441 train, 429 validation, 450 test samples
# 3441 training sample labels, 429 validation sample labels, 450 test sample labels
# Features (MFCC matrix) shape: 40 mel frequency coefficients x 282 time steps

# %% [markdown]
# ### Check Augmented Waveforms:

# %%
# pick a random waveform, but same one from native and augmented set for easier comparison
plt.figure(figsize=(15,4))
plt.subplot(1, 2, 1)
librosa.display.waveshow(waveforms[12], sr=sample_rate)
plt.title('Native')

plt.subplot(1, 2, 2)
# augmented waveforms are 2D len 1440 list with 2 waveforms in each position
librosa.display.waveshow(augmented_waveforms_temp[0][0], sr=sample_rate)
plt.title('AWGN Augmented')
plt.show()

plt.figure(figsize=(15,4))
plt.subplot(1, 2, 1)
librosa.display.waveshow(augmented_waveforms_temp[2][0], sr=sample_rate)
plt.title('AWGN Augmented')

plt.subplot(1, 2, 2)
librosa.display.waveshow(augmented_waveforms_temp[7][0], sr=sample_rate)
plt.title('AWGN Augmented')
plt.show()

# %% [markdown]
# Looks noisy alright. Noise is clearly visible in otherwise-silent regions of the waveform. We can see the variability of the noise, which should have an SNR between 15 and 30.
#
# **Note that augmentation was only done after splitting data into train, validation, and test sets - and we processed each set separately.**
#
# **When we augmented the data before splitting it, test and validation data leaked into the training set giving a 97% test accuracy after training.**
#
# ## Format Data into Tensor Ready 4D Arrays
# We don't have a colour channel in our MFCC feature array of dim (#samples, #MFC coefficients, time steps). **We have an analog of a black and white image: instead of 3 colour channels, we have 1 signal intensity channel: magnitude of each of 40 mel frequency coefficients at time t.**
#
# **We need an input channel dim to expand to output channels using CNN filters. We create a dummy channel dim to expand features into 2D-CNN-ready 4D tensor format: N x C x H x W.**

# %%
# need to make dummy input channel for CNN input feature tensor
X_train = np.expand_dims(features_train,1)
X_valid = np.expand_dims(features_valid, 1)
X_test = np.expand_dims(features_test,1)

# convert emotion labels from list back to numpy arrays for PyTorch to work with
y_train = np.array(y_train)
y_valid = np.array(y_valid)
y_test = np.array(y_test)

# confiorm that we have tensor-ready 4D data array
# should print (batch, channel, width, height) == (4320, 1, 128, 282) when multiples==2
print(f'Shape of 4D feature array for input tensor: {X_train.shape} train, {X_valid.shape} validation, {X_test.shape} test')
print(f'Shape of emotion labels: {y_train.shape} train, {y_valid.shape} validation, {y_test.shape} test')
# Out:
# Shape of 4D feature array for input tensor: (3441, 1, 40, 282) train, (429, 1, 40, 282) validation, (450, 1, 40, 282) test
# Shape of emotion labels: (3441,) train, (429,) validation, (450,) test

# %%
# free up some RAM - no longer need full feature set or any waveforms
del features_train, features_valid, features_test, waveforms, augmented_waveforms_temp

# %% [markdown]
# ## Feature Scaling
# Scaling will drastically decrease the length of time the model needs to train to convergence - it will have easier computations to perform on smaller magnitudes. **For reference, scaling reduces the time to convergence from about 500 to 200 epochs for this model.**
#
# **Standard Scaling makes the most sense because we have features whose target distribution we don't know.** When I performed classification on this dataset with an MLP classifier standard scaling was best across a variety of conditions and features.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

#### Scale the training data ####
# store shape so we can transform it back
N,C,H,W = X_train.shape
# Reshape to 1D because StandardScaler operates on a 1D array
# tell numpy to infer shape of 1D array with '-1' argument
X_train = np.reshape(X_train, (N,-1))
X_train = scaler.fit_transform(X_train)
# Transform back to NxCxHxW 4D tensor format
X_train = np.reshape(X_train, (N,C,H,W))

##### Scale the validation set ####
N,C,H,W = X_valid.shape
X_valid = np.reshape(X_valid, (N,-1))
X_valid = scaler.transform(X_valid)
X_valid = np.reshape(X_valid, (N,C,H,W))

#### Scale the test set ####
N,C,H,W = X_test.shape
X_test = np.reshape(X_test, (N,-1))
X_test = scaler.transform(X_test)
X_test = np.reshape(X_test, (N,C,H,W))

# check shape of each set again
print(f'X_train scaled:{X_train.shape}, y_train:{y_train.shape}')
print(f'X_valid scaled:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'X_test scaled:{X_test.shape}, y_test:{y_test.shape}')
# Out:
# X_train scaled:(3441, 1, 40, 282), y_train:(3441,)
# X_valid scaled:(429, 1, 40, 282), y_valid:(429,)
# X_test scaled:(450, 1, 40, 282), y_test:(450,)

# %% [markdown]
# ## Save and Reload Data as NumPy Arrays
# We can save the training/validation/test data as numpy arrays to enable faster loading in case the notebook kernel crashes / google colab runtime crashes / any number of reasons the training data might be cleared from memory. This is much faster than loading 1440 files and computing their features again - not to mention augmented features.

# %%
###### SAVE #########
# choose save file name
filename = 'features+labels.npy'

# open file in write mode and write data
with open(filename, 'wb') as f:
    np.save(f, X_train)
    np.save(f, X_valid)
    np.save(f, X_test)
    np.save(f, y_train)
    np.save(f, y_valid)
    np.save(f, y_test)

print(f'Features and labels saved to {filename}')
# Out:
# Features and labels saved to features+labels.npy

# %%
##### LOAD #########
# choose load file name
filename = 'features+labels.npy'

# open file in read mode and read data
with open(filename, 'rb') as f:
    X_train = np.load(f)
    X_valid = np.load(f)
    X_test = np.load(f)
    y_train = np.load(f)
    y_valid = np.load(f)
    y_test = np.load(f)

# Check that we've recovered the right data
print(f'X_train:{X_train.shape}, y_train:{y_train.shape}')
print(f'X_valid:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'X_test:{X_test.shape}, y_test:{y_test.shape}')
# Out:
# X_train:(3441, 1, 40, 282), y_train:(3441,)
# X_valid:(429, 1, 40, 282), y_valid:(429,)
# X_test:(450, 1, 40, 282), y_test:(450,)

# %%
X_train.min()
# Out:
# -9.83280490603208

# %%
import torch
import torch.nn as nn

class Encoder1(nn.Module):
    def __init__(self):
        super(Encoder1, self).__init__()

        self.encoder1 = nn.Sequential(
            # 1st 2D convolution layer
            nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(16),
            nn.SELU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(p=0.3),

            # 2nd 2D convolution layer
            nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(32),
            nn.SELU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),

            # 3rd 2D convolution layer
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.SELU(),
            nn.MaxPool2d(kernel_size=4, stride=4)
        )

    def forward(self, x):
        return self.encoder1(x)

# %%
class Decoder1(nn.Module):
    def __init__(self):
        super(Decoder1, self).__init__()

        self.decoder1 = nn.Sequential(
            # 1st 2D transpose convolution layer
            nn.ConvTranspose2d(64, 32, kernel_size=5, stride=(1, 4), padding=0, output_padding=(0, 2)),
            nn.BatchNorm2d(32),
            nn.SELU(),

            # 2nd 2D transpose convolution layer
            nn.ConvTranspose2d(32, 16, kernel_size=3, stride=4, padding=0, output_padding=(1, 2)),
            nn.BatchNorm2d(16),
            nn.SELU(),

            # 3rd 2D transpose convolution layer
            nn.ConvTranspose2d(16, 1, kernel_size=3, stride=2, padding=1, output_padding=1)
        )

    def forward(self, x):
        return self.decoder1(x)

# %%
class Autoencoder1(nn.Module):
    def __init__(self):
        super(Autoencoder1, self).__init__()
        self.encoder = Encoder1()
        self.decoder = Decoder1()

    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return encoded, decoded

# %%
# Example usage
autoencoder = Autoencoder1()
input_data = torch.randn(1, 1, 40, 282)  # Replace with your input shape
encoded1, decoded1 = autoencoder(input_data)
encoded1.shape, decoded1.shape
# Out:
# (torch.Size([1, 64, 1, 8]), torch.Size([1, 1, 40, 282]))

# %%
import torch.nn as nn

class Encoder2(nn.Module):
    def __init__(self):
        super(Encoder2, self).__init__()

        # Define the 2D convolutional layers
        self.conv2Dblock = nn.Sequential(
            # 1st 2D convolution layer
            nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(16),
            nn.SELU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(p=0.3),

            # 2nd 2D convolution layer
            nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(32),
            nn.SELU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),

            # 3rd 2D convolution layer
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.SELU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3)
        )

    def forward(self, x):
        # Pass the input through the convolutional layers
        return self.conv2Dblock(x)

# %%
import torch.nn as nn

class Decoder2(nn.Module):
    def __init__(self):
        super(Decoder2, self).__init__()

        # Define the 2D transposed convolutional layers for the decoder
        self.decoder2 = nn.Sequential(
            # 1st 2D transposed convolution layer
            nn.ConvTranspose2d(64, 32, kernel_size=5, stride=(1, 4), padding=0, output_padding=(0, 2)),
            nn.BatchNorm2d(32),
            nn.SELU(),

            # 2nd 2D transposed convolution layer
            nn.ConvTranspose2d(32, 16, kernel_size=3, stride=4, padding=0, output_padding=(1, 2)),
            nn.BatchNorm2d(16),
            nn.SELU(),

            # 3rd 2D transposed convolution layer
            nn.ConvTranspose2d(16, 1, kernel_size=3, stride=2, padding=1, output_padding=1)
        )

    def forward(self, x):
        # Pass the input through the decoder's transposed convolutional layers
        return self.decoder2(x)

# %%
import torch.nn as nn

class Autoencoder2(nn.Module):
    def __init__(self):
        super(Autoencoder2, self).__init__()

        # Define the encoder and decoder
        self.encoder = Encoder2()
        self.decoder = Decoder2()

    def forward(self, x):
        # Encode the input
        encoded = self.encoder(x)

        # Decode the encoded representation
        decoded = self.decoder(encoded)

        return encoded, decoded
# Example usage
autoencoder2 = Autoencoder2()
input_data = torch.randn(1, 1, 40, 282)  # Replace with your input shape
encoded2, decoded2 = autoencoder2(input_data)
encoded2.shape, decoded2.shape
# Out:
# (torch.Size([1, 64, 1, 8]), torch.Size([1, 1, 40, 282]))

# %%
import torch.nn as nn

class TransformerBlock(nn.Module):
    def __init__(self):
        super(TransformerBlock, self).__init__()

        # Maxpool the input feature map/tensor to the transformer
        self.transformer_maxpool = nn.MaxPool2d(kernel_size=[1, 4], stride=[1, 4])

        # Define a single transformer encoder layer
        transformer_layer = nn.TransformerEncoderLayer(
            d_model=40,            # Input feature (frequency) dim after max-pooling: 40*282 -> 40*70 (MFC * time)
            nhead=4,               # Number of self-attention layers in each multi-head self-attention layer in each encoder block
            dim_feedforward=512,   # Dimension for the feedforward network in each encoder block: 40 -> 512 -> 40
            dropout=0.4,
            activation='relu'      # Activation function (e.g., ReLU) for feedforward network
        )

        # The complete transformer block contains 4 full transformer encoder layers
        self.transformer_encoder = nn.TransformerEncoder(transformer_layer, num_layers=4)

    def forward(self, x):


                ########## 4-encoder-layer Transformer block w/ 40-->512-->40 feedfwd network ##############
        # maxpool input feature map: 1*40*282 w/ 1*4 kernel --> 1*40*70
        x_maxpool = self.transformer_maxpool(x)

        # remove channel dim: 1*40*70 --> 40*70
        x_maxpool_reduced = torch.squeeze(x_maxpool,1)

        # convert maxpooled feature map format: batch * freq * time ---> time * batch * freq format
        # because transformer encoder layer requires tensor in format: time * batch * embedding (freq)
        x = x_maxpool_reduced.permute(2,0,1)

        # finally, pass reduced input feature map x into transformer encoder layers
        transformer_output = self.transformer_encoder(x)

        # create final feature emedding from transformer layer by taking mean in the time dimension (now the 0th dim)
        # transformer outputs 2x40 (MFCC embedding*time) feature map, take mean of columns i.e. take time average
        transformer_embedding = torch.mean(transformer_output, dim=0) # dim 40x70 --> 40
        return transformer_embedding

# You can use this TransformerBlock within your larger model as needed.

# %%
import torch.nn as nn

class EmotionClassifier(nn.Module):
    def __init__(self, num_emotions):
        super(EmotionClassifier, self).__init__()

        # Linear softmax layer to take the final concatenated embedding tensor
        # from parallel 2D convolutional and transformer blocks, output 8 logits
        # Each full convolution block outputs (64*1*8) embedding flattened to dim 512 1D array
        # Full transformer block outputs 40*70 feature map, which we time-avg to dim 40 1D array
        # 512*2 + 40 == 1064 input features --> 8 output emotions
        self.fc1_linear = nn.Linear(512*2 + 40, num_emotions)

        # Softmax layer for the 8 output logits from the final FC linear layer
        self.softmax_out = nn.Softmax(dim=1)  # dim==1 refers to the frequency embedding

    def forward(self,x):

        # Pass the concatenated features through the final linear layer
        output = self.fc1_linear(x)

        # Apply softmax to get the class probabilities
        class_probs = self.softmax_out(output)

        return output , class_probs

# You can use this EmotionClassifier as part of your larger model to perform emotion classification.

# %%
# Combine the models
class MultiTaskModel(nn.Module):
    def __init__(self,num_emotions):
        super(MultiTaskModel, self).__init__()
        self.autoencoder1 = Autoencoder1()
        self.autoencoder2 = Autoencoder2()
        self.transformerblock = TransformerBlock()
        self.emotion_classifier = EmotionClassifier(num_emotions)

    def forward(self, x):
        encoded1, decoded1 = self.autoencoder1(x)
        encoded1_embedding1 = torch.flatten(encoded1, start_dim=1)

        encoded2, decoded2= self.autoencoder2(x)
        encoded2_embedding2 = torch.flatten(encoded2, start_dim=1)

        transformer_embedding = self.transformerblock(x)

        complete_embedding = torch.cat([encoded1_embedding1, encoded2_embedding2,transformer_embedding], dim=1)

        output_logits, output_softmax = self.emotion_classifier(complete_embedding)

        return decoded1, decoded2, output_logits, output_softmax

# %%
# Example usage
model = MultiTaskModel(num_emotions=8)
input_data = torch.randn(1, 1, 40, 282)  # Replace with your input shape
decoded1, decoded2, output_logits, output_softmax = model(input_data)
decoded1.shape, decoded2.shape, output_logits, output_softmax
# Out:
# (torch.Size([1, 1, 40, 282]),
#  torch.Size([1, 1, 40, 282]),
#  tensor([[ 1.8307, -0.2191, -1.2337,  0.8446, -1.1893, -2.4461,  1.3175, -0.7330]],
#         grad_fn=<AddmmBackward0>),
#  tensor([[0.4373, 0.0563, 0.0204, 0.1631, 0.0213, 0.0061, 0.2618, 0.0337]],
#         grad_fn=<SoftmaxBackward0>))

# %%
# Loss functions
autoencoder_criterion = nn.MSELoss()  # Use Mean Squared Error for autoencoder loss
classifier_criterion = nn.CrossEntropyLoss()  # Use Cross-Entropy for emotion classification loss
optimizer = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

# %%
# define function to create a single step of the training phase
def make_train_step(model, autoencoder_criterion, classifier_criterion, optimizer):

    # define the training step of the training phase
    def train_step(X,Y):

        # forward pass
        decoded1, decoded2, output_logits, output_softmax  = model(X)
        predictions = torch.argmax(output_softmax,dim=1)
        accuracy = torch.sum(Y==predictions)/float(len(Y))

        # Compute losses
        autoencoder_loss1 = autoencoder_criterion(decoded1, X)
        autoencoder_loss2 = autoencoder_criterion(decoded2, X)
        classifier_loss = classifier_criterion(output_logits, Y)

        # Define a trade-off parameter to balance losses
        tradeoff = 0.4 # Adjust as needed

        # Calculate the combined loss
        loss = tradeoff * (autoencoder_loss1 + autoencoder_loss2) + (1 - tradeoff) * classifier_loss

        # compute gradients for the optimizer to use
        loss.backward()

        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()

        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad()

        return loss.item(), accuracy*100, autoencoder_loss1.item(), autoencoder_loss2.item(), classifier_loss.item()
    return train_step

# %%
def make_validate_fnc(model,autoencoder_criterion, classifier_criterion):
    def validate(X,Y):

        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase:
        with torch.no_grad():

            # set model to validation phase i.e. turn off dropout and batchnorm layers
            model.eval()

            # get the model's predictions on the validation set
            decoded1, decoded2, output_logits, output_softmax  = model(X)
            predictions = torch.argmax(output_softmax,dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y==predictions)/float(len(Y))

            # Compute losses
            autoencoder_loss1 = autoencoder_criterion(decoded1, X)
            autoencoder_loss2 = autoencoder_criterion(decoded2, X)
            classifier_loss = classifier_criterion(output_logits, Y)

            # compute error from logits (nn.crossentropy implements softmax)
            # Define a trade-off parameter to balance losses
            tradeoff = 0.4 # Adjust as needed

            # Calculate the combined loss
            loss = tradeoff * (autoencoder_loss1 + autoencoder_loss2) + (1 - tradeoff) * classifier_loss


        return loss.item(), accuracy*100, autoencoder_loss1.item(), autoencoder_loss2.item(), classifier_loss.item(), predictions
    return validate

# %%
def make_save_checkpoint():
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint

def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
# get training set size to calculate # iterations and minibatch indices
train_size = X_train.shape[0]

# pick minibatch size (of 32... always)
minibatch = 32

# set device to GPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'{device} selected')
# Out:
# cuda selected

# %%
# instantiate model and move to GPU for training
model = MultiTaskModel(num_emotions=len(emotions_dict)).to(device)
print('Number of trainable params: ',sum(p.numel() for p in model.parameters()) )
# Out:
# Number of trainable params:  360682

# %%
# encountered bugs in google colab only, unless I explicitly defined optimizer in this cell...
optimizer = torch.optim.SGD(model.parameters(),lr=0.00001, weight_decay=1e-3, momentum=0.8)
# Loss functions
autoencoder_criterion = nn.MSELoss()  # Use Mean Squared Error for autoencoder loss
classifier_criterion = nn.CrossEntropyLoss()  # Use Cross-Entropy for emotion classification loss

# %%
# instantiate the checkpoint save function
save_checkpoint = make_save_checkpoint()

# instantiate the training step function
train_step = make_train_step(model, autoencoder_criterion, classifier_criterion, optimizer=optimizer)

# instantiate the validation loop function
validate = make_validate_fnc(model,autoencoder_criterion, classifier_criterion)

# %%
# instantiate lists to hold scalar performance metrics to plot later
train_losses=[]
valid_losses = []
train_autoencoder_losses1=[]
train_autoencoder_losses2=[]
train_classifier_losses=[]


valid_autoencoder_losses1=[]
valid_autoencoder_losses2=[]
valid_classifier_losses=[]

# %%
# create training loop for one complete epoch (entire training set)
def train(optimizer, model, num_epochs, X_train, Y_train, X_valid, Y_valid):

    for epoch in range(num_epochs):

        # set model to train phase
        model.train()

        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size)

        # shuffle the training set for each epoch:
        X_train = X_train[train_indices,:,:,:]
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate
        epoch_acc = 0
        epoch_loss = 0
        epoch_autoencoder_loss1 = 0
        epoch_autoencoder_loss2 = 0
        epoch_classifier_loss = 0




        num_iterations = int(train_size / minibatch)

        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):

            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size)
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start

            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end,:,:,:]
            # get training minibatch labels
            Y = Y_train[batch_start:batch_end]

            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float()
            Y_tensor = torch.tensor(Y, dtype=torch.long,device=device)
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc, autoencoder_loss1, autoencoder_loss2, classifier_loss = train_step(X_tensor,Y_tensor)

            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size
            epoch_autoencoder_loss1 += autoencoder_loss1 * actual_batch_size / train_size
            epoch_autoencoder_loss2 += autoencoder_loss2 * actual_batch_size / train_size
            epoch_classifier_loss += classifier_loss * actual_batch_size / train_size



            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}',end='')

        # create tensors from validation set
        X_valid_tensor = torch.tensor(X_valid,device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid,dtype=torch.long,device=device)

        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, valid_autoencoder_loss1, valid_autoencoder_loss2, valid_classifier_loss, _ = validate(X_valid_tensor,
                                                                                                                     Y_valid_tensor)

        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        train_autoencoder_losses1.append(epoch_autoencoder_loss1)
        train_autoencoder_losses2.append(epoch_autoencoder_loss2)
        train_classifier_losses.append(epoch_classifier_loss)

        valid_losses.append(valid_loss)
        valid_autoencoder_losses1.append(valid_autoencoder_loss1)
        valid_autoencoder_losses2.append(valid_autoencoder_loss2)
        valid_classifier_losses.append(valid_classifier_loss)


        # Save checkpoint of the model
        checkpoint_filename = '/content/parallel_all_you_wantFINAL.pkl'.format(epoch)
        save_checkpoint(optimizer, model, epoch, checkpoint_filename)

        # keep track of each epoch's progress
        print(f'\nEpoch {epoch} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')
        print(f'\nEpoch {epoch} --- epoch_autoencoder_loss1:{epoch_autoencoder_loss1:.3f}, epoch_autoencoder_loss2:{epoch_autoencoder_loss2:.2f}, epoch_classifier_loss:{epoch_classifier_loss:.3f}')
        print(f'\nEpoch {epoch} --- valid_autoencoder_loss1:{valid_autoencoder_loss1:.3f}, valid_autoencoder_loss2:{valid_autoencoder_loss2:.2f}, valid_classifier_loss:{valid_classifier_loss:.3f}\n\n')

# %%
# choose number of epochs higher than reasonable so we can manually stop training
num_epochs = 5000

# train it!
train(optimizer, model, num_epochs, X_train, y_train, X_valid, y_valid)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Epoch 333 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.107
#
# Epoch 333 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.310
#
#
# Epoch 334: iteration 106/107
# Epoch 334 --- loss:1.456, Epoch accuracy:60.83%, Validation loss:1.575, Validation accuracy:55.48%
#
# Epoch 334 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.087
#
# Epoch 334 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.306
#
#
# Epoch 335: iteration 106/107
# Epoch 335 --- loss:1.457, Epoch accuracy:60.83%, Validation loss:1.575, Validation accuracy:55.71%
#
# Epoch 335 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.088
#
# Epoch 335 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.306
#
#
# Epoch 336: iteration 106/107
# Epoch 336 --- loss:1.454, Epoch accuracy:61.38%, Validation loss:1.574, Validation accuracy:55.71%
#
# Epoch 336 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.083
#
# Epoch 336 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.303
#
#
# Epoch 337: iteration 106/107
# Epoch 337 --- loss:1.462, Epoch accuracy:60.68%, Validation loss:1.570, Validation accuracy:55.71%
#
# Epoch 337 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.097
#
# Epoch 337 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.297
#
#
# Epoch 338: iteration 106/107
# Epoch 338 --- loss:1.460, Epoch accuracy:60.94%, Validation loss:1.577, Validation accuracy:55.71%
#
# Epoch 338 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.093
#
# Epoch 338 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.309
#
#
# Epoch 339: iteration 106/107
# Epoch 339 --- loss:1.462, Epoch accuracy:60.27%, Validation loss:1.571, Validation accuracy:55.71%
#
# Epoch 339 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.095
#
# Epoch 339 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.298
#
#
# Epoch 340: iteration 106/107
# Epoch 340 --- loss:1.461, Epoch accuracy:59.84%, Validation loss:1.575, Validation accuracy:55.71%
#
# Epoch 340 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.094
#
# Epoch 340 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.305
#
#
# Epoch 341: iteration 106/107
# Epoch 341 --- loss:1.456, Epoch accuracy:61.20%, Validation loss:1.571, Validation accuracy:55.48%
#
# Epoch 341 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.088
#
# Epoch 341 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.299
#
#
# Epoch 342: iteration 106/107
# Epoch 342 --- loss:1.458, Epoch accuracy:60.65%, Validation loss:1.577, Validation accuracy:55.48%
#
# Epoch 342 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.090
#
# Epoch 342 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.309
#
#
# Epoch 343: iteration 106/107
# Epoch 343 --- loss:1.458, Epoch accuracy:61.17%, Validation loss:1.573, Validation accuracy:55.48%
#
# Epoch 343 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.089
#
# Epoch 343 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.302
#
#
# Epoch 344: iteration 106/107
# Epoch 344 --- loss:1.461, Epoch accuracy:60.36%, Validation loss:1.578, Validation accuracy:55.71%
#
# Epoch 344 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.095
#
# Epoch 344 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.311
#
#
# Epoch 345: iteration 106/107
# Epoch 345 --- loss:1.468, Epoch accuracy:60.85%, Validation loss:1.569, Validation accuracy:55.71%
#
# Epoch 345 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.107
#
# Epoch 345 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.295
#
#
# Epoch 346: iteration 106/107
# Epoch 346 --- loss:1.453, Epoch accuracy:61.03%, Validation loss:1.574, Validation accuracy:56.18%
#
# Epoch 346 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.081
#
# Epoch 346 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.303
#
#
# Epoch 347: iteration 106/107
# Epoch 347 --- loss:1.458, Epoch accuracy:60.83%, Validation loss:1.570, Validation accuracy:55.71%
#
# Epoch 347 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.089
#
# Epoch 347 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.296
#
#
# Epoch 348: iteration 106/107
# Epoch 348 --- loss:1.456, Epoch accuracy:60.80%, Validation loss:1.574, Validation accuracy:55.71%
#
# Epoch 348 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.087
#
# Epoch 348 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.303
#
#
# Epoch 349: iteration 106/107
# Epoch 349 --- loss:1.453, Epoch accuracy:61.73%, Validation loss:1.572, Validation accuracy:55.71%
#
# Epoch 349 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.082
#
# Epoch 349 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.300
#
#
# Epoch 350: iteration 106/107
# Epoch 350 --- loss:1.457, Epoch accuracy:60.48%, Validation loss:1.571, Validation accuracy:55.71%
#
# Epoch 350 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.087
#
# Epoch 350 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.299
#
#
# Epoch 351: iteration 106/107
# Epoch 351 --- loss:1.466, Epoch accuracy:59.55%, Validation loss:1.575, Validation accuracy:55.01%
#
# Epoch 351 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.102
#
# Epoch 351 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.305
#
#
# Epoch 352: iteration 106/107
# Epoch 352 --- loss:1.455, Epoch accuracy:60.42%, Validation loss:1.575, Validation accuracy:55.24%
#
# Epoch 352 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.084
#
# Epoch 352 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.306
#
#
# Epoch 353: iteration 106/107
# Epoch 353 --- loss:1.456, Epoch accuracy:60.85%, Validation loss:1.572, Validation accuracy:55.24%
#
# Epoch 353 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.086
#
# Epoch 353 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.301
#
#
# Epoch 354: iteration 106/107
# Epoch 354 --- loss:1.457, Epoch accuracy:61.41%, Validation loss:1.569, Validation accuracy:55.48%
#
# Epoch 354 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.087
#
# Epoch 354 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.296
#
#
# Epoch 355: iteration 106/107
# Epoch 355 --- loss:1.455, Epoch accuracy:61.23%, Validation loss:1.576, Validation accuracy:55.24%
#
# Epoch 355 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.084
#
# Epoch 355 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.306
#
#
# Epoch 356: iteration 106/107
# Epoch 356 --- loss:1.462, Epoch accuracy:60.74%, Validation loss:1.577, Validation accuracy:55.71%
#
# Epoch 356 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.096
#
# Epoch 356 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.308
#
#
# Epoch 357: iteration 106/107
# Epoch 357 --- loss:1.454, Epoch accuracy:60.80%, Validation loss:1.578, Validation accuracy:55.71%
#
# Epoch 357 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.082
#
# Epoch 357 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.310
#
#
# Epoch 358: iteration 106/107
# Epoch 358 --- loss:1.458, Epoch accuracy:60.53%, Validation loss:1.577, Validation accuracy:55.48%
#
# Epoch 358 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.090
#
# Epoch 358 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.308
#
#
# Epoch 359: iteration 106/107
# Epoch 359 --- loss:1.456, Epoch accuracy:60.83%, Validation loss:1.574, Validation accuracy:55.24%
#
# Epoch 359 --- epoch_autoencoder_loss1:1.001, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.086
#
# Epoch 359 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.304
#
#
# Epoch 360: iteration 106/107
# Epoch 360 --- loss:1.456, Epoch accuracy:61.00%, Validation loss:1.573, Validation accuracy:55.71%
#
# Epoch 360 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.087
#
# Epoch 360 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.302
#
#
# Epoch 361: iteration 106/107
# Epoch 361 --- loss:1.456, Epoch accuracy:61.15%, Validation loss:1.571, Validation accuracy:55.71%
#
# Epoch 361 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.087
#
# Epoch 361 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.299
#
#
# Epoch 362: iteration 106/107
# Epoch 362 --- loss:1.454, Epoch accuracy:61.32%, Validation loss:1.576, Validation accuracy:55.71%
#
# Epoch 362 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.084
#
# Epoch 362 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.307
#
#
# Epoch 363: iteration 106/107
# Epoch 363 --- loss:1.459, Epoch accuracy:61.64%, Validation loss:1.576, Validation accuracy:55.71%
#
# Epoch 363 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.092
#
# Epoch 363 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.307
#
#
# Epoch 364: iteration 106/107
# Epoch 364 --- loss:1.454, Epoch accuracy:60.53%, Validation loss:1.572, Validation accuracy:56.41%
#
# Epoch 364 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.083
#
# Epoch 364 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.301
#
#
# Epoch 365: iteration 106/107
# Epoch 365 --- loss:1.458, Epoch accuracy:60.97%, Validation loss:1.569, Validation accuracy:55.71%
#
# Epoch 365 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.089
#
# Epoch 365 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.296
#
#
# Epoch 366: iteration 106/107
# Epoch 366 --- loss:1.459, Epoch accuracy:60.74%, Validation loss:1.573, Validation accuracy:55.71%
#
# Epoch 366 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.091
#
# Epoch 366 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.302
#
#
# Epoch 367: iteration 106/107
# Epoch 367 --- loss:1.455, Epoch accuracy:60.74%, Validation loss:1.573, Validation accuracy:55.48%
#
# Epoch 367 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.084
#
# Epoch 367 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.302
#
#
# Epoch 368: iteration 106/107
# Epoch 368 --- loss:1.453, Epoch accuracy:61.52%, Validation loss:1.573, Validation accuracy:55.24%
#
# Epoch 368 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.082
#
# Epoch 368 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.302
#
#
# Epoch 369: iteration 106/107
# Epoch 369 --- loss:1.459, Epoch accuracy:61.52%, Validation loss:1.571, Validation accuracy:55.94%
#
# Epoch 369 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.090
#
# Epoch 369 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.299
#
#
# Epoch 370: iteration 106/107
# Epoch 370 --- loss:1.462, Epoch accuracy:61.35%, Validation loss:1.574, Validation accuracy:55.48%
#
# Epoch 370 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.095
#
# Epoch 370 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.304
#
#
# Epoch 371: iteration 106/107
# Epoch 371 --- loss:1.460, Epoch accuracy:60.19%, Validation loss:1.570, Validation accuracy:55.94%
#
# Epoch 371 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.093
#
# Epoch 371 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.297
#
#
# Epoch 372: iteration 106/107
# Epoch 372 --- loss:1.463, Epoch accuracy:60.88%, Validation loss:1.572, Validation accuracy:55.71%
#
# Epoch 372 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.097
#
# Epoch 372 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.300
#
#
# Epoch 373: iteration 106/107
# Epoch 373 --- loss:1.453, Epoch accuracy:60.68%, Validation loss:1.573, Validation accuracy:55.48%
#
# Epoch 373 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.081
#
# Epoch 373 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.301
#
#
# Epoch 374: iteration 106/107
# Epoch 374 --- loss:1.455, Epoch accuracy:61.90%, Validation loss:1.570, Validation accuracy:55.48%
#
# Epoch 374 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.086
#
# Epoch 374 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.297
#
#
# Epoch 375: iteration 106/107
# Epoch 375 --- loss:1.456, Epoch accuracy:60.85%, Validation loss:1.568, Validation accuracy:55.71%
#
# Epoch 375 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.086
#
# Epoch 375 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.293
#
#
# Epoch 376: iteration 106/107
# Epoch 376 --- loss:1.459, Epoch accuracy:61.17%, Validation loss:1.570, Validation accuracy:55.48%
#
# Epoch 376 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.092
#
# Epoch 376 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.296
#
#
# Epoch 377: iteration 106/107
# Epoch 377 --- loss:1.457, Epoch accuracy:60.36%, Validation loss:1.570, Validation accuracy:55.48%
#
# Epoch 377 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.088
#
# Epoch 377 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.296
#
#
# Epoch 378: iteration 106/107
# Epoch 378 --- loss:1.456, Epoch accuracy:61.26%, Validation loss:1.574, Validation accuracy:55.48%
#
# Epoch 378 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.087
#
# Epoch 378 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.304
#
#
# Epoch 379: iteration 106/107
# Epoch 379 --- loss:1.460, Epoch accuracy:60.13%, Validation loss:1.568, Validation accuracy:56.41%
#
# Epoch 379 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.093
#
# Epoch 379 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.294
#
#
# Epoch 380: iteration 106/107
# Epoch 380 --- loss:1.458, Epoch accuracy:60.71%, Validation loss:1.572, Validation accuracy:55.48%
#
# Epoch 380 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.089
#
# Epoch 380 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.300
#
#
# Epoch 381: iteration 106/107
# Epoch 381 --- loss:1.456, Epoch accuracy:61.09%, Validation loss:1.568, Validation accuracy:55.71%
#
# Epoch 381 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.087
#
# Epoch 381 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.294
#
#
# Epoch 382: iteration 106/107
# Epoch 382 --- loss:1.456, Epoch accuracy:61.06%, Validation loss:1.573, Validation accuracy:55.71%
#
# Epoch 382 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.087
#
# Epoch 382 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.302
#
#
# Epoch 383: iteration 106/107
# Epoch 383 --- loss:1.456, Epoch accuracy:61.29%, Validation loss:1.575, Validation accuracy:55.94%
#
# Epoch 383 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.086
#
# Epoch 383 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.305
#
#
# Epoch 384: iteration 106/107
# Epoch 384 --- loss:1.458, Epoch accuracy:60.30%, Validation loss:1.569, Validation accuracy:55.48%
#
# Epoch 384 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.090
#
# Epoch 384 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.295
#
#
# Epoch 385: iteration 106/107
# Epoch 385 --- loss:1.458, Epoch accuracy:61.32%, Validation loss:1.575, Validation accuracy:55.24%
#
# Epoch 385 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.089
#
# Epoch 385 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.305
#
#
# Epoch 386: iteration 106/107
# Epoch 386 --- loss:1.458, Epoch accuracy:60.83%, Validation loss:1.572, Validation accuracy:55.94%
#
# Epoch 386 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.090
#
# Epoch 386 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.301
#
#
# Epoch 387: iteration 106/107
# Epoch 387 --- loss:1.457, Epoch accuracy:60.42%, Validation loss:1.570, Validation accuracy:56.18%
#
# Epoch 387 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.089
#
# Epoch 387 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.297
#
#
# Epoch 388: iteration 106/107
# Epoch 388 --- loss:1.453, Epoch accuracy:61.32%, Validation loss:1.568, Validation accuracy:55.48%
#
# Epoch 388 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.081
#
# Epoch 388 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.294
#
#
# Epoch 389: iteration 106/107
# Epoch 389 --- loss:1.454, Epoch accuracy:61.15%, Validation loss:1.567, Validation accuracy:55.94%
#
# Epoch 389 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.082
#
# Epoch 389 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.291
#
#
# Epoch 390: iteration 106/107
# Epoch 390 --- loss:1.458, Epoch accuracy:60.91%, Validation loss:1.571, Validation accuracy:55.48%
#
# Epoch 390 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.089
#
# Epoch 390 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.299
#
#
# Epoch 391: iteration 106/107
# Epoch 391 --- loss:1.456, Epoch accuracy:60.36%, Validation loss:1.571, Validation accuracy:55.48%
#
# Epoch 391 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.087
#
# Epoch 391 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.298
#
#
# Epoch 392: iteration 106/107
# Epoch 392 --- loss:1.456, Epoch accuracy:60.74%, Validation loss:1.565, Validation accuracy:55.48%
#
# Epoch 392 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.087
#
# Epoch 392 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.289
#
#
# Epoch 393: iteration 106/107
# Epoch 393 --- loss:1.459, Epoch accuracy:60.10%, Validation loss:1.567, Validation accuracy:55.24%
#
# Epoch 393 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.091
#
# Epoch 393 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.292
#
#
# Epoch 394: iteration 106/107
# Epoch 394 --- loss:1.455, Epoch accuracy:61.61%, Validation loss:1.569, Validation accuracy:55.24%
#
# Epoch 394 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.086
#
# Epoch 394 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.296
#
#
# Epoch 395: iteration 106/107
# Epoch 395 --- loss:1.454, Epoch accuracy:61.23%, Validation loss:1.576, Validation accuracy:55.24%
#
# Epoch 395 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.085
#
# Epoch 395 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.307
#
#
# Epoch 396: iteration 106/107
# Epoch 396 --- loss:1.456, Epoch accuracy:61.23%, Validation loss:1.569, Validation accuracy:56.18%
#
# Epoch 396 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.087
#
# Epoch 396 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.296
#
#
# Epoch 397: iteration 106/107
# Epoch 397 --- loss:1.458, Epoch accuracy:60.97%, Validation loss:1.573, Validation accuracy:55.71%
#
# Epoch 397 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.090
#
# Epoch 397 --- valid_autoencoder_loss1:0.990, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.302
#
#
# Epoch 398: iteration 106/107
# Epoch 398 --- loss:1.457, Epoch accuracy:60.71%, Validation loss:1.566, Validation accuracy:55.71%
#
# Epoch 398 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.089
#
# Epoch 398 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.290
#
#
# Epoch 399: iteration 106/107
# Epoch 399 --- loss:1.453, Epoch accuracy:60.56%, Validation loss:1.567, Validation accuracy:56.18%
#
# Epoch 399 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.082
#
# Epoch 399 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.293
#
#
# Epoch 400: iteration 106/107
# Epoch 400 --- loss:1.453, Epoch accuracy:61.49%, Validation loss:1.572, Validation accuracy:55.71%
#
# Epoch 400 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.081
#
# Epoch 400 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.300
#
#
# Epoch 401: iteration 106/107
# Epoch 401 --- loss:1.447, Epoch accuracy:62.34%, Validation loss:1.565, Validation accuracy:55.48%
#
# Epoch 401 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.072
#
# Epoch 401 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.290
#
#
# Epoch 402: iteration 106/107
# Epoch 402 --- loss:1.457, Epoch accuracy:61.00%, Validation loss:1.567, Validation accuracy:55.94%
#
# Epoch 402 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.089
#
# Epoch 402 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.292
#
#
# Epoch 403: iteration 106/107
# Epoch 403 --- loss:1.450, Epoch accuracy:61.49%, Validation loss:1.570, Validation accuracy:55.71%
#
# Epoch 403 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.077
#
# Epoch 403 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.296
#
#
# Epoch 404: iteration 106/107
# Epoch 404 --- loss:1.450, Epoch accuracy:61.32%, Validation loss:1.566, Validation accuracy:55.71%
#
# Epoch 404 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.077
#
# Epoch 404 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.290
#
#
# Epoch 405: iteration 106/107
# Epoch 405 --- loss:1.454, Epoch accuracy:60.97%, Validation loss:1.568, Validation accuracy:55.71%
#
# Epoch 405 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.084
#
# Epoch 405 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.294
#
#
# Epoch 406: iteration 106/107
# Epoch 406 --- loss:1.458, Epoch accuracy:60.30%, Validation loss:1.569, Validation accuracy:55.71%
#
# Epoch 406 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.090
#
# Epoch 406 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.295
#
#
# Epoch 407: iteration 106/107
# Epoch 407 --- loss:1.459, Epoch accuracy:61.09%, Validation loss:1.572, Validation accuracy:55.94%
#
# Epoch 407 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.092
#
# Epoch 407 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.300
#
#
# Epoch 408: iteration 106/107
# Epoch 408 --- loss:1.449, Epoch accuracy:61.70%, Validation loss:1.570, Validation accuracy:55.24%
#
# Epoch 408 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.075
#
# Epoch 408 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.297
#
#
# Epoch 409: iteration 106/107
# Epoch 409 --- loss:1.461, Epoch accuracy:60.71%, Validation loss:1.569, Validation accuracy:55.71%
#
# Epoch 409 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.095
#
# Epoch 409 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.295
#
#
# Epoch 410: iteration 106/107
# Epoch 410 --- loss:1.456, Epoch accuracy:61.03%, Validation loss:1.572, Validation accuracy:55.94%
#
# Epoch 410 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.086
#
# Epoch 410 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.300
#
#
# Epoch 411: iteration 106/107
# Epoch 411 --- loss:1.455, Epoch accuracy:61.23%, Validation loss:1.569, Validation accuracy:55.48%
#
# Epoch 411 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.084
#
# Epoch 411 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.296
#
#
# Epoch 412: iteration 106/107
# Epoch 412 --- loss:1.453, Epoch accuracy:61.06%, Validation loss:1.574, Validation accuracy:55.94%
#
# Epoch 412 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.082
#
# Epoch 412 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.303
#
#
# Epoch 413: iteration 106/107
# Epoch 413 --- loss:1.451, Epoch accuracy:61.46%, Validation loss:1.571, Validation accuracy:55.48%
#
# Epoch 413 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.078
#
# Epoch 413 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.299
#
#
# Epoch 414: iteration 106/107
# Epoch 414 --- loss:1.456, Epoch accuracy:60.85%, Validation loss:1.573, Validation accuracy:56.41%
#
# Epoch 414 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.088
#
# Epoch 414 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.302
#
#
# Epoch 415: iteration 106/107
# Epoch 415 --- loss:1.452, Epoch accuracy:61.32%, Validation loss:1.566, Validation accuracy:55.71%
#
# Epoch 415 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.081
#
# Epoch 415 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.290
#
#
# Epoch 416: iteration 106/107
# Epoch 416 --- loss:1.460, Epoch accuracy:61.06%, Validation loss:1.566, Validation accuracy:56.18%
#
# Epoch 416 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.093
#
# Epoch 416 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.290
#
#
# Epoch 417: iteration 106/107
# Epoch 417 --- loss:1.456, Epoch accuracy:60.42%, Validation loss:1.569, Validation accuracy:56.41%
#
# Epoch 417 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.087
#
# Epoch 417 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.296
#
#
# Epoch 418: iteration 106/107
# Epoch 418 --- loss:1.454, Epoch accuracy:61.17%, Validation loss:1.560, Validation accuracy:56.41%
#
# Epoch 418 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.083
#
# Epoch 418 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.281
#
#
# Epoch 419: iteration 106/107
# Epoch 419 --- loss:1.451, Epoch accuracy:61.58%, Validation loss:1.570, Validation accuracy:55.24%
#
# Epoch 419 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.079
#
# Epoch 419 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.297
#
#
# Epoch 420: iteration 106/107
# Epoch 420 --- loss:1.454, Epoch accuracy:61.12%, Validation loss:1.570, Validation accuracy:55.94%
#
# Epoch 420 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.083
#
# Epoch 420 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.297
#
#
# Epoch 421: iteration 106/107
# Epoch 421 --- loss:1.458, Epoch accuracy:61.15%, Validation loss:1.571, Validation accuracy:56.18%
#
# Epoch 421 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.089
#
# Epoch 421 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.299
#
#
# Epoch 422: iteration 106/107
# Epoch 422 --- loss:1.456, Epoch accuracy:61.49%, Validation loss:1.566, Validation accuracy:55.48%
#
# Epoch 422 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.088
#
# Epoch 422 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.291
#
#
# Epoch 423: iteration 106/107
# Epoch 423 --- loss:1.457, Epoch accuracy:59.26%, Validation loss:1.567, Validation accuracy:55.94%
#
# Epoch 423 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.088
#
# Epoch 423 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.292
#
#
# Epoch 424: iteration 106/107
# Epoch 424 --- loss:1.454, Epoch accuracy:60.80%, Validation loss:1.564, Validation accuracy:55.71%
#
# Epoch 424 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.084
#
# Epoch 424 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.287
#
#
# Epoch 425: iteration 106/107
# Epoch 425 --- loss:1.448, Epoch accuracy:61.87%, Validation loss:1.564, Validation accuracy:55.71%
#
# Epoch 425 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.074
#
# Epoch 425 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.287
#
#
# Epoch 426: iteration 106/107
# Epoch 426 --- loss:1.455, Epoch accuracy:60.13%, Validation loss:1.568, Validation accuracy:55.48%
#
# Epoch 426 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.086
#
# Epoch 426 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.294
#
#
# Epoch 427: iteration 106/107
# Epoch 427 --- loss:1.455, Epoch accuracy:60.80%, Validation loss:1.566, Validation accuracy:56.18%
#
# Epoch 427 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.085
#
# Epoch 427 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.291
#
#
# Epoch 428: iteration 106/107
# Epoch 428 --- loss:1.444, Epoch accuracy:61.52%, Validation loss:1.569, Validation accuracy:55.24%
#
# Epoch 428 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.067
#
# Epoch 428 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.296
#
#
# Epoch 429: iteration 106/107
# Epoch 429 --- loss:1.445, Epoch accuracy:61.61%, Validation loss:1.569, Validation accuracy:55.94%
#
# Epoch 429 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.069
#
# Epoch 429 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.295
#
#
# Epoch 430: iteration 106/107
# Epoch 430 --- loss:1.443, Epoch accuracy:62.39%, Validation loss:1.565, Validation accuracy:55.48%
#
# Epoch 430 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.065
#
# Epoch 430 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.290
#
#
# Epoch 431: iteration 106/107
# Epoch 431 --- loss:1.456, Epoch accuracy:61.00%, Validation loss:1.566, Validation accuracy:56.18%
#
# Epoch 431 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.087
#
# Epoch 431 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.290
#
#
# Epoch 432: iteration 106/107
# Epoch 432 --- loss:1.450, Epoch accuracy:61.64%, Validation loss:1.569, Validation accuracy:55.94%
#
# Epoch 432 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.078
#
# Epoch 432 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.295
#
#
# Epoch 433: iteration 106/107
# Epoch 433 --- loss:1.453, Epoch accuracy:61.67%, Validation loss:1.567, Validation accuracy:55.48%
#
# Epoch 433 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.082
#
# Epoch 433 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.293
#
#
# Epoch 434: iteration 106/107
# Epoch 434 --- loss:1.453, Epoch accuracy:61.38%, Validation loss:1.563, Validation accuracy:56.18%
#
# Epoch 434 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.083
#
# Epoch 434 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.286
#
#
# Epoch 435: iteration 106/107
# Epoch 435 --- loss:1.443, Epoch accuracy:62.60%, Validation loss:1.568, Validation accuracy:56.41%
#
# Epoch 435 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.065
#
# Epoch 435 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.294
#
#
# Epoch 436: iteration 106/107
# Epoch 436 --- loss:1.457, Epoch accuracy:60.97%, Validation loss:1.564, Validation accuracy:55.94%
#
# Epoch 436 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.089
#
# Epoch 436 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.287
#
#
# Epoch 437: iteration 106/107
# Epoch 437 --- loss:1.448, Epoch accuracy:61.76%, Validation loss:1.569, Validation accuracy:56.18%
#
# Epoch 437 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.073
#
# Epoch 437 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.295
#
#
# Epoch 438: iteration 106/107
# Epoch 438 --- loss:1.449, Epoch accuracy:60.97%, Validation loss:1.567, Validation accuracy:55.24%
#
# Epoch 438 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.076
#
# Epoch 438 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.293
#
#
# Epoch 439: iteration 106/107
# Epoch 439 --- loss:1.457, Epoch accuracy:61.17%, Validation loss:1.572, Validation accuracy:55.94%
#
# Epoch 439 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.088
#
# Epoch 439 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.300
#
#
# Epoch 440: iteration 106/107
# Epoch 440 --- loss:1.444, Epoch accuracy:61.76%, Validation loss:1.563, Validation accuracy:55.94%
#
# Epoch 440 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.068
#
# Epoch 440 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.285
#
#
# Epoch 441: iteration 106/107
# Epoch 441 --- loss:1.448, Epoch accuracy:62.07%, Validation loss:1.565, Validation accuracy:55.71%
#
# Epoch 441 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.072
#
# Epoch 441 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.290
#
#
# Epoch 442: iteration 106/107
# Epoch 442 --- loss:1.451, Epoch accuracy:61.06%, Validation loss:1.567, Validation accuracy:55.94%
#
# Epoch 442 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.078
#
# Epoch 442 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.293
#
#
# Epoch 443: iteration 106/107
# Epoch 443 --- loss:1.450, Epoch accuracy:61.93%, Validation loss:1.563, Validation accuracy:55.94%
#
# Epoch 443 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.078
#
# Epoch 443 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.286
#
#
# Epoch 444: iteration 106/107
# Epoch 444 --- loss:1.450, Epoch accuracy:61.38%, Validation loss:1.573, Validation accuracy:55.48%
#
# Epoch 444 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.077
#
# Epoch 444 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.302
#
#
# Epoch 445: iteration 106/107
# Epoch 445 --- loss:1.447, Epoch accuracy:61.96%, Validation loss:1.566, Validation accuracy:55.71%
#
# Epoch 445 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.072
#
# Epoch 445 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.290
#
#
# Epoch 446: iteration 106/107
# Epoch 446 --- loss:1.454, Epoch accuracy:60.62%, Validation loss:1.568, Validation accuracy:55.71%
#
# Epoch 446 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.084
#
# Epoch 446 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.294
#
#
# Epoch 447: iteration 106/107
# Epoch 447 --- loss:1.451, Epoch accuracy:61.49%, Validation loss:1.563, Validation accuracy:56.41%
#
# Epoch 447 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.080
#
# Epoch 447 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.287
#
#
# Epoch 448: iteration 106/107
# Epoch 448 --- loss:1.454, Epoch accuracy:60.80%, Validation loss:1.560, Validation accuracy:55.94%
#
# Epoch 448 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.084
#
# Epoch 448 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.281
#
#
# Epoch 449: iteration 106/107
# Epoch 449 --- loss:1.447, Epoch accuracy:61.96%, Validation loss:1.567, Validation accuracy:56.18%
#
# Epoch 449 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.071
#
# Epoch 449 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.293
#
#
# Epoch 450: iteration 106/107
# Epoch 450 --- loss:1.458, Epoch accuracy:60.94%, Validation loss:1.567, Validation accuracy:55.24%
#
# Epoch 450 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.089
#
# Epoch 450 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.293
#
#
# Epoch 451: iteration 106/107
# Epoch 451 --- loss:1.453, Epoch accuracy:61.87%, Validation loss:1.562, Validation accuracy:55.94%
#
# Epoch 451 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.081
#
# Epoch 451 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.284
#
#
# Epoch 452: iteration 106/107
# Epoch 452 --- loss:1.447, Epoch accuracy:61.73%, Validation loss:1.564, Validation accuracy:55.71%
#
# Epoch 452 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.072
#
# Epoch 452 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.288
#
#
# Epoch 453: iteration 106/107
# Epoch 453 --- loss:1.451, Epoch accuracy:61.52%, Validation loss:1.565, Validation accuracy:55.71%
#
# Epoch 453 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.079
#
# Epoch 453 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.289
#
#
# Epoch 454: iteration 106/107
# Epoch 454 --- loss:1.445, Epoch accuracy:61.96%, Validation loss:1.564, Validation accuracy:55.71%
#
# Epoch 454 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.069
#
# Epoch 454 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.288
#
#
# Epoch 455: iteration 106/107
# Epoch 455 --- loss:1.446, Epoch accuracy:61.46%, Validation loss:1.564, Validation accuracy:55.71%
#
# Epoch 455 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.071
#
# Epoch 455 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.288
#
#
# Epoch 456: iteration 106/107
# Epoch 456 --- loss:1.447, Epoch accuracy:61.26%, Validation loss:1.566, Validation accuracy:55.94%
#
# Epoch 456 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.073
#
# Epoch 456 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.290
#
#
# Epoch 457: iteration 106/107
# Epoch 457 --- loss:1.446, Epoch accuracy:62.34%, Validation loss:1.570, Validation accuracy:55.71%
#
# Epoch 457 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.071
#
# Epoch 457 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.298
#
#
# Epoch 458: iteration 106/107
# Epoch 458 --- loss:1.447, Epoch accuracy:61.70%, Validation loss:1.558, Validation accuracy:56.64%
#
# Epoch 458 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.074
#
# Epoch 458 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.278
#
#
# Epoch 459: iteration 106/107
# Epoch 459 --- loss:1.447, Epoch accuracy:61.81%, Validation loss:1.563, Validation accuracy:55.94%
#
# Epoch 459 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.072
#
# Epoch 459 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.285
#
#
# Epoch 460: iteration 106/107
# Epoch 460 --- loss:1.442, Epoch accuracy:62.28%, Validation loss:1.564, Validation accuracy:55.71%
#
# Epoch 460 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.064
#
# Epoch 460 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.288
#
#
# Epoch 461: iteration 106/107
# Epoch 461 --- loss:1.452, Epoch accuracy:61.78%, Validation loss:1.565, Validation accuracy:55.48%
#
# Epoch 461 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.081
#
# Epoch 461 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.289
#
#
# Epoch 462: iteration 106/107
# Epoch 462 --- loss:1.444, Epoch accuracy:61.70%, Validation loss:1.562, Validation accuracy:55.94%
#
# Epoch 462 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.067
#
# Epoch 462 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.284
#
#
# Epoch 463: iteration 106/107
# Epoch 463 --- loss:1.442, Epoch accuracy:62.60%, Validation loss:1.568, Validation accuracy:55.94%
#
# Epoch 463 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.063
#
# Epoch 463 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.294
#
#
# Epoch 464: iteration 106/107
# Epoch 464 --- loss:1.444, Epoch accuracy:62.42%, Validation loss:1.562, Validation accuracy:55.94%
#
# Epoch 464 --- epoch_autoencoder_loss1:1.000, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.067
#
# Epoch 464 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.284
#
#
# Epoch 465: iteration 106/107
# Epoch 465 --- loss:1.450, Epoch accuracy:61.90%, Validation loss:1.560, Validation accuracy:55.94%
#
# Epoch 465 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.078
#
# Epoch 465 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.282
#
#
# Epoch 466: iteration 106/107
# Epoch 466 --- loss:1.443, Epoch accuracy:61.93%, Validation loss:1.562, Validation accuracy:56.41%
#
# Epoch 466 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.066
#
# Epoch 466 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.285
#
#
# Epoch 467: iteration 106/107
# Epoch 467 --- loss:1.455, Epoch accuracy:60.59%, Validation loss:1.566, Validation accuracy:55.48%
#
# Epoch 467 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.086
#
# Epoch 467 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.291
#
#
# Epoch 468: iteration 106/107
# Epoch 468 --- loss:1.442, Epoch accuracy:62.19%, Validation loss:1.564, Validation accuracy:55.94%
#
# Epoch 468 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.064
#
# Epoch 468 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.288
#
#
# Epoch 469: iteration 106/107
# Epoch 469 --- loss:1.442, Epoch accuracy:61.64%, Validation loss:1.566, Validation accuracy:56.18%
#
# Epoch 469 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.063
#
# Epoch 469 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.291
#
#
# Epoch 470: iteration 106/107
# Epoch 470 --- loss:1.446, Epoch accuracy:62.02%, Validation loss:1.558, Validation accuracy:56.41%
#
# Epoch 470 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.070
#
# Epoch 470 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.278
#
#
# Epoch 471: iteration 106/107
# Epoch 471 --- loss:1.448, Epoch accuracy:61.70%, Validation loss:1.564, Validation accuracy:55.94%
#
# Epoch 471 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.073
#
# Epoch 471 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.287
#
#
# Epoch 472: iteration 106/107
# Epoch 472 --- loss:1.446, Epoch accuracy:61.78%, Validation loss:1.561, Validation accuracy:56.18%
#
# Epoch 472 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.070
#
# Epoch 472 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.283
#
#
# Epoch 473: iteration 106/107
# Epoch 473 --- loss:1.449, Epoch accuracy:61.49%, Validation loss:1.558, Validation accuracy:56.18%
#
# Epoch 473 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.076
#
# Epoch 473 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.278
#
#
# Epoch 474: iteration 106/107
# Epoch 474 --- loss:1.448, Epoch accuracy:61.52%, Validation loss:1.564, Validation accuracy:55.71%
#
# Epoch 474 --- epoch_autoencoder_loss1:0.999, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.075
#
# Epoch 474 --- valid_autoencoder_loss1:0.989, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.287
#
#
# Epoch 475: iteration 106/107
# ...
#
#
# Epoch 911: iteration 106/107
# Epoch 911 --- loss:1.409, Epoch accuracy:64.66%, Validation loss:1.530, Validation accuracy:59.21%
#
# Epoch 911 --- epoch_autoencoder_loss1:0.996, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.012
#
# Epoch 911 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.234
#
#
# Epoch 912: iteration 106/107
# Epoch 912 --- loss:1.409, Epoch accuracy:63.59%, Validation loss:1.532, Validation accuracy:58.97%
#
# Epoch 912 --- epoch_autoencoder_loss1:0.996, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.014
#
# Epoch 912 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.238
#
#
# Epoch 913: iteration 106/107
# Epoch 913 --- loss:1.403, Epoch accuracy:65.39%, Validation loss:1.532, Validation accuracy:58.97%
#
# Epoch 913 --- epoch_autoencoder_loss1:0.996, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.003
#
# Epoch 913 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.237
#
#
# Epoch 914: iteration 106/107
# Epoch 914 --- loss:1.403, Epoch accuracy:63.44%, Validation loss:1.534, Validation accuracy:58.74%
#
# Epoch 914 --- epoch_autoencoder_loss1:0.996, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.004
#
# Epoch 914 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.241
#
#
# Epoch 915: iteration 106/107
# Epoch 915 --- loss:1.408, Epoch accuracy:64.69%, Validation loss:1.535, Validation accuracy:58.74%
#
# Epoch 915 --- epoch_autoencoder_loss1:0.995, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.013
#
# Epoch 915 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.242
#
#
# Epoch 916: iteration 106/107
# Epoch 916 --- loss:1.409, Epoch accuracy:63.00%, Validation loss:1.536, Validation accuracy:58.51%
#
# Epoch 916 --- epoch_autoencoder_loss1:0.996, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.013
#
# Epoch 916 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.245
#
#
# Epoch 917: iteration 106/107
# Epoch 917 --- loss:1.403, Epoch accuracy:64.17%, Validation loss:1.534, Validation accuracy:58.51%
#
# Epoch 917 --- epoch_autoencoder_loss1:0.996, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.002
#
# Epoch 917 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.241
#
#
# Epoch 918: iteration 106/107
# Epoch 918 --- loss:1.407, Epoch accuracy:64.69%, Validation loss:1.530, Validation accuracy:58.97%
#
# Epoch 918 --- epoch_autoencoder_loss1:0.995, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.011
#
# Epoch 918 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.234
#
#
# Epoch 919: iteration 106/107
# Epoch 919 --- loss:1.410, Epoch accuracy:64.11%, Validation loss:1.529, Validation accuracy:59.44%
#
# Epoch 919 --- epoch_autoencoder_loss1:0.996, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.015
#
# Epoch 919 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.233
#
#
# Epoch 920: iteration 106/107
# Epoch 920 --- loss:1.409, Epoch accuracy:64.05%, Validation loss:1.530, Validation accuracy:58.97%
#
# Epoch 920 --- epoch_autoencoder_loss1:0.996, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.014
#
# Epoch 920 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.234
#
#
# Epoch 921: iteration 106/107
# Epoch 921 --- loss:1.407, Epoch accuracy:62.95%, Validation loss:1.530, Validation accuracy:58.97%
#
# Epoch 921 --- epoch_autoencoder_loss1:0.995, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.011
#
# Epoch 921 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.234
#
#
# Epoch 922: iteration 106/107
# Epoch 922 --- loss:1.407, Epoch accuracy:63.59%, Validation loss:1.533, Validation accuracy:58.74%
#
# Epoch 922 --- epoch_autoencoder_loss1:0.996, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.011
#
# Epoch 922 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.238
#
#
# Epoch 923: iteration 106/107
# Epoch 923 --- loss:1.407, Epoch accuracy:63.47%, Validation loss:1.531, Validation accuracy:58.97%
#
# Epoch 923 --- epoch_autoencoder_loss1:0.996, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.010
#
# Epoch 923 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.235
#
#
# Epoch 924: iteration 106/107
# Epoch 924 --- loss:1.404, Epoch accuracy:63.99%, Validation loss:1.531, Validation accuracy:58.74%
#
# Epoch 924 --- epoch_autoencoder_loss1:0.996, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.005
#
# Epoch 924 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.236
#
#
# Epoch 925: iteration 106/107
# Epoch 925 --- loss:1.409, Epoch accuracy:63.64%, Validation loss:1.535, Validation accuracy:58.28%
#
# Epoch 925 --- epoch_autoencoder_loss1:0.996, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.012
#
# Epoch 925 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.243
#
#
# Epoch 926: iteration 106/107
# Epoch 926 --- loss:1.408, Epoch accuracy:64.78%, Validation loss:1.531, Validation accuracy:58.97%
#
# Epoch 926 --- epoch_autoencoder_loss1:0.996, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.012
#
# Epoch 926 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.236
#
#
# Epoch 927: iteration 106/107
# Epoch 927 --- loss:1.402, Epoch accuracy:65.18%, Validation loss:1.530, Validation accuracy:58.97%
#
# Epoch 927 --- epoch_autoencoder_loss1:0.995, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.002
#
# Epoch 927 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.234
#
#
# Epoch 928: iteration 106/107
# Epoch 928 --- loss:1.401, Epoch accuracy:64.66%, Validation loss:1.530, Validation accuracy:59.21%
#
# Epoch 928 --- epoch_autoencoder_loss1:0.996, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.000
#
# Epoch 928 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.234
#
#
# Epoch 929: iteration 106/107
# Epoch 929 --- loss:1.407, Epoch accuracy:63.85%, Validation loss:1.535, Validation accuracy:58.28%
#
# Epoch 929 --- epoch_autoencoder_loss1:0.995, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.011
#
# Epoch 929 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.243
#
#
# Epoch 930: iteration 106/107
# Epoch 930 --- loss:1.408, Epoch accuracy:63.62%, Validation loss:1.529, Validation accuracy:58.97%
#
# Epoch 930 --- epoch_autoencoder_loss1:0.996, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.011
#
# Epoch 930 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.232
#
#
# Epoch 931: iteration 106/107
# Epoch 931 --- loss:1.409, Epoch accuracy:63.96%, Validation loss:1.529, Validation accuracy:58.97%
#
# Epoch 931 --- epoch_autoencoder_loss1:0.996, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.014
#
# Epoch 931 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.233
#
#
# Epoch 932: iteration 106/107
# Epoch 932 --- loss:1.409, Epoch accuracy:64.02%, Validation loss:1.528, Validation accuracy:58.97%
#
# Epoch 932 --- epoch_autoencoder_loss1:0.995, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.014
#
# Epoch 932 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.230
#
#
# Epoch 933: iteration 106/107
# Epoch 933 --- loss:1.407, Epoch accuracy:63.91%, Validation loss:1.531, Validation accuracy:59.21%
#
# Epoch 933 --- epoch_autoencoder_loss1:0.996, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.011
#
# Epoch 933 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.235
#
#
# Epoch 934: iteration 106/107
# Epoch 934 --- loss:1.409, Epoch accuracy:63.53%, Validation loss:1.530, Validation accuracy:58.51%
#
# Epoch 934 --- epoch_autoencoder_loss1:0.996, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.012
#
# Epoch 934 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.235
#
#
# Epoch 935: iteration 106/107
# Epoch 935 --- loss:1.398, Epoch accuracy:64.95%, Validation loss:1.530, Validation accuracy:58.97%
#
# Epoch 935 --- epoch_autoencoder_loss1:0.995, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:0.996
#
# Epoch 935 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.235
#
#
# Epoch 936: iteration 106/107
# Epoch 936 --- loss:1.402, Epoch accuracy:64.20%, Validation loss:1.525, Validation accuracy:59.44%
#
# Epoch 936 --- epoch_autoencoder_loss1:0.996, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.001
#
# Epoch 936 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.226
#
#
# Epoch 937: iteration 106/107
# Epoch 937 --- loss:1.399, Epoch accuracy:65.36%, Validation loss:1.531, Validation accuracy:58.97%
#
# Epoch 937 --- epoch_autoencoder_loss1:0.996, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:0.997
#
# Epoch 937 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.235
#
#
# Epoch 938: iteration 106/107
# Epoch 938 --- loss:1.399, Epoch accuracy:65.39%, Validation loss:1.530, Validation accuracy:59.21%
#
# Epoch 938 --- epoch_autoencoder_loss1:0.996, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:0.997
#
# Epoch 938 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.234
#
#
# Epoch 939: iteration 106/107
# Epoch 939 --- loss:1.406, Epoch accuracy:64.20%, Validation loss:1.531, Validation accuracy:58.97%
#
# Epoch 939 --- epoch_autoencoder_loss1:0.995, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.008
#
# Epoch 939 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.236
#
#
# Epoch 940: iteration 106/107
# Epoch 940 --- loss:1.405, Epoch accuracy:63.88%, Validation loss:1.530, Validation accuracy:58.97%
#
# Epoch 940 --- epoch_autoencoder_loss1:0.995, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.008
#
# Epoch 940 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.234
#
#
# Epoch 941: iteration 106/107
# Epoch 941 --- loss:1.403, Epoch accuracy:64.25%, Validation loss:1.529, Validation accuracy:59.21%
#
# Epoch 941 --- epoch_autoencoder_loss1:0.995, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.006
#
# Epoch 941 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.233
#
#
# Epoch 942: iteration 106/107
# Epoch 942 --- loss:1.404, Epoch accuracy:64.69%, Validation loss:1.533, Validation accuracy:58.51%
#
# Epoch 942 --- epoch_autoencoder_loss1:0.996, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.006
#
# Epoch 942 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.239
#
#
# Epoch 943: iteration 106/107
# Epoch 943 --- loss:1.402, Epoch accuracy:64.40%, Validation loss:1.529, Validation accuracy:58.97%
#
# Epoch 943 --- epoch_autoencoder_loss1:0.995, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.002
#
# Epoch 943 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.232
#
#
# Epoch 944: iteration 106/107
# Epoch 944 --- loss:1.400, Epoch accuracy:64.86%, Validation loss:1.531, Validation accuracy:59.21%
#
# Epoch 944 --- epoch_autoencoder_loss1:0.996, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:0.998
#
# Epoch 944 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.236
#
#
# Epoch 945: iteration 106/107
# Epoch 945 --- loss:1.405, Epoch accuracy:63.85%, Validation loss:1.534, Validation accuracy:58.28%
#
# Epoch 945 --- epoch_autoencoder_loss1:0.996, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.005
#
# Epoch 945 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.240
#
#
# Epoch 946: iteration 106/107
# Epoch 946 --- loss:1.406, Epoch accuracy:63.85%, Validation loss:1.529, Validation accuracy:59.21%
#
# Epoch 946 --- epoch_autoencoder_loss1:0.996, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.009
#
# Epoch 946 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.232
#
#
# Epoch 947: iteration 106/107
# Epoch 947 --- loss:1.410, Epoch accuracy:63.30%, Validation loss:1.532, Validation accuracy:58.74%
#
# Epoch 947 --- epoch_autoencoder_loss1:0.996, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.015
#
# Epoch 947 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.238
#
#
# Epoch 948: iteration 106/107
# Epoch 948 --- loss:1.402, Epoch accuracy:65.27%, Validation loss:1.532, Validation accuracy:58.51%
#
# Epoch 948 --- epoch_autoencoder_loss1:0.996, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.002
#
# Epoch 948 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.238
#
#
# Epoch 949: iteration 106/107
# Epoch 949 --- loss:1.408, Epoch accuracy:63.85%, Validation loss:1.532, Validation accuracy:58.51%
#
# Epoch 949 --- epoch_autoencoder_loss1:0.996, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.012
#
# Epoch 949 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.238
#
#
# Epoch 950: iteration 106/107
# Epoch 950 --- loss:1.410, Epoch accuracy:63.93%, Validation loss:1.526, Validation accuracy:58.74%
#
# Epoch 950 --- epoch_autoencoder_loss1:0.996, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.015
#
# Epoch 950 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.228
#
#
# Epoch 951: iteration 106/107
# Epoch 951 --- loss:1.402, Epoch accuracy:64.66%, Validation loss:1.529, Validation accuracy:59.21%
#
# Epoch 951 --- epoch_autoencoder_loss1:0.996, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.001
#
# Epoch 951 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.232
#
#
# Epoch 952: iteration 106/107
# Epoch 952 --- loss:1.407, Epoch accuracy:64.37%, Validation loss:1.533, Validation accuracy:58.51%
#
# Epoch 952 --- epoch_autoencoder_loss1:0.995, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.011
#
# Epoch 952 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.240
#
#
# Epoch 953: iteration 106/107
# Epoch 953 --- loss:1.403, Epoch accuracy:64.52%, Validation loss:1.527, Validation accuracy:59.21%
#
# Epoch 953 --- epoch_autoencoder_loss1:0.996, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.003
#
# Epoch 953 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.229
#
#
# Epoch 954: iteration 106/107
# Epoch 954 --- loss:1.405, Epoch accuracy:64.49%, Validation loss:1.531, Validation accuracy:58.97%
#
# Epoch 954 --- epoch_autoencoder_loss1:0.996, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.007
#
# Epoch 954 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.236
#
#
# Epoch 955: iteration 106/107
# Epoch 955 --- loss:1.401, Epoch accuracy:64.57%, Validation loss:1.530, Validation accuracy:59.21%
#
# Epoch 955 --- epoch_autoencoder_loss1:0.995, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.001
#
# Epoch 955 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.234
#
#
# Epoch 956: iteration 106/107
# Epoch 956 --- loss:1.403, Epoch accuracy:65.27%, Validation loss:1.532, Validation accuracy:59.21%
#
# Epoch 956 --- epoch_autoencoder_loss1:0.996, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:1.004
#
# Epoch 956 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.238
#
#
# Epoch 957: iteration 106/107
# Epoch 957 --- loss:1.398, Epoch accuracy:65.10%, Validation loss:1.530, Validation accuracy:58.97%
#
# Epoch 957 --- epoch_autoencoder_loss1:0.995, epoch_autoencoder_loss2:1.01, epoch_classifier_loss:0.995
#
# Epoch 957 --- valid_autoencoder_loss1:0.986, valid_autoencoder_loss2:0.99, valid_classifier_loss:1.235
#
#
# Epoch 958: iteration 82/107

# %%
plt.title('Loss Curve for Parallel is All You Want Model')
plt.ylabel('Loss', fontsize=16)
plt.xlabel('Epoch', fontsize=16)
plt.plot(train_losses[:],'b')
plt.plot(valid_losses[:],'r')
plt.legend(['Training loss','Validation loss'])
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
